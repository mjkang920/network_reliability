# %%
import json, os, itertools
from collections import defaultdict
import gurobipy as gp
import pandas as pd
import numpy as np

BASE_DIR = r"D:\MINJI\NETWORK RELIABILITY\QGIS\7.Korea_Full\json"   
edge_fp   = os.path.join(BASE_DIR, "edges.json")
route_fp  = os.path.join(BASE_DIR, "routes_nodes.json")
demand_fp = os.path.join(BASE_DIR, "demand_full.json")
dept_fp   = os.path.join(BASE_DIR, "dep_time.json")

# %%
# 0-b. 고정 파라미터
T        = 32
max_wait = 0
CAPACITY = 30
failed_edges = {"e43r"}
w1, w2, w3 = 1000, 1000, 10
BIG_M = 10**6
SINK  = "SINK"
W_ROUTE = 100

# 0-c. JSON 로드
with open(edge_fp, encoding="utf-8") as f:
    edges_raw = json.load(f)
edges = {eid: (src, dst, int(tau)) for eid, (src, dst, tau) in edges_raw.items()}

with open(route_fp, encoding="utf-8") as f:
    routes_nodes = json.load(f)

with open(dept_fp, encoding="utf-8") as f:
    dep_time = {tr: int(t) for tr, t in json.load(f).items()}

with open(demand_fp, encoding="utf-8") as f:
    dem_raw = json.load(f)
demand = {tr: [(o, d, float(q)) for o, d, q in lst] for tr, lst in dem_raw.items()}

trains = list(routes_nodes)
nodes  = {n for _, (s, d, _) in edges.items() for n in (s, d)}
nodes.add(SINK)

# ----- 시간-확장 아크 ---------------------------------------------------
arc_list = []                       # (from,to,eid,tau,t0,t1)
for eid, (src, dst, tau) in edges.items():
    if eid in failed_edges: continue
    for t in range(T + 1 - tau):
        arc_list.append((f"{src}^{t}", f"{dst}^{t+tau}", eid, tau, t, t+tau))

for n in nodes - {SINK}:
    for w in range(1, max_wait+1):
        for t in range(T + 1 - w):
            arc_list.append((f"{n}^{t}", f"{n}^{t+w}", f"w_{n}_{w}", w, t, t+w))

for n in nodes - {SINK}:
    for t in range(T+1):
        arc_list.append((f"{n}^{t}", f"{SINK}^{t}", f"dummy_{n}", 0, t, t))

arc_idx = {info: i for i, info in enumerate(arc_list)}

# ───────────────── 캐싱: arc → 노드·시각 별 in/out ─────────────────
out_arcs = defaultdict(list)   # (node,t) → [arcIdx…]
in_arcs  = defaultdict(list)   # (node,t) → [arcIdx…]
node_in_arcs  = defaultdict(list)   # 노드 방문용
node_out_arcs = defaultdict(list)

for k, (fr, to, eid, _, t0, t1) in enumerate(arc_list):
    n_fr, tt_fr = fr.split("^"); tt_fr = int(tt_fr)
    n_to, tt_to = to.split("^"); tt_to = int(tt_to)

    out_arcs[(n_fr, tt_fr)].append(k)
    in_arcs [(n_to, tt_to)].append(k)

    if not eid.startswith(("w_", "dummy")):      # s[tr,n] 계산용
        node_out_arcs[n_fr].append(k)
        node_in_arcs [n_to].append(k)


# ----- 예정 도착시각 ----------------------------------------------------
sched = {}
for tr, path in routes_nodes.items():
    t, arr = 0, {path[0]: dep_time[tr]}
    for u, v in zip(path[:-1], path[1:]):
        eid = next(e for e, (s, d, _) in edges.items() if s == u and d == v)
        t += edges[eid][2]; arr[v] = dep_time[tr] + t
    sched[tr] = arr

q_r = {tr: sum(q for *_, q in demand[tr]) for tr in trains}



# 가장 늦은 기차의 도착시간
latest_arrivals = {tr: max(times.values()) for tr, times in sched.items()}
max_arrival = max(latest_arrivals.values())
latest_train = max(latest_arrivals, key=latest_arrivals.get)
print("가장 늦은 도착시간:", max_arrival)
print("해당 기차:", latest_train)
# Out:
# 가장 늦은 도착시간: 31
# 해당 기차: 경부선1_6

# %%
# ===== (NEW) 계획 엣지 / blocked / 접미 실패 / 종료 허용노드 =====
uv2eid = {}
dup_keys = set()
for eid, (s, d, _) in edges.items():
    key = (s, d)
    if key in uv2eid and uv2eid[key] != eid:
        dup_keys.add(key)  # 동일 (s,d)에 eid가 여러 개면 체크
    else:
        uv2eid[key] = eid

if dup_keys:
    # 필요시 여기서 raise 하거나, 첫 번째 eid만 쓰고 경고 출력
    print(f"[warn] multiple eids share the same (u,v): {sorted(list(dup_keys))[:5]} ...")

def planned_eids_of(tr):
    """열차 tr의 계획 경로 상 (u,v)들에 대한 eid 리스트를 O(1)로 반환"""
    path = routes_nodes[tr]
    eids = []
    for u, v in zip(path[:-1], path[1:]):
        eid = uv2eid.get((u, v))
        if eid is None:
            raise KeyError(f"No edge (u={u} -> v={v}) found in edges; check routes_nodes or edges.json")
        eids.append(eid)
    return eids

# 이제 O(1)로 추출
planned_eids = {tr: planned_eids_of(tr) for tr in trains}

# 이 열차의 계획경로가 실패엣지를 포함하면 blocked=1
blocked = {tr: int(any(e in failed_edges for e in planned_eids[tr]))
           for tr in trains}

# 접미 실패 플래그 F_{r,i}와 reach_r, 그리고 노드별 종료 허용 allow_stop[(tr,n)]
allow_stop = {}
reach = {}
for tr in trains:
    path = routes_nodes[tr]           # [n0, n1, ..., nL]
    eids = planned_eids[tr]           # [e0, e1, ..., e_{L-1}]
    L = len(path) - 1
    # 종착 스케줄이 T 이내인지
    t_sched_term = sched[tr].get(path[-1], 10**9)
    reach[tr] = int(t_sched_term <= T)

    # 노드 기준 접미 실패 플래그 F_{r,i}
    suffix_failed = [0]*(L+1)         # index = node i
    hit = 0
    for i in range(L-1, -1, -1):      # edge index i maps to node i
        if eids[i] in failed_edges:
            hit = 1
        suffix_failed[i] = hit
    # suffix_failed[L] = 0 (종착 노드)

    # 종료 허용 노드: path[1:] (origin 제외)
    for i in range(1, L+1):
        n = path[i]
        if i == L:                             # 종착은 항상 허용
            allow = 1
        elif reach[tr] == 0:                   # 종착이 T 이후면 완화
            allow = 1
        else:                                  # 종착이 T 이내면 접미 실패가 있어야 조기 종료
            allow = suffix_failed[i]
        allow_stop[(tr, n)] = int(allow)

# %%
def build_base_model():

    m = gp.Model(); m.Params.OutputFlag = 1
    nA, nT = len(arc_list), len(trains)
    x = m.addVars(nA, nT, vtype=gp.GRB.BINARY, name="x")
    h = m.addVars(trains, vtype=gp.GRB.BINARY, name="h")
    y = {(tr, n): m.addVar(vtype=gp.GRB.BINARY) for tr in trains for n in routes_nodes[tr][1:]}
    s = {(tr, n): m.addVar(vtype=gp.GRB.BINARY) for tr in trains for n in nodes - {SINK}}
    z = {(tr,o,d): m.addVar(vtype=gp.GRB.BINARY) for tr in trains for (o,d,_) in demand[tr]}
    delta = {(tr,o,d): m.addVar(lb=0) for tr in trains for (o,d,_) in demand[tr]}
    t_arr = {(tr, n): m.addVar(lb=0, ub=T, vtype=gp.GRB.INTEGER)
             for tr in trains for n in nodes - {SINK}}
    
    # === (NEW) 고장 시엔 무제한 우회 가능, 다만 우회 1개당 벌점 W_ROUTE가 들어감
    real_eids = {eid for (_,_,eid,_,_,_) in arc_list if not str(eid).startswith(("w_","dummy"))}
    u_eid = {}  # key: (tr, eid)

    for tr_i, tr in enumerate(trains):
        P = set(planned_eids[tr])  
        for eid in real_eids:
            if eid in P: 
                continue  
            u_eid[(tr, eid)] = m.addVar(vtype=gp.GRB.BINARY, name=f"u_eid[{tr},{eid}]")

            for k, (fr, to, e, *_ ) in enumerate(arc_list):
                if e == eid:
                    m.addConstr(x[k, tr_i] <= u_eid[(tr, eid)])

    for tr in trains:
        if blocked[tr] == 0:
            m.addConstr(gp.quicksum(u_eid[key] for key in u_eid.keys() if key[0]==tr) == 0)
        else:
            pass

    # (2) 출발-flow
    for tr_i, tr in enumerate(trains):
        r_o, t_dep = routes_nodes[tr][0], dep_time[tr]
        idx_out = out_arcs[(r_o, t_dep)]       
        m.addConstr(x.sum(idx_out, tr_i) == h[tr])

    # (5) 노드-시간 보존
    for tr_i, tr in enumerate(trains):
        r_o, t_dep = routes_nodes[tr][0], dep_time[tr]
        for n in nodes - {SINK}:
            for t in range(T+1):
                inflow  = x.sum(in_arcs[(n, t)],  tr_i)
                outflow = x.sum(out_arcs[(n, t)], tr_i)
                if (n == r_o) and (t == t_dep):
                    m.addConstr(outflow - inflow == h[tr])
                else:
                    m.addConstr(inflow == outflow)

    # === (NEW) 종료 허용 노드만 y 가능 (또는 더미x 가능)
    for tr_i, tr in enumerate(trains):
        for n in routes_nodes[tr][1:]:
            if allow_stop[(tr, n)] == 0:
                y[tr, n].UB = 0
                idx_dum = [i for i,(fr,to,eid,_,_,_) in enumerate(arc_list) if eid == f"dummy_{n}"]
                for k in idx_dum:
                    x[k, tr_i].UB = 0

    # terminal & dummy
    for tr_i, tr in enumerate(trains):
        cand = routes_nodes[tr][1:]
        m.addConstr(gp.quicksum(y[tr, n] for n in cand) == h[tr])
        for n in cand:
            idx_dum = [arc_idx[a] for a in arc_list if a[2] == f"dummy_{n}"]
            m.addConstr(x.sum(idx_dum, tr_i) == y[tr, n])

    # s (visit)
    for (tr, n), var in s.items():
        tr_i = trains.index(tr)
        idx = node_out_arcs[n] + node_in_arcs[n] 
        flow = x.sum(idx, tr_i)
        m.addConstr(flow >= var)
        m.addConstr(flow <= BIG_M * var)
        
    # z-logic & delta
    for tr in trains:
        for (o, d, q) in demand[tr]:
            m.addConstr(z[tr, o, d] <= s[tr, o])
            m.addConstr(z[tr, o, d] <= s[tr, d])
            m.addConstr(z[tr, o, d] >= s[tr, o] + s[tr, d] - 1)
            m.addConstr(z[tr, o, d] <= h[tr])

    for tr_i, tr in enumerate(trains):
        for k, (fr, to, eid, *_ ) in enumerate(arc_list):
            if eid.startswith(("w_", "dummy")): continue
            n_to, tt = to.split("^"); tt = int(tt)
            m.addConstr(t_arr[tr, n_to] >= tt - BIG_M * (1 - x[k, tr_i]))
            m.addConstr(t_arr[tr, n_to] <= tt + BIG_M * (1 - x[k, tr_i]))
        for (o, d, q) in demand[tr]:
            sched_t = sched[tr].get(d, T)
            m.addConstr(delta[tr, o, d] >= t_arr[tr, d] - sched_t - BIG_M * (1 - z[tr, o, d]))
            m.addConstr(delta[tr, o, d] <= BIG_M * z[tr, o, d])

    # Objective function
    obj  = gp.quicksum(w1 * q_r[tr] * (1 - h[tr]) for tr in trains)
    obj += gp.quicksum(w2 * q * (1 - z[tr, o, d]) for tr in trains for (o, d, q) in demand[tr])
    obj += gp.quicksum(w3 * q * delta[tr, o, d] for tr in trains for (o, d, q) in demand[tr])
    
    #  === (NEW)        
    if u_eid: 
        obj += W_ROUTE * gp.quicksum(u_eid.values())

    m.setObjective(obj)
    return m, x, h, delta, z

# cap_map: (eid,tt) → [arcIdx …]
cap_map = defaultdict(list)
for k, (fr, to, eid, _, t0, t1) in enumerate(arc_list):
    if eid.startswith(("w_", "dummy")): continue
    for tt in range(t0, t1):
        cap_map[(eid, tt)].append(k)

# %%
working_set, sol_prev = set(), None
MAX_ITER, EPS, SHOW = 40, 1e-6, 30

for it in range(MAX_ITER):
    base, xvar, hvar, delta, z = build_base_model()

    constr_refs = {}
    for (eid, tt) in working_set:
        expr = gp.quicksum(xvar[idx, ti] for idx in cap_map[(eid, tt)]
                           for ti in range(len(trains)))
        constr_refs[(eid, tt)] = base.addConstr(expr <= CAPACITY,
                                               name=f"cap_{eid}_{tt}")

    if sol_prev:
        for (idx, ti), v in sol_prev.items():
            xvar[idx, ti].Start = v

    base.optimize()
    if base.Status != gp.GRB.OPTIMAL:
        raise RuntimeError("non-optimal")

    x_val = {(idx, ti): round(xvar[idx, ti].X)
         for idx in range(len(arc_list))
         for ti  in range(len(trains))}
    
    # ③-c violation search
    x_mat = np.zeros((len(arc_list), len(trains)), dtype=np.uint8)
    for (idx, ti), v in x_val.items():      # x_val 은 아래에서 다시 만듦
        if v: x_mat[idx, ti] = 1
    cap_keys   = list(cap_map)                         # [(eid,tt), …]
    cap_idxarr = [np.fromiter(cap_map[k], dtype=int)   # each → np.array
                for k in cap_keys]
    viol = set()
    for k, idx_arr in zip(cap_keys, cap_idxarr):
        if x_mat[idx_arr].sum() > CAPACITY + EPS:
            viol.add(k)

    # ③-d negative dual search
    neg_pi = set()
    lp = base.relax(); lp.optimize()
    if lp.Status == gp.GRB.OPTIMAL:
        for key, c in constr_refs.items():
            if c.Pi < -EPS: neg_pi.add(key)
            
    # ③-e working-set update
    updated = False
    for k in viol:
        if k not in working_set: working_set.add(k); updated = True
    for k in neg_pi:
        if k in working_set: working_set.remove(k); updated = True

    ws = sorted(working_set)
    print(f"[Iter {it}] |W|={len(ws)}  preview={ws[:SHOW]}")
    print(f"          add={len(viol)} drop={len(neg_pi)}")
    sol_prev = x_val
    if not updated:
        print("↳ converged"); break
else:
    print("⚠ MAX_ITER reached")
# Out:
# Set parameter Username
# Set parameter LicenseID to value 2637066
# Academic license - for non-commercial use only - expires 2026-03-16
# Set parameter OutputFlag to value 1
# Gurobi Optimizer version 12.0.2 build v12.0.2rc0 (win64 - Windows 10.0 (19045.2))
#
# CPU model: AMD Ryzen 5 3600XT 6-Core Processor, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 2183661 rows, 951546 columns and 7911748 nonzeros
# Model fingerprint: 0x1aa08891
# Variable types: 6312 continuous, 945234 integer (936939 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+06]
#   Objective range  [2e-01, 1e+06]
#   Bounds range     [1e+00, 3e+01]
#   RHS range        [1e+00, 1e+06]
# Found heuristic solution: objective 1.786467e+08
# Presolve removed 2011196 rows and 879905 columns
# Presolve time: 4.04s
# Presolved: 172465 rows, 71641 columns, 569444 nonzeros
# Variable types: 0 continuous, 71641 integer (63562 binary)
# Performing another presolve...
# Presolve removed 72683 rows and 23498 columns (presolve time = 5s)...
# Presolve removed 170048 rows and 51348 columns (presolve time = 12s)...
# Presolve removed 170048 rows and 51348 columns
# Presolve time: 12.42s
# Found heuristic solution: objective 7985681.6000
#
# Deterministic concurrent LP optimizer: primal and dual simplex (primal and dual model)
# Showing primal log only...
#
# Root relaxation presolved: 73205 rows, 20293 columns, 192344 nonzeros
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    8.9161092e+06   0.000000e+00   5.590127e+06     19s
#    11366    5.6757718e+06   0.000000e+00   2.139660e+10     20s
#    22941    8.4639763e+05   0.000000e+00   2.526987e+10     25s
# Concurrent spin time: 0.05s
#
# Solved with primal simplex
#
# Root relaxation: objective 4.971482e+05, 52481 iterations, 8.08 seconds (5.32 work units)
# Total elapsed time = 26.49s (DegenMoves)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 497148.188    0 2232 7985681.60 497148.188  93.8%     -   30s
#      0     0 529625.962    0 1123 7985681.60 529625.962  93.4%     -   34s
#      0     0 531672.428    0 1246 7985681.60 531672.428  93.3%     -   35s
#      0     0 531742.369    0 1210 7985681.60 531742.369  93.3%     -   36s
#      0     0 531742.436    0 1206 7985681.60 531742.436  93.3%     -   36s
#      0     0 531742.730    0 1218 7985681.60 531742.730  93.3%     -   36s
#      0     0 531742.737    0 1225 7985681.60 531742.737  93.3%     -   36s
# H    0     0                    2546412.2000 531742.737  79.1%     -   36s
# H    0     0                    733322.40000 531742.737  27.5%     -   36s
#      0     0 584573.934    0 1777 733322.400 584573.934  20.3%     -   41s
#      0     0 584630.515    0 1740 733322.400 584630.515  20.3%     -   42s
#      0     0 589502.025    0 1623 733322.400 589502.025  19.6%     -   42s
#      0     0 589502.025    0 1593 733322.400 589502.025  19.6%     -   42s
#      0     0 589695.346    0 1597 733322.400 589695.346  19.6%     -   42s
#      0     0 592482.803    0 1544 733322.400 592482.803  19.2%     -   44s
#      0     0 592482.936    0 1541 733322.400 592482.936  19.2%     -   44s
#      0     0 593946.558    0 1630 733322.400 593946.558  19.0%     -   45s
#      0     0 593946.558    0 1626 733322.400 593946.558  19.0%     -   45s
#      0     0 594179.969    0 1632 733322.400 594179.969  19.0%     -   46s
#      0     0 594180.131    0 1622 733322.400 594180.131  19.0%     -   46s
#      0     0 594180.131    0 1623 733322.400 594180.131  19.0%     -   46s
#      0     0 594180.131    0 1624 733322.400 594180.131  19.0%     -   46s
#      0     0 594180.195    0 1631 733322.400 594180.195  19.0%     -   46s
#      0     0 594180.195    0 1622 733322.400 594180.195  19.0%     -   46s
#      0     0 594189.191    0 1612 733322.400 594189.191  19.0%     -   46s
#      0     0 602774.269    0 1434 733322.400 602774.269  17.8%     -   48s
#      0     0 602782.373    0 1425 733322.400 602782.373  17.8%     -   48s
#      0     0 602782.728    0 1410 733322.400 602782.728  17.8%     -   48s
#      0     0 602784.017    0 1428 733322.400 602784.017  17.8%     -   48s
#      0     0 602788.022    0 1433 733322.400 602788.022  17.8%     -   48s
#      0     0 603104.114    0 1518 733322.400 603104.114  17.8%     -   48s
#      0     0 603104.270    0 1510 733322.400 603104.270  17.8%     -   49s
#      0     0 603293.983    0 1489 733322.400 603293.983  17.7%     -   49s
#      0     0 603308.078    0 1512 733322.400 603308.078  17.7%     -   49s
#      0     0 603319.912    0 1523 733322.400 603319.912  17.7%     -   49s
#      0     0 605095.102    0 1410 733322.400 605095.102  17.5%     -   50s
#      0     0 605095.102    0 1407 733322.400 605095.102  17.5%     -   50s
#      0     0 606390.216    0 1421 733322.400 606390.216  17.3%     -   50s
#      0     0 606501.534    0 1411 733322.400 606501.534  17.3%     -   51s
#      0     0 606502.310    0 1420 733322.400 606502.310  17.3%     -   51s
#      0     0 606523.476    0 1426 733322.400 606523.476  17.3%     -   51s
#      0     0 606529.382    0 1430 733322.400 606529.382  17.3%     -   51s
#      0     0 607009.107    0 1418 733322.400 607009.107  17.2%     -   52s
#      0     0 607053.427    0 1439 733322.400 607053.427  17.2%     -   52s
#      0     0 607107.451    0 1467 733322.400 607107.451  17.2%     -   52s
#      0     0 607107.598    0 1468 733322.400 607107.598  17.2%     -   52s
#      0     0 607117.817    0 1459 733322.400 607117.817  17.2%     -   53s
#      0     0 607118.197    0 1460 733322.400 607118.197  17.2%     -   53s
#      0     0 607385.336    0 1481 733322.400 607385.336  17.2%     -   53s
#      0     0 607385.336    0 1480 733322.400 607385.336  17.2%     -   53s
#      0     0 607388.900    0 1427 733322.400 607388.900  17.2%     -   54s
#      0     0 607548.024    0 1460 733322.400 607548.024  17.2%     -   54s
#      0     0 607561.066    0 1441 733322.400 607561.066  17.1%     -   55s
#      0     0 607568.508    0 1457 733322.400 607568.508  17.1%     -   55s
#      0     0 607597.230    0 1524 733322.400 607597.230  17.1%     -   56s
#      0     0 607637.257    0 1420 733322.400 607637.257  17.1%     -   56s
#      0     0 607643.948    0 1490 733322.400 607643.948  17.1%     -   57s
#      0     0 607676.671    0 1493 733322.400 607676.671  17.1%     -   57s
#      0     0 614378.168    0 1245 733322.400 614378.168  16.2%     -   58s
#
# Explored 1 nodes (90044 simplex iterations) in 62.06 seconds (47.07 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 5: 733322 733322 2.54641e+06 ... 1.78647e+08
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.333224000002e+05, best bound 7.333224000002e+05, gap 0.0000%
# Gurobi Optimizer version 12.0.2 build v12.0.2rc0 (win64 - Windows 10.0 (19045.2))
#
# CPU model: AMD Ryzen 5 3600XT 6-Core Processor, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 2183661 rows, 951546 columns and 7911748 nonzeros
# Model fingerprint: 0xbc542437
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+06]
#   Objective range  [2e-01, 1e+06]
#   Bounds range     [1e+00, 3e+01]
#   RHS range        [1e+00, 1e+06]
# Presolve removed 2028450 rows and 888246 columns
# Presolve time: 7.99s
# Presolved: 54349 rows, 226007 columns, 658780 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.20s
#
# Barrier statistics:
#  Dense cols : 122
#  Free vars  : 408
#  AA' NZ     : 2.461e+06
#  Factor NZ  : 5.616e+06 (roughly 160 MB of memory)
#  Factor Ops : 1.025e+09 (less than 1 second per iteration)
#  Threads    : 4
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0  -4.19595702e+14  1.78646740e+08  1.76e+08 0.00e+00  2.36e+09     9s
#    1  -2.25533085e+14  3.94694066e+10  8.51e+07 4.83e+02  1.16e+09     9s
#    2  -1.66883168e+14  6.53904195e+10  5.98e+07 1.93e+02  7.27e+08     9s
#    3  -7.83627482e+13  7.28941404e+10  2.58e+07 6.31e+01  3.22e+08     9s
#    4  -1.04921084e+13  6.19302476e+10  2.89e+06 2.47e+01  4.39e+07    10s
#    5  -3.66157598e+12  4.90883390e+10  9.36e+05 1.76e+01  1.65e+07    10s
#    6  -3.52962631e+12  4.73582011e+10  9.04e+05 1.68e+01  1.60e+07    10s
#    7  -3.34487335e+12  4.66188298e+10  8.59e+05 1.64e+01  1.53e+07    10s
#    8  -2.91981547e+12  4.30702406e+10  7.55e+05 1.48e+01  1.35e+07    10s
#    9  -2.45125923e+12  3.98272735e+10  6.35e+05 1.34e+01  1.15e+07    10s
#   10  -2.13391448e+12  3.51387120e+10  5.50e+05 1.15e+01  9.98e+06    10s
#   11  -1.86778885e+12  3.04219897e+10  4.80e+05 9.68e+00  8.69e+06    10s
#   12  -1.59960206e+12  2.75907542e+10  4.21e+05 8.64e+00  7.67e+06    11s
#   13  -1.25385691e+12  2.53207433e+10  3.32e+05 7.76e+00  6.27e+06    11s
#   14  -8.84702911e+11  1.92042527e+10  2.25e+05 5.49e+00  4.42e+06    11s
#   15  -6.51865949e+11  1.62180401e+10  1.63e+05 4.52e+00  3.37e+06    11s
#   16  -3.52702191e+11  9.40990565e+09  8.04e+04 2.37e+00  1.78e+06    11s
#   17  -2.86758818e+11  6.01378877e+09  6.40e+04 1.37e+00  1.33e+06    11s
#   18  -2.31643565e+11  4.54538456e+09  5.06e+04 9.86e-01  1.04e+06    12s
#   19  -2.19077605e+11  4.53099155e+09  4.86e+04 9.82e-01  1.01e+06    12s
#   20  -2.08407871e+11  4.49318798e+09  4.72e+04 9.73e-01  9.84e+05    12s
#   21  -1.97708133e+11  3.00763878e+09  4.55e+04 5.99e-01  8.74e+05    12s
#   22  -7.23634418e+10  1.10537336e+09  1.36e+04 1.35e-01  2.96e+05    12s
#   23  -1.01646670e+10  2.21789050e+08  1.57e+03 6.18e-02  3.93e+04    12s
#   24  -1.49664859e+09  9.09589742e+07  2.16e+02 4.20e-02  5.92e+03    12s
#   25  -4.99451207e+08  5.48146737e+07  6.90e+01 7.92e-03  2.06e+03    12s
#   26  -1.80646341e+08  2.87513993e+07  2.41e+01 3.02e-03  7.75e+02    13s
#   27  -1.05865501e+08  1.54642800e+07  1.38e+01 1.51e-03  4.46e+02    13s
#   28  -8.19087609e+07  1.09819120e+07  1.06e+01 1.04e-03  3.41e+02    13s
#   29  -3.91321661e+07  7.24592296e+06  4.96e+00 6.83e-04  1.71e+02    13s
#   30  -2.93083219e+07  5.50996720e+06  3.62e+00 5.04e-04  1.28e+02    13s
#   31  -2.49399502e+07  3.93041386e+06  3.07e+00 3.56e-04  1.06e+02    13s
#   32  -2.32872956e+07  3.44559288e+06  2.86e+00 3.07e-04  9.79e+01    13s
#   33  -1.98194487e+07  2.47445916e+06  2.42e+00 1.94e-04  8.14e+01    13s
#   34  -1.68131425e+07  1.17539514e+06  2.04e+00 8.02e-05  6.54e+01    13s
#   35  -6.34265457e+06  7.83485940e+05  7.55e-01 5.04e-05  2.60e+01    13s
#   36  -6.20861085e+05  1.93124622e+05  7.06e-02 1.06e-05  3.01e+00    14s
#   37  -2.71406637e+05  9.98428883e+04  4.03e-02 4.25e-06  1.37e+00    14s
#   38  -2.31682555e+05  9.70446734e+04  9.48e-02 4.12e-06  1.22e+00    14s
#   39  -2.25212531e+05  9.10981619e+04  9.30e-02 3.84e-06  1.17e+00    14s
#   40  -2.22187081e+05  8.83576047e+04  9.19e-02 3.71e-06  1.15e+00    14s
#   41  -2.02916667e+05  7.78514767e+04  1.01e-01 3.27e-06  1.04e+00    14s
#   42  -1.75665799e+05  6.59575606e+04  8.72e-02 2.78e-06  8.93e-01    14s
#   43  -1.75625101e+05  6.59552683e+04  8.71e-02 2.78e-06  8.92e-01    15s
#   44  -1.51361712e+05  5.09045443e+04  7.23e-02 2.05e-06  7.47e-01    15s
#   45  -1.50147750e+05  4.91309715e+04  7.17e-02 8.64e-07  7.35e-01    15s
#   46  -1.43082748e+05  4.58637570e+04  6.81e-02 7.94e-07  6.97e-01    15s
#   47  -1.42831697e+05  4.57992702e+04  6.75e-02 7.92e-07  6.96e-01    15s
#   48  -1.35220295e+05  4.47321039e+04  6.44e-02 7.67e-07  6.64e-01    15s
#
# Barrier performed 48 iterations in 15.38 seconds (9.83 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
# Extra simplex iterations after uncrush: 2076
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#    55864    1.2824816e+03   0.000000e+00   0.000000e+00     19s
#
# Solved in 55864 iterations and 18.82 seconds (9.80 work units)
# Optimal objective  1.282481550e+03
# [Iter 0] |W|=0  preview=[]
#           add=0 drop=0
# ↳ converged

# %%
# ========== Cell 5 (교체) ==========
pd.set_option('display.max_rows', None)

# 1) Timetable (요약만 표시)
rows = []
for tr_i, tr in enumerate(trains):
    if hvar[tr].X < 0.5:
        rows.append([tr, '-', '-', '-', '-', 'Cancelled'])
        continue
    legs = [(int(arc_list[k][0].split("^")[1]),
             arc_list[k][0].split("^")[0],
             arc_list[k][1].split("^")[0],
             int(arc_list[k][1].split("^")[1]),
             arc_list[k][2])
            for k in range(len(arc_list))
            if xvar[k, tr_i].X > 0.5 and not arc_list[k][2].startswith(("w_", "dummy"))]
    legs.sort(key=lambda v: v[0])
    for dep, frm, to, arr, eid in legs:
        rows.append([tr, frm, dep, to, arr, eid])

df = pd.DataFrame(rows, columns=["Train", "From", "Dep", "To", "Arr", "Edge"])
print("\n=== Timetable (head) ===")
display(df)

# 2) 유틸리티
def planned_path_and_eids(tr):
    path = routes_nodes[tr]
    eids = []
    for u, v in zip(path[:-1], path[1:]):
        eid = next(e for e, (s, d, _) in edges.items() if s == u and d == v)
        eids.append(eid)
    return path, eids

def build_actual_legs(tr):
    tr_i = trains.index(tr)
    legs = [(int(arc_list[k][0].split("^")[1]),
             arc_list[k][0].split("^")[0],
             arc_list[k][1].split("^")[0],
             int(arc_list[k][1].split("^")[1]),
             arc_list[k][2])
            for k in range(len(arc_list))
            if xvar[k, tr_i].X > 0.5 and not arc_list[k][2].startswith(("w_", "dummy"))]
    legs.sort(key=lambda v: v[0])
    return legs

def path_nodes_from_legs(legs):
    if not legs: return []
    nodes = [legs[0][1]]
    for _, _, to, _, _ in legs:
        nodes.append(to)
    return nodes

def actual_arrival_map(legs):
    """노드별 최초 도착시각 dict"""
    amap = {}
    for _, frm, to, arr, _ in legs:
        if to not in amap or arr < amap[to]:
            amap[to] = arr
    if legs:
        # 출발 노드는 dep 시각(legs[0][2]==to가 아니라, from의 dep)도 기록할 수 있지만
        # 지연 판정엔 주로 도착 노드가 쓰임
        pass
    return amap

# 3) 상태 요약 (T-제한 비교)
stat_rows = []
for tr in trains:
    departed = (hvar[tr].X >= 0.5)
    planned_path, planned_eids = planned_path_and_eids(tr)
    planned_terminal = planned_path[-1]
    planned_terminal_sched = sched[tr].get(planned_terminal, None)

    if not departed:
        stat_rows.append({
            "Train": tr, "Departed": False, "ArrivedInHorizon": False,
            "PlannedTerminal": planned_terminal,
            "ActualTerminal": None,
            "Delay(min)": None,                 # 도착 안 했으므로 없음
            "HorizonDelay(min)": None,          # T-기준 prefix 지연
            "Truncated": False, "Rerouted": False,
            "Status": "Cancelled"
        })
        continue

    # 실제 운행 legs / 경로
    legs = build_actual_legs(tr)
    actual_nodes = path_nodes_from_legs(legs)
    actual_eids  = [e for *_, e in legs]
    arr_map      = actual_arrival_map(legs)
    actual_terminal = actual_nodes[-1] if actual_nodes else None
    actual_arrival  = max(arr for *_, arr, _ in legs) if legs else None

    # 계획 prefix (T 이내에 '완료'되는 엣지들만)
    # sched[tr][node]는 그 노드 예정 도착시각.
    # node0=origin은 dep_time, 이후 node1.. 의 예정도착이 있음.
    # T 이내인 마지막 노드를 찾아 prefix를 정함.
    prefix_last_idx = 0  # 최소 origin(=index 0)
    for i, node in enumerate(planned_path):
        t_planned = sched[tr].get(node, None)
        if t_planned is not None and t_planned <= T:
            prefix_last_idx = i
    planned_prefix_nodes = planned_path[:prefix_last_idx+1]
    planned_prefix_eids  = planned_eids[:max(0, prefix_last_idx)]

    # 도착/Truncated 판정 (목적지의 예정 도착이 T 이내일 때만 Truncated 고려)
    arrived_in_horizon = (actual_terminal == planned_terminal) and (actual_arrival is not None) and (actual_arrival <= T)
    if planned_terminal_sched is not None and planned_terminal_sched <= T:
        truncated = (not arrived_in_horizon)
    else:
        truncated = False  # 원래 T 이후 도착 예정이면 Truncated로 보지 않음

    # 재루팅: T 이내 계획 prefix vs 실제 사용 prefix 비교
    # 실제 사용 엣지(actual_eids)는 모두 T 이내에 끝난 아크들로 구성(모델링상 t1<=T)
    # → 계획 prefix 길이와 겹치는 구간까지 비교
    common = min(len(actual_eids), len(planned_prefix_eids))
    rerouted = (actual_eids[:common] != planned_prefix_eids[:common])
    # 만약 계획 prefix가 더 길고, 실제가 prefix 길이만큼 동일한 채 더 못 갔다면
    # 단순 '지연/진행중'일 수 있으므로 여기서는 rerouted로 보지 않음.

    # Delay 계산
    delay_min = None
    horizon_delay_min = None

    # ① 목적지가 T 이내 도착 예정이었고, 실제도 T 이내 도착했다면 → 목적지 기준 지연
    if planned_terminal_sched is not None and planned_terminal_sched <= T and arrived_in_horizon:
        delay_min = max(0, actual_arrival - planned_terminal_sched)

    # ② T 이내 계획 prefix의 '마지막 계획 노드'에서의 지연(도달했을 때만)
    if planned_prefix_nodes:
        last_plan_node = planned_prefix_nodes[-1]
        t_plan_last    = sched[tr].get(last_plan_node, None)
        t_act_last     = arr_map.get(last_plan_node, None)
        if (t_plan_last is not None) and (t_act_last is not None):
            horizon_delay_min = max(0, t_act_last - t_plan_last)

    # 상태 라벨
    if not departed:
        status = "Cancelled"
    elif truncated:
        status = "Truncated"
    elif rerouted:
        status = "Rerouted"
    elif (planned_terminal_sched is not None and planned_terminal_sched <= T and delay_min and delay_min > 0) \
         or (horizon_delay_min is not None and horizon_delay_min > 0):
        status = "Delayed"
    else:
        # 목적지가 T 이후 예정이라 아직 진행 중인 경우
        if planned_terminal_sched is not None and planned_terminal_sched > T and not arrived_in_horizon:
            status = "On-time & in-progress"
        else:
            status = "On-time & complete"

    stat_rows.append({
        "Train": tr,
        "Departed": True,
        "ArrivedInHorizon": arrived_in_horizon,
        "PlannedTerminal": planned_terminal,
        "ActualTerminal": actual_terminal,
        "Delay(min)": delay_min,
        "HorizonDelay(min)": horizon_delay_min,
        "Truncated": truncated,
        "Rerouted": rerouted,
        "Status": status
    })

df_stat = pd.DataFrame(stat_rows, columns=[
    "Train","Departed","ArrivedInHorizon","PlannedTerminal","ActualTerminal",
    "Delay(min)","HorizonDelay(min)","Truncated","Rerouted","Status"
])
print("\n=== Train status summary — horizon-aware (T-based) ===")
display(df_stat)
# Out:
# === Timetable (head) ===
#            Train From  Dep   To  Arr  Edge
# 0      경부고속철도1_1   n4    0   n3    1    e4
# 1      경부고속철도1_1   n3    1   n1    2    e3
# 2      경부고속철도1_1   n1    2   n2    3    e1
# 3      경부고속철도1_1   n2    3  n13    5   e9r
# 4      경부고속철도1_1  n13    5  n18    6  e17r
# 5      경부고속철도1_1  n18    6  n28    7   e26
# 6      경부고속철도1_1  n28    7  n41   10  e42r
# 7      경부고속철도1_1  n41   10  n46   11  e55r
# 8      경부고속철도1_1  n46   11  n59   13   e66
# 9      경부고속철도1_1  n59   13  n60   14  e72r
# 10     경부고속철도1_1  n60   14  n72   16   e81
# 11     경부고속철도1_1  n72   16  n75   17   e89
# 12     경부고속철도1_1  n75   17  n79   19   e93
# 13     경부고속철도1_2   n4    1   n3    2    e4
# 14     경부고속철도1_2   n3    2   n1    3    e3
# 15     경부고속철도1_2   n1    3   n2    4    e1
# 16     경부고속철도1_2   n2    4  n13    6   e9r
# 17     경부고속철도1_2  n13    6  n18    7  e17r
# 18     경부고속철도1_2  n18    7  n28    8   e26
# 19     경부고속철도1_2  n28    8  n41   11  e42r
# 20     경부고속철도1_2  n41   11  n46   12  e55r
# 21     경부고속철도1_2  n46   12  n59   14   e66
# 22     경부고속철도1_2  n59   14  n60   15  e72r
# 23     경부고속철도1_2  n60   15  n72   17   e81
# 24     경부고속철도1_2  n72   17  n75   18   e89
# 25     경부고속철도1_2  n75   18  n79   20   e93
# 26     경부고속철도1_3   n4    2   n3    3    e4
# 27     경부고속철도1_3   n3    3   n1    4    e3
# 28     경부고속철도1_3   n1    4   n2    5    e1
# 29     경부고속철도1_3   n2    5  n13    7   e9r
# 30     경부고속철도1_3  n13    7  n18    8  e17r
# 31     경부고속철도1_3  n18    8  n28    9   e26
# 32     경부고속철도1_3  n28    9  n41   12  e42r
# 33     경부고속철도1_3  n41   12  n46   13  e55r
# 34     경부고속철도1_3  n46   13  n59   15   e66
# 35     경부고속철도1_3  n59   15  n60   16  e72r
# 36     경부고속철도1_3  n60   16  n72   18   e81
# 37     경부고속철도1_3  n72   18  n75   19   e89
# 38     경부고속철도1_3  n75   19  n79   21   e93
# 39     경부고속철도1_4   n4    3   n3    4    e4
# 40     경부고속철도1_4   n3    4   n1    5    e3
# 41     경부고속철도1_4   n1    5   n2    6    e1
# 42     경부고속철도1_4   n2    6  n13    8   e9r
# 43     경부고속철도1_4  n13    8  n18    9  e17r
# 44     경부고속철도1_4  n18    9  n28   10   e26
# 45     경부고속철도1_4  n28   10  n41   13  e42r
# 46     경부고속철도1_4  n41   13  n46   14  e55r
# 47     경부고속철도1_4  n46   14  n59   16   e66
# 48     경부고속철도1_4  n59   16  n60   17  e72r
# 49     경부고속철도1_4  n60   17  n72   19   e81
# 50     경부고속철도1_4  n72   19  n75   20   e89
# 51     경부고속철도1_4  n75   20  n79   22   e93
# 52     경부고속철도1_5   n4    4   n3    5    e4
# 53     경부고속철도1_5   n3    5   n1    6    e3
# 54     경부고속철도1_5   n1    6   n2    7    e1
# 55     경부고속철도1_5   n2    7  n13    9   e9r
# 56     경부고속철도1_5  n13    9  n18   10  e17r
# 57     경부고속철도1_5  n18   10  n28   11   e26
# 58     경부고속철도1_5  n28   11  n41   14  e42r
# 59     경부고속철도1_5  n41   14  n46   15  e55r
# 60     경부고속철도1_5  n46   15  n59   17   e66
# 61     경부고속철도1_5  n59   17  n60   18  e72r
# 62     경부고속철도1_5  n60   18  n72   20   e81
# 63     경부고속철도1_5  n72   20  n75   21   e89
# 64     경부고속철도1_5  n75   21  n79   23   e93
# 65     경부고속철도1_6   n4    5   n3    6    e4
# 66     경부고속철도1_6   n3    6   n1    7    e3
# 67     경부고속철도1_6   n1    7   n2    8    e1
# 68     경부고속철도1_6   n2    8  n13   10   e9r
# 69     경부고속철도1_6  n13   10  n18   11  e17r
# 70     경부고속철도1_6  n18   11  n28   12   e26
# 71     경부고속철도1_6  n28   12  n41   15  e42r
# 72     경부고속철도1_6  n41   15  n46   16  e55r
# 73     경부고속철도1_6  n46   16  n59   18   e66
# 74     경부고속철도1_6  n59   18  n60   19  e72r
# 75     경부고속철도1_6  n60   19  n72   21   e81
# 76     경부고속철도1_6  n72   21  n75   22   e89
# 77     경부고속철도1_6  n75   22  n79   24   e93
# 78     경부고속철도1_7   n4    6   n3    7    e4
# 79     경부고속철도1_7   n3    7   n1    8    e3
# 80     경부고속철도1_7   n1    8   n2    9    e1
# 81     경부고속철도1_7   n2    9  n13   11   e9r
# 82     경부고속철도1_7  n13   11  n18   12  e17r
# 83     경부고속철도1_7  n18   12  n28   13   e26
# 84     경부고속철도1_7  n28   13  n41   16  e42r
# 85     경부고속철도1_7  n41   16  n46   17  e55r
# 86     경부고속철도1_7  n46   17  n59   19   e66
# 87     경부고속철도1_7  n59   19  n60   20  e72r
# 88     경부고속철도1_7  n60   20  n72   22   e81
# 89     경부고속철도1_7  n72   22  n75   23   e89
# 90     경부고속철도1_7  n75   23  n79   25   e93
# 91     경부고속철도1_8   n4    7   n3    8    e4
# 92     경부고속철도1_8   n3    8   n1    9    e3
# 93     경부고속철도1_8   n1    9   n2   10    e1
# 94     경부고속철도1_8   n2   10  n13   12   e9r
# 95     경부고속철도1_8  n13   12  n18   13  e17r
# 96     경부고속철도1_8  n18   13  n28   14   e26
# 97     경부고속철도1_8  n28   14  n41   17  e42r
# 98     경부고속철도1_8  n41   17  n46   18  e55r
# 99     경부고속철도1_8  n46   18  n59   20   e66
# 100    경부고속철도1_8  n59   20  n60   21  e72r
# 101    경부고속철도1_8  n60   21  n72   23   e81
# 102    경부고속철도1_8  n72   23  n75   24   e89
# 103    경부고속철도1_8  n75   24  n79   26   e93
# 104    경부고속철도1_9   n4    8   n3    9    e4
# 105    경부고속철도1_9   n3    9   n1   10    e3
# 106    경부고속철도1_9   n1   10   n2   11    e1
# 107    경부고속철도1_9   n2   11  n13   13   e9r
# 108    경부고속철도1_9  n13   13  n18   14  e17r
# 109    경부고속철도1_9  n18   14  n28   15   e26
# 110    경부고속철도1_9  n28   15  n41   18  e42r
# 111    경부고속철도1_9  n41   18  n46   19  e55r
# 112    경부고속철도1_9  n46   19  n59   21   e66
# 113    경부고속철도1_9  n59   21  n60   22  e72r
# 114    경부고속철도1_9  n60   22  n72   24   e81
# 115    경부고속철도1_9  n72   24  n75   25   e89
# 116    경부고속철도1_9  n75   25  n79   27   e93
# 117   경부고속철도1_10   n4    9   n3   10    e4
# 118   경부고속철도1_10   n3   10   n1   11    e3
# 119   경부고속철도1_10   n1   11   n2   12    e1
# 120   경부고속철도1_10   n2   12  n13   14   e9r
# 121   경부고속철도1_10  n13   14  n18   15  e17r
# 122   경부고속철도1_10  n18   15  n28   16   e26
# 123   경부고속철도1_10  n28   16  n41   19  e42r
# 124   경부고속철도1_10  n41   19  n46   20  e55r
# 125   경부고속철도1_10  n46   20  n59   22   e66
# 126   경부고속철도1_10  n59   22  n60   23  e72r
# 127   경부고속철도1_10  n60   23  n72   25   e81
# 128   경부고속철도1_10  n72   25  n75   26   e89
# 129   경부고속철도1_10  n75   26  n79   28   e93
# 130   경부고속철도1_11   n4   10   n3   11    e4
# 131   경부고속철도1_11   n3   11   n1   12    e3
# 132   경부고속철도1_11   n1   12   n2   13    e1
# 133   경부고속철도1_11   n2   13  n13   15   e9r
# 134   경부고속철도1_11  n13   15  n18   16  e17r
# 135   경부고속철도1_11  n18   16  n28   17   e26
# 136   경부고속철도1_11  n28   17  n41   20  e42r
# 137   경부고속철도1_11  n41   20  n46   21  e55r
# 138   경부고속철도1_11  n46   21  n59   23   e66
# 139   경부고속철도1_11  n59   23  n60   24  e72r
# 140   경부고속철도1_11  n60   24  n72   26   e81
# 141   경부고속철도1_11  n72   26  n75   27   e89
# 142   경부고속철도1_11  n75   27  n79   29   e93
# 143   경부고속철도1_12   n4   11   n3   12    e4
# 144   경부고속철도1_12   n3   12   n1   13    e3
# 145   경부고속철도1_12   n1   13   n2   14    e1
# 146   경부고속철도1_12   n2   14  n13   16   e9r
# 147   경부고속철도1_12  n13   16  n18   17  e17r
# 148   경부고속철도1_12  n18   17  n28   18   e26
# 149   경부고속철도1_12  n28   18  n41   21  e42r
# 150   경부고속철도1_12  n41   21  n46   22  e55r
# 151   경부고속철도1_12  n46   22  n59   24   e66
# 152   경부고속철도1_12  n59   24  n60   25  e72r
# 153   경부고속철도1_12  n60   25  n72   27   e81
# 154   경부고속철도1_12  n72   27  n75   28   e89
# 155   경부고속철도1_12  n75   28  n79   30   e93
# 156    경부고속철도2_1  n79    0  n75    2  e93r
# 157    경부고속철도2_1  n75    2  n72    3  e89r
# 158    경부고속철도2_1  n72    3  n60    5  e81r
# 159    경부고속철도2_1  n60    5  n42    7  e61r
# 160    경부고속철도2_1  n42    7  n28    9   e43
# 161    경부고속철도2_1  n28    9  n18   10  e26r
# 162    경부고속철도2_1  n18   10  n13   11   e17
# 163    경부고속철도2_1  n13   11   n2   13    e9
# 164    경부고속철도2_1   n2   13   n1   14   e1r
# 165    경부고속철도2_1   n1   14   n3   15   e3r
# 166    경부고속철도2_1   n3   15   n4   16   e4r
# 167    경부고속철도2_2  n79    1  n75    3  e93r
# 168    경부고속철도2_2  n75    3  n72    4  e89r
# 169    경부고속철도2_2  n72    4  n60    6  e81r
# 170    경부고속철도2_2  n60    6  n42    8  e61r
# 171    경부고속철도2_2  n42    8  n28   10   e43
# 172    경부고속철도2_2  n28   10  n18   11  e26r
# 173    경부고속철도2_2  n18   11  n13   12   e17
# 174    경부고속철도2_2  n13   12   n2   14    e9
# 175    경부고속철도2_2   n2   14   n1   15   e1r
# 176    경부고속철도2_2   n1   15   n3   16   e3r
# 177    경부고속철도2_2   n3   16   n4   17   e4r
# 178    경부고속철도2_3  n79    2  n75    4  e93r
# 179    경부고속철도2_3  n75    4  n72    5  e89r
# 180    경부고속철도2_3  n72    5  n60    7  e81r
# 181    경부고속철도2_3  n60    7  n42    9  e61r
# 182    경부고속철도2_3  n42    9  n28   11   e43
# 183    경부고속철도2_3  n28   11  n18   12  e26r
# 184    경부고속철도2_3  n18   12  n13   13   e17
# 185    경부고속철도2_3  n13   13   n2   15    e9
# 186    경부고속철도2_3   n2   15   n1   16   e1r
# 187    경부고속철도2_3   n1   16   n3   17   e3r
# 188    경부고속철도2_3   n3   17   n4   18   e4r
# 189    경부고속철도2_4  n79    3  n75    5  e93r
# 190    경부고속철도2_4  n75    5  n72    6  e89r
# 191    경부고속철도2_4  n72    6  n60    8  e81r
# 192    경부고속철도2_4  n60    8  n42   10  e61r
# 193    경부고속철도2_4  n42   10  n28   12   e43
# 194    경부고속철도2_4  n28   12  n18   13  e26r
# 195    경부고속철도2_4  n18   13  n13   14   e17
# 196    경부고속철도2_4  n13   14   n2   16    e9
# 197    경부고속철도2_4   n2   16   n1   17   e1r
# 198    경부고속철도2_4   n1   17   n3   18   e3r
# 199    경부고속철도2_4   n3   18   n4   19   e4r
# 200    경부고속철도2_5  n79    4  n75    6  e93r
# 201    경부고속철도2_5  n75    6  n72    7  e89r
# 202    경부고속철도2_5  n72    7  n60    9  e81r
# 203    경부고속철도2_5  n60    9  n42   11  e61r
# 204    경부고속철도2_5  n42   11  n28   13   e43
# 205    경부고속철도2_5  n28   13  n18   14  e26r
# 206    경부고속철도2_5  n18   14  n13   15   e17
# 207    경부고속철도2_5  n13   15   n2   17    e9
# 208    경부고속철도2_5   n2   17   n1   18   e1r
# 209    경부고속철도2_5   n1   18   n3   19   e3r
# 210    경부고속철도2_5   n3   19   n4   20   e4r
# 211    경부고속철도2_6  n79    5  n75    7  e93r
# 212    경부고속철도2_6  n75    7  n72    8  e89r
# 213    경부고속철도2_6  n72    8  n60   10  e81r
# 214    경부고속철도2_6  n60   10  n42   12  e61r
# 215    경부고속철도2_6  n42   12  n28   14   e43
# 216    경부고속철도2_6  n28   14  n18   15  e26r
# 217    경부고속철도2_6  n18   15  n13   16   e17
# 218    경부고속철도2_6  n13   16   n2   18    e9
# 219    경부고속철도2_6   n2   18   n1   19   e1r
# 220    경부고속철도2_6   n1   19   n3   20   e3r
# 221    경부고속철도2_6   n3   20   n4   21   e4r
# 222    경부고속철도2_7  n79    6  n75    8  e93r
# 223    경부고속철도2_7  n75    8  n72    9  e89r
# 224    경부고속철도2_7  n72    9  n60   11  e81r
# 225    경부고속철도2_7  n60   11  n42   13  e61r
# 226    경부고속철도2_7  n42   13  n28   15   e43
# 227    경부고속철도2_7  n28   15  n18   16  e26r
# 228    경부고속철도2_7  n18   16  n13   17   e17
# 229    경부고속철도2_7  n13   17   n2   19    e9
# 230    경부고속철도2_7   n2   19   n1   20   e1r
# 231    경부고속철도2_7   n1   20   n3   21   e3r
# 232    경부고속철도2_7   n3   21   n4   22   e4r
# 233    경부고속철도2_8  n79    7  n75    9  e93r
# 234    경부고속철도2_8  n75    9  n72   10  e89r
# 235    경부고속철도2_8  n72   10  n60   12  e81r
# 236    경부고속철도2_8  n60   12  n42   14  e61r
# 237    경부고속철도2_8  n42   14  n28   16   e43
# 238    경부고속철도2_8  n28   16  n18   17  e26r
# 239    경부고속철도2_8  n18   17  n13   18   e17
# 240    경부고속철도2_8  n13   18   n2   20    e9
# 241    경부고속철도2_8   n2   20   n1   21   e1r
# 242    경부고속철도2_8   n1   21   n3   22   e3r
# 243    경부고속철도2_8   n3   22   n4   23   e4r
# 244    경부고속철도2_9  n79    8  n75   10  e93r
# 245    경부고속철도2_9  n75   10  n72   11  e89r
# 246    경부고속철도2_9  n72   11  n60   13  e81r
# 247    경부고속철도2_9  n60   13  n42   15  e61r
# 248    경부고속철도2_9  n42   15  n28   17   e43
# 249    경부고속철도2_9  n28   17  n18   18  e26r
# 250    경부고속철도2_9  n18   18  n13   19   e17
# 251    경부고속철도2_9  n13   19   n2   21    e9
# 252    경부고속철도2_9   n2   21   n1   22   e1r
# 253    경부고속철도2_9   n1   22   n3   23   e3r
# 254    경부고속철도2_9   n3   23   n4   24   e4r
# 255   경부고속철도2_10  n79    9  n75   11  e93r
# 256   경부고속철도2_10  n75   11  n72   12  e89r
# 257   경부고속철도2_10  n72   12  n60   14  e81r
# 258   경부고속철도2_10  n60   14  n42   16  e61r
# 259   경부고속철도2_10  n42   16  n28   18   e43
# 260   경부고속철도2_10  n28   18  n18   19  e26r
# 261   경부고속철도2_10  n18   19  n13   20   e17
# 262   경부고속철도2_10  n13   20   n2   22    e9
# 263   경부고속철도2_10   n2   22   n1   23   e1r
# 264   경부고속철도2_10   n1   23   n3   24   e3r
# 265   경부고속철도2_10   n3   24   n4   25   e4r
# 266   경부고속철도2_11  n79   10  n75   12  e93r
# 267   경부고속철도2_11  n75   12  n72   13  e89r
# 268   경부고속철도2_11  n72   13  n60   15  e81r
# 269   경부고속철도2_11  n60   15  n42   17  e61r
# 270   경부고속철도2_11  n42   17  n28   19   e43
# 271   경부고속철도2_11  n28   19  n18   20  e26r
# 272   경부고속철도2_11  n18   20  n13   21   e17
# 273   경부고속철도2_11  n13   21   n2   23    e9
# 274   경부고속철도2_11   n2   23   n1   24   e1r
# 275   경부고속철도2_11   n1   24   n3   25   e3r
# 276   경부고속철도2_11   n3   25   n4   26   e4r
# 277       경부선1_1   n4    0   n1    1    e2
# 278       경부선1_1   n1    1   n7    2   e6r
# 279       경부선1_1   n7    2   n9    3  e10r
# 280       경부선1_1   n9    3  n14    4   e12
# 281       경부선1_1  n14    4  n17    5  e16r
# 282       경부선1_1  n17    5  n28    7   e25
# 283       경부선1_1  n28    7  n41   10  e42r
# 284       경부선1_1  n41   10  n46   11  e55r
# 285       경부선1_1  n46   11  n59   13   e66
# 286       경부선1_1  n59   13  n60   14  e72r
# 287       경부선1_1  n60   14  n63   15   e75
# 288       경부선1_1  n63   15  n70   17   e82
# 289       경부선1_1  n70   17  n73   18   e86
# 290       경부선1_1  n73   18  n76   19   e90
# 291       경부선1_1  n76   19  n77   20   e92
# 292       경부선1_1  n77   20  n79   21   e94
# 293       경부선1_2   n4    2   n1    3    e2
# 294       경부선1_2   n1    3   n7    4   e6r
# 295       경부선1_2   n7    4   n9    5  e10r
# 296       경부선1_2   n9    5  n14    6   e12
# 297       경부선1_2  n14    6  n17    7  e16r
# 298       경부선1_2  n17    7  n28    9   e25
# 299       경부선1_2  n28    9  n41   12  e42r
# 300       경부선1_2  n41   12  n46   13  e55r
# 301       경부선1_2  n46   13  n59   15   e66
# 302       경부선1_2  n59   15  n60   16  e72r
# 303       경부선1_2  n60   16  n63   17   e75
# 304       경부선1_2  n63   17  n70   19   e82
# 305       경부선1_2  n70   19  n73   20   e86
# 306       경부선1_2  n73   20  n76   21   e90
# 307       경부선1_2  n76   21  n77   22   e92
# 308       경부선1_2  n77   22  n79   23   e94
# 309       경부선1_3   n4    4   n1    5    e2
# 310       경부선1_3   n1    5   n7    6   e6r
# 311       경부선1_3   n7    6   n9    7  e10r
# 312       경부선1_3   n9    7  n14    8   e12
# 313       경부선1_3  n14    8  n17    9  e16r
# 314       경부선1_3  n17    9  n28   11   e25
# 315       경부선1_3  n28   11  n41   14  e42r
# 316       경부선1_3  n41   14  n46   15  e55r
# 317       경부선1_3  n46   15  n59   17   e66
# 318       경부선1_3  n59   17  n60   18  e72r
# 319       경부선1_3  n60   18  n63   19   e75
# 320       경부선1_3  n63   19  n70   21   e82
# 321       경부선1_3  n70   21  n73   22   e86
# 322       경부선1_3  n73   22  n76   23   e90
# 323       경부선1_3  n76   23  n77   24   e92
# 324       경부선1_3  n77   24  n79   25   e94
# 325       경부선1_4   n4    6   n1    7    e2
# 326       경부선1_4   n1    7   n7    8   e6r
# 327       경부선1_4   n7    8   n9    9  e10r
# 328       경부선1_4   n9    9  n14   10   e12
# 329       경부선1_4  n14   10  n17   11  e16r
# 330       경부선1_4  n17   11  n28   13   e25
# 331       경부선1_4  n28   13  n41   16  e42r
# 332       경부선1_4  n41   16  n46   17  e55r
# 333       경부선1_4  n46   17  n59   19   e66
# 334       경부선1_4  n59   19  n60   20  e72r
# 335       경부선1_4  n60   20  n63   21   e75
# 336       경부선1_4  n63   21  n70   23   e82
# 337       경부선1_4  n70   23  n73   24   e86
# 338       경부선1_4  n73   24  n76   25   e90
# 339       경부선1_4  n76   25  n77   26   e92
# 340       경부선1_4  n77   26  n79   27   e94
# 341       경부선1_5   n4    8   n1    9    e2
# 342       경부선1_5   n1    9   n7   10   e6r
# 343       경부선1_5   n7   10   n9   11  e10r
# 344       경부선1_5   n9   11  n14   12   e12
# 345       경부선1_5  n14   12  n17   13  e16r
# 346       경부선1_5  n17   13  n28   15   e25
# 347       경부선1_5  n28   15  n41   18  e42r
# 348       경부선1_5  n41   18  n46   19  e55r
# 349       경부선1_5  n46   19  n59   21   e66
# 350       경부선1_5  n59   21  n60   22  e72r
# 351       경부선1_5  n60   22  n63   23   e75
# 352       경부선1_5  n63   23  n70   25   e82
# 353       경부선1_5  n70   25  n73   26   e86
# 354       경부선1_5  n73   26  n76   27   e90
# 355       경부선1_5  n76   27  n77   28   e92
# 356       경부선1_5  n77   28  n79   29   e94
# 357       경부선1_6   n4   10   n1   11    e2
# 358       경부선1_6   n1   11   n7   12   e6r
# 359       경부선1_6   n7   12   n9   13  e10r
# 360       경부선1_6   n9   13  n14   14   e12
# 361       경부선1_6  n14   14  n17   15  e16r
# 362       경부선1_6  n17   15  n28   17   e25
# 363       경부선1_6  n28   17  n41   20  e42r
# 364       경부선1_6  n41   20  n46   21  e55r
# 365       경부선1_6  n46   21  n59   23   e66
# 366       경부선1_6  n59   23  n60   24  e72r
# 367       경부선1_6  n60   24  n63   25   e75
# 368       경부선1_6  n63   25  n70   27   e82
# 369       경부선1_6  n70   27  n73   28   e86
# 370       경부선1_6  n73   28  n76   29   e90
# 371       경부선1_6  n76   29  n77   30   e92
# 372       경부선1_6  n77   30  n79   31   e94
# 373       경부선2_1  n79    0  n77    1  e94r
# 374       경부선2_1  n77    1  n76    2  e92r
# 375       경부선2_1  n76    2  n73    3  e90r
# 376       경부선2_1  n73    3  n70    4  e86r
# 377       경부선2_1  n70    4  n63    6  e82r
# 378       경부선2_1  n63    6  n60    7  e75r
# 379       경부선2_1  n60    7  n59    8   e72
# 380       경부선2_1  n59    8  n46   10  e66r
# 381       경부선2_1  n46   10  n41   11   e55
# 382       경부선2_1  n41   11  n28   14   e42
# 383       경부선2_1  n28   14  n17   16  e25r
# 384       경부선2_1  n17   16  n14   17   e16
# 385       경부선2_1  n14   17   n9   18  e12r
# 386       경부선2_1   n9   18   n7   19   e10
# 387       경부선2_1   n7   19   n1   20    e6
# 388       경부선2_1   n1   20   n4   21   e2r
# 389       경부선2_2  n79    2  n77    3  e94r
# 390       경부선2_2  n77    3  n76    4  e92r
# 391       경부선2_2  n76    4  n73    5  e90r
# 392       경부선2_2  n73    5  n70    6  e86r
# 393       경부선2_2  n70    6  n63    8  e82r
# 394       경부선2_2  n63    8  n60    9  e75r
# 395       경부선2_2  n60    9  n59   10   e72
# 396       경부선2_2  n59   10  n46   12  e66r
# 397       경부선2_2  n46   12  n41   13   e55
# 398       경부선2_2  n41   13  n28   16   e42
# 399       경부선2_2  n28   16  n17   18  e25r
# 400       경부선2_2  n17   18  n14   19   e16
# 401       경부선2_2  n14   19   n9   20  e12r
# 402       경부선2_2   n9   20   n7   21   e10
# 403       경부선2_2   n7   21   n1   22    e6
# 404       경부선2_2   n1   22   n4   23   e2r
# 405       경부선2_3  n79    4  n77    5  e94r
# 406       경부선2_3  n77    5  n76    6  e92r
# 407       경부선2_3  n76    6  n73    7  e90r
# 408       경부선2_3  n73    7  n70    8  e86r
# 409       경부선2_3  n70    8  n63   10  e82r
# 410       경부선2_3  n63   10  n60   11  e75r
# 411       경부선2_3  n60   11  n59   12   e72
# 412       경부선2_3  n59   12  n46   14  e66r
# 413       경부선2_3  n46   14  n41   15   e55
# 414       경부선2_3  n41   15  n28   18   e42
# 415       경부선2_3  n28   18  n17   20  e25r
# 416       경부선2_3  n17   20  n14   21   e16
# 417       경부선2_3  n14   21   n9   22  e12r
# 418       경부선2_3   n9   22   n7   23   e10
# 419       경부선2_3   n7   23   n1   24    e6
# 420       경부선2_3   n1   24   n4   25   e2r
# 421       경부선2_4  n79    6  n77    7  e94r
# 422       경부선2_4  n77    7  n76    8  e92r
# 423       경부선2_4  n76    8  n73    9  e90r
# 424       경부선2_4  n73    9  n70   10  e86r
# 425       경부선2_4  n70   10  n63   12  e82r
# 426       경부선2_4  n63   12  n60   13  e75r
# 427       경부선2_4  n60   13  n59   14   e72
# 428       경부선2_4  n59   14  n46   16  e66r
# 429       경부선2_4  n46   16  n41   17   e55
# 430       경부선2_4  n41   17  n28   20   e42
# 431       경부선2_4  n28   20  n17   22  e25r
# 432       경부선2_4  n17   22  n14   23   e16
# 433       경부선2_4  n14   23   n9   24  e12r
# 434       경부선2_4   n9   24   n7   25   e10
# 435       경부선2_4   n7   25   n1   26    e6
# 436       경부선2_4   n1   26   n4   27   e2r
# 437       경부선2_5  n79    8  n77    9  e94r
# 438       경부선2_5  n77    9  n76   10  e92r
# 439       경부선2_5  n76   10  n73   11  e90r
# 440       경부선2_5  n73   11  n70   12  e86r
# 441       경부선2_5  n70   12  n63   14  e82r
# 442       경부선2_5  n63   14  n60   15  e75r
# 443       경부선2_5  n60   15  n59   16   e72
# 444       경부선2_5  n59   16  n46   18  e66r
# 445       경부선2_5  n46   18  n41   19   e55
# 446       경부선2_5  n41   19  n28   22   e42
# 447       경부선2_5  n28   22  n17   24  e25r
# 448       경부선2_5  n17   24  n14   25   e16
# 449       경부선2_5  n14   25   n9   26  e12r
# 450       경부선2_5   n9   26   n7   27   e10
# 451       경부선2_5   n7   27   n1   28    e6
# 452       경부선2_5   n1   28   n4   29   e2r
# 453       경부선2_6  n79   10  n77   11  e94r
# 454       경부선2_6  n77   11  n76   12  e92r
# 455       경부선2_6  n76   12  n73   13  e90r
# 456       경부선2_6  n73   13  n70   14  e86r
# 457       경부선2_6  n70   14  n63   16  e82r
# 458       경부선2_6  n63   16  n60   17  e75r
# 459       경부선2_6  n60   17  n59   18   e72
# 460       경부선2_6  n59   18  n46   20  e66r
# 461       경부선2_6  n46   20  n41   21   e55
# 462       경부선2_6  n41   21  n28   24   e42
# 463       경부선2_6  n28   24  n17   26  e25r
# 464       경부선2_6  n17   26  n14   27   e16
# 465       경부선2_6  n14   27   n9   28  e12r
# 466       경부선2_6   n9   28   n7   29   e10
# 467       경부선2_6   n7   29   n1   30    e6
# 468       경부선2_6   n1   30   n4   31   e2r
# 469       경북선1_1  n43    0  n40    1   e53
# 470       경북선1_1  n40    1  n36    2   e47
# 471       경북선1_1  n36    2  n38    3   e45
# 472       경북선1_1  n38    3  n41    4   e49
# 473       경북선2_1  n41    0  n38    1  e49r
# 474       경북선2_1  n38    1  n36    2  e45r
# 475       경북선2_1  n36    2  n40    3  e47r
# 476       경북선2_1  n40    3  n43    4  e53r
# 477       경전선1_1  n48    0  n57    1   e65
# 478       경전선1_1  n57    1  n64    2   e74
# 479       경전선1_1  n64    2  n65    3  e79r
# 480       경전선1_1  n65    3  n62    4  e76r
# 481       경전선1_1  n62    4  n66    6  e78r
# 482       경전선1_1  n66    6  n71    8  e83r
# 483       경전선1_1  n71    8  n73   10  e87r
# 484       경전선1_2  n48    6  n57    7   e65
# 485       경전선1_2  n57    7  n64    8   e74
# 486       경전선1_2  n64    8  n65    9  e79r
# 487       경전선1_2  n65    9  n62   10  e76r
# 488       경전선1_2  n62   10  n66   12  e78r
# 489       경전선1_2  n66   12  n71   14  e83r
# 490       경전선1_2  n71   14  n73   16  e87r
# 491       경전선2_1  n73    0  n71    2   e87
# 492       경전선2_1  n71    2  n66    4   e83
# 493       경전선2_1  n66    4  n62    6   e78
# 494       경전선2_1  n62    6  n65    7   e76
# 495       경전선2_1  n65    7  n64    8   e79
# 496       경전선2_1  n64    8  n57    9  e74r
# 497       경전선2_1  n57    9  n48   10  e65r
# 498       경전선2_2  n73    6  n71    8   e87
# 499       경전선2_2  n71    8  n66   10   e83
# 500       경전선2_2  n66   10  n62   12   e78
# 501       경전선2_2  n62   12  n65   13   e76
# 502       경전선2_2  n65   13  n64   14   e79
# 503       경전선2_2  n64   14  n57   15  e74r
# 504       경전선2_2  n57   15  n48   16  e65r
# 505       동해선1_1  n55    0  n58    1   e69
# 506       동해선1_1  n58    1  n69    3   e77
# 507       동해선1_1  n69    3  n74    5   e85
# 508       동해선1_1  n74    5  n72    6   e88
# 509       동해선1_2  n55    6  n58    7   e69
# 510       동해선1_2  n58    7  n69    9   e77
# 511       동해선1_2  n69    9  n74   11   e85
# 512       동해선1_2  n74   11  n72   12   e88
# 513       동해선2_1  n72    0  n74    1  e88r
# 514       동해선2_1  n74    1  n69    3  e85r
# 515       동해선2_1  n69    3  n58    5  e77r
# 516       동해선2_1  n58    5  n55    6  e69r
# 517       동해선2_2  n72    6  n74    7  e88r
# 518       동해선2_2  n74    7  n69    9  e85r
# 519       동해선2_2  n69    9  n58   11  e77r
# 520       동해선2_2  n58   11  n55   12  e69r
# 521       영동선1_1  n51    0  n55    1   e67
# 522       영동선1_1  n55    1  n54    3   e68
# 523       영동선1_1  n54    3  n50    5   e64
# 524       영동선1_1  n50    5  n43    7   e58
# 525       영동선2_1  n43    0  n50    2  e58r
# 526       영동선2_1  n50    2  n54    4  e64r
# 527       영동선2_1  n54    4  n55    6  e68r
# 528       영동선2_1  n55    6  n51    7  e67r
# 529       장항선1_1  n14    0  n11    1   e14
# 530       장항선1_1  n11    1  n10    2   e13
# 531       장항선1_1  n10    2  n15    3   e15
# 532       장항선1_1  n15    3  n16    4   e18
# 533       장항선1_1  n16    4  n27    5   e24
# 534       장항선1_1  n27    5  n30    6  e35r
# 535       장항선1_2  n14    3  n11    4   e14
# 536       장항선1_2  n11    4  n10    5   e13
# 537       장항선1_2  n10    5  n15    6   e15
# 538       장항선1_2  n15    6  n16    7   e18
# 539       장항선1_2  n16    7  n27    8   e24
# 540       장항선1_2  n27    8  n30    9  e35r
# 541       장항선1_3  n14    6  n11    7   e14
# 542       장항선1_3  n11    7  n10    8   e13
# 543       장항선1_3  n10    8  n15    9   e15
# 544       장항선1_3  n15    9  n16   10   e18
# 545       장항선1_3  n16   10  n27   11   e24
# 546       장항선1_3  n27   11  n30   12  e35r
# 547       장항선2_1  n30    0  n27    1   e35
# 548       장항선2_1  n27    1  n16    2  e24r
# 549       장항선2_1  n16    2  n15    3  e18r
# 550       장항선2_1  n15    3  n10    4  e15r
# 551       장항선2_1  n10    4  n11    5  e13r
# 552       장항선2_1  n11    5  n14    6  e14r
# 553       장항선2_2  n30    3  n27    4   e35
# 554       장항선2_2  n27    4  n16    5  e24r
# 555       장항선2_2  n16    5  n15    6  e18r
# 556       장항선2_2  n15    6  n10    7  e15r
# 557       장항선2_2  n10    7  n11    8  e13r
# 558       장항선2_2  n11    8  n14    9  e14r
# 559       장항선2_3  n30    6  n27    7   e35
# 560       장항선2_3  n27    7  n16    8  e24r
# 561       장항선2_3  n16    8  n15    9  e18r
# 562       장항선2_3  n15    9  n10   10  e15r
# 563       장항선2_3  n10   10  n11   11  e13r
# 564       장항선2_3  n11   11  n14   12  e14r
# 565       전라선1_1  n30    0  n33    1  e39r
# 566       전라선1_1  n33    1  n45    3   e48
# 567       전라선1_1  n45    3  n47    4   e59
# 568       전라선1_1  n47    4  n56    5   e63
# 569       전라선1_1  n56    5  n62    6   e71
# 570       전라선1_1  n62    6  n68    7   e80
# 571       전라선1_2  n30    4  n33    5  e39r
# 572       전라선1_2  n33    5  n45    7   e48
# 573       전라선1_2  n45    7  n47    8   e59
# 574       전라선1_2  n47    8  n56    9   e63
# 575       전라선1_2  n56    9  n62   10   e71
# 576       전라선1_2  n62   10  n68   11   e80
# 577       전라선1_3  n30    8  n33    9  e39r
# 578       전라선1_3  n33    9  n45   11   e48
# 579       전라선1_3  n45   11  n47   12   e59
# 580       전라선1_3  n47   12  n56   13   e63
# 581       전라선1_3  n56   13  n62   14   e71
# 582       전라선1_3  n62   14  n68   15   e80
# 583       전라선2_1  n68    0  n62    1  e80r
# 584       전라선2_1  n62    1  n56    2  e71r
# 585       전라선2_1  n56    2  n47    3  e63r
# 586       전라선2_1  n47    3  n45    4  e59r
# 587       전라선2_1  n45    4  n33    6  e48r
# 588       전라선2_1  n33    6  n30    7   e39
# 589       전라선2_2  n68    4  n62    5  e80r
# 590       전라선2_2  n62    5  n56    6  e71r
# 591       전라선2_2  n56    6  n47    7  e63r
# 592       전라선2_2  n47    7  n45    8  e59r
# 593       전라선2_2  n45    8  n33   10  e48r
# 594       전라선2_2  n33   10  n30   11   e39
# 595       전라선2_3  n68    8  n62    9  e80r
# 596       전라선2_3  n62    9  n56   10  e71r
# 597       전라선2_3  n56   10  n47   11  e63r
# 598       전라선2_3  n47   11  n45   12  e59r
# 599       전라선2_3  n45   12  n33   14  e48r
# 600       전라선2_3  n33   14  n30   15   e39
# 601       중앙선1_1   n3    0   n5    1   e5r
# 602       중앙선1_1   n5    1   n6    2   e7r
# 603       중앙선1_1   n6    2   n8    3   e8r
# 604       중앙선1_1   n8    3  n12    4  e11r
# 605       중앙선1_1  n12    4  n22    6  e19r
# 606       중앙선1_1  n22    6  n29    7  e32r
# 607       중앙선1_1  n29    7  n31    8  e37r
# 608       중앙선1_1  n31    8  n35    9  e40r
# 609       중앙선1_1  n35    9  n39   10  e46r
# 610       중앙선1_1  n39   10  n43   11   e52
# 611       중앙선1_1  n43   11  n49   12   e56
# 612       중앙선1_1  n49   12  n52   13   e60
# 613       중앙선1_1  n52   13  n67   15   e73
# 614       중앙선1_1  n67   15  n72   17   e84
# 615       중앙선1_1  n72   17  n78   19   e91
# 616       중앙선1_1  n78   19  n79   21   e95
# 617       중앙선1_2   n3    2   n5    3   e5r
# 618       중앙선1_2   n5    3   n6    4   e7r
# 619       중앙선1_2   n6    4   n8    5   e8r
# 620       중앙선1_2   n8    5  n12    6  e11r
# 621       중앙선1_2  n12    6  n22    8  e19r
# 622       중앙선1_2  n22    8  n29    9  e32r
# 623       중앙선1_2  n29    9  n31   10  e37r
# 624       중앙선1_2  n31   10  n35   11  e40r
# 625       중앙선1_2  n35   11  n39   12  e46r
# 626       중앙선1_2  n39   12  n43   13   e52
# 627       중앙선1_2  n43   13  n49   14   e56
# 628       중앙선1_2  n49   14  n52   15   e60
# 629       중앙선1_2  n52   15  n67   17   e73
# 630       중앙선1_2  n67   17  n72   19   e84
# 631       중앙선1_2  n72   19  n78   21   e91
# 632       중앙선1_2  n78   21  n79   23   e95
# 633       중앙선1_3   n3    4   n5    5   e5r
# 634       중앙선1_3   n5    5   n6    6   e7r
# 635       중앙선1_3   n6    6   n8    7   e8r
# 636       중앙선1_3   n8    7  n12    8  e11r
# 637       중앙선1_3  n12    8  n22   10  e19r
# 638       중앙선1_3  n22   10  n29   11  e32r
# 639       중앙선1_3  n29   11  n31   12  e37r
# 640       중앙선1_3  n31   12  n35   13  e40r
# 641       중앙선1_3  n35   13  n39   14  e46r
# 642       중앙선1_3  n39   14  n43   15   e52
# 643       중앙선1_3  n43   15  n49   16   e56
# 644       중앙선1_3  n49   16  n52   17   e60
# 645       중앙선1_3  n52   17  n67   19   e73
# 646       중앙선1_3  n67   19  n72   21   e84
# 647       중앙선1_3  n72   21  n78   23   e91
# 648       중앙선1_3  n78   23  n79   25   e95
# 649       중앙선1_4   n3    6   n5    7   e5r
# 650       중앙선1_4   n5    7   n6    8   e7r
# 651       중앙선1_4   n6    8   n8    9   e8r
# 652       중앙선1_4   n8    9  n12   10  e11r
# 653       중앙선1_4  n12   10  n22   12  e19r
# 654       중앙선1_4  n22   12  n29   13  e32r
# 655       중앙선1_4  n29   13  n31   14  e37r
# 656       중앙선1_4  n31   14  n35   15  e40r
# 657       중앙선1_4  n35   15  n39   16  e46r
# 658       중앙선1_4  n39   16  n43   17   e52
# 659       중앙선1_4  n43   17  n49   18   e56
# 660       중앙선1_4  n49   18  n52   19   e60
# 661       중앙선1_4  n52   19  n67   21   e73
# 662       중앙선1_4  n67   21  n72   23   e84
# 663       중앙선1_4  n72   23  n78   25   e91
# 664       중앙선1_4  n78   25  n79   27   e95
# 665       중앙선1_5   n3    8   n5    9   e5r
# 666       중앙선1_5   n5    9   n6   10   e7r
# 667       중앙선1_5   n6   10   n8   11   e8r
# 668       중앙선1_5   n8   11  n12   12  e11r
# 669       중앙선1_5  n12   12  n22   14  e19r
# 670       중앙선1_5  n22   14  n29   15  e32r
# 671       중앙선1_5  n29   15  n31   16  e37r
# 672       중앙선1_5  n31   16  n35   17  e40r
# 673       중앙선1_5  n35   17  n39   18  e46r
# 674       중앙선1_5  n39   18  n43   19   e52
# 675       중앙선1_5  n43   19  n49   20   e56
# 676       중앙선1_5  n49   20  n52   21   e60
# 677       중앙선1_5  n52   21  n67   23   e73
# 678       중앙선1_5  n67   23  n72   25   e84
# 679       중앙선1_5  n72   25  n78   27   e91
# 680       중앙선1_5  n78   27  n79   29   e95
# 681       중앙선1_6   n3   10   n5   11   e5r
# 682       중앙선1_6   n5   11   n6   12   e7r
# 683       중앙선1_6   n6   12   n8   13   e8r
# 684       중앙선1_6   n8   13  n12   14  e11r
# 685       중앙선1_6  n12   14  n22   16  e19r
# 686       중앙선1_6  n22   16  n29   17  e32r
# 687       중앙선1_6  n29   17  n31   18  e37r
# 688       중앙선1_6  n31   18  n35   19  e40r
# 689       중앙선1_6  n35   19  n39   20  e46r
# 690       중앙선1_6  n39   20  n43   21   e52
# 691       중앙선1_6  n43   21  n49   22   e56
# 692       중앙선1_6  n49   22  n52   23   e60
# 693       중앙선1_6  n52   23  n67   25   e73
# 694       중앙선1_6  n67   25  n72   27   e84
# 695       중앙선1_6  n72   27  n78   29   e91
# 696       중앙선1_6  n78   29  n79   31   e95
# 697       중앙선2_1  n79    0  n78    2  e95r
# 698       중앙선2_1  n78    2  n72    4  e91r
# 699       중앙선2_1  n72    4  n67    6  e84r
# 700       중앙선2_1  n67    6  n52    8  e73r
# 701       중앙선2_1  n52    8  n49    9  e60r
# 702       중앙선2_1  n49    9  n43   10  e56r
# 703       중앙선2_1  n43   10  n39   11  e52r
# 704       중앙선2_1  n39   11  n35   12   e46
# 705       중앙선2_1  n35   12  n31   13   e40
# 706       중앙선2_1  n31   13  n29   14   e37
# 707       중앙선2_1  n29   14  n22   15   e32
# 708       중앙선2_1  n22   15  n12   17   e19
# 709       중앙선2_1  n12   17   n8   18   e11
# 710       중앙선2_1   n8   18   n6   19    e8
# 711       중앙선2_1   n6   19   n5   20    e7
# 712       중앙선2_1   n5   20   n3   21    e5
# 713       중앙선2_2  n79    2  n78    4  e95r
# 714       중앙선2_2  n78    4  n72    6  e91r
# 715       중앙선2_2  n72    6  n67    8  e84r
# 716       중앙선2_2  n67    8  n52   10  e73r
# 717       중앙선2_2  n52   10  n49   11  e60r
# 718       중앙선2_2  n49   11  n43   12  e56r
# 719       중앙선2_2  n43   12  n39   13  e52r
# 720       중앙선2_2  n39   13  n35   14   e46
# 721       중앙선2_2  n35   14  n31   15   e40
# 722       중앙선2_2  n31   15  n29   16   e37
# 723       중앙선2_2  n29   16  n22   17   e32
# 724       중앙선2_2  n22   17  n12   19   e19
# 725       중앙선2_2  n12   19   n8   20   e11
# 726       중앙선2_2   n8   20   n6   21    e8
# 727       중앙선2_2   n6   21   n5   22    e7
# 728       중앙선2_2   n5   22   n3   23    e5
# 729       중앙선2_3  n79    4  n78    6  e95r
# 730       중앙선2_3  n78    6  n72    8  e91r
# 731       중앙선2_3  n72    8  n67   10  e84r
# 732       중앙선2_3  n67   10  n52   12  e73r
# 733       중앙선2_3  n52   12  n49   13  e60r
# 734       중앙선2_3  n49   13  n43   14  e56r
# 735       중앙선2_3  n43   14  n39   15  e52r
# 736       중앙선2_3  n39   15  n35   16   e46
# 737       중앙선2_3  n35   16  n31   17   e40
# 738       중앙선2_3  n31   17  n29   18   e37
# 739       중앙선2_3  n29   18  n22   19   e32
# 740       중앙선2_3  n22   19  n12   21   e19
# 741       중앙선2_3  n12   21   n8   22   e11
# 742       중앙선2_3   n8   22   n6   23    e8
# 743       중앙선2_3   n6   23   n5   24    e7
# 744       중앙선2_3   n5   24   n3   25    e5
# 745       중앙선2_4  n79    6  n78    8  e95r
# 746       중앙선2_4  n78    8  n72   10  e91r
# 747       중앙선2_4  n72   10  n67   12  e84r
# 748       중앙선2_4  n67   12  n52   14  e73r
# 749       중앙선2_4  n52   14  n49   15  e60r
# 750       중앙선2_4  n49   15  n43   16  e56r
# 751       중앙선2_4  n43   16  n39   17  e52r
# 752       중앙선2_4  n39   17  n35   18   e46
# 753       중앙선2_4  n35   18  n31   19   e40
# 754       중앙선2_4  n31   19  n29   20   e37
# 755       중앙선2_4  n29   20  n22   21   e32
# 756       중앙선2_4  n22   21  n12   23   e19
# 757       중앙선2_4  n12   23   n8   24   e11
# 758       중앙선2_4   n8   24   n6   25    e8
# 759       중앙선2_4   n6   25   n5   26    e7
# 760       중앙선2_4   n5   26   n3   27    e5
# 761       중앙선2_5  n79    8  n78   10  e95r
# 762       중앙선2_5  n78   10  n72   12  e91r
# 763       중앙선2_5  n72   12  n67   14  e84r
# 764       중앙선2_5  n67   14  n52   16  e73r
# 765       중앙선2_5  n52   16  n49   17  e60r
# 766       중앙선2_5  n49   17  n43   18  e56r
# 767       중앙선2_5  n43   18  n39   19  e52r
# 768       중앙선2_5  n39   19  n35   20   e46
# 769       중앙선2_5  n35   20  n31   21   e40
# 770       중앙선2_5  n31   21  n29   22   e37
# 771       중앙선2_5  n29   22  n22   23   e32
# 772       중앙선2_5  n22   23  n12   25   e19
# 773       중앙선2_5  n12   25   n8   26   e11
# 774       중앙선2_5   n8   26   n6   27    e8
# 775       중앙선2_5   n6   27   n5   28    e7
# 776       중앙선2_5   n5   28   n3   29    e5
# 777       중앙선2_6  n79   10  n78   12  e95r
# 778       중앙선2_6  n78   12  n72   14  e91r
# 779       중앙선2_6  n72   14  n67   16  e84r
# 780       중앙선2_6  n67   16  n52   18  e73r
# 781       중앙선2_6  n52   18  n49   19  e60r
# 782       중앙선2_6  n49   19  n43   20  e56r
# 783       중앙선2_6  n43   20  n39   21  e52r
# 784       중앙선2_6  n39   21  n35   22   e46
# 785       중앙선2_6  n35   22  n31   23   e40
# 786       중앙선2_6  n31   23  n29   24   e37
# 787       중앙선2_6  n29   24  n22   25   e32
# 788       중앙선2_6  n22   25  n12   27   e19
# 789       중앙선2_6  n12   27   n8   28   e11
# 790       중앙선2_6   n8   28   n6   29    e8
# 791       중앙선2_6   n6   29   n5   30    e7
# 792       중앙선2_6   n5   30   n3   31    e5
# 793       충북선1_1  n29    0  n26    1   e34
# 794       충북선1_1  n26    1  n20    2   e27
# 795       충북선1_1  n20    2  n19    4   e23
# 796       충북선1_1  n19    4  n18    5   e21
# 797       충북선1_1  n18    5  n17    6   e20
# 798       충북선1_2  n29    4  n26    5   e34
# 799       충북선1_2  n26    5  n20    6   e27
# 800       충북선1_2  n20    6  n19    8   e23
# 801       충북선1_2  n19    8  n18    9   e21
# 802       충북선1_2  n18    9  n17   10   e20
# 803       충북선1_3  n29    8  n26    9   e34
# 804       충북선1_3  n26    9  n20   10   e27
# 805       충북선1_3  n20   10  n19   12   e23
# 806       충북선1_3  n19   12  n18   13   e21
# 807       충북선1_3  n18   13  n17   14   e20
# 808       충북선2_1  n17    0  n18    1  e20r
# 809       충북선2_1  n18    1  n19    2  e21r
# 810       충북선2_1  n19    2  n20    4  e23r
# 811       충북선2_1  n20    4  n26    5  e27r
# 812       충북선2_1  n26    5  n29    6  e34r
# 813       충북선2_2  n17    4  n18    5  e20r
# 814       충북선2_2  n18    5  n19    6  e21r
# 815       충북선2_2  n19    6  n20    8  e23r
# 816       충북선2_2  n20    8  n26    9  e27r
# 817       충북선2_2  n26    9  n29   10  e34r
# 818       충북선2_3  n17    8  n18    9  e20r
# 819       충북선2_3  n18    9  n19   10  e21r
# 820       충북선2_3  n19   10  n20   12  e23r
# 821       충북선2_3  n20   12  n26   13  e27r
# 822       충북선2_3  n26   13  n29   14  e34r
# 823    호남고속철도1_1   n3    0   n1    1    e3
# 824    호남고속철도1_1   n1    1   n2    2    e1
# 825    호남고속철도1_1   n2    2  n13    4   e9r
# 826    호남고속철도1_1  n13    4  n18    5  e17r
# 827    호남고속철도1_1  n18    5  n21    7   e22
# 828    호남고속철도1_1  n21    7  n30    9   e30
# 829    호남고속철도1_1  n30    9  n37   11   e41
# 830    호남고속철도1_1  n37   11  n48   13   e54
# 831    호남고속철도1_2   n3    2   n1    3    e3
# 832    호남고속철도1_2   n1    3   n2    4    e1
# 833    호남고속철도1_2   n2    4  n13    6   e9r
# 834    호남고속철도1_2  n13    6  n18    7  e17r
# 835    호남고속철도1_2  n18    7  n21    9   e22
# 836    호남고속철도1_2  n21    9  n30   11   e30
# 837    호남고속철도1_2  n30   11  n37   13   e41
# 838    호남고속철도1_2  n37   13  n48   15   e54
# 839    호남고속철도1_3   n3    4   n1    5    e3
# 840    호남고속철도1_3   n1    5   n2    6    e1
# 841    호남고속철도1_3   n2    6  n13    8   e9r
# 842    호남고속철도1_3  n13    8  n18    9  e17r
# 843    호남고속철도1_3  n18    9  n21   11   e22
# 844    호남고속철도1_3  n21   11  n30   13   e30
# 845    호남고속철도1_3  n30   13  n37   15   e41
# 846    호남고속철도1_3  n37   15  n48   17   e54
# 847    호남고속철도1_4   n3    6   n1    7    e3
# 848    호남고속철도1_4   n1    7   n2    8    e1
# 849    호남고속철도1_4   n2    8  n13   10   e9r
# 850    호남고속철도1_4  n13   10  n18   11  e17r
# 851    호남고속철도1_4  n18   11  n21   13   e22
# 852    호남고속철도1_4  n21   13  n30   15   e30
# 853    호남고속철도1_4  n30   15  n37   17   e41
# 854    호남고속철도1_4  n37   17  n48   19   e54
# 855    호남고속철도1_5   n3    8   n1    9    e3
# 856    호남고속철도1_5   n1    9   n2   10    e1
# 857    호남고속철도1_5   n2   10  n13   12   e9r
# 858    호남고속철도1_5  n13   12  n18   13  e17r
# 859    호남고속철도1_5  n18   13  n21   15   e22
# 860    호남고속철도1_5  n21   15  n30   17   e30
# 861    호남고속철도1_5  n30   17  n37   19   e41
# 862    호남고속철도1_5  n37   19  n48   21   e54
# 863    호남고속철도1_6   n3   10   n1   11    e3
# 864    호남고속철도1_6   n1   11   n2   12    e1
# 865    호남고속철도1_6   n2   12  n13   14   e9r
# 866    호남고속철도1_6  n13   14  n18   15  e17r
# 867    호남고속철도1_6  n18   15  n21   17   e22
# 868    호남고속철도1_6  n21   17  n30   19   e30
# 869    호남고속철도1_6  n30   19  n37   21   e41
# 870    호남고속철도1_6  n37   21  n48   23   e54
# 871    호남고속철도2_1  n48    0  n37    2  e54r
# 872    호남고속철도2_1  n37    2  n30    4  e41r
# 873    호남고속철도2_1  n30    4  n21    6  e30r
# 874    호남고속철도2_1  n21    6  n18    8  e22r
# 875    호남고속철도2_1  n18    8  n13    9   e17
# 876    호남고속철도2_1  n13    9   n2   11    e9
# 877    호남고속철도2_1   n2   11   n1   12   e1r
# 878    호남고속철도2_1   n1   12   n3   13   e3r
# 879    호남고속철도2_2  n48    2  n37    4  e54r
# 880    호남고속철도2_2  n37    4  n30    6  e41r
# 881    호남고속철도2_2  n30    6  n21    8  e30r
# 882    호남고속철도2_2  n21    8  n18   10  e22r
# 883    호남고속철도2_2  n18   10  n13   11   e17
# 884    호남고속철도2_2  n13   11   n2   13    e9
# 885    호남고속철도2_2   n2   13   n1   14   e1r
# 886    호남고속철도2_2   n1   14   n3   15   e3r
# 887    호남고속철도2_3  n48    4  n37    6  e54r
# 888    호남고속철도2_3  n37    6  n30    8  e41r
# 889    호남고속철도2_3  n30    8  n21   10  e30r
# 890    호남고속철도2_3  n21   10  n18   12  e22r
# 891    호남고속철도2_3  n18   12  n13   13   e17
# 892    호남고속철도2_3  n13   13   n2   15    e9
# 893    호남고속철도2_3   n2   15   n1   16   e1r
# 894    호남고속철도2_3   n1   16   n3   17   e3r
# 895    호남고속철도2_4  n48    6  n37    8  e54r
# 896    호남고속철도2_4  n37    8  n30   10  e41r
# 897    호남고속철도2_4  n30   10  n21   12  e30r
# 898    호남고속철도2_4  n21   12  n18   14  e22r
# 899    호남고속철도2_4  n18   14  n13   15   e17
# 900    호남고속철도2_4  n13   15   n2   17    e9
# 901    호남고속철도2_4   n2   17   n1   18   e1r
# 902    호남고속철도2_4   n1   18   n3   19   e3r
# 903    호남고속철도2_5  n48    8  n37   10  e54r
# 904    호남고속철도2_5  n37   10  n30   12  e41r
# 905    호남고속철도2_5  n30   12  n21   14  e30r
# 906    호남고속철도2_5  n21   14  n18   16  e22r
# 907    호남고속철도2_5  n18   16  n13   17   e17
# 908    호남고속철도2_5  n13   17   n2   19    e9
# 909    호남고속철도2_5   n2   19   n1   20   e1r
# 910    호남고속철도2_5   n1   20   n3   21   e3r
# 911    호남고속철도2_6  n48   10  n37   12  e54r
# 912    호남고속철도2_6  n37   12  n30   14  e41r
# 913    호남고속철도2_6  n30   14  n21   16  e30r
# 914    호남고속철도2_6  n21   16  n18   18  e22r
# 915    호남고속철도2_6  n18   18  n13   19   e17
# 916    호남고속철도2_6  n13   19   n2   21    e9
# 917    호남고속철도2_6   n2   21   n1   22   e1r
# 918    호남고속철도2_6   n1   22   n3   23   e3r
# 919       호남선1_1  n28    0  n25    1   e31
# 920       호남선1_1  n25    1  n24    2   e29
# 921       호남선1_1  n24    2  n30    3   e33
# 922       호남선1_1  n30    3  n32    4   e38
# 923       호남선1_1  n32    4  n37    5   e44
# 924       호남선1_1  n37    5  n44    6   e50
# 925       호남선1_1  n44    6  n48    7   e57
# 926       호남선1_1  n48    7  n53    8   e62
# 927       호남선1_1  n53    8  n61   10   e70
# 928       호남선1_2  n28    2  n25    3   e31
# 929       호남선1_2  n25    3  n24    4   e29
# 930       호남선1_2  n24    4  n30    5   e33
# 931       호남선1_2  n30    5  n32    6   e38
# 932       호남선1_2  n32    6  n37    7   e44
# 933       호남선1_2  n37    7  n44    8   e50
# 934       호남선1_2  n44    8  n48    9   e57
# 935       호남선1_2  n48    9  n53   10   e62
# 936       호남선1_2  n53   10  n61   12   e70
# 937       호남선1_3  n28    4  n25    5   e31
# 938       호남선1_3  n25    5  n24    6   e29
# 939       호남선1_3  n24    6  n30    7   e33
# 940       호남선1_3  n30    7  n32    8   e38
# 941       호남선1_3  n32    8  n37    9   e44
# 942       호남선1_3  n37    9  n44   10   e50
# 943       호남선1_3  n44   10  n48   11   e57
# 944       호남선1_3  n48   11  n53   12   e62
# 945       호남선1_3  n53   12  n61   14   e70
# 946       호남선1_4  n28    6  n25    7   e31
# 947       호남선1_4  n25    7  n24    8   e29
# 948       호남선1_4  n24    8  n30    9   e33
# 949       호남선1_4  n30    9  n32   10   e38
# 950       호남선1_4  n32   10  n37   11   e44
# 951       호남선1_4  n37   11  n44   12   e50
# 952       호남선1_4  n44   12  n48   13   e57
# 953       호남선1_4  n48   13  n53   14   e62
# 954       호남선1_4  n53   14  n61   16   e70
# 955       호남선1_5  n28    8  n25    9   e31
# 956       호남선1_5  n25    9  n24   10   e29
# 957       호남선1_5  n24   10  n30   11   e33
# 958       호남선1_5  n30   11  n32   12   e38
# 959       호남선1_5  n32   12  n37   13   e44
# 960       호남선1_5  n37   13  n44   14   e50
# 961       호남선1_5  n44   14  n48   15   e57
# 962       호남선1_5  n48   15  n53   16   e62
# 963       호남선1_5  n53   16  n61   18   e70
# 964       호남선1_6  n28   10  n25   11   e31
# 965       호남선1_6  n25   11  n24   12   e29
# 966       호남선1_6  n24   12  n30   13   e33
# 967       호남선1_6  n30   13  n32   14   e38
# 968       호남선1_6  n32   14  n37   15   e44
# 969       호남선1_6  n37   15  n44   16   e50
# 970       호남선1_6  n44   16  n48   17   e57
# 971       호남선1_6  n48   17  n53   18   e62
# 972       호남선1_6  n53   18  n61   20   e70
# 973       호남선2_1  n61    0  n53    2  e70r
# 974       호남선2_1  n53    2  n48    3  e62r
# 975       호남선2_1  n48    3  n44    4  e57r
# 976       호남선2_1  n44    4  n37    5  e50r
# 977       호남선2_1  n37    5  n32    6  e44r
# 978       호남선2_1  n32    6  n30    7  e38r
# 979       호남선2_1  n30    7  n24    8  e33r
# 980       호남선2_1  n24    8  n25    9  e29r
# 981       호남선2_1  n25    9  n28   10  e31r
# 982       호남선2_2  n61    2  n53    4  e70r
# 983       호남선2_2  n53    4  n48    5  e62r
# 984       호남선2_2  n48    5  n44    6  e57r
# 985       호남선2_2  n44    6  n37    7  e50r
# 986       호남선2_2  n37    7  n32    8  e44r
# 987       호남선2_2  n32    8  n30    9  e38r
# 988       호남선2_2  n30    9  n24   10  e33r
# 989       호남선2_2  n24   10  n25   11  e29r
# 990       호남선2_2  n25   11  n28   12  e31r
# 991       호남선2_3  n61    4  n53    6  e70r
# 992       호남선2_3  n53    6  n48    7  e62r
# 993       호남선2_3  n48    7  n44    8  e57r
# 994       호남선2_3  n44    8  n37    9  e50r
# 995       호남선2_3  n37    9  n32   10  e44r
# 996       호남선2_3  n32   10  n30   11  e38r
# 997       호남선2_3  n30   11  n24   12  e33r
# 998       호남선2_3  n24   12  n25   13  e29r
# 999       호남선2_3  n25   13  n28   14  e31r
# 1000      호남선2_4  n61    6  n53    8  e70r
# 1001      호남선2_4  n53    8  n48    9  e62r
# 1002      호남선2_4  n48    9  n44   10  e57r
# 1003      호남선2_4  n44   10  n37   11  e50r
# 1004      호남선2_4  n37   11  n32   12  e44r
# 1005      호남선2_4  n32   12  n30   13  e38r
# 1006      호남선2_4  n30   13  n24   14  e33r
# 1007      호남선2_4  n24   14  n25   15  e29r
# 1008      호남선2_4  n25   15  n28   16  e31r
# 1009      호남선2_5  n61    8  n53   10  e70r
# 1010      호남선2_5  n53   10  n48   11  e62r
# 1011      호남선2_5  n48   11  n44   12  e57r
# 1012      호남선2_5  n44   12  n37   13  e50r
# 1013      호남선2_5  n37   13  n32   14  e44r
# 1014      호남선2_5  n32   14  n30   15  e38r
# 1015      호남선2_5  n30   15  n24   16  e33r
# 1016      호남선2_5  n24   16  n25   17  e29r
# 1017      호남선2_5  n25   17  n28   18  e31r
# 1018      호남선2_6  n61   10  n53   12  e70r
# 1019      호남선2_6  n53   12  n48   13  e62r
# 1020      호남선2_6  n48   13  n44   14  e57r
# 1021      호남선2_6  n44   14  n37   15  e50r
# 1022      호남선2_6  n37   15  n32   16  e44r
# 1023      호남선2_6  n32   16  n30   17  e38r
# 1024      호남선2_6  n30   17  n24   18  e33r
# 1025      호남선2_6  n24   18  n25   19  e29r
# 1026      호남선2_6  n25   19  n28   20  e31r
# 1027   KTX강릉선1_1  n51    0  n34    2   e51
# 1028   KTX강릉선1_1  n34    2  n23    3   e36
# 1029   KTX강릉선1_1  n23    3  n22    4   e28
# 1030   KTX강릉선1_2  n51    6  n34    8   e51
# 1031   KTX강릉선1_2  n34    8  n23    9   e36
# 1032   KTX강릉선1_2  n23    9  n22   10   e28
# 1033   KTX강릉선2_1  n22    0  n23    1  e28r
# 1034   KTX강릉선2_1  n23    1  n34    2  e36r
# 1035   KTX강릉선2_1  n34    2  n51    4  e51r
# 1036   KTX강릉선2_2  n22    6  n23    7  e28r
# 1037   KTX강릉선2_2  n23    7  n34    8  e36r
# 1038   KTX강릉선2_2  n34    8  n51   10  e51r
# === Train status summary — horizon-aware (T-based) ===
#           Train  Departed  ArrivedInHorizon PlannedTerminal ActualTerminal  \
# 0     경부고속철도1_1      True              True             n79            n79
# 1     경부고속철도1_2      True              True             n79            n79
# 2     경부고속철도1_3      True              True             n79            n79
# 3     경부고속철도1_4      True              True             n79            n79
# 4     경부고속철도1_5      True              True             n79            n79
# 5     경부고속철도1_6      True              True             n79            n79
# 6     경부고속철도1_7      True              True             n79            n79
# 7     경부고속철도1_8      True              True             n79            n79
# 8     경부고속철도1_9      True              True             n79            n79
# 9    경부고속철도1_10      True              True             n79            n79
# 10   경부고속철도1_11      True              True             n79            n79
# 11   경부고속철도1_12      True              True             n79            n79
# 12    경부고속철도2_1      True              True              n4             n4
# 13    경부고속철도2_2      True              True              n4             n4
# 14    경부고속철도2_3      True              True              n4             n4
# 15    경부고속철도2_4      True              True              n4             n4
# 16    경부고속철도2_5      True              True              n4             n4
# 17    경부고속철도2_6      True              True              n4             n4
# 18    경부고속철도2_7      True              True              n4             n4
# 19    경부고속철도2_8      True              True              n4             n4
# 20    경부고속철도2_9      True              True              n4             n4
# 21   경부고속철도2_10      True              True              n4             n4
# 22   경부고속철도2_11      True              True              n4             n4
# 23       경부선1_1      True              True             n79            n79
# 24       경부선1_2      True              True             n79            n79
# 25       경부선1_3      True              True             n79            n79
# 26       경부선1_4      True              True             n79            n79
# 27       경부선1_5      True              True             n79            n79
# 28       경부선1_6      True              True             n79            n79
# 29       경부선2_1      True              True              n4             n4
# 30       경부선2_2      True              True              n4             n4
# 31       경부선2_3      True              True              n4             n4
# 32       경부선2_4      True              True              n4             n4
# 33       경부선2_5      True              True              n4             n4
# 34       경부선2_6      True              True              n4             n4
# 35       경북선1_1      True              True             n41            n41
# 36       경북선2_1      True              True             n43            n43
# 37       경전선1_1      True              True             n73            n73
# 38       경전선1_2      True              True             n73            n73
# 39       경전선2_1      True              True             n48            n48
# 40       경전선2_2      True              True             n48            n48
# 41       동해선1_1      True              True             n72            n72
# 42       동해선1_2      True              True             n72            n72
# 43       동해선2_1      True              True             n55            n55
# 44       동해선2_2      True              True             n55            n55
# 45       영동선1_1      True              True             n43            n43
# 46       영동선2_1      True              True             n51            n51
# 47       장항선1_1      True              True             n30            n30
# 48       장항선1_2      True              True             n30            n30
# 49       장항선1_3      True              True             n30            n30
# 50       장항선2_1      True              True             n14            n14
# 51       장항선2_2      True              True             n14            n14
# 52       장항선2_3      True              True             n14            n14
# 53       전라선1_1      True              True             n68            n68
# 54       전라선1_2      True              True             n68            n68
# 55       전라선1_3      True              True             n68            n68
# 56       전라선2_1      True              True             n30            n30
# 57       전라선2_2      True              True             n30            n30
# 58       전라선2_3      True              True             n30            n30
# 59       중앙선1_1      True              True             n79            n79
# 60       중앙선1_2      True              True             n79            n79
# 61       중앙선1_3      True              True             n79            n79
# 62       중앙선1_4      True              True             n79            n79
# 63       중앙선1_5      True              True             n79            n79
# 64       중앙선1_6      True              True             n79            n79
# 65       중앙선2_1      True              True              n3             n3
# 66       중앙선2_2      True              True              n3             n3
# 67       중앙선2_3      True              True              n3             n3
# 68       중앙선2_4      True              True              n3             n3
# 69       중앙선2_5      True              True              n3             n3
# 70       중앙선2_6      True              True              n3             n3
# 71       충북선1_1      True              True             n17            n17
# 72       충북선1_2      True              True             n17            n17
# 73       충북선1_3      True              True             n17            n17
# 74       충북선2_1      True              True             n29            n29
# 75       충북선2_2      True              True             n29            n29
# 76       충북선2_3      True              True             n29            n29
# 77    호남고속철도1_1      True              True             n48            n48
# 78    호남고속철도1_2      True              True             n48            n48
# 79    호남고속철도1_3      True              True             n48            n48
# 80    호남고속철도1_4      True              True             n48            n48
# 81    호남고속철도1_5      True              True             n48            n48
# 82    호남고속철도1_6      True              True             n48            n48
# 83    호남고속철도2_1      True              True              n3             n3
# 84    호남고속철도2_2      True              True              n3             n3
# 85    호남고속철도2_3      True              True              n3             n3
# 86    호남고속철도2_4      True              True              n3             n3
# 87    호남고속철도2_5      True              True              n3             n3
# 88    호남고속철도2_6      True              True              n3             n3
# 89       호남선1_1      True              True             n61            n61
# 90       호남선1_2      True              True             n61            n61
# 91       호남선1_3      True              True             n61            n61
# 92       호남선1_4      True              True             n61            n61
# 93       호남선1_5      True              True             n61            n61
# 94       호남선1_6      True              True             n61            n61
# 95       호남선2_1      True              True             n28            n28
# 96       호남선2_2      True              True             n28            n28
# 97       호남선2_3      True              True             n28            n28
# 98       호남선2_4      True              True             n28            n28
# 99       호남선2_5      True              True             n28            n28
# 100      호남선2_6      True              True             n28            n28
# 101   KTX강릉선1_1      True              True             n22            n22
# 102   KTX강릉선1_2      True              True             n22            n22
# 103   KTX강릉선2_1      True              True             n51            n51
# 104   KTX강릉선2_2      True              True             n51            n51
#
#      Delay(min)  HorizonDelay(min)  Truncated  Rerouted              Status
# 0             3                  3      False      True            Rerouted
# 1             3                  3      False      True            Rerouted
# 2             3                  3      False      True            Rerouted
# 3             3                  3      False      True            Rerouted
# 4             3                  3      False      True            Rerouted
# 5             3                  3      False      True            Rerouted
# 6             3                  3      False      True            Rerouted
# 7             3                  3      False      True            Rerouted
# 8             3                  3      False      True            Rerouted
# 9             3                  3      False      True            Rerouted
# 10            3                  3      False      True            Rerouted
# 11            3                  3      False      True            Rerouted
# 12            0                  0      False     False  On-time & complete
# 13            0                  0      False     False  On-time & complete
# 14            0                  0      False     False  On-time & complete
# 15            0                  0      False     False  On-time & complete
# 16            0                  0      False     False  On-time & complete
# 17            0                  0      False     False  On-time & complete
# 18            0                  0      False     False  On-time & complete
# 19            0                  0      False     False  On-time & complete
# 20            0                  0      False     False  On-time & complete
# 21            0                  0      False     False  On-time & complete
# 22            0                  0      False     False  On-time & complete
# 23            0                  0      False     False  On-time & complete
# 24            0                  0      False     False  On-time & complete
# 25            0                  0      False     False  On-time & complete
# 26            0                  0      False     False  On-time & complete
# 27            0                  0      False     False  On-time & complete
# 28            0                  0      False     False  On-time & complete
# 29            0                  0      False     False  On-time & complete
# 30            0                  0      False     False  On-time & complete
# 31            0                  0      False     False  On-time & complete
# 32            0                  0      False     False  On-time & complete
# 33            0                  0      False     False  On-time & complete
# 34            0                  0      False     False  On-time & complete
# 35            0                  0      False     False  On-time & complete
# 36            0                  0      False     False  On-time & complete
# 37            0                  0      False     False  On-time & complete
# 38            0                  0      False     False  On-time & complete
# 39            0                  0      False     False  On-time & complete
# 40            0                  0      False     False  On-time & complete
# 41            0                  0      False     False  On-time & complete
# 42            0                  0      False     False  On-time & complete
# 43            0                  0      False     False  On-time & complete
# 44            0                  0      False     False  On-time & complete
# 45            0                  0      False     False  On-time & complete
# 46            0                  0      False     False  On-time & complete
# 47            0                  0      False     False  On-time & complete
# 48            0                  0      False     False  On-time & complete
# 49            0                  0      False     False  On-time & complete
# 50            0                  0      False     False  On-time & complete
# 51            0                  0      False     False  On-time & complete
# 52            0                  0      False     False  On-time & complete
# 53            0                  0      False     False  On-time & complete
# 54            0                  0      False     False  On-time & complete
# 55            0                  0      False     False  On-time & complete
# 56            0                  0      False     False  On-time & complete
# 57            0                  0      False     False  On-time & complete
# 58            0                  0      False     False  On-time & complete
# 59            0                  0      False     False  On-time & complete
# 60            0                  0      False     False  On-time & complete
# 61            0                  0      False     False  On-time & complete
# 62            0                  0      False     False  On-time & complete
# 63            0                  0      False     False  On-time & complete
# 64            0                  0      False     False  On-time & complete
# 65            0                  0      False     False  On-time & complete
# 66            0                  0      False     False  On-time & complete
# 67            0                  0      False     False  On-time & complete
# 68            0                  0      False     False  On-time & complete
# 69            0                  0      False     False  On-time & complete
# 70            0                  0      False     False  On-time & complete
# 71            0                  0      False     False  On-time & complete
# 72            0                  0      False     False  On-time & complete
# 73            0                  0      False     False  On-time & complete
# 74            0                  0      False     False  On-time & complete
# 75            0                  0      False     False  On-time & complete
# 76            0                  0      False     False  On-time & complete
# 77            0                  0      False     False  On-time & complete
# 78            0                  0      False     False  On-time & complete
# 79            0                  0      False     False  On-time & complete
# 80            0                  0      False     False  On-time & complete
# 81            0                  0      False     False  On-time & complete
# 82            0                  0      False     False  On-time & complete
# 83            0                  0      False     False  On-time & complete
# 84            0                  0      False     False  On-time & complete
# 85            0                  0      False     False  On-time & complete
# 86            0                  0      False     False  On-time & complete
# 87            0                  0      False     False  On-time & complete
# 88            0                  0      False     False  On-time & complete
# 89            0                  0      False     False  On-time & complete
# 90            0                  0      False     False  On-time & complete
# 91            0                  0      False     False  On-time & complete
# 92            0                  0      False     False  On-time & complete
# 93            0                  0      False     False  On-time & complete
# 94            0                  0      False     False  On-time & complete
# 95            0                  0      False     False  On-time & complete
# 96            0                  0      False     False  On-time & complete
# 97            0                  0      False     False  On-time & complete
# 98            0                  0      False     False  On-time & complete
# 99            0                  0      False     False  On-time & complete
# 100           0                  0      False     False  On-time & complete
# 101           0                  0      False     False  On-time & complete
# 102           0                  0      False     False  On-time & complete
# 103           0                  0      False     False  On-time & complete
# 104           0                  0      False     False  On-time & complete

# %%
# ============================================================
# timestep_flow_plot.py
# ----------------------
# (1) Gurobi 결과에서 시점별 edge-flow 계산
# (2) QGIS에서 export한 엑셀·JSON으로 좌표·수요 읽기
# (3) contextily + networkx 로 지도 시각화
#     - 엣지가 edge_fp에 존재하면 흐름이 0이어도 "무조건" 그린다
#     - demand에 없거나 흐름이 없는 것은 0으로 처리한다
#     - 컬러 스케일은 0부터 시작
# ============================================================

import json, math, itertools, contextily as ctx
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
import networkx as nx
import numpy as np
import pandas as pd
import geopandas as gpd
from pathlib import Path
from shapely import wkt
from collections import defaultdict

# ============================================================
# 0. 사용자 설정
# ============================================================
BASE      = Path(r"D:\MINJI\NETWORK RELIABILITY\QGIS\7.Korea_Full\json")
xlsx_fp   = BASE / "qgis_export.xlsx"              # QGIS export 엑셀
edge_fp   = BASE / "edges.json"                    # 네트워크 엣지
json_fp   = BASE / r"json\demand_fig.json"         # (선택) 기타 참고 JSON
flow_type = "trains"    # "trains" (열차 수) / "pax" (승객수 합)
t_focus    = 12        # 시점
cumulative = True       # True: t<=t_focus 누적 / False: t 구간 내만

# ============================================================
# 1. (필요 시) Gurobi 결과 로딩 안내
#    - 이 스크립트는 x_val, arc_list, trains, demand 변수가
#      메모리에 있다고 가정. 없으면 아래처럼 불러오도록 구현하세요.
# ============================================================
# 예) pickle로 저장해두었다면:
# import pickle
# with open("result_vars.pkl", "rb") as f:
#     data = pickle.load(f)
# x_val   = data["x_val"]     # {(arcIdx, trainIdx): 0/1}
# arc_list= data["arc_list"]  # [(from^t, to^t', eid, tau, t0, t1), ...]
# trains  = data["trains"]    # ["T1","T2",...]
# demand  = data["demand"]    # {"T1":[(o,d,q),...], ...}

# ============================================================
# 2. split_node_time 유틸
# ============================================================
def split_node_time(s):
    """
    "n123^7"  → ("n123", 7)
    "n123"    → ("n123", None)
    123       → ("n123", None)
    "SINK"    → ("SINK", None)
    """
    if isinstance(s, (int, np.integer)):
        return f"n{int(s)}", None
    s = str(s)
    if "^" in s:
        node, t = s.split("^", 1)
        return node, int(t)
    if s.isdigit():
        return f"n{int(s)}", None
    return s, None

# ============================================================
# 3. edge_fp 로드 (엣지 목록: 존재하면 0이라도 그릴 기준)
# ============================================================
with open(edge_fp, encoding="utf-8") as f:
    edges_raw = json.load(f)  # {eid: [src, dst, tau], ...}
edges = {eid: (src, dst, int(tau)) for eid, (src, dst, tau) in edges_raw.items()}

# (NEW) 실패 엣지의 (u,v) 쌍 만들기 — edges.json의 src/dst는 "n123" 형식이라 G의 노드와 일치
failed_pairs = {(s, d) for eid, (s, d, _) in edges.items() if eid in failed_edges}


# ============================================================
# 4. Gurobi 결과로부터 시점별 flow 집계
#    - x_val에서 1로 선택된 arc만 집계
#    - flow_type=="trains" → 1열차당 +1
#    - flow_type=="pax"    → 그 열차의 총 승객수 q_tot를 더함
#    - 시간필터: cumulative / non-cumulative
# ============================================================
edge_flow_t = defaultdict(float)  # (u,v) -> flow

for (idx, ti), val in x_val.items():
    if val < 0.5:
        continue
    fr_str, to_str, eid = arc_list[idx][:3]
    if eid.startswith(("w_", "dummy")):
        continue

    u_raw, t_dep = split_node_time(fr_str)
    v_raw, t_arr = split_node_time(to_str)
    if t_dep is None or t_arr is None:
        continue

    cond = (t_dep <= t_focus) if cumulative else (t_dep <= t_focus < t_arr)
    if not cond:
        continue

    if flow_type == "trains":
        edge_flow_t[(u_raw, v_raw)] += 1.0
    else:
        tr_name = trains[ti]
        q_tot   = sum(q for _, _, q in demand[tr_name]) if demand.get(tr_name) else 0.0
        edge_flow_t[(u_raw, v_raw)] += float(q_tot)

# ============================================================
# 5. QGIS Export: 노드·엣지 좌표 읽기
# ============================================================
node_df = pd.read_excel(xlsx_fp, sheet_name="NODE", usecols=["node_id", "geometry"])
edge_df = pd.read_excel(xlsx_fp, sheet_name="EDGE",
                        usecols=["edge_id", "from_node_id", "to_node_id", "geometry"])

node_gdf = gpd.GeoDataFrame(
    node_df.assign(geometry=node_df["geometry"].apply(wkt.loads)),
    geometry="geometry", crs="EPSG:4326"
).to_crs(epsg=3857)

edge_gdf = gpd.GeoDataFrame(
    edge_df.assign(geometry=edge_df["geometry"].apply(wkt.loads)),
    geometry="geometry", crs="EPSG:4326"
).to_crs(epsg=3857)

# 5-A. 노드 좌표 dict
pos = {f"n{int(r.node_id)}": (r.geometry.x, r.geometry.y)
       for r in node_gdf.itertuples(index=False)}

# 5-B. 엣지 (u,v) 쌍 및 양방향 처리 (edge_fp의 존재 기준으로 모두 그림)
edges_bidir = {}
for r in edge_gdf.itertuples(index=False):
    u = f"n{int(r.from_node_id)}"
    v = f"n{int(r.to_node_id)}"
    edges_bidir[(u, v)] = r.geometry

# 반대방향이 없으면 동일 geometry로 보강
for (u, v), geom in list(edges_bidir.items()):
    if (v, u) not in edges_bidir:
        edges_bidir[(v, u)] = geom

# ============================================================
# 6. edge_flow_t에 없는 엣지도 0으로 채워 넣기(누락 방지)
# ============================================================
for (u, v) in edges_bidir.keys():
    if (u, v) not in edge_flow_t:
        edge_flow_t[(u, v)] = 0.0

# ============================================================
# 7. NetworkX 그래프 생성 (모든 엣지를 추가; 0이면 얇고 회색)
# ============================================================
G = nx.DiGraph()
for n, xy in pos.items():
    G.add_node(n, pos=xy)

for (u, v), geom in edges_bidir.items():
    flow = float(edge_flow_t.get((u, v), 0.0))
    G.add_edge(u, v, weight=flow, geom=geom)  # 무조건 추가

# ============================================================
# 8. 색상 매핑 (log 스케일, 0부터)
# ============================================================
flows = [d["weight"] for _, _, d in G.edges(data=True)]
logf  = [math.log10(max(0.0, f) + 1.0) for f in flows]  # f=0 -> 0
vmax  = max(logf) if logf else 1.0
if vmax <= 0:
    vmax = 1.0
norm  = mpl.colors.Normalize(vmin=0.0, vmax=vmax)
cmap  = sns.color_palette("viridis", as_cmap=True)

# ============================================================
# 9. 시각화
# ============================================================
fig, ax = plt.subplots(figsize=(10, 10))
ax.set_facecolor("white")

# 9-A. 지도 범위 & 배경
if pos:
    xs, ys = zip(*pos.values())
    ax.set_xlim(min(xs), max(xs))
    ax.set_ylim(min(ys), max(ys))
ctx.add_basemap(ax, crs="EPSG:3857", source=ctx.providers.CartoDB.Positron, alpha=0.7)

# 9-B. 엣지 그리기 — 일반 먼저, 실패(red) 나중에 가장 위로
# 9-B-1) 일반 엣지 먼저
for (u, v, data) in G.edges(data=True):
    if (u, v) in failed_pairs:
        continue
    f  = float(data["weight"])
    lf = math.log10(f + 1.0)
    color = cmap(norm(lf))
    nx.draw_networkx_edges(
        G, pos, edgelist=[(u, v)],
        width=2.8, edge_color=[color],
        arrowstyle="-|>", arrowsize=9,
        connectionstyle="arc3,rad=0.07", ax=ax
    )

# 9-C) 노드 (원하는 경우 노드는 실패엣지 아래/위 결정)
nx.draw_networkx_nodes(G, pos, node_size=18, node_color="black", ax=ax)

# 9-B-2) 실패 엣지 마지막(빨강) → 최상단
for (u, v, data) in G.edges(data=True):
    if (u, v) not in failed_pairs:
        continue
    nx.draw_networkx_edges(
        G, pos, edgelist=[(u, v)],
        width=3.4, edge_color=[(0.9, 0.0, 0.1, 1.0)],  # 빨강
        arrowstyle="-|>", arrowsize=9,
        connectionstyle="arc3,rad=0.07", ax=ax
    )



# 9-D. 컬러바(양의 흐름이 있는 경우만 의미 있음)
if any(f > 0.0 for f in flows):
    sm = mpl.cm.ScalarMappable(cmap=cmap, norm=norm); sm.set_array([])
    cbar = fig.colorbar(sm, ax=ax, fraction=0.046, pad=0.04)
    label = "Trains" if flow_type == "trains" else "Passengers"
    cbar.set_label(f"Flow at t={t_focus} ({label}, log scale)")

ax.set_title(f"Flow distribution at timestep t={t_focus}", fontsize=15)
ax.axis("off")
plt.tight_layout()
plt.show()
