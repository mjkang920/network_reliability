# %%
import json, os, itertools
from collections import defaultdict
import gurobipy as gp
import pandas as pd
import numpy as np

BASE_DIR = r"D:\MINJI\NETWORK RELIABILITY\QGIS\7.Korea_Full\json"   

# edge_fp만 다른 하위 폴더 사용
edge_fp   = r"D:\MINJI\NETWORK RELIABILITY\QGIS\7.Korea_Full\json\5 min\edges.json"

route_fp  = os.path.join(BASE_DIR, "routes_nodes.json")
demand_fp = os.path.join(BASE_DIR, "demand_full.json")
dept_fp   = os.path.join(BASE_DIR, "dep_time.json")

# %%
# 0-b. 고정 파라미터
T        = 96
max_wait = 0
CAPACITY = 30
failed_edges = {"e43", "e43r"} # set(), {"e81"}
w1, w2, w3 = 1000, 1000, 10
BIG_M = 10**6
SINK  = "SINK"
W_ROUTE = 100

# 0-c. JSON 로드
with open(edge_fp, encoding="utf-8") as f:
    edges_raw = json.load(f)
edges = {eid: (src, dst, int(tau)) for eid, (src, dst, tau) in edges_raw.items()}

with open(route_fp, encoding="utf-8") as f:
    routes_nodes = json.load(f)

with open(dept_fp, encoding="utf-8") as f:
    dep_time = {tr: int(t) for tr, t in json.load(f).items()}

with open(demand_fp, encoding="utf-8") as f:
    dem_raw = json.load(f)
demand = {tr: [(o, d, float(q)) for o, d, q in lst] for tr, lst in dem_raw.items()}

trains = list(routes_nodes)
nodes  = {n for _, (s, d, _) in edges.items() for n in (s, d)}
nodes.add(SINK)

# ----- 시간-확장 아크 ---------------------------------------------------
arc_list = []                       # (from,to,eid,tau,t0,t1)
for eid, (src, dst, tau) in edges.items():
    if eid in failed_edges: continue
    for t in range(T + 1 - tau):
        arc_list.append((f"{src}^{t}", f"{dst}^{t+tau}", eid, tau, t, t+tau))

for n in nodes - {SINK}:
    for w in range(1, max_wait+1):
        for t in range(T + 1 - w):
            arc_list.append((f"{n}^{t}", f"{n}^{t+w}", f"w_{n}_{w}", w, t, t+w))

for n in nodes - {SINK}:
    for t in range(T+1):
        arc_list.append((f"{n}^{t}", f"{SINK}^{t}", f"dummy_{n}", 0, t, t))

arc_idx = {info: i for i, info in enumerate(arc_list)}

# ───────────────── 캐싱: arc → 노드·시각 별 in/out ─────────────────
out_arcs = defaultdict(list)   # (node,t) → [arcIdx…]
in_arcs  = defaultdict(list)   # (node,t) → [arcIdx…]
node_in_arcs  = defaultdict(list)   # 노드 방문용
node_out_arcs = defaultdict(list)

for k, (fr, to, eid, _, t0, t1) in enumerate(arc_list):
    n_fr, tt_fr = fr.split("^"); tt_fr = int(tt_fr)
    n_to, tt_to = to.split("^"); tt_to = int(tt_to)

    out_arcs[(n_fr, tt_fr)].append(k)
    in_arcs [(n_to, tt_to)].append(k)

    if not eid.startswith(("w_", "dummy")):      # s[tr,n] 계산용
        node_out_arcs[n_fr].append(k)
        node_in_arcs [n_to].append(k)

# ----- 예정 도착시각 ----------------------------------------------------
sched = {}
for tr, path in routes_nodes.items():
    t, arr = 0, {path[0]: dep_time[tr]}
    for u, v in zip(path[:-1], path[1:]):
        eid = next(e for e, (s, d, _) in edges.items() if s == u and d == v)
        t += edges[eid][2]; arr[v] = dep_time[tr] + t
    sched[tr] = arr

q_r = {tr: sum(q for *_, q in demand[tr]) for tr in trains}

# %%
import re
from collections import defaultdict

def route_prefix(tr_id: str) -> str:
    # 예: "경부고속철도1_1" -> "경부고속철도"
    m = re.match(r'^([^\d]+)\d+_\d+$', tr_id)
    return m.group(1) if m else tr_id.rsplit('_', 1)[0]

# 1) 노선별로 열차 묶기
by_route = defaultdict(list)
for tr in trains:
    by_route[route_prefix(tr)].append(tr)

# 2) 각 노선의 '대표(…1_1)' 선택 → 순수주행시간(run = arr - dep) 계산
route_runtime = {}  # {노선접두부: run}
for rname, tr_list in by_route.items():
    # 대표 후보: 정확히 rname + 숫자 + "_1" 형태(예: 경부선1_1, 경부고속철도1_1)
    reps = [tr for tr in tr_list if re.fullmatch(re.escape(rname) + r'\d+_1', tr)]
    if not reps:
        # 백업: '_1'로 끝나는 것 중 하나
        reps = [tr for tr in tr_list if tr.endswith('_1')]
    if not reps:
        # 그래도 없으면 첫번째
        reps = [sorted(tr_list)[0]]

    rep = reps[0]
    dest = routes_nodes[rep][-1]
    run = sched[rep][dest] - dep_time[rep]
    route_runtime[rname] = run

# 3) 각 기차 r에 대해 T_r = dep_time[r] + route_runtime[prefix(r)] + 4
PADDING = 4
T_limit = {}
for tr in trains:
    rname = route_prefix(tr)
    base_run = route_runtime[rname]   # 노선별 대표 주행시간
    T_limit[tr] = dep_time[tr] + base_run + PADDING

# %%
# ===== (NEW) 계획 엣지 / blocked / 접미 실패 / 종료 허용노드 =====
uv2eid = {}
dup_keys = set()
for eid, (s, d, _) in edges.items():
    key = (s, d)
    if key in uv2eid and uv2eid[key] != eid:
        dup_keys.add(key)  # 동일 (s,d)에 eid가 여러 개면 체크
    else:
        uv2eid[key] = eid

if dup_keys:
    # 필요시 여기서 raise 하거나, 첫 번째 eid만 쓰고 경고 출력
    print(f"[warn] multiple eids share the same (u,v): {sorted(list(dup_keys))[:5]} ...")

def planned_eids_of(tr):
    """열차 tr의 계획 경로 상 (u,v)들에 대한 eid 리스트를 O(1)로 반환"""
    path = routes_nodes[tr]
    eids = []
    for u, v in zip(path[:-1], path[1:]):
        eid = uv2eid.get((u, v))
        if eid is None:
            raise KeyError(f"No edge (u={u} -> v={v}) found in edges; check routes_nodes or edges.json")
        eids.append(eid)
    return eids

# 이제 O(1)로 추출
planned_eids = {tr: planned_eids_of(tr) for tr in trains}
blocked = {tr: int(any(e in failed_edges for e in planned_eids[tr])) for tr in trains}

# 이 열차의 계획경로가 실패엣지를 포함하면 blocked=1
blocked = {tr: int(any(e in failed_edges for e in planned_eids[tr]))
           for tr in trains}

# 접미 실패 플래그 F_{r,i}와 reach_r, 그리고 노드별 종료 허용 allow_stop[(tr,n)]
allow_stop = {}
reach = {}
for tr in trains:
    path = routes_nodes[tr]         # [n0, ..., nL]
    eids = planned_eids[tr]         # [e0, ..., e_{L-1}]
    L = len(path) - 1

    t_sched_term = sched[tr].get(path[-1], 10**9)
    reach[tr] = int(t_sched_term <= T_limit[tr])  # ★ 여기서 T_limit 사용

    # suffix failure (노드 기준)
    suffix_failed = [0]*(L+1)
    hit = 0
    for i in range(L-1, -1, -1):
        if eids[i] in failed_edges:
            hit = 1
        suffix_failed[i] = hit

    # 종료 허용 (origin 제외)
    for i in range(1, L+1):
        n = path[i]
        if i == L:
            allow = 1
        elif reach[tr] == 0:
            allow = 1
        else:
            allow = suffix_failed[i]
        allow_stop[(tr, n)] = int(allow)

eid_to_arcidx = defaultdict(list)
dummy_idx_of = defaultdict(list)
for k, (_, _, eid, *_ ) in enumerate(arc_list):
    if str(eid).startswith("dummy_"):
        n = eid.split("dummy_")[1]
        dummy_idx_of[n].append(k)
    elif not str(eid).startswith("w_"):
        eid_to_arcidx[eid].append(k)
     
T_aff = [tr for tr in trains if blocked[tr] == 1]   # 실패엣지 포함 열차
T_ok  = [tr for tr in trains if blocked[tr] == 0]   # 정상 열차

# %%
def build_base_model():

    m = gp.Model(); m.Params.OutputFlag = 1
    nA, nT = len(arc_list), len(trains)

    # 공통 변수 (모든 열차)
    x = m.addVars(nA, nT, vtype=gp.GRB.BINARY, name="x")
    t_arr = {(tr, n): m.addVar(lb=0, ub=T, vtype=gp.GRB.INTEGER, name=f"tarr[{tr},{n}]")
             for tr in trains for n in nodes - {SINK}}
    delta = {(tr,o,d): m.addVar(lb=0, name=f"delta[{tr},{o},{d}]")
             for tr in trains for (o,d,_) in demand[tr]}

    # T_aff만 추가 변수  ### CHG
    h = {}
    y = {}
    s = {}
    z = {}
    u_eid = {}

    if T_aff:
        h = m.addVars(T_aff, vtype=gp.GRB.BINARY, name="h")
        y = {(tr, n): m.addVar(vtype=gp.GRB.BINARY, name=f"y[{tr},{n}]")
             for tr in T_aff for n in routes_nodes[tr][1:]}
        s = {(tr, n): m.addVar(vtype=gp.GRB.BINARY, name=f"s[{tr},{n}]")
             for tr in T_aff for n in nodes - {SINK}}
        z = {(tr,o,d): m.addVar(vtype=gp.GRB.BINARY, name=f"z[{tr},{o},{d}]")
             for tr in T_aff for (o,d,_) in demand[tr]}

        # 우회 허용: 계획에 없는 eid만 u_eid 생성 + x ≤ u_eid  ### CHG
        real_eids = {eid for (_,_,eid,_,_,_) in arc_list if not str(eid).startswith(("w_","dummy"))}
        for tr in T_aff:
            P = set(planned_eids[tr])
            for eid in real_eids:
                if eid in P:
                    continue
                u_eid[(tr, eid)] = m.addVar(vtype=gp.GRB.BINARY, name=f"u_eid[{tr},{eid}]")
                # 해당 eid의 모든 arcIdx에 대해 x ≤ u_eid
                for k in eid_to_arcidx[eid]:
                    ti = trains.index(tr)
                    m.addConstr(x[k, ti] <= u_eid[(tr, eid)])

    # T_ok: 비계획 eid는 x=0으로 막아 경로공간 축소  ### CHG
    for tr in T_ok:
        ti = trains.index(tr)
        P = set(planned_eids[tr])
        for eid in eid_to_arcidx.keys():
            if eid not in P:
                for k in eid_to_arcidx[eid]:
                    x[k, ti].UB = 0  # 비계획 아크 사용 금지

    # --- 출발/흐름 보존 ---
    for tr in T_aff:
        tr_i = trains.index(tr)
        r_o, t_dep = routes_nodes[tr][0], dep_time[tr]
        m.addConstr(x.sum(out_arcs[(r_o, t_dep)], tr_i) == h[tr])
        # 노드-시간 보존
        for n in nodes - {SINK}:
            for t in range(T+1):
                inflow  = x.sum(in_arcs[(n, t)],  tr_i)
                outflow = x.sum(out_arcs[(n, t)], tr_i)
                if (n == r_o) and (t == t_dep):
                    m.addConstr(outflow - inflow == h[tr])
                else:
                    m.addConstr(inflow == outflow)

    for tr in T_ok:
        tr_i = trains.index(tr)
        r_o, t_dep = routes_nodes[tr][0], dep_time[tr]
        # 취소 불가 → 반드시 출발 1
        m.addConstr(x.sum(out_arcs[(r_o, t_dep)], tr_i) == 1)
        for n in nodes - {SINK}:
            for t in range(T+1):
                inflow  = x.sum(in_arcs[(n, t)],  tr_i)
                outflow = x.sum(out_arcs[(n, t)], tr_i)
                if (n == r_o) and (t == t_dep):
                    m.addConstr(outflow - inflow == 1)
                else:
                    m.addConstr(inflow == outflow)

    # --- 종료 허용노드 처리 (더미 아크) ---
    # 허용되지 않는 노드의 더미 아크는 모두 금지
    for tr in trains:
        for n in routes_nodes[tr][1:]:
            if allow_stop[(tr, n)] == 0:
                for k in dummy_idx_of[n]:
                    ti = trains.index(tr)
                    x[k, ti].UB = 0
    # T_aff: y로 종료 선택
    for tr in T_aff:
        tr_i = trains.index(tr)
        cand = routes_nodes[tr][1:]
        m.addConstr(gp.quicksum(y[tr, n] for n in cand) == h[tr])
        for n in cand:
            idx_dum = dummy_idx_of[n]
            m.addConstr(x.sum(idx_dum, tr_i) == y[tr, n])
        # 허용 안 되는 노드는 위에서 x UB=0, 여기선 y=0
        for n in cand:
            if allow_stop[(tr, n)] == 0:
                y[tr, n].UB = 0
    # T_ok: y 없이 “더미 1개” 직접 강제
    for tr in T_ok:
        tr_i = trains.index(tr)
        cand = [n for n in routes_nodes[tr][1:] if allow_stop[(tr, n)] == 1]
        lhs = 0
        for n in cand:
            lhs += x.sum(dummy_idx_of[n], tr_i)
        m.addConstr(lhs == 1)

    # --- s(방문) & z 로직: T_aff만 ---
    for tr in T_aff:
        tr_i = trains.index(tr)
        for n in nodes - {SINK}:
            idx = node_out_arcs[n] + node_in_arcs[n]
            flow = x.sum(idx, tr_i)
            m.addConstr(flow >= s[tr, n])
            m.addConstr(flow <= BIG_M * s[tr, n])
        for (o, d, q) in demand[tr]:
            m.addConstr(z[tr, o, d] <= s[tr, o])
            m.addConstr(z[tr, o, d] <= s[tr, d])
            m.addConstr(z[tr, o, d] >= s[tr, o] + s[tr, d] - 1)
            m.addConstr(z[tr, o, d] <= h[tr])

    # --- t_arr 링킹 (모든 열차) ---
    for tr in trains:
        tr_i = trains.index(tr)
        for k, (fr, to, eid, *_ ) in enumerate(arc_list):
            if str(eid).startswith(("w_", "dummy")): 
                continue
            n_to, tt = to.split("^"); tt = int(tt)
            m.addConstr(t_arr[tr, n_to] >= tt - BIG_M * (1 - x[k, tr_i]))
            m.addConstr(t_arr[tr, n_to] <= tt + BIG_M * (1 - x[k, tr_i]))

        # --- (추가) 기차별 시간상한: r ∈ R_aff (y로 종착노드 선택)
        for tr in T_aff:
            Tlim = T_limit[tr]
            for n in routes_nodes[tr][1:]:  # 종착 후보들
                # y[tr,n] = 1로 그 노드에서 종료하면 t_arr[tr,n] ≤ Tlim 이 강제됨
                m.addConstr(
                    t_arr[tr, n] <= Tlim + BIG_M * (1 - y[tr, n]),
                    name=f"timecap_aff[{tr},{n}]"
                )

        # --- (추가) 기차별 시간상한: r ∈ R_ok (y 없이 dummy-arc 합으로 종착노드 지표 대체)
        for tr in T_ok:
            Tlim = T_limit[tr]
            tr_i = trains.index(tr)
            for n in [nn for nn in routes_nodes[tr][1:] if allow_stop[(tr, nn)] == 1]:
                # 이 합은 해당 노드 n에서의 종료 dummy arc 사용(시간 미포함 합계)이 1이면 활성화
                term_n = x.sum(dummy_idx_of[n], tr_i)
                m.addConstr(
                    t_arr[tr, n] <= Tlim + BIG_M * (1 - term_n),
                    name=f"timecap_ok[{tr},{n}]"
                )

    # --- δ 제약 ---
    # T_aff: 기존처럼 z로 게이트
    for tr in T_aff:
        for (o, d, q) in demand[tr]:
            sched_t = sched[tr].get(d, T)
            m.addConstr(delta[tr, o, d] >= t_arr[tr, d] - sched_t - BIG_M * (1 - z[tr, o, d]))
            m.addConstr(delta[tr, o, d] <= BIG_M * z[tr, o, d])
    # T_ok: z 없이 “지연만” 측정
    for tr in T_ok:
        for (o, d, q) in demand[tr]:
            sched_t = sched[tr].get(d, T)
            m.addConstr(delta[tr, o, d] >= t_arr[tr, d] - sched_t)
            # delta는 lb=0 이므로 자연히 max(0, …)

    # --- 목적함수 ---
    obj = 0
    # T_aff: 취소/미서빙/지연 + 우회
    for tr in T_aff:
        obj += w1 * q_r[tr] * (1 - h[tr])
        for (o, d, q) in demand[tr]:
            obj += w2 * q * (1 - z[tr, o, d])
            obj += w3 * q * delta[tr, o, d]
    if u_eid:
        obj += W_ROUTE * gp.quicksum(u_eid.values())

    # T_ok: 지연만 패널티
    for tr in T_ok:
        for (o, d, q) in demand[tr]:
            obj += w3 * q * delta[tr, o, d]

    m.setObjective(obj, sense=gp.GRB.MINIMIZE)
    return m, x, t_arr, delta, h, z

# cap_map: (eid,tt) → [arcIdx …]
cap_map = defaultdict(list)
for k, (fr, to, eid, _, t0, t1) in enumerate(arc_list):
    if str(eid).startswith(("w_", "dummy")): 
        continue
    for tt in range(t0, t1):
        cap_map[(eid, tt)].append(k)

# %%
# ===== Active-set (working set) 용량 반복 동일 유지 =====
working_set, sol_prev = set(), None
MAX_ITER, EPS, SHOW = 40, 1e-6, 30

for it in range(MAX_ITER):
    base, xvar, t_arr_var, delta_var, hvar, zvar = build_base_model()
    constr_refs = {}
    for (eid, tt) in working_set:
        expr = gp.quicksum(xvar[idx, ti] for idx in cap_map[(eid, tt)]
                           for ti in range(len(trains)))
        constr_refs[(eid, tt)] = base.addConstr(expr <= CAPACITY,
                                               name=f"cap_{eid}_{tt}")

    if sol_prev:
        for (idx, ti), v in sol_prev.items():
            xvar[idx, ti].Start = v

    base.optimize()

    if base.Status == gp.GRB.INFEASIBLE:
        base.computeIIS()
        base.write(f"iis_iter{it}.ilp")   # 반복 번호 붙여 저장
        raise RuntimeError("infeasible (IIS written)")
    elif base.Status != gp.GRB.OPTIMAL:
        raise RuntimeError(f"non-optimal status: {base.Status}")


    x_val = {(idx, ti): round(xvar[idx, ti].X)
         for idx in range(len(arc_list))
         for ti  in range(len(trains))}
    
    # ③-c violation search
    x_mat = np.zeros((len(arc_list), len(trains)), dtype=np.uint8)
    for (idx, ti), v in x_val.items():      # x_val 은 아래에서 다시 만듦
        if v: x_mat[idx, ti] = 1
    cap_keys   = list(cap_map)                         # [(eid,tt), …]
    cap_idxarr = [np.fromiter(cap_map[k], dtype=int)   # each → np.array
                for k in cap_keys]
    viol = set()
    for k, idx_arr in zip(cap_keys, cap_idxarr):
        if x_mat[idx_arr].sum() > CAPACITY + EPS:
            viol.add(k)

    # ③-d negative dual search
    neg_pi = set()
    lp = base.relax(); lp.optimize()
    if lp.Status == gp.GRB.OPTIMAL:
        for key, c in constr_refs.items():
            if c.Pi < -EPS: neg_pi.add(key)
            
    # ③-e working-set update
    updated = False
    for k in viol:
        if k not in working_set: working_set.add(k); updated = True
    for k in neg_pi:
        if k in working_set: working_set.remove(k); updated = True

    ws = sorted(working_set)
    print(f"[Iter {it}] |W|={len(ws)}  preview={ws[:SHOW]}")
    print(f"          add={len(viol)} drop={len(neg_pi)}")
    sol_prev = x_val
    if not updated:
        print("↳ converged"); break
else:
    print("⚠ MAX_ITER reached")
# Out:
# Set parameter Username
# Set parameter LicenseID to value 2637066
# Academic license - for non-commercial use only - expires 2026-03-16
# Set parameter OutputFlag to value 1
# Gurobi Optimizer version 12.0.2 build v12.0.2rc0 (win64 - Windows 10.0 (19045.2))
#
# CPU model: AMD Ryzen 5 3600XT 6-Core Processor, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 4952882 rows, 2682067 columns and 15295410 nonzeros
# Model fingerprint: 0x1ba789ba
# Variable types: 6312 continuous, 2675755 integer (2667460 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+06]
#   Objective range  [2e-01, 9e+05]
#   Bounds range     [1e+00, 1e+02]
#   RHS range        [1e+00, 1e+06]
# Presolve removed 3398947 rows and 2028418 columns (presolve time = 5s)...
# Presolve removed 3841444 rows and 2232277 columns (presolve time = 10s)...
# Presolve removed 3877369 rows and 2244933 columns
# Presolve time: 11.10s
# Presolved: 1075513 rows, 437134 columns, 3871848 nonzeros
# Variable types: 0 continuous, 437134 integer (433799 binary)
# Found heuristic solution: objective 4.347838e+07
# Found heuristic solution: objective 4.306898e+07
# Found heuristic solution: objective 4.209551e+07
# Performing another presolve...
# Presolve removed 348540 rows and 132057 columns (presolve time = 5s)...
# Presolve removed 358401 rows and 132057 columns (presolve time = 10s)...
# Presolve removed 358401 rows and 132057 columns (presolve time = 15s)...
# Presolve removed 358401 rows and 132057 columns (presolve time = 20s)...
# Presolve removed 358401 rows and 132057 columns (presolve time = 25s)...
# Presolve removed 358401 rows and 132057 columns (presolve time = 30s)...
# Presolve removed 358401 rows and 132057 columns (presolve time = 35s)...
# Presolve removed 358401 rows and 165788 columns (presolve time = 43s)...
# Presolve removed 492692 rows and 175630 columns (presolve time = 45s)...
# Presolve removed 747770 rows and 241353 columns (presolve time = 66s)...
# Presolve removed 747770 rows and 241353 columns
# Presolve time: 66.05s
# Found heuristic solution: objective 2.771486e+07
#
# Deterministic concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Root barrier log...
#
# Elapsed ordering time = 5s
# Ordering time: 13.49s
# Elapsed ordering time = 14s
# Elapsed ordering time = 15s
# Elapsed ordering time = 20s
# Elapsed ordering time = 25s
# Elapsed ordering time = 30s
# Elapsed ordering time = 35s
# Elapsed ordering time = 40s
# Elapsed ordering time = 40s
# Elapsed ordering time = 45s
# Elapsed ordering time = 50s
# Elapsed ordering time = 55s
# Ordering time: 57.58s
# Elapsed ordering time = 58s
# Elapsed ordering time = 60s
# Elapsed ordering time = 65s
# Elapsed ordering time = 70s
# Ordering time: 70.81s
#
# Barrier statistics:
#  Dense cols : 787
#  AA' NZ     : 3.448e+07
#  Factor NZ  : 2.191e+08 (roughly 2.0 GB of memory)
#  Factor Ops : 1.299e+11 (roughly 2 seconds per iteration)
#  Threads    : 4
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0  -2.86306231e+08 -2.06959438e+11  8.96e+02 1.31e+04  3.85e+06   176s
#    1  -2.37596316e+08 -2.58186497e+11  5.56e+02 1.65e+04  1.58e+06   178s
#    2  -1.29643468e+08 -1.96432130e+11  2.67e+02 5.39e+01  6.92e+05   180s
#    3  -2.71946498e+07 -1.02305884e+11  6.35e+01 3.48e+00  1.79e+05   182s
#    4  -1.96858847e+06 -3.92650111e+10  1.82e+01 1.10e+00  5.11e+04   185s
#    5   2.09730409e+06 -1.07908725e+10  1.05e+01 7.38e-01  1.60e+04   188s
#    6   4.55787077e+06 -4.81914868e+09  5.60e+00 4.10e-01  7.60e+03   191s
#    7   5.33166216e+06 -1.57454419e+09  3.42e+00 8.24e-01  3.19e+03   194s
#    8   5.65241116e+06 -6.21664026e+08  1.18e+00 2.97e-01  1.18e+03   197s
#    9   5.38631645e+06 -4.23360754e+08  7.66e-01 1.96e-01  7.86e+02   199s
#   10   4.93188240e+06 -3.01956381e+08  5.18e-01 1.39e-01  5.46e+02   202s
#   11   4.46053329e+06 -1.26269259e+08  3.60e-01 5.75e-02  2.98e+02   205s
#   12   3.85167130e+06 -6.96048924e+07  2.44e-01 3.17e-02  1.84e+02   208s
#   13   3.31760509e+06 -3.40556680e+07  1.73e-01 1.57e-02  1.14e+02   211s
#   14   3.01241931e+06 -1.92727263e+07  1.34e-01 9.37e-03  8.05e+01   214s
#   15   2.76328891e+06 -1.70009417e+07  1.05e-01 8.42e-03  6.53e+01   217s
#   16   2.58889084e+06 -1.46845741e+07  8.54e-02 7.45e-03  5.44e+01   220s
#   17   2.41473392e+06 -1.24660930e+07  6.74e-02 6.52e-03  4.42e+01   223s
#   18   2.24699798e+06 -7.77030097e+06  5.34e-02 4.56e-03  3.31e+01   226s
#   19   2.10593884e+06 -5.02533045e+06  4.23e-02 3.38e-03  2.53e+01   229s
#   20   1.95282542e+06 -3.88836096e+06  3.24e-02 2.83e-03  1.96e+01   232s
#   21   1.85145085e+06 -2.22707746e+06  2.55e-02 2.07e-03  1.48e+01   235s
#   22   1.80211002e+06 -1.24969193e+06  2.09e-02 1.56e-03  1.17e+01   239s
#   23   1.71072107e+06 -9.97422847e+05  1.51e-02 1.42e-03  8.76e+00   242s
#   24   1.67055941e+06 -1.47863940e+05  1.20e-02 9.55e-04  6.44e+00   245s
#   25   1.62187021e+06  3.14012114e+05  9.26e-03 6.71e-04  4.86e+00   248s
#   26   1.58285410e+06  6.11661074e+05  6.85e-03 4.90e-04  3.52e+00   251s
#   27   1.56037387e+06  1.01653696e+06  5.67e-03 2.60e-04  2.63e+00   255s
#   28   1.52789319e+06  1.13895138e+06  3.68e-03 1.81e-04  1.75e+00   258s
#   29   1.50981757e+06  1.24870198e+06  2.89e-03 1.20e-04  1.28e+00   261s
#   30   1.49565845e+06  1.31652481e+06  2.36e-03 8.27e-05  1.01e+00   264s
#   31   1.48888121e+06  1.34772931e+06  2.04e-03 6.61e-05  8.32e-01   267s
#   32   1.48258341e+06  1.36909914e+06  1.67e-03 5.39e-05  6.71e-01   270s
#   33   1.47540081e+06  1.39437657e+06  1.31e-03 4.12e-05  5.07e-01   274s
#   34   1.47272397e+06  1.40114019e+06  1.08e-03 3.77e-05  4.22e-01   277s
#   35   1.46994632e+06  1.40883201e+06  9.37e-04 3.39e-05  3.64e-01   280s
#   36   1.46932302e+06  1.41513430e+06  9.10e-04 3.09e-05  3.49e-01   283s
#   37   1.46824976e+06  1.42326599e+06  7.78e-04 2.67e-05  2.96e-01   286s
#   38   1.46687463e+06  1.42908696e+06  5.95e-04 2.36e-05  2.29e-01   289s
#   39   1.46545991e+06  1.43448336e+06  5.25e-04 2.12e-05  1.97e-01   293s
#   40   1.46707439e+06  1.43755452e+06  4.44e-04 1.98e-05  1.71e-01   296s
#   41   1.46640897e+06  1.44670094e+06  4.29e-04 1.56e-05  1.59e-01   299s
#   42   1.46642049e+06  1.45158624e+06  3.28e-04 1.35e-05  1.22e-01   302s
#   43   1.46676142e+06  1.45882935e+06  2.65e-04 1.03e-05  9.65e-02   305s
#   44   1.46750926e+06  1.46390347e+06  2.36e-04 8.04e-06  8.47e-02   309s
#   45   1.46789057e+06  1.46608147e+06  2.11e-04 7.14e-06  7.57e-02   314s
#   46   1.46953378e+06  1.46936259e+06  1.58e-04 5.83e-06  5.61e-02   319s
#   47   1.47012045e+06  1.47300356e+06  1.41e-04 4.14e-06  4.61e-02   326s
#   48   1.47057166e+06  1.47410847e+06  1.29e-04 3.71e-06  4.18e-02   332s
#   49   1.47121922e+06  1.47647398e+06  1.11e-04 2.90e-06  3.48e-02   340s
#   50   1.47192270e+06  1.47815901e+06  9.87e-05 2.30e-06  3.04e-02   349s
#   51   1.47251972e+06  1.47894403e+06  1.28e-04 2.06e-06  2.65e-02   358s
#   52   1.47301422e+06  1.47981860e+06  1.77e-04 1.78e-06  2.31e-02   367s
#   53   1.47381986e+06  1.48050638e+06  2.53e-04 1.61e-06  2.04e-02   376s
#   54   1.47440486e+06  1.48141359e+06  3.05e-04 1.35e-06  1.80e-02   384s
#   55   1.47543283e+06  1.48212330e+06  3.74e-04 1.17e-06  1.48e-02   393s
#   56   1.47593385e+06  1.48229538e+06  3.61e-04 1.13e-06  1.35e-02   401s
#   57   1.47669981e+06  1.48256216e+06  3.25e-04 1.06e-06  1.24e-02   410s
#   58   1.47786851e+06  1.48304385e+06  4.28e-04 8.89e-07  9.96e-03   421s
#   59   1.47885795e+06  1.48323606e+06  4.61e-04 8.20e-07  8.34e-03   430s
#   60   1.47985815e+06  1.48348934e+06  4.83e-04 7.26e-07  6.64e-03   438s
#   61   1.48033967e+06  1.48380416e+06  4.45e-04 6.06e-07  5.85e-03   445s
#   62   1.48084772e+06  1.48398347e+06  3.85e-04 5.44e-07  5.14e-03   454s
#   63   1.48110426e+06  1.48436065e+06  3.57e-04 4.10e-07  4.54e-03   461s
#   64   1.48203535e+06  1.48447399e+06  2.75e-04 3.57e-07  3.42e-03   471s
#   65   1.48317605e+06  1.48505227e+06  2.55e-04 1.22e-07  1.92e-03   480s
#   66   1.48402795e+06  1.48521347e+06  2.92e-04 5.82e-08  9.75e-04   488s
#   67   1.48453760e+06  1.48533058e+06  3.22e-04 1.65e-08  4.00e-04   492s
#   68   1.48468954e+06  1.48534517e+06  3.31e-04 1.44e-08  2.50e-04   495s
#   69   1.48468786e+06  1.48535286e+06  3.31e-04 1.42e-08  2.36e-04   499s
#   70   1.48477516e+06  1.48536317e+06  3.37e-04 1.54e-08  1.42e-04   502s
#   71   1.48486369e+06  1.48537782e+06  3.41e-04 1.42e-08  4.08e-05   505s
#   72   1.48488323e+06  1.48538362e+06  3.43e-04 8.85e-09  1.58e-05   508s
#   73   1.48489572e+06  1.48538387e+06  3.43e-04 6.52e-09  3.71e-06   511s
#   74   1.48489788e+06  1.48538398e+06  2.71e-04 4.66e-09  1.82e-06   513s
#   75   1.48489944e+06  1.48538440e+06  1.84e-04 1.30e-08  3.09e-07   516s
#   76   1.48489951e+06  1.48538450e+06  1.80e-04 8.61e-09  2.04e-07   519s
#   77   1.48489969e+06  1.48538451e+06  1.75e-04 8.15e-09  1.34e-07   522s
#   78   1.48489969e+06  1.48538451e+06  1.75e-04 7.92e-09  1.29e-07   526s
#   79   1.48489969e+06  1.48538453e+06  1.75e-04 7.45e-09  1.20e-07   529s
#   80   1.48489969e+06  1.48538455e+06  1.75e-04 5.82e-09  1.04e-07   534s
#   81   1.48489982e+06  1.48538465e+06  1.78e-04 3.73e-09  3.82e-08   537s
#   82   1.48489990e+06  1.48538466e+06  1.75e-04 3.03e-09  3.38e-08   541s
#
# Barrier performed 82 iterations in 541.04 seconds (473.72 work units)
# Barrier solve interrupted - model solved by another algorithm
#
# Concurrent spin time: 1.35s
#
# Solved with dual simplex
#
# Root relaxation: objective 1.485471e+06, 463958 iterations, 451.55 seconds (241.18 work units)
# Total elapsed time = 541.43s (DegenMoves)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1485470.62    0 2454 2.7715e+07 1485470.62  94.6%     -  556s
#      0     0 1492302.49    0  979 2.7715e+07 1492302.49  94.6%     -  557s
# H    0     0                    1562885.2000 1492302.49  4.52%     -  558s
#      0     0 1553196.90    0 1878 1562885.20 1553196.90  0.62%     -  563s
#
# Explored 1 nodes (479751 simplex iterations) in 565.57 seconds (348.75 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 8: 1.56289e+06 1.56289e+06 2.77149e+07 ... 4.34784e+07
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.562885200000e+06, best bound 1.562885200000e+06, gap 0.0000%
# Gurobi Optimizer version 12.0.2 build v12.0.2rc0 (win64 - Windows 10.0 (19045.2))
#
# CPU model: AMD Ryzen 5 3600XT 6-Core Processor, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 4952882 rows, 2682067 columns and 15295410 nonzeros
# Model fingerprint: 0x1bbae970
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+06]
#   Objective range  [2e-01, 9e+05]
#   Bounds range     [1e+00, 1e+02]
#   RHS range        [1e+00, 1e+06]
# Presolve removed 4214287 rows and 2378961 columns (presolve time = 5s)...
# Presolve removed 4214287 rows and 2378961 columns
# Presolve time: 16.33s
# Presolved: 225938 rows, 1051547 columns, 3318473 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 4.63s
#
# Barrier statistics:
#  Dense cols : 1683
#  Free vars  : 3382
#  AA' NZ     : 1.463e+07
#  Factor NZ  : 7.485e+07 (roughly 1.1 GB of memory)
#  Factor Ops : 3.953e+10 (roughly 1 second per iteration)
#  Threads    : 4
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0  -1.08923958e+15  4.30689800e+07  6.88e+07 0.00e+00  1.31e+09    26s
#    1  -5.52277200e+14  1.03627566e+10  3.09e+07 5.39e+02  6.22e+08    27s
#    2  -5.00741496e+14  1.54806269e+10  2.75e+07 2.33e+02  4.59e+08    29s
#    3  -3.16925031e+14  1.72179454e+10  1.68e+07 1.02e+02  2.73e+08    30s
#    4  -9.69481962e+13  1.65933778e+10  4.84e+06 4.78e+01  8.85e+07    31s
#    5  -1.30674128e+13  9.35903248e+09  5.10e+05 8.48e+00  1.13e+07    33s
#    6  -1.13929029e+13  8.53031985e+09  4.49e+05 7.45e+00  9.92e+06    35s
#    7  -1.06240182e+13  8.21391977e+09  4.19e+05 7.14e+00  9.30e+06    36s
#    8  -9.72080517e+12  7.76105817e+09  3.82e+05 6.65e+00  8.57e+06    37s
#    9  -8.42449294e+12  7.38936293e+09  3.35e+05 6.28e+00  7.56e+06    38s
#   10  -7.38960204e+12  6.90830244e+09  2.93e+05 5.76e+00  6.72e+06    39s
#   11  -7.07674906e+12  6.72839054e+09  2.81e+05 5.57e+00  6.46e+06    40s
#   12  -6.88965002e+12  6.61216921e+09  2.75e+05 5.47e+00  6.31e+06    42s
#   13  -6.55672851e+12  6.47780680e+09  2.63e+05 5.34e+00  6.06e+06    43s
#   14  -6.42669414e+12  6.39091213e+09  2.59e+05 5.24e+00  5.97e+06    44s
#   15  -6.32685388e+12  6.34126506e+09  2.58e+05 5.18e+00  5.93e+06    46s
#   16  -6.10909195e+12  6.20995631e+09  2.54e+05 5.08e+00  5.84e+06    47s
#   17  -5.31084695e+12  5.97911168e+09  2.26e+05 4.00e+00  5.20e+06    49s
#   18  -4.87147163e+12  5.70399228e+09  2.04e+05 3.79e+00  4.79e+06    50s
#   19  -4.04915718e+12  5.58591715e+09  1.71e+05 3.70e+00  4.16e+06    52s
#   20  -2.05686105e+12  4.49525423e+09  8.66e+04 2.82e+00  2.41e+06    54s
#   21  -1.35622436e+12  2.92576811e+09  5.39e+04 1.74e+00  1.56e+06    55s
#   22  -1.00825541e+12  2.02960763e+09  3.91e+04 1.20e+00  1.13e+06    57s
#   23  -8.75437288e+11  1.04076348e+09  3.31e+04 5.44e-01  8.47e+05    59s
#   24  -4.25211472e+11  4.96246279e+08  1.50e+04 2.17e-01  3.98e+05    60s
#   25  -2.16114677e+11  2.67883903e+08  6.97e+03 1.69e-01  1.97e+05    61s
#   26  -1.49438582e+11  1.62250314e+08  4.69e+03 1.58e-01  1.31e+05    62s
#   27  -8.30024460e+10  8.65201472e+07  2.50e+03 2.68e-01  7.05e+04    63s
#   28  -2.54245909e+10  4.64009507e+07  7.01e+02 1.72e-01  2.17e+04    64s
#   29  -1.20489359e+10  3.03259937e+07  3.23e+02 5.93e-02  1.02e+04    65s
#   30  -5.98339917e+09  1.56945240e+07  1.54e+02 3.29e-02  4.79e+03    66s
#   31  -1.65056213e+09  1.12254483e+07  4.11e+01 2.33e-02  1.32e+03    67s
#   32  -8.23952338e+08  7.66939327e+06  1.93e+01 1.21e-02  6.62e+02    68s
#   33  -3.31425241e+08  5.01421634e+06  6.92e+00 6.90e-03  2.68e+02    69s
#   34  -2.52360236e+08  3.55942942e+06  5.15e+00 3.68e-03  2.03e+02    70s
#   35  -1.80379509e+08  2.60950628e+06  3.64e+00 2.38e-03  1.45e+02    71s
#   36  -1.52031422e+08  2.21401116e+06  3.04e+00 2.08e-03  1.22e+02    72s
#   37  -1.10152760e+08  1.74325240e+06  2.18e+00 1.59e-03  8.89e+01    73s
#   38  -6.01128389e+07  1.35501142e+06  1.12e+00 8.60e-04  4.90e+01    75s
#   39  -5.12344897e+07  7.53324326e+05  9.50e-01 3.99e-04  4.12e+01    76s
#   40  -4.23681086e+07  6.72032235e+05  7.80e-01 3.27e-04  3.42e+01    78s
#   41  -2.48224448e+07  6.17275041e+05  4.49e-01 2.71e-04  2.03e+01    79s
#   42  -8.14071898e+06  4.19147298e+05  1.47e-01 1.56e-04  6.83e+00    80s
#   43  -5.02029570e+06  3.78431243e+05  2.23e-01 7.47e-05  4.30e+00    82s
#   44  -4.60343155e+06  3.73660625e+05  2.05e-01 7.11e-05  3.96e+00    84s
#   45  -2.29494125e+06  2.90468187e+05  1.05e-01 3.38e-05  2.05e+00    85s
#   46  -2.26745190e+06  2.88517642e+05  1.04e-01 3.35e-05  2.03e+00    86s
#   47  -2.26745801e+06  2.88517060e+05  1.04e-01 3.35e-05  2.03e+00    87s
#   48  -2.25875522e+06  2.88060370e+05  1.09e-01 3.34e-05  2.02e+00    89s
#   49  -1.13312898e+06  1.69134834e+05  2.06e-01 1.78e-05  1.04e+00    92s
#   50  -1.13288575e+06  1.69102450e+05  2.06e-01 1.78e-05  1.04e+00    94s
#   51  -1.13287548e+06  1.69100932e+05  2.06e-01 1.78e-05  1.04e+00    95s
#   52  -1.13287307e+06  1.69100693e+05  2.06e-01 1.78e-05  1.04e+00    97s
#   53  -1.13288087e+06  1.69103676e+05  2.06e-01 1.78e-05  1.04e+00    99s
#   54  -1.13288046e+06  1.69101732e+05  2.06e-01 1.78e-05  1.04e+00   100s
#   55  -1.12620717e+06  1.67944101e+05  2.05e-01 1.77e-05  1.04e+00   102s
#   56  -1.10845587e+06  1.64913087e+05  2.00e-01 1.73e-05  1.02e+00   103s
#   57  -1.07644973e+06  1.60464648e+05  2.00e-01 1.69e-05  9.91e-01   105s
#   58  -1.04985433e+06  1.50835359e+05  1.97e-01 1.60e-05  9.61e-01   106s
#   59  -1.04890395e+06  1.50655579e+05  1.96e-01 1.59e-05  9.60e-01   108s
#
# Barrier performed 59 iterations in 108.00 seconds (87.92 work units)
# Numerical trouble encountered
#
# Model may be infeasible or unbounded.  Consider using the
# homogeneous algorithm (through parameter 'BarHomogeneous')
#
#
# Solved with dual simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#   217703    8.8964991e+02   0.000000e+00   4.730500e-02    156s
# Extra simplex iterations after uncrush: 47120
#   264823    8.8964993e+02   6.515773e-01   0.000000e+00    160s
# Extra simplex iterations from dual to original model: 8
#   264831    8.8965002e+02   0.000000e+00   0.000000e+00    161s
#
# Solved in 264831 iterations and 161.05 seconds (84.88 work units)
# Optimal objective  8.896500228e+02
# [Iter 0] |W|=0  preview=[]
#           add=0 drop=0
# ↳ converged

# %%
# ========== Cell 5 (교체) ==========
pd.set_option('display.max_rows', None)

def h_get(tr):
    if tr in T_aff:
        return float(hvar[tr].X)
    return 1.0

# 1) Timetable
rows = []
for tr_i, tr in enumerate(trains):
    if h_get(tr) < 0.5:
        rows.append([tr, '-', '-', '-', '-', 'Cancelled'])
        continue
    legs = [(int(arc_list[k][0].split("^")[1]),
             arc_list[k][0].split("^")[0],
             arc_list[k][1].split("^")[0],
             int(arc_list[k][1].split("^")[1]),
             arc_list[k][2])
            for k in range(len(arc_list))
            if xvar[k, tr_i].X > 0.5 and not str(arc_list[k][2]).startswith(("w_", "dummy"))]
    legs.sort(key=lambda v: v[0])
    for dep, frm, to, arr, eid in legs:
        rows.append([tr, frm, dep, to, arr, eid])

df = pd.DataFrame(rows, columns=["Train", "From", "Dep", "To", "Arr", "Edge"])
print("\n=== Timetable (head) ===")
display(df)

# 2) 유틸리티
def planned_path_and_eids(tr):
    path = routes_nodes[tr]
    eids = []
    for u, v in zip(path[:-1], path[1:]):
        eid = next(e for e, (s, d, _) in edges.items() if s == u and d == v)
        eids.append(eid)
    return path, eids

def build_actual_legs(tr):
    tr_i = trains.index(tr)
    legs = [(int(arc_list[k][0].split("^")[1]),
             arc_list[k][0].split("^")[0],
             arc_list[k][1].split("^")[0],
             int(arc_list[k][1].split("^")[1]),
             arc_list[k][2])
            for k in range(len(arc_list))
            if xvar[k, tr_i].X > 0.5 and not str(arc_list[k][2]).startswith(("w_", "dummy"))]
    legs.sort(key=lambda v: v[0])
    return legs

def path_nodes_from_legs(legs):
    if not legs: return []
    nodes_seq = [legs[0][1]]
    for _, _, to, _, _ in legs:
        nodes_seq.append(to)
    return nodes_seq

def actual_arrival_map(legs):
    amap = {}
    for _, frm, to, arr, _ in legs:
        if to not in amap or arr < amap[to]:
            amap[to] = arr
    return amap

# 3) 상태 요약
stat_rows = []
for tr in trains:
    departed = (h_get(tr) >= 0.5)
    planned_path, planned_eids = planned_path_and_eids(tr)
    planned_terminal = planned_path[-1]
    planned_terminal_sched = sched[tr].get(planned_terminal, None)

    if not departed:
        stat_rows.append({
            "Train": tr, "Departed": False, "ArrivedInHorizon": False,
            "PlannedTerminal": planned_terminal,
            "ActualTerminal": None,
            "Delay(min)": None, "HorizonDelay(min)": None,
            "Truncated": False, "Rerouted": False, "Status": "Cancelled"
        })
        continue

    legs = build_actual_legs(tr)
    actual_nodes = path_nodes_from_legs(legs)
    actual_eids  = [e for *_, e in legs]
    arr_map      = actual_arrival_map(legs)
    actual_terminal = actual_nodes[-1] if actual_nodes else None
    actual_arrival  = max(arr for *_, arr, _ in legs) if legs else None

    prefix_last_idx = 0
    for i, node in enumerate(planned_path):
        t_planned = sched[tr].get(node, None)
        if t_planned is not None and t_planned <= T:
            prefix_last_idx = i
    planned_prefix_nodes = planned_path[:prefix_last_idx+1]
    planned_prefix_eids  = planned_eids[:max(0, prefix_last_idx)]

    arrived_in_horizon = (actual_terminal == planned_terminal) and (actual_arrival is not None) and (actual_arrival <= T)
    if planned_terminal_sched is not None and planned_terminal_sched <= T:
        truncated = (not arrived_in_horizon)
    else:
        truncated = False

    common = min(len(actual_eids), len(planned_prefix_eids))
    rerouted = (actual_eids[:common] != planned_prefix_eids[:common])

    delay_min = None
    horizon_delay_min = None
    if planned_terminal_sched is not None and planned_terminal_sched <= T and arrived_in_horizon:
        delay_min = max(0, actual_arrival - planned_terminal_sched)

    if planned_prefix_nodes:
        last_plan_node = planned_prefix_nodes[-1]
        t_plan_last    = sched[tr].get(last_plan_node, None)
        t_act_last     = arr_map.get(last_plan_node, None)
        if (t_plan_last is not None) and (t_act_last is not None):
            horizon_delay_min = max(0, t_act_last - t_plan_last)

    if not departed:
        status = "Cancelled"
    elif truncated:
        status = "Truncated"
    elif rerouted:
        status = "Rerouted"
    elif (planned_terminal_sched is not None and planned_terminal_sched <= T and delay_min and delay_min > 0) \
         or (horizon_delay_min is not None and horizon_delay_min > 0):
        status = "Delayed"
    else:
        if planned_terminal_sched is not None and planned_terminal_sched > T and not arrived_in_horizon:
            status = "On-time & in-progress"
        else:
            status = "On-time & complete"

    stat_rows.append({
        "Train": tr,
        "Departed": True,
        "ArrivedInHorizon": arrived_in_horizon,
        "PlannedTerminal": planned_terminal,
        "ActualTerminal": actual_terminal,
        "Delay(min)": delay_min,
        "HorizonDelay(min)": horizon_delay_min,
        "Truncated": truncated,
        "Rerouted": rerouted,
        "Status": status
    })

df_stat = pd.DataFrame(stat_rows, columns=[
    "Train","Departed","ArrivedInHorizon","PlannedTerminal","ActualTerminal",
    "Delay(min)","HorizonDelay(min)","Truncated","Rerouted","Status"
])
print("\n=== Train status summary — horizon-aware (T-based) ===")
display(df_stat)
# Out:
# === Timetable (head) ===
#            Train From  Dep   To  Arr  Edge
# 0      경부고속철도1_1   n4    0   n3    1    e4
# 1      경부고속철도1_1   n3    1   n1    2    e3
# 2      경부고속철도1_1   n1    2   n2    4    e1
# 3      경부고속철도1_1   n2    4  n13   10   e9r
# 4      경부고속철도1_1  n13   10  n18   13  e17r
# 5      경부고속철도1_1  n18   13  n28   16   e26
# 6      경부고속철도1_1  n28   16  n41   23  e42r
# 7      경부고속철도1_1  n41   23  n46   25  e55r
# 8      경부고속철도1_1  n46   25  n59   29   e66
# 9      경부고속철도1_1  n59   29  n60   30  e72r
# 10     경부고속철도1_1  n60   30  n72   34   e81
# 11     경부고속철도1_1  n72   34  n75   37   e89
# 12     경부고속철도1_1  n75   37  n79   42   e93
# 13     경부고속철도1_2   n4    3   n3    4    e4
# 14     경부고속철도1_2   n3    4   n1    5    e3
# 15     경부고속철도1_2   n1    5   n2    7    e1
# 16     경부고속철도1_2   n2    7  n13   13   e9r
# 17     경부고속철도1_2  n13   13  n18   16  e17r
# 18     경부고속철도1_2  n18   16  n28   19   e26
# 19     경부고속철도1_2  n28   19  n41   26  e42r
# 20     경부고속철도1_2  n41   26  n46   28  e55r
# 21     경부고속철도1_2  n46   28  n59   32   e66
# 22     경부고속철도1_2  n59   32  n60   33  e72r
# 23     경부고속철도1_2  n60   33  n72   37   e81
# 24     경부고속철도1_2  n72   37  n75   40   e89
# 25     경부고속철도1_2  n75   40  n79   45   e93
# 26     경부고속철도1_3   n4    6   n3    7    e4
# 27     경부고속철도1_3   n3    7   n1    8    e3
# 28     경부고속철도1_3   n1    8   n2   10    e1
# 29     경부고속철도1_3   n2   10  n13   16   e9r
# 30     경부고속철도1_3  n13   16  n18   19  e17r
# 31     경부고속철도1_3  n18   19  n28   22   e26
# 32     경부고속철도1_3  n28   22  n41   29  e42r
# 33     경부고속철도1_3  n41   29  n46   31  e55r
# 34     경부고속철도1_3  n46   31  n59   35   e66
# 35     경부고속철도1_3  n59   35  n60   36  e72r
# 36     경부고속철도1_3  n60   36  n72   40   e81
# 37     경부고속철도1_3  n72   40  n75   43   e89
# 38     경부고속철도1_3  n75   43  n79   48   e93
# 39     경부고속철도1_4   n4    9   n3   10    e4
# 40     경부고속철도1_4   n3   10   n1   11    e3
# 41     경부고속철도1_4   n1   11   n2   13    e1
# 42     경부고속철도1_4   n2   13  n13   19   e9r
# 43     경부고속철도1_4  n13   19  n18   22  e17r
# 44     경부고속철도1_4  n18   22  n28   25   e26
# 45     경부고속철도1_4  n28   25  n41   32  e42r
# 46     경부고속철도1_4  n41   32  n46   34  e55r
# 47     경부고속철도1_4  n46   34  n59   38   e66
# 48     경부고속철도1_4  n59   38  n60   39  e72r
# 49     경부고속철도1_4  n60   39  n72   43   e81
# 50     경부고속철도1_4  n72   43  n75   46   e89
# 51     경부고속철도1_4  n75   46  n79   51   e93
# 52     경부고속철도1_5   n4   12   n3   13    e4
# 53     경부고속철도1_5   n3   13   n1   14    e3
# 54     경부고속철도1_5   n1   14   n2   16    e1
# 55     경부고속철도1_5   n2   16  n13   22   e9r
# 56     경부고속철도1_5  n13   22  n18   25  e17r
# 57     경부고속철도1_5  n18   25  n28   28   e26
# 58     경부고속철도1_5  n28   28  n41   35  e42r
# 59     경부고속철도1_5  n41   35  n46   37  e55r
# 60     경부고속철도1_5  n46   37  n59   41   e66
# 61     경부고속철도1_5  n59   41  n60   42  e72r
# 62     경부고속철도1_5  n60   42  n72   46   e81
# 63     경부고속철도1_5  n72   46  n75   49   e89
# 64     경부고속철도1_5  n75   49  n79   54   e93
# 65     경부고속철도1_6   n4   15   n3   16    e4
# 66     경부고속철도1_6   n3   16   n1   17    e3
# 67     경부고속철도1_6   n1   17   n2   19    e1
# 68     경부고속철도1_6   n2   19  n13   25   e9r
# 69     경부고속철도1_6  n13   25  n18   28  e17r
# 70     경부고속철도1_6  n18   28  n28   31   e26
# 71     경부고속철도1_6  n28   31  n41   38  e42r
# 72     경부고속철도1_6  n41   38  n46   40  e55r
# 73     경부고속철도1_6  n46   40  n59   44   e66
# 74     경부고속철도1_6  n59   44  n60   45  e72r
# 75     경부고속철도1_6  n60   45  n72   49   e81
# 76     경부고속철도1_6  n72   49  n75   52   e89
# 77     경부고속철도1_6  n75   52  n79   57   e93
# 78     경부고속철도1_7   n4   18   n3   19    e4
# 79     경부고속철도1_7   n3   19   n1   20    e3
# 80     경부고속철도1_7   n1   20   n2   22    e1
# 81     경부고속철도1_7   n2   22  n13   28   e9r
# 82     경부고속철도1_7  n13   28  n18   31  e17r
# 83     경부고속철도1_7  n18   31  n28   34   e26
# 84     경부고속철도1_7  n28   34  n41   41  e42r
# 85     경부고속철도1_7  n41   41  n46   43  e55r
# 86     경부고속철도1_7  n46   43  n59   47   e66
# 87     경부고속철도1_7  n59   47  n60   48  e72r
# 88     경부고속철도1_7  n60   48  n72   52   e81
# 89     경부고속철도1_7  n72   52  n75   55   e89
# 90     경부고속철도1_7  n75   55  n79   60   e93
# 91     경부고속철도1_8   n4   21   n3   22    e4
# 92     경부고속철도1_8   n3   22   n1   23    e3
# 93     경부고속철도1_8   n1   23   n2   25    e1
# 94     경부고속철도1_8   n2   25  n13   31   e9r
# 95     경부고속철도1_8  n13   31  n18   34  e17r
# 96     경부고속철도1_8  n18   34  n28   37   e26
# 97     경부고속철도1_8  n28   37  n41   44  e42r
# 98     경부고속철도1_8  n41   44  n46   46  e55r
# 99     경부고속철도1_8  n46   46  n59   50   e66
# 100    경부고속철도1_8  n59   50  n60   51  e72r
# 101    경부고속철도1_8  n60   51  n72   55   e81
# 102    경부고속철도1_8  n72   55  n75   58   e89
# 103    경부고속철도1_8  n75   58  n79   63   e93
# 104    경부고속철도1_9   n4   24   n3   25    e4
# 105    경부고속철도1_9   n3   25   n1   26    e3
# 106    경부고속철도1_9   n1   26   n2   28    e1
# 107    경부고속철도1_9   n2   28  n13   34   e9r
# 108    경부고속철도1_9  n13   34  n18   37  e17r
# 109    경부고속철도1_9  n18   37  n28   40   e26
# 110    경부고속철도1_9  n28   40  n41   47  e42r
# 111    경부고속철도1_9  n41   47  n46   49  e55r
# 112    경부고속철도1_9  n46   49  n59   53   e66
# 113    경부고속철도1_9  n59   53  n60   54  e72r
# 114    경부고속철도1_9  n60   54  n72   58   e81
# 115    경부고속철도1_9  n72   58  n75   61   e89
# 116    경부고속철도1_9  n75   61  n79   66   e93
# 117   경부고속철도1_10   n4   27   n3   28    e4
# 118   경부고속철도1_10   n3   28   n1   29    e3
# 119   경부고속철도1_10   n1   29   n2   31    e1
# 120   경부고속철도1_10   n2   31  n13   37   e9r
# 121   경부고속철도1_10  n13   37  n18   40  e17r
# 122   경부고속철도1_10  n18   40  n28   43   e26
# 123   경부고속철도1_10  n28   43  n41   50  e42r
# 124   경부고속철도1_10  n41   50  n46   52  e55r
# 125   경부고속철도1_10  n46   52  n59   56   e66
# 126   경부고속철도1_10  n59   56  n60   57  e72r
# 127   경부고속철도1_10  n60   57  n72   61   e81
# 128   경부고속철도1_10  n72   61  n75   64   e89
# 129   경부고속철도1_10  n75   64  n79   69   e93
# 130   경부고속철도1_11   n4   30   n3   31    e4
# 131   경부고속철도1_11   n3   31   n1   32    e3
# 132   경부고속철도1_11   n1   32   n2   34    e1
# 133   경부고속철도1_11   n2   34  n13   40   e9r
# 134   경부고속철도1_11  n13   40  n18   43  e17r
# 135   경부고속철도1_11  n18   43  n28   46   e26
# 136   경부고속철도1_11  n28   46  n41   53  e42r
# 137   경부고속철도1_11  n41   53  n46   55  e55r
# 138   경부고속철도1_11  n46   55  n59   59   e66
# 139   경부고속철도1_11  n59   59  n60   60  e72r
# 140   경부고속철도1_11  n60   60  n72   64   e81
# 141   경부고속철도1_11  n72   64  n75   67   e89
# 142   경부고속철도1_11  n75   67  n79   72   e93
# 143   경부고속철도1_12   n4   33   n3   34    e4
# 144   경부고속철도1_12   n3   34   n1   35    e3
# 145   경부고속철도1_12   n1   35   n2   37    e1
# 146   경부고속철도1_12   n2   37  n13   43   e9r
# 147   경부고속철도1_12  n13   43  n18   46  e17r
# 148   경부고속철도1_12  n18   46  n28   49   e26
# 149   경부고속철도1_12  n28   49  n41   56  e42r
# 150   경부고속철도1_12  n41   56  n46   58  e55r
# 151   경부고속철도1_12  n46   58  n59   62   e66
# 152   경부고속철도1_12  n59   62  n60   63  e72r
# 153   경부고속철도1_12  n60   63  n72   67   e81
# 154   경부고속철도1_12  n72   67  n75   70   e89
# 155   경부고속철도1_12  n75   70  n79   75   e93
# 156    경부고속철도2_1  n79    0  n75    5  e93r
# 157    경부고속철도2_1  n75    5  n72    8  e89r
# 158    경부고속철도2_1  n72    8  n60   12  e81r
# 159    경부고속철도2_1  n60   12  n59   13   e72
# 160    경부고속철도2_1  n59   13  n46   17  e66r
# 161    경부고속철도2_1  n46   17  n41   19   e55
# 162    경부고속철도2_1  n41   19  n28   26   e42
# 163    경부고속철도2_1  n28   26  n18   29  e26r
# 164    경부고속철도2_1  n18   29  n13   32   e17
# 165    경부고속철도2_1  n13   32   n2   38    e9
# 166    경부고속철도2_1   n2   38   n1   40   e1r
# 167    경부고속철도2_1   n1   40   n3   41   e3r
# 168    경부고속철도2_1   n3   41   n4   42   e4r
# 169    경부고속철도2_2  n79    3  n75    8  e93r
# 170    경부고속철도2_2  n75    8  n72   11  e89r
# 171    경부고속철도2_2  n72   11  n60   15  e81r
# 172    경부고속철도2_2  n60   15  n59   16   e72
# 173    경부고속철도2_2  n59   16  n46   20  e66r
# 174    경부고속철도2_2  n46   20  n41   22   e55
# 175    경부고속철도2_2  n41   22  n28   29   e42
# 176    경부고속철도2_2  n28   29  n18   32  e26r
# 177    경부고속철도2_2  n18   32  n13   35   e17
# 178    경부고속철도2_2  n13   35   n2   41    e9
# 179    경부고속철도2_2   n2   41   n1   43   e1r
# 180    경부고속철도2_2   n1   43   n3   44   e3r
# 181    경부고속철도2_2   n3   44   n4   45   e4r
# 182    경부고속철도2_3  n79    6  n75   11  e93r
# 183    경부고속철도2_3  n75   11  n72   14  e89r
# 184    경부고속철도2_3  n72   14  n60   18  e81r
# 185    경부고속철도2_3  n60   18  n59   19   e72
# 186    경부고속철도2_3  n59   19  n46   23  e66r
# 187    경부고속철도2_3  n46   23  n41   25   e55
# 188    경부고속철도2_3  n41   25  n28   32   e42
# 189    경부고속철도2_3  n28   32  n18   35  e26r
# 190    경부고속철도2_3  n18   35  n13   38   e17
# 191    경부고속철도2_3  n13   38   n2   44    e9
# 192    경부고속철도2_3   n2   44   n1   46   e1r
# 193    경부고속철도2_3   n1   46   n3   47   e3r
# 194    경부고속철도2_3   n3   47   n4   48   e4r
# 195    경부고속철도2_4  n79    9  n75   14  e93r
# 196    경부고속철도2_4  n75   14  n72   17  e89r
# 197    경부고속철도2_4  n72   17  n60   21  e81r
# 198    경부고속철도2_4  n60   21  n59   22   e72
# 199    경부고속철도2_4  n59   22  n46   26  e66r
# 200    경부고속철도2_4  n46   26  n41   28   e55
# 201    경부고속철도2_4  n41   28  n28   35   e42
# 202    경부고속철도2_4  n28   35  n18   38  e26r
# 203    경부고속철도2_4  n18   38  n13   41   e17
# 204    경부고속철도2_4  n13   41   n2   47    e9
# 205    경부고속철도2_4   n2   47   n1   49   e1r
# 206    경부고속철도2_4   n1   49   n3   50   e3r
# 207    경부고속철도2_4   n3   50   n4   51   e4r
# 208    경부고속철도2_5  n79   12  n75   17  e93r
# 209    경부고속철도2_5  n75   17  n72   20  e89r
# 210    경부고속철도2_5  n72   20  n60   24  e81r
# 211    경부고속철도2_5  n60   24  n59   25   e72
# 212    경부고속철도2_5  n59   25  n46   29  e66r
# 213    경부고속철도2_5  n46   29  n41   31   e55
# 214    경부고속철도2_5  n41   31  n28   38   e42
# 215    경부고속철도2_5  n28   38  n18   41  e26r
# 216    경부고속철도2_5  n18   41  n13   44   e17
# 217    경부고속철도2_5  n13   44   n2   50    e9
# 218    경부고속철도2_5   n2   50   n1   52   e1r
# 219    경부고속철도2_5   n1   52   n3   53   e3r
# 220    경부고속철도2_5   n3   53   n4   54   e4r
# 221    경부고속철도2_6  n79   15  n75   20  e93r
# 222    경부고속철도2_6  n75   20  n72   23  e89r
# 223    경부고속철도2_6  n72   23  n60   27  e81r
# 224    경부고속철도2_6  n60   27  n59   28   e72
# 225    경부고속철도2_6  n59   28  n46   32  e66r
# 226    경부고속철도2_6  n46   32  n41   34   e55
# 227    경부고속철도2_6  n41   34  n28   41   e42
# 228    경부고속철도2_6  n28   41  n18   44  e26r
# 229    경부고속철도2_6  n18   44  n13   47   e17
# 230    경부고속철도2_6  n13   47   n2   53    e9
# 231    경부고속철도2_6   n2   53   n1   55   e1r
# 232    경부고속철도2_6   n1   55   n3   56   e3r
# 233    경부고속철도2_6   n3   56   n4   57   e4r
# 234    경부고속철도2_7  n79   18  n75   23  e93r
# 235    경부고속철도2_7  n75   23  n72   26  e89r
# 236    경부고속철도2_7  n72   26  n60   30  e81r
# 237    경부고속철도2_7  n60   30  n59   31   e72
# 238    경부고속철도2_7  n59   31  n46   35  e66r
# 239    경부고속철도2_7  n46   35  n41   37   e55
# 240    경부고속철도2_7  n41   37  n28   44   e42
# 241    경부고속철도2_7  n28   44  n18   47  e26r
# 242    경부고속철도2_7  n18   47  n13   50   e17
# 243    경부고속철도2_7  n13   50   n2   56    e9
# 244    경부고속철도2_7   n2   56   n1   58   e1r
# 245    경부고속철도2_7   n1   58   n3   59   e3r
# 246    경부고속철도2_7   n3   59   n4   60   e4r
# 247    경부고속철도2_8  n79   21  n75   26  e93r
# 248    경부고속철도2_8  n75   26  n72   29  e89r
# 249    경부고속철도2_8  n72   29  n60   33  e81r
# 250    경부고속철도2_8  n60   33  n59   34   e72
# 251    경부고속철도2_8  n59   34  n46   38  e66r
# 252    경부고속철도2_8  n46   38  n41   40   e55
# 253    경부고속철도2_8  n41   40  n28   47   e42
# 254    경부고속철도2_8  n28   47  n18   50  e26r
# 255    경부고속철도2_8  n18   50  n13   53   e17
# 256    경부고속철도2_8  n13   53   n2   59    e9
# 257    경부고속철도2_8   n2   59   n1   61   e1r
# 258    경부고속철도2_8   n1   61   n3   62   e3r
# 259    경부고속철도2_8   n3   62   n4   63   e4r
# 260    경부고속철도2_9  n79   24  n75   29  e93r
# 261    경부고속철도2_9  n75   29  n72   32  e89r
# 262    경부고속철도2_9  n72   32  n60   36  e81r
# 263    경부고속철도2_9  n60   36  n59   37   e72
# 264    경부고속철도2_9  n59   37  n46   41  e66r
# 265    경부고속철도2_9  n46   41  n41   43   e55
# 266    경부고속철도2_9  n41   43  n28   50   e42
# 267    경부고속철도2_9  n28   50  n18   53  e26r
# 268    경부고속철도2_9  n18   53  n13   56   e17
# 269    경부고속철도2_9  n13   56   n2   62    e9
# 270    경부고속철도2_9   n2   62   n1   64   e1r
# 271    경부고속철도2_9   n1   64   n3   65   e3r
# 272    경부고속철도2_9   n3   65   n4   66   e4r
# 273   경부고속철도2_10  n79   27  n75   32  e93r
# 274   경부고속철도2_10  n75   32  n72   35  e89r
# 275   경부고속철도2_10  n72   35  n60   39  e81r
# 276   경부고속철도2_10  n60   39  n59   40   e72
# 277   경부고속철도2_10  n59   40  n46   44  e66r
# 278   경부고속철도2_10  n46   44  n41   46   e55
# 279   경부고속철도2_10  n41   46  n28   53   e42
# 280   경부고속철도2_10  n28   53  n18   56  e26r
# 281   경부고속철도2_10  n18   56  n13   59   e17
# 282   경부고속철도2_10  n13   59   n2   65    e9
# 283   경부고속철도2_10   n2   65   n1   67   e1r
# 284   경부고속철도2_10   n1   67   n3   68   e3r
# 285   경부고속철도2_10   n3   68   n4   69   e4r
# 286   경부고속철도2_11  n79   30  n75   35  e93r
# 287   경부고속철도2_11  n75   35  n72   38  e89r
# 288   경부고속철도2_11  n72   38  n60   42  e81r
# 289   경부고속철도2_11  n60   42  n59   43   e72
# 290   경부고속철도2_11  n59   43  n46   47  e66r
# 291   경부고속철도2_11  n46   47  n41   49   e55
# 292   경부고속철도2_11  n41   49  n28   56   e42
# 293   경부고속철도2_11  n28   56  n18   59  e26r
# 294   경부고속철도2_11  n18   59  n13   62   e17
# 295   경부고속철도2_11  n13   62   n2   68    e9
# 296   경부고속철도2_11   n2   68   n1   70   e1r
# 297   경부고속철도2_11   n1   70   n3   71   e3r
# 298   경부고속철도2_11   n3   71   n4   72   e4r
# 299       경부선1_1   n4    0   n1    1    e2
# 300       경부선1_1   n1    1   n7    4   e6r
# 301       경부선1_1   n7    4   n9    7  e10r
# 302       경부선1_1   n9    7  n14    9   e12
# 303       경부선1_1  n14    9  n17   12  e16r
# 304       경부선1_1  n17   12  n28   16   e25
# 305       경부선1_1  n28   16  n41   23  e42r
# 306       경부선1_1  n41   23  n46   25  e55r
# 307       경부선1_1  n46   25  n59   29   e66
# 308       경부선1_1  n59   29  n60   30  e72r
# 309       경부선1_1  n60   30  n63   31   e75
# 310       경부선1_1  n63   31  n70   35   e82
# 311       경부선1_1  n70   35  n73   36   e86
# 312       경부선1_1  n73   36  n76   38   e90
# 313       경부선1_1  n76   38  n77   40   e92
# 314       경부선1_1  n77   40  n79   42   e94
# 315       경부선1_2   n4    6   n1    7    e2
# 316       경부선1_2   n1    7   n7   10   e6r
# 317       경부선1_2   n7   10   n9   13  e10r
# 318       경부선1_2   n9   13  n14   15   e12
# 319       경부선1_2  n14   15  n17   18  e16r
# 320       경부선1_2  n17   18  n28   22   e25
# 321       경부선1_2  n28   22  n41   29  e42r
# 322       경부선1_2  n41   29  n46   31  e55r
# 323       경부선1_2  n46   31  n59   35   e66
# 324       경부선1_2  n59   35  n60   36  e72r
# 325       경부선1_2  n60   36  n63   37   e75
# 326       경부선1_2  n63   37  n70   41   e82
# 327       경부선1_2  n70   41  n73   42   e86
# 328       경부선1_2  n73   42  n76   44   e90
# 329       경부선1_2  n76   44  n77   46   e92
# 330       경부선1_2  n77   46  n79   48   e94
# 331       경부선1_3   n4   12   n1   13    e2
# 332       경부선1_3   n1   13   n7   16   e6r
# 333       경부선1_3   n7   16   n9   19  e10r
# 334       경부선1_3   n9   19  n14   21   e12
# 335       경부선1_3  n14   21  n17   24  e16r
# 336       경부선1_3  n17   24  n28   28   e25
# 337       경부선1_3  n28   28  n41   35  e42r
# 338       경부선1_3  n41   35  n46   37  e55r
# 339       경부선1_3  n46   37  n59   41   e66
# 340       경부선1_3  n59   41  n60   42  e72r
# 341       경부선1_3  n60   42  n63   43   e75
# 342       경부선1_3  n63   43  n70   47   e82
# 343       경부선1_3  n70   47  n73   48   e86
# 344       경부선1_3  n73   48  n76   50   e90
# 345       경부선1_3  n76   50  n77   52   e92
# 346       경부선1_3  n77   52  n79   54   e94
# 347       경부선1_4   n4   18   n1   19    e2
# 348       경부선1_4   n1   19   n7   22   e6r
# 349       경부선1_4   n7   22   n9   25  e10r
# 350       경부선1_4   n9   25  n14   27   e12
# 351       경부선1_4  n14   27  n17   30  e16r
# 352       경부선1_4  n17   30  n28   34   e25
# 353       경부선1_4  n28   34  n41   41  e42r
# 354       경부선1_4  n41   41  n46   43  e55r
# 355       경부선1_4  n46   43  n59   47   e66
# 356       경부선1_4  n59   47  n60   48  e72r
# 357       경부선1_4  n60   48  n63   49   e75
# 358       경부선1_4  n63   49  n70   53   e82
# 359       경부선1_4  n70   53  n73   54   e86
# 360       경부선1_4  n73   54  n76   56   e90
# 361       경부선1_4  n76   56  n77   58   e92
# 362       경부선1_4  n77   58  n79   60   e94
# 363       경부선1_5   n4   24   n1   25    e2
# 364       경부선1_5   n1   25   n7   28   e6r
# 365       경부선1_5   n7   28   n9   31  e10r
# 366       경부선1_5   n9   31  n14   33   e12
# 367       경부선1_5  n14   33  n17   36  e16r
# 368       경부선1_5  n17   36  n28   40   e25
# 369       경부선1_5  n28   40  n41   47  e42r
# 370       경부선1_5  n41   47  n46   49  e55r
# 371       경부선1_5  n46   49  n59   53   e66
# 372       경부선1_5  n59   53  n60   54  e72r
# 373       경부선1_5  n60   54  n63   55   e75
# 374       경부선1_5  n63   55  n70   59   e82
# 375       경부선1_5  n70   59  n73   60   e86
# 376       경부선1_5  n73   60  n76   62   e90
# 377       경부선1_5  n76   62  n77   64   e92
# 378       경부선1_5  n77   64  n79   66   e94
# 379       경부선1_6   n4   30   n1   31    e2
# 380       경부선1_6   n1   31   n7   34   e6r
# 381       경부선1_6   n7   34   n9   37  e10r
# 382       경부선1_6   n9   37  n14   39   e12
# 383       경부선1_6  n14   39  n17   42  e16r
# 384       경부선1_6  n17   42  n28   46   e25
# 385       경부선1_6  n28   46  n41   53  e42r
# 386       경부선1_6  n41   53  n46   55  e55r
# 387       경부선1_6  n46   55  n59   59   e66
# 388       경부선1_6  n59   59  n60   60  e72r
# 389       경부선1_6  n60   60  n63   61   e75
# 390       경부선1_6  n63   61  n70   65   e82
# 391       경부선1_6  n70   65  n73   66   e86
# 392       경부선1_6  n73   66  n76   68   e90
# 393       경부선1_6  n76   68  n77   70   e92
# 394       경부선1_6  n77   70  n79   72   e94
# 395       경부선2_1  n79    0  n77    2  e94r
# 396       경부선2_1  n77    2  n76    4  e92r
# 397       경부선2_1  n76    4  n73    6  e90r
# 398       경부선2_1  n73    6  n70    7  e86r
# 399       경부선2_1  n70    7  n63   11  e82r
# 400       경부선2_1  n63   11  n60   12  e75r
# 401       경부선2_1  n60   12  n59   13   e72
# 402       경부선2_1  n59   13  n46   17  e66r
# 403       경부선2_1  n46   17  n41   19   e55
# 404       경부선2_1  n41   19  n28   26   e42
# 405       경부선2_1  n28   26  n17   30  e25r
# 406       경부선2_1  n17   30  n14   33   e16
# 407       경부선2_1  n14   33   n9   35  e12r
# 408       경부선2_1   n9   35   n7   38   e10
# 409       경부선2_1   n7   38   n1   41    e6
# 410       경부선2_1   n1   41   n4   42   e2r
# 411       경부선2_2  n79    6  n77    8  e94r
# 412       경부선2_2  n77    8  n76   10  e92r
# 413       경부선2_2  n76   10  n73   12  e90r
# 414       경부선2_2  n73   12  n70   13  e86r
# 415       경부선2_2  n70   13  n63   17  e82r
# 416       경부선2_2  n63   17  n60   18  e75r
# 417       경부선2_2  n60   18  n59   19   e72
# 418       경부선2_2  n59   19  n46   23  e66r
# 419       경부선2_2  n46   23  n41   25   e55
# 420       경부선2_2  n41   25  n28   32   e42
# 421       경부선2_2  n28   32  n17   36  e25r
# 422       경부선2_2  n17   36  n14   39   e16
# 423       경부선2_2  n14   39   n9   41  e12r
# 424       경부선2_2   n9   41   n7   44   e10
# 425       경부선2_2   n7   44   n1   47    e6
# 426       경부선2_2   n1   47   n4   48   e2r
# 427       경부선2_3  n79   12  n77   14  e94r
# 428       경부선2_3  n77   14  n76   16  e92r
# 429       경부선2_3  n76   16  n73   18  e90r
# 430       경부선2_3  n73   18  n70   19  e86r
# 431       경부선2_3  n70   19  n63   23  e82r
# 432       경부선2_3  n63   23  n60   24  e75r
# 433       경부선2_3  n60   24  n59   25   e72
# 434       경부선2_3  n59   25  n46   29  e66r
# 435       경부선2_3  n46   29  n41   31   e55
# 436       경부선2_3  n41   31  n28   38   e42
# 437       경부선2_3  n28   38  n17   42  e25r
# 438       경부선2_3  n17   42  n14   45   e16
# 439       경부선2_3  n14   45   n9   47  e12r
# 440       경부선2_3   n9   47   n7   50   e10
# 441       경부선2_3   n7   50   n1   53    e6
# 442       경부선2_3   n1   53   n4   54   e2r
# 443       경부선2_4  n79   18  n77   20  e94r
# 444       경부선2_4  n77   20  n76   22  e92r
# 445       경부선2_4  n76   22  n73   24  e90r
# 446       경부선2_4  n73   24  n70   25  e86r
# 447       경부선2_4  n70   25  n63   29  e82r
# 448       경부선2_4  n63   29  n60   30  e75r
# 449       경부선2_4  n60   30  n59   31   e72
# 450       경부선2_4  n59   31  n46   35  e66r
# 451       경부선2_4  n46   35  n41   37   e55
# 452       경부선2_4  n41   37  n28   44   e42
# 453       경부선2_4  n28   44  n17   48  e25r
# 454       경부선2_4  n17   48  n14   51   e16
# 455       경부선2_4  n14   51   n9   53  e12r
# 456       경부선2_4   n9   53   n7   56   e10
# 457       경부선2_4   n7   56   n1   59    e6
# 458       경부선2_4   n1   59   n4   60   e2r
# 459       경부선2_5  n79   24  n77   26  e94r
# 460       경부선2_5  n77   26  n76   28  e92r
# 461       경부선2_5  n76   28  n73   30  e90r
# 462       경부선2_5  n73   30  n70   31  e86r
# 463       경부선2_5  n70   31  n63   35  e82r
# 464       경부선2_5  n63   35  n60   36  e75r
# 465       경부선2_5  n60   36  n59   37   e72
# 466       경부선2_5  n59   37  n46   41  e66r
# 467       경부선2_5  n46   41  n41   43   e55
# 468       경부선2_5  n41   43  n28   50   e42
# 469       경부선2_5  n28   50  n17   54  e25r
# 470       경부선2_5  n17   54  n14   57   e16
# 471       경부선2_5  n14   57   n9   59  e12r
# 472       경부선2_5   n9   59   n7   62   e10
# 473       경부선2_5   n7   62   n1   65    e6
# 474       경부선2_5   n1   65   n4   66   e2r
# 475       경부선2_6  n79   30  n77   32  e94r
# 476       경부선2_6  n77   32  n76   34  e92r
# 477       경부선2_6  n76   34  n73   36  e90r
# 478       경부선2_6  n73   36  n70   37  e86r
# 479       경부선2_6  n70   37  n63   41  e82r
# 480       경부선2_6  n63   41  n60   42  e75r
# 481       경부선2_6  n60   42  n59   43   e72
# 482       경부선2_6  n59   43  n46   47  e66r
# 483       경부선2_6  n46   47  n41   49   e55
# 484       경부선2_6  n41   49  n28   56   e42
# 485       경부선2_6  n28   56  n17   60  e25r
# 486       경부선2_6  n17   60  n14   63   e16
# 487       경부선2_6  n14   63   n9   65  e12r
# 488       경부선2_6   n9   65   n7   68   e10
# 489       경부선2_6   n7   68   n1   71    e6
# 490       경부선2_6   n1   71   n4   72   e2r
# 491       경북선1_1  n43    0  n40    3   e53
# 492       경북선1_1  n40    3  n36    5   e47
# 493       경북선1_1  n36    5  n38    7   e45
# 494       경북선1_1  n38    7  n41   10   e49
# 495       경북선2_1  n41    0  n38    3  e49r
# 496       경북선2_1  n38    3  n36    5  e45r
# 497       경북선2_1  n36    5  n40    7  e47r
# 498       경북선2_1  n40    7  n43   10  e53r
# 499       경전선1_1  n48    0  n57    3   e65
# 500       경전선1_1  n57    3  n64    6   e74
# 501       경전선1_1  n64    6  n65    9  e79r
# 502       경전선1_1  n65    9  n62   11  e76r
# 503       경전선1_1  n62   11  n66   17  e78r
# 504       경전선1_1  n66   17  n71   21  e83r
# 505       경전선1_1  n71   21  n73   25  e87r
# 506       경전선1_2  n48   18  n57   21   e65
# 507       경전선1_2  n57   21  n64   24   e74
# 508       경전선1_2  n64   24  n65   27  e79r
# 509       경전선1_2  n65   27  n62   29  e76r
# 510       경전선1_2  n62   29  n66   35  e78r
# 511       경전선1_2  n66   35  n71   39  e83r
# 512       경전선1_2  n71   39  n73   43  e87r
# 513       경전선2_1  n73    0  n71    4   e87
# 514       경전선2_1  n71    4  n66    8   e83
# 515       경전선2_1  n66    8  n62   14   e78
# 516       경전선2_1  n62   14  n65   16   e76
# 517       경전선2_1  n65   16  n64   19   e79
# 518       경전선2_1  n64   19  n57   22  e74r
# 519       경전선2_1  n57   22  n48   25  e65r
# 520       경전선2_2  n73   18  n71   22   e87
# 521       경전선2_2  n71   22  n66   26   e83
# 522       경전선2_2  n66   26  n62   32   e78
# 523       경전선2_2  n62   32  n65   34   e76
# 524       경전선2_2  n65   34  n64   37   e79
# 525       경전선2_2  n64   37  n57   40  e74r
# 526       경전선2_2  n57   40  n48   43  e65r
# 527       동해선1_1  n55    0  n58    2   e69
# 528       동해선1_1  n58    2  n69    8   e77
# 529       동해선1_1  n69    8  n74   12   e85
# 530       동해선1_1  n74   12  n72   15   e88
# 531       동해선1_2  n55   18  n58   20   e69
# 532       동해선1_2  n58   20  n69   26   e77
# 533       동해선1_2  n69   26  n74   30   e85
# 534       동해선1_2  n74   30  n72   33   e88
# 535       동해선2_1  n72    0  n74    3  e88r
# 536       동해선2_1  n74    3  n69    7  e85r
# 537       동해선2_1  n69    7  n58   13  e77r
# 538       동해선2_1  n58   13  n55   15  e69r
# 539       동해선2_2  n72   18  n74   21  e88r
# 540       동해선2_2  n74   21  n69   25  e85r
# 541       동해선2_2  n69   25  n58   31  e77r
# 542       동해선2_2  n58   31  n55   33  e69r
# 543       영동선1_1  n51    0  n55    3   e67
# 544       영동선1_1  n55    3  n54    8   e68
# 545       영동선1_1  n54    8  n50   13   e64
# 546       영동선1_1  n50   13  n43   17   e58
# 547       영동선2_1  n43    0  n50    4  e58r
# 548       영동선2_1  n50    4  n54    9  e64r
# 549       영동선2_1  n54    9  n55   14  e68r
# 550       영동선2_1  n55   14  n51   17  e67r
# 551       장항선1_1  n14    0  n11    2   e14
# 552       장항선1_1  n11    2  n10    4   e13
# 553       장항선1_1  n10    4  n15    7   e15
# 554       장항선1_1  n15    7  n16    9   e18
# 555       장항선1_1  n16    9  n27   12   e24
# 556       장항선1_1  n27   12  n30   15  e35r
# 557       장항선1_2  n14    9  n11   11   e14
# 558       장항선1_2  n11   11  n10   13   e13
# 559       장항선1_2  n10   13  n15   16   e15
# 560       장항선1_2  n15   16  n16   18   e18
# 561       장항선1_2  n16   18  n27   21   e24
# 562       장항선1_2  n27   21  n30   24  e35r
# 563       장항선1_3  n14   18  n11   20   e14
# 564       장항선1_3  n11   20  n10   22   e13
# 565       장항선1_3  n10   22  n15   25   e15
# 566       장항선1_3  n15   25  n16   27   e18
# 567       장항선1_3  n16   27  n27   30   e24
# 568       장항선1_3  n27   30  n30   33  e35r
# 569       장항선2_1  n30    0  n27    3   e35
# 570       장항선2_1  n27    3  n16    6  e24r
# 571       장항선2_1  n16    6  n15    8  e18r
# 572       장항선2_1  n15    8  n10   11  e15r
# 573       장항선2_1  n10   11  n11   13  e13r
# 574       장항선2_1  n11   13  n14   15  e14r
# 575       장항선2_2  n30    9  n27   12   e35
# 576       장항선2_2  n27   12  n16   15  e24r
# 577       장항선2_2  n16   15  n15   17  e18r
# 578       장항선2_2  n15   17  n10   20  e15r
# 579       장항선2_2  n10   20  n11   22  e13r
# 580       장항선2_2  n11   22  n14   24  e14r
# 581       장항선2_3  n30   18  n27   21   e35
# 582       장항선2_3  n27   21  n16   24  e24r
# 583       장항선2_3  n16   24  n15   26  e18r
# 584       장항선2_3  n15   26  n10   29  e15r
# 585       장항선2_3  n10   29  n11   31  e13r
# 586       장항선2_3  n11   31  n14   33  e14r
# 587       전라선1_1  n30    0  n33    3  e39r
# 588       전라선1_1  n33    3  n45    8   e48
# 589       전라선1_1  n45    8  n47   10   e59
# 590       전라선1_1  n47   10  n56   12   e63
# 591       전라선1_1  n56   12  n62   15   e71
# 592       전라선1_1  n62   15  n68   18   e80
# 593       전라선1_2  n30   12  n33   15  e39r
# 594       전라선1_2  n33   15  n45   20   e48
# 595       전라선1_2  n45   20  n47   22   e59
# 596       전라선1_2  n47   22  n56   24   e63
# 597       전라선1_2  n56   24  n62   27   e71
# 598       전라선1_2  n62   27  n68   30   e80
# 599       전라선1_3  n30   24  n33   27  e39r
# 600       전라선1_3  n33   27  n45   32   e48
# 601       전라선1_3  n45   32  n47   34   e59
# 602       전라선1_3  n47   34  n56   36   e63
# 603       전라선1_3  n56   36  n62   39   e71
# 604       전라선1_3  n62   39  n68   42   e80
# 605       전라선2_1  n68    0  n62    3  e80r
# 606       전라선2_1  n62    3  n56    6  e71r
# 607       전라선2_1  n56    6  n47    8  e63r
# 608       전라선2_1  n47    8  n45   10  e59r
# 609       전라선2_1  n45   10  n33   15  e48r
# 610       전라선2_1  n33   15  n30   18   e39
# 611       전라선2_2  n68   12  n62   15  e80r
# 612       전라선2_2  n62   15  n56   18  e71r
# 613       전라선2_2  n56   18  n47   20  e63r
# 614       전라선2_2  n47   20  n45   22  e59r
# 615       전라선2_2  n45   22  n33   27  e48r
# 616       전라선2_2  n33   27  n30   30   e39
# 617       전라선2_3  n68   24  n62   27  e80r
# 618       전라선2_3  n62   27  n56   30  e71r
# 619       전라선2_3  n56   30  n47   32  e63r
# 620       전라선2_3  n47   32  n45   34  e59r
# 621       전라선2_3  n45   34  n33   39  e48r
# 622       전라선2_3  n33   39  n30   42   e39
# 623       중앙선1_1   n3    0   n5    1   e5r
# 624       중앙선1_1   n5    1   n6    2   e7r
# 625       중앙선1_1   n6    2   n8    4   e8r
# 626       중앙선1_1   n8    4  n12    7  e11r
# 627       중앙선1_1  n12    7  n22   11  e19r
# 628       중앙선1_1  n22   11  n29   14  e32r
# 629       중앙선1_1  n29   14  n31   15  e37r
# 630       중앙선1_1  n31   15  n35   18  e40r
# 631       중앙선1_1  n35   18  n39   20  e46r
# 632       중앙선1_1  n39   20  n43   21   e52
# 633       중앙선1_1  n43   21  n49   24   e56
# 634       중앙선1_1  n49   24  n52   27   e60
# 635       중앙선1_1  n52   27  n67   32   e73
# 636       중앙선1_1  n67   32  n72   36   e84
# 637       중앙선1_1  n72   36  n78   40   e91
# 638       중앙선1_1  n78   40  n79   46   e95
# 639       중앙선1_2   n3    6   n5    7   e5r
# 640       중앙선1_2   n5    7   n6    8   e7r
# 641       중앙선1_2   n6    8   n8   10   e8r
# 642       중앙선1_2   n8   10  n12   13  e11r
# 643       중앙선1_2  n12   13  n22   17  e19r
# 644       중앙선1_2  n22   17  n29   20  e32r
# 645       중앙선1_2  n29   20  n31   21  e37r
# 646       중앙선1_2  n31   21  n35   24  e40r
# 647       중앙선1_2  n35   24  n39   26  e46r
# 648       중앙선1_2  n39   26  n43   27   e52
# 649       중앙선1_2  n43   27  n49   30   e56
# 650       중앙선1_2  n49   30  n52   33   e60
# 651       중앙선1_2  n52   33  n67   38   e73
# 652       중앙선1_2  n67   38  n72   42   e84
# 653       중앙선1_2  n72   42  n78   46   e91
# 654       중앙선1_2  n78   46  n79   52   e95
# 655       중앙선1_3   n3   12   n5   13   e5r
# 656       중앙선1_3   n5   13   n6   14   e7r
# 657       중앙선1_3   n6   14   n8   16   e8r
# 658       중앙선1_3   n8   16  n12   19  e11r
# 659       중앙선1_3  n12   19  n22   23  e19r
# 660       중앙선1_3  n22   23  n29   26  e32r
# 661       중앙선1_3  n29   26  n31   27  e37r
# 662       중앙선1_3  n31   27  n35   30  e40r
# 663       중앙선1_3  n35   30  n39   32  e46r
# 664       중앙선1_3  n39   32  n43   33   e52
# 665       중앙선1_3  n43   33  n49   36   e56
# 666       중앙선1_3  n49   36  n52   39   e60
# 667       중앙선1_3  n52   39  n67   44   e73
# 668       중앙선1_3  n67   44  n72   48   e84
# 669       중앙선1_3  n72   48  n78   52   e91
# 670       중앙선1_3  n78   52  n79   58   e95
# 671       중앙선1_4   n3   18   n5   19   e5r
# 672       중앙선1_4   n5   19   n6   20   e7r
# 673       중앙선1_4   n6   20   n8   22   e8r
# 674       중앙선1_4   n8   22  n12   25  e11r
# 675       중앙선1_4  n12   25  n22   29  e19r
# 676       중앙선1_4  n22   29  n29   32  e32r
# 677       중앙선1_4  n29   32  n31   33  e37r
# 678       중앙선1_4  n31   33  n35   36  e40r
# 679       중앙선1_4  n35   36  n39   38  e46r
# 680       중앙선1_4  n39   38  n43   39   e52
# 681       중앙선1_4  n43   39  n49   42   e56
# 682       중앙선1_4  n49   42  n52   45   e60
# 683       중앙선1_4  n52   45  n67   50   e73
# 684       중앙선1_4  n67   50  n72   54   e84
# 685       중앙선1_4  n72   54  n78   58   e91
# 686       중앙선1_4  n78   58  n79   64   e95
# 687       중앙선1_5   n3   24   n5   25   e5r
# 688       중앙선1_5   n5   25   n6   26   e7r
# 689       중앙선1_5   n6   26   n8   28   e8r
# 690       중앙선1_5   n8   28  n12   31  e11r
# 691       중앙선1_5  n12   31  n22   35  e19r
# 692       중앙선1_5  n22   35  n29   38  e32r
# 693       중앙선1_5  n29   38  n31   39  e37r
# 694       중앙선1_5  n31   39  n35   42  e40r
# 695       중앙선1_5  n35   42  n39   44  e46r
# 696       중앙선1_5  n39   44  n43   45   e52
# 697       중앙선1_5  n43   45  n49   48   e56
# 698       중앙선1_5  n49   48  n52   51   e60
# 699       중앙선1_5  n52   51  n67   56   e73
# 700       중앙선1_5  n67   56  n72   60   e84
# 701       중앙선1_5  n72   60  n78   64   e91
# 702       중앙선1_5  n78   64  n79   70   e95
# 703       중앙선1_6   n3   30   n5   31   e5r
# 704       중앙선1_6   n5   31   n6   32   e7r
# 705       중앙선1_6   n6   32   n8   34   e8r
# 706       중앙선1_6   n8   34  n12   37  e11r
# 707       중앙선1_6  n12   37  n22   41  e19r
# 708       중앙선1_6  n22   41  n29   44  e32r
# 709       중앙선1_6  n29   44  n31   45  e37r
# 710       중앙선1_6  n31   45  n35   48  e40r
# 711       중앙선1_6  n35   48  n39   50  e46r
# 712       중앙선1_6  n39   50  n43   51   e52
# 713       중앙선1_6  n43   51  n49   54   e56
# 714       중앙선1_6  n49   54  n52   57   e60
# 715       중앙선1_6  n52   57  n67   62   e73
# 716       중앙선1_6  n67   62  n72   66   e84
# 717       중앙선1_6  n72   66  n78   70   e91
# 718       중앙선1_6  n78   70  n79   76   e95
# 719       중앙선2_1  n79    0  n78    6  e95r
# 720       중앙선2_1  n78    6  n72   10  e91r
# 721       중앙선2_1  n72   10  n67   14  e84r
# 722       중앙선2_1  n67   14  n52   19  e73r
# 723       중앙선2_1  n52   19  n49   22  e60r
# 724       중앙선2_1  n49   22  n43   25  e56r
# 725       중앙선2_1  n43   25  n39   26  e52r
# 726       중앙선2_1  n39   26  n35   28   e46
# 727       중앙선2_1  n35   28  n31   31   e40
# 728       중앙선2_1  n31   31  n29   32   e37
# 729       중앙선2_1  n29   32  n22   35   e32
# 730       중앙선2_1  n22   35  n12   39   e19
# 731       중앙선2_1  n12   39   n8   42   e11
# 732       중앙선2_1   n8   42   n6   44    e8
# 733       중앙선2_1   n6   44   n5   45    e7
# 734       중앙선2_1   n5   45   n3   46    e5
# 735       중앙선2_2  n79    6  n78   12  e95r
# 736       중앙선2_2  n78   12  n72   16  e91r
# 737       중앙선2_2  n72   16  n67   20  e84r
# 738       중앙선2_2  n67   20  n52   25  e73r
# 739       중앙선2_2  n52   25  n49   28  e60r
# 740       중앙선2_2  n49   28  n43   31  e56r
# 741       중앙선2_2  n43   31  n39   32  e52r
# 742       중앙선2_2  n39   32  n35   34   e46
# 743       중앙선2_2  n35   34  n31   37   e40
# 744       중앙선2_2  n31   37  n29   38   e37
# 745       중앙선2_2  n29   38  n22   41   e32
# 746       중앙선2_2  n22   41  n12   45   e19
# 747       중앙선2_2  n12   45   n8   48   e11
# 748       중앙선2_2   n8   48   n6   50    e8
# 749       중앙선2_2   n6   50   n5   51    e7
# 750       중앙선2_2   n5   51   n3   52    e5
# 751       중앙선2_3  n79   12  n78   18  e95r
# 752       중앙선2_3  n78   18  n72   22  e91r
# 753       중앙선2_3  n72   22  n67   26  e84r
# 754       중앙선2_3  n67   26  n52   31  e73r
# 755       중앙선2_3  n52   31  n49   34  e60r
# 756       중앙선2_3  n49   34  n43   37  e56r
# 757       중앙선2_3  n43   37  n39   38  e52r
# 758       중앙선2_3  n39   38  n35   40   e46
# 759       중앙선2_3  n35   40  n31   43   e40
# 760       중앙선2_3  n31   43  n29   44   e37
# 761       중앙선2_3  n29   44  n22   47   e32
# 762       중앙선2_3  n22   47  n12   51   e19
# 763       중앙선2_3  n12   51   n8   54   e11
# 764       중앙선2_3   n8   54   n6   56    e8
# 765       중앙선2_3   n6   56   n5   57    e7
# 766       중앙선2_3   n5   57   n3   58    e5
# 767       중앙선2_4  n79   18  n78   24  e95r
# 768       중앙선2_4  n78   24  n72   28  e91r
# 769       중앙선2_4  n72   28  n67   32  e84r
# 770       중앙선2_4  n67   32  n52   37  e73r
# 771       중앙선2_4  n52   37  n49   40  e60r
# 772       중앙선2_4  n49   40  n43   43  e56r
# 773       중앙선2_4  n43   43  n39   44  e52r
# 774       중앙선2_4  n39   44  n35   46   e46
# 775       중앙선2_4  n35   46  n31   49   e40
# 776       중앙선2_4  n31   49  n29   50   e37
# 777       중앙선2_4  n29   50  n22   53   e32
# 778       중앙선2_4  n22   53  n12   57   e19
# 779       중앙선2_4  n12   57   n8   60   e11
# 780       중앙선2_4   n8   60   n6   62    e8
# 781       중앙선2_4   n6   62   n5   63    e7
# 782       중앙선2_4   n5   63   n3   64    e5
# 783       중앙선2_5  n79   24  n78   30  e95r
# 784       중앙선2_5  n78   30  n72   34  e91r
# 785       중앙선2_5  n72   34  n67   38  e84r
# 786       중앙선2_5  n67   38  n52   43  e73r
# 787       중앙선2_5  n52   43  n49   46  e60r
# 788       중앙선2_5  n49   46  n43   49  e56r
# 789       중앙선2_5  n43   49  n39   50  e52r
# 790       중앙선2_5  n39   50  n35   52   e46
# 791       중앙선2_5  n35   52  n31   55   e40
# 792       중앙선2_5  n31   55  n29   56   e37
# 793       중앙선2_5  n29   56  n22   59   e32
# 794       중앙선2_5  n22   59  n12   63   e19
# 795       중앙선2_5  n12   63   n8   66   e11
# 796       중앙선2_5   n8   66   n6   68    e8
# 797       중앙선2_5   n6   68   n5   69    e7
# 798       중앙선2_5   n5   69   n3   70    e5
# 799       중앙선2_6  n79   30  n78   36  e95r
# 800       중앙선2_6  n78   36  n72   40  e91r
# 801       중앙선2_6  n72   40  n67   44  e84r
# 802       중앙선2_6  n67   44  n52   49  e73r
# 803       중앙선2_6  n52   49  n49   52  e60r
# 804       중앙선2_6  n49   52  n43   55  e56r
# 805       중앙선2_6  n43   55  n39   56  e52r
# 806       중앙선2_6  n39   56  n35   58   e46
# 807       중앙선2_6  n35   58  n31   61   e40
# 808       중앙선2_6  n31   61  n29   62   e37
# 809       중앙선2_6  n29   62  n22   65   e32
# 810       중앙선2_6  n22   65  n12   69   e19
# 811       중앙선2_6  n12   69   n8   72   e11
# 812       중앙선2_6   n8   72   n6   74    e8
# 813       중앙선2_6   n6   74   n5   75    e7
# 814       중앙선2_6   n5   75   n3   76    e5
# 815       충북선1_1  n29    0  n26    3   e34
# 816       충북선1_1  n26    3  n20    6   e27
# 817       충북선1_1  n20    6  n19   10   e23
# 818       충북선1_1  n19   10  n18   11   e21
# 819       충북선1_1  n18   11  n17   13   e20
# 820       충북선1_2  n29   12  n26   15   e34
# 821       충북선1_2  n26   15  n20   18   e27
# 822       충북선1_2  n20   18  n19   22   e23
# 823       충북선1_2  n19   22  n18   23   e21
# 824       충북선1_2  n18   23  n17   25   e20
# 825       충북선1_3  n29   24  n26   27   e34
# 826       충북선1_3  n26   27  n20   30   e27
# 827       충북선1_3  n20   30  n19   34   e23
# 828       충북선1_3  n19   34  n18   35   e21
# 829       충북선1_3  n18   35  n17   37   e20
# 830       충북선2_1  n17    0  n18    2  e20r
# 831       충북선2_1  n18    2  n19    3  e21r
# 832       충북선2_1  n19    3  n20    7  e23r
# 833       충북선2_1  n20    7  n26   10  e27r
# 834       충북선2_1  n26   10  n29   13  e34r
# 835       충북선2_2  n17   12  n18   14  e20r
# 836       충북선2_2  n18   14  n19   15  e21r
# 837       충북선2_2  n19   15  n20   19  e23r
# 838       충북선2_2  n20   19  n26   22  e27r
# 839       충북선2_2  n26   22  n29   25  e34r
# 840       충북선2_3  n17   24  n18   26  e20r
# 841       충북선2_3  n18   26  n19   27  e21r
# 842       충북선2_3  n19   27  n20   31  e23r
# 843       충북선2_3  n20   31  n26   34  e27r
# 844       충북선2_3  n26   34  n29   37  e34r
# 845    호남고속철도1_1   n3    0   n1    1    e3
# 846    호남고속철도1_1   n1    1   n2    3    e1
# 847    호남고속철도1_1   n2    3  n13    9   e9r
# 848    호남고속철도1_1  n13    9  n18   12  e17r
# 849    호남고속철도1_1  n18   12  n21   16   e22
# 850    호남고속철도1_1  n21   16  n30   20   e30
# 851    호남고속철도1_1  n30   20  n37   24   e41
# 852    호남고속철도1_1  n37   24  n48   29   e54
# 853    호남고속철도1_2   n3    6   n1    7    e3
# 854    호남고속철도1_2   n1    7   n2    9    e1
# 855    호남고속철도1_2   n2    9  n13   15   e9r
# 856    호남고속철도1_2  n13   15  n18   18  e17r
# 857    호남고속철도1_2  n18   18  n21   22   e22
# 858    호남고속철도1_2  n21   22  n30   26   e30
# 859    호남고속철도1_2  n30   26  n37   30   e41
# 860    호남고속철도1_2  n37   30  n48   35   e54
# 861    호남고속철도1_3   n3   12   n1   13    e3
# 862    호남고속철도1_3   n1   13   n2   15    e1
# 863    호남고속철도1_3   n2   15  n13   21   e9r
# 864    호남고속철도1_3  n13   21  n18   24  e17r
# 865    호남고속철도1_3  n18   24  n21   28   e22
# 866    호남고속철도1_3  n21   28  n30   32   e30
# 867    호남고속철도1_3  n30   32  n37   36   e41
# 868    호남고속철도1_3  n37   36  n48   41   e54
# 869    호남고속철도1_4   n3   18   n1   19    e3
# 870    호남고속철도1_4   n1   19   n2   21    e1
# 871    호남고속철도1_4   n2   21  n13   27   e9r
# 872    호남고속철도1_4  n13   27  n18   30  e17r
# 873    호남고속철도1_4  n18   30  n21   34   e22
# 874    호남고속철도1_4  n21   34  n30   38   e30
# 875    호남고속철도1_4  n30   38  n37   42   e41
# 876    호남고속철도1_4  n37   42  n48   47   e54
# 877    호남고속철도1_5   n3   24   n1   25    e3
# 878    호남고속철도1_5   n1   25   n2   27    e1
# 879    호남고속철도1_5   n2   27  n13   33   e9r
# 880    호남고속철도1_5  n13   33  n18   36  e17r
# 881    호남고속철도1_5  n18   36  n21   40   e22
# 882    호남고속철도1_5  n21   40  n30   44   e30
# 883    호남고속철도1_5  n30   44  n37   48   e41
# 884    호남고속철도1_5  n37   48  n48   53   e54
# 885    호남고속철도1_6   n3   30   n1   31    e3
# 886    호남고속철도1_6   n1   31   n2   33    e1
# 887    호남고속철도1_6   n2   33  n13   39   e9r
# 888    호남고속철도1_6  n13   39  n18   42  e17r
# 889    호남고속철도1_6  n18   42  n21   46   e22
# 890    호남고속철도1_6  n21   46  n30   50   e30
# 891    호남고속철도1_6  n30   50  n37   54   e41
# 892    호남고속철도1_6  n37   54  n48   59   e54
# 893    호남고속철도2_1  n48    0  n37    5  e54r
# 894    호남고속철도2_1  n37    5  n30    9  e41r
# 895    호남고속철도2_1  n30    9  n21   13  e30r
# 896    호남고속철도2_1  n21   13  n18   17  e22r
# 897    호남고속철도2_1  n18   17  n13   20   e17
# 898    호남고속철도2_1  n13   20   n2   26    e9
# 899    호남고속철도2_1   n2   26   n1   28   e1r
# 900    호남고속철도2_1   n1   28   n3   29   e3r
# 901    호남고속철도2_2  n48    6  n37   11  e54r
# 902    호남고속철도2_2  n37   11  n30   15  e41r
# 903    호남고속철도2_2  n30   15  n21   19  e30r
# 904    호남고속철도2_2  n21   19  n18   23  e22r
# 905    호남고속철도2_2  n18   23  n13   26   e17
# 906    호남고속철도2_2  n13   26   n2   32    e9
# 907    호남고속철도2_2   n2   32   n1   34   e1r
# 908    호남고속철도2_2   n1   34   n3   35   e3r
# 909    호남고속철도2_3  n48   12  n37   17  e54r
# 910    호남고속철도2_3  n37   17  n30   21  e41r
# 911    호남고속철도2_3  n30   21  n21   25  e30r
# 912    호남고속철도2_3  n21   25  n18   29  e22r
# 913    호남고속철도2_3  n18   29  n13   32   e17
# 914    호남고속철도2_3  n13   32   n2   38    e9
# 915    호남고속철도2_3   n2   38   n1   40   e1r
# 916    호남고속철도2_3   n1   40   n3   41   e3r
# 917    호남고속철도2_4  n48   18  n37   23  e54r
# 918    호남고속철도2_4  n37   23  n30   27  e41r
# 919    호남고속철도2_4  n30   27  n21   31  e30r
# 920    호남고속철도2_4  n21   31  n18   35  e22r
# 921    호남고속철도2_4  n18   35  n13   38   e17
# 922    호남고속철도2_4  n13   38   n2   44    e9
# 923    호남고속철도2_4   n2   44   n1   46   e1r
# 924    호남고속철도2_4   n1   46   n3   47   e3r
# 925    호남고속철도2_5  n48   24  n37   29  e54r
# 926    호남고속철도2_5  n37   29  n30   33  e41r
# 927    호남고속철도2_5  n30   33  n21   37  e30r
# 928    호남고속철도2_5  n21   37  n18   41  e22r
# 929    호남고속철도2_5  n18   41  n13   44   e17
# 930    호남고속철도2_5  n13   44   n2   50    e9
# 931    호남고속철도2_5   n2   50   n1   52   e1r
# 932    호남고속철도2_5   n1   52   n3   53   e3r
# 933    호남고속철도2_6  n48   30  n37   35  e54r
# 934    호남고속철도2_6  n37   35  n30   39  e41r
# 935    호남고속철도2_6  n30   39  n21   43  e30r
# 936    호남고속철도2_6  n21   43  n18   47  e22r
# 937    호남고속철도2_6  n18   47  n13   50   e17
# 938    호남고속철도2_6  n13   50   n2   56    e9
# 939    호남고속철도2_6   n2   56   n1   58   e1r
# 940    호남고속철도2_6   n1   58   n3   59   e3r
# 941       호남선1_1  n28    0  n25    2   e31
# 942       호남선1_1  n25    2  n24    5   e29
# 943       호남선1_1  n24    5  n30    8   e33
# 944       호남선1_1  n30    8  n32   10   e38
# 945       호남선1_1  n32   10  n37   13   e44
# 946       호남선1_1  n37   13  n44   16   e50
# 947       호남선1_1  n44   16  n48   18   e57
# 948       호남선1_1  n48   18  n53   20   e62
# 949       호남선1_1  n53   20  n61   25   e70
# 950       호남선1_2  n28    6  n25    8   e31
# 951       호남선1_2  n25    8  n24   11   e29
# 952       호남선1_2  n24   11  n30   14   e33
# 953       호남선1_2  n30   14  n32   16   e38
# 954       호남선1_2  n32   16  n37   19   e44
# 955       호남선1_2  n37   19  n44   22   e50
# 956       호남선1_2  n44   22  n48   24   e57
# 957       호남선1_2  n48   24  n53   26   e62
# 958       호남선1_2  n53   26  n61   31   e70
# 959       호남선1_3  n28   12  n25   14   e31
# 960       호남선1_3  n25   14  n24   17   e29
# 961       호남선1_3  n24   17  n30   20   e33
# 962       호남선1_3  n30   20  n32   22   e38
# 963       호남선1_3  n32   22  n37   25   e44
# 964       호남선1_3  n37   25  n44   28   e50
# 965       호남선1_3  n44   28  n48   30   e57
# 966       호남선1_3  n48   30  n53   32   e62
# 967       호남선1_3  n53   32  n61   37   e70
# 968       호남선1_4  n28   18  n25   20   e31
# 969       호남선1_4  n25   20  n24   23   e29
# 970       호남선1_4  n24   23  n30   26   e33
# 971       호남선1_4  n30   26  n32   28   e38
# 972       호남선1_4  n32   28  n37   31   e44
# 973       호남선1_4  n37   31  n44   34   e50
# 974       호남선1_4  n44   34  n48   36   e57
# 975       호남선1_4  n48   36  n53   38   e62
# 976       호남선1_4  n53   38  n61   43   e70
# 977       호남선1_5  n28   24  n25   26   e31
# 978       호남선1_5  n25   26  n24   29   e29
# 979       호남선1_5  n24   29  n30   32   e33
# 980       호남선1_5  n30   32  n32   34   e38
# 981       호남선1_5  n32   34  n37   37   e44
# 982       호남선1_5  n37   37  n44   40   e50
# 983       호남선1_5  n44   40  n48   42   e57
# 984       호남선1_5  n48   42  n53   44   e62
# 985       호남선1_5  n53   44  n61   49   e70
# 986       호남선1_6  n28   30  n25   32   e31
# 987       호남선1_6  n25   32  n24   35   e29
# 988       호남선1_6  n24   35  n30   38   e33
# 989       호남선1_6  n30   38  n32   40   e38
# 990       호남선1_6  n32   40  n37   43   e44
# 991       호남선1_6  n37   43  n44   46   e50
# 992       호남선1_6  n44   46  n48   48   e57
# 993       호남선1_6  n48   48  n53   50   e62
# 994       호남선1_6  n53   50  n61   55   e70
# 995       호남선2_1  n61    0  n53    5  e70r
# 996       호남선2_1  n53    5  n48    7  e62r
# 997       호남선2_1  n48    7  n44    9  e57r
# 998       호남선2_1  n44    9  n37   12  e50r
# 999       호남선2_1  n37   12  n32   15  e44r
# 1000      호남선2_1  n32   15  n30   17  e38r
# 1001      호남선2_1  n30   17  n24   20  e33r
# 1002      호남선2_1  n24   20  n25   23  e29r
# 1003      호남선2_1  n25   23  n28   25  e31r
# 1004      호남선2_2  n61    6  n53   11  e70r
# 1005      호남선2_2  n53   11  n48   13  e62r
# 1006      호남선2_2  n48   13  n44   15  e57r
# 1007      호남선2_2  n44   15  n37   18  e50r
# 1008      호남선2_2  n37   18  n32   21  e44r
# 1009      호남선2_2  n32   21  n30   23  e38r
# 1010      호남선2_2  n30   23  n24   26  e33r
# 1011      호남선2_2  n24   26  n25   29  e29r
# 1012      호남선2_2  n25   29  n28   31  e31r
# 1013      호남선2_3  n61   12  n53   17  e70r
# 1014      호남선2_3  n53   17  n48   19  e62r
# 1015      호남선2_3  n48   19  n44   21  e57r
# 1016      호남선2_3  n44   21  n37   24  e50r
# 1017      호남선2_3  n37   24  n32   27  e44r
# 1018      호남선2_3  n32   27  n30   29  e38r
# 1019      호남선2_3  n30   29  n24   32  e33r
# 1020      호남선2_3  n24   32  n25   35  e29r
# 1021      호남선2_3  n25   35  n28   37  e31r
# 1022      호남선2_4  n61   18  n53   23  e70r
# 1023      호남선2_4  n53   23  n48   25  e62r
# 1024      호남선2_4  n48   25  n44   27  e57r
# 1025      호남선2_4  n44   27  n37   30  e50r
# 1026      호남선2_4  n37   30  n32   33  e44r
# 1027      호남선2_4  n32   33  n30   35  e38r
# 1028      호남선2_4  n30   35  n24   38  e33r
# 1029      호남선2_4  n24   38  n25   41  e29r
# 1030      호남선2_4  n25   41  n28   43  e31r
# 1031      호남선2_5  n61   24  n53   29  e70r
# 1032      호남선2_5  n53   29  n48   31  e62r
# 1033      호남선2_5  n48   31  n44   33  e57r
# 1034      호남선2_5  n44   33  n37   36  e50r
# 1035      호남선2_5  n37   36  n32   39  e44r
# 1036      호남선2_5  n32   39  n30   41  e38r
# 1037      호남선2_5  n30   41  n24   44  e33r
# 1038      호남선2_5  n24   44  n25   47  e29r
# 1039      호남선2_5  n25   47  n28   49  e31r
# 1040      호남선2_6  n61   30  n53   35  e70r
# 1041      호남선2_6  n53   35  n48   37  e62r
# 1042      호남선2_6  n48   37  n44   39  e57r
# 1043      호남선2_6  n44   39  n37   42  e50r
# 1044      호남선2_6  n37   42  n32   45  e44r
# 1045      호남선2_6  n32   45  n30   47  e38r
# 1046      호남선2_6  n30   47  n24   50  e33r
# 1047      호남선2_6  n24   50  n25   53  e29r
# 1048      호남선2_6  n25   53  n28   55  e31r
# 1049   KTX강릉선1_1  n51    0  n34    4   e51
# 1050   KTX강릉선1_1  n34    4  n23    6   e36
# 1051   KTX강릉선1_1  n23    6  n22    8   e28
# 1052   KTX강릉선1_2  n51   18  n34   22   e51
# 1053   KTX강릉선1_2  n34   22  n23   24   e36
# 1054   KTX강릉선1_2  n23   24  n22   26   e28
# 1055   KTX강릉선2_1  n22    0  n23    2  e28r
# 1056   KTX강릉선2_1  n23    2  n34    4  e36r
# 1057   KTX강릉선2_1  n34    4  n51    8  e51r
# 1058   KTX강릉선2_2  n22   18  n23   20  e28r
# 1059   KTX강릉선2_2  n23   20  n34   22  e36r
# 1060   KTX강릉선2_2  n34   22  n51   26  e51r
# === Train status summary — horizon-aware (T-based) ===
#           Train  Departed  ArrivedInHorizon PlannedTerminal ActualTerminal  \
# 0     경부고속철도1_1      True              True             n79            n79
# 1     경부고속철도1_2      True              True             n79            n79
# 2     경부고속철도1_3      True              True             n79            n79
# 3     경부고속철도1_4      True              True             n79            n79
# 4     경부고속철도1_5      True              True             n79            n79
# 5     경부고속철도1_6      True              True             n79            n79
# 6     경부고속철도1_7      True              True             n79            n79
# 7     경부고속철도1_8      True              True             n79            n79
# 8     경부고속철도1_9      True              True             n79            n79
# 9    경부고속철도1_10      True              True             n79            n79
# 10   경부고속철도1_11      True              True             n79            n79
# 11   경부고속철도1_12      True              True             n79            n79
# 12    경부고속철도2_1      True              True              n4             n4
# 13    경부고속철도2_2      True              True              n4             n4
# 14    경부고속철도2_3      True              True              n4             n4
# 15    경부고속철도2_4      True              True              n4             n4
# 16    경부고속철도2_5      True              True              n4             n4
# 17    경부고속철도2_6      True              True              n4             n4
# 18    경부고속철도2_7      True              True              n4             n4
# 19    경부고속철도2_8      True              True              n4             n4
# 20    경부고속철도2_9      True              True              n4             n4
# 21   경부고속철도2_10      True              True              n4             n4
# 22   경부고속철도2_11      True              True              n4             n4
# 23       경부선1_1      True              True             n79            n79
# 24       경부선1_2      True              True             n79            n79
# 25       경부선1_3      True              True             n79            n79
# 26       경부선1_4      True              True             n79            n79
# 27       경부선1_5      True              True             n79            n79
# 28       경부선1_6      True              True             n79            n79
# 29       경부선2_1      True              True              n4             n4
# 30       경부선2_2      True              True              n4             n4
# 31       경부선2_3      True              True              n4             n4
# 32       경부선2_4      True              True              n4             n4
# 33       경부선2_5      True              True              n4             n4
# 34       경부선2_6      True              True              n4             n4
# 35       경북선1_1      True              True             n41            n41
# 36       경북선2_1      True              True             n43            n43
# 37       경전선1_1      True              True             n73            n73
# 38       경전선1_2      True              True             n73            n73
# 39       경전선2_1      True              True             n48            n48
# 40       경전선2_2      True              True             n48            n48
# 41       동해선1_1      True              True             n72            n72
# 42       동해선1_2      True              True             n72            n72
# 43       동해선2_1      True              True             n55            n55
# 44       동해선2_2      True              True             n55            n55
# 45       영동선1_1      True              True             n43            n43
# 46       영동선2_1      True              True             n51            n51
# 47       장항선1_1      True              True             n30            n30
# 48       장항선1_2      True              True             n30            n30
# 49       장항선1_3      True              True             n30            n30
# 50       장항선2_1      True              True             n14            n14
# 51       장항선2_2      True              True             n14            n14
# 52       장항선2_3      True              True             n14            n14
# 53       전라선1_1      True              True             n68            n68
# 54       전라선1_2      True              True             n68            n68
# 55       전라선1_3      True              True             n68            n68
# 56       전라선2_1      True              True             n30            n30
# 57       전라선2_2      True              True             n30            n30
# 58       전라선2_3      True              True             n30            n30
# 59       중앙선1_1      True              True             n79            n79
# 60       중앙선1_2      True              True             n79            n79
# 61       중앙선1_3      True              True             n79            n79
# 62       중앙선1_4      True              True             n79            n79
# 63       중앙선1_5      True              True             n79            n79
# 64       중앙선1_6      True              True             n79            n79
# 65       중앙선2_1      True              True              n3             n3
# 66       중앙선2_2      True              True              n3             n3
# 67       중앙선2_3      True              True              n3             n3
# 68       중앙선2_4      True              True              n3             n3
# 69       중앙선2_5      True              True              n3             n3
# 70       중앙선2_6      True              True              n3             n3
# 71       충북선1_1      True              True             n17            n17
# 72       충북선1_2      True              True             n17            n17
# 73       충북선1_3      True              True             n17            n17
# 74       충북선2_1      True              True             n29            n29
# 75       충북선2_2      True              True             n29            n29
# 76       충북선2_3      True              True             n29            n29
# 77    호남고속철도1_1      True              True             n48            n48
# 78    호남고속철도1_2      True              True             n48            n48
# 79    호남고속철도1_3      True              True             n48            n48
# 80    호남고속철도1_4      True              True             n48            n48
# 81    호남고속철도1_5      True              True             n48            n48
# 82    호남고속철도1_6      True              True             n48            n48
# 83    호남고속철도2_1      True              True              n3             n3
# 84    호남고속철도2_2      True              True              n3             n3
# 85    호남고속철도2_3      True              True              n3             n3
# 86    호남고속철도2_4      True              True              n3             n3
# 87    호남고속철도2_5      True              True              n3             n3
# 88    호남고속철도2_6      True              True              n3             n3
# 89       호남선1_1      True              True             n61            n61
# 90       호남선1_2      True              True             n61            n61
# 91       호남선1_3      True              True             n61            n61
# 92       호남선1_4      True              True             n61            n61
# 93       호남선1_5      True              True             n61            n61
# 94       호남선1_6      True              True             n61            n61
# 95       호남선2_1      True              True             n28            n28
# 96       호남선2_2      True              True             n28            n28
# 97       호남선2_3      True              True             n28            n28
# 98       호남선2_4      True              True             n28            n28
# 99       호남선2_5      True              True             n28            n28
# 100      호남선2_6      True              True             n28            n28
# 101   KTX강릉선1_1      True              True             n22            n22
# 102   KTX강릉선1_2      True              True             n22            n22
# 103   KTX강릉선2_1      True              True             n51            n51
# 104   KTX강릉선2_2      True              True             n51            n51
#
#      Delay(min)  HorizonDelay(min)  Truncated  Rerouted              Status
# 0             3                  3      False      True            Rerouted
# 1             3                  3      False      True            Rerouted
# 2             3                  3      False      True            Rerouted
# 3             3                  3      False      True            Rerouted
# 4             3                  3      False      True            Rerouted
# 5             3                  3      False      True            Rerouted
# 6             3                  3      False      True            Rerouted
# 7             3                  3      False      True            Rerouted
# 8             3                  3      False      True            Rerouted
# 9             3                  3      False      True            Rerouted
# 10            3                  3      False      True            Rerouted
# 11            3                  3      False      True            Rerouted
# 12            3                  3      False      True            Rerouted
# 13            3                  3      False      True            Rerouted
# 14            3                  3      False      True            Rerouted
# 15            3                  3      False      True            Rerouted
# 16            3                  3      False      True            Rerouted
# 17            3                  3      False      True            Rerouted
# 18            3                  3      False      True            Rerouted
# 19            3                  3      False      True            Rerouted
# 20            3                  3      False      True            Rerouted
# 21            3                  3      False      True            Rerouted
# 22            3                  3      False      True            Rerouted
# 23            0                  0      False     False  On-time & complete
# 24            0                  0      False     False  On-time & complete
# 25            0                  0      False     False  On-time & complete
# 26            0                  0      False     False  On-time & complete
# 27            0                  0      False     False  On-time & complete
# 28            0                  0      False     False  On-time & complete
# 29            0                  0      False     False  On-time & complete
# 30            0                  0      False     False  On-time & complete
# 31            0                  0      False     False  On-time & complete
# 32            0                  0      False     False  On-time & complete
# 33            0                  0      False     False  On-time & complete
# 34            0                  0      False     False  On-time & complete
# 35            0                  0      False     False  On-time & complete
# 36            0                  0      False     False  On-time & complete
# 37            0                  0      False     False  On-time & complete
# 38            0                  0      False     False  On-time & complete
# 39            0                  0      False     False  On-time & complete
# 40            0                  0      False     False  On-time & complete
# 41            0                  0      False     False  On-time & complete
# 42            0                  0      False     False  On-time & complete
# 43            0                  0      False     False  On-time & complete
# 44            0                  0      False     False  On-time & complete
# 45            0                  0      False     False  On-time & complete
# 46            0                  0      False     False  On-time & complete
# 47            0                  0      False     False  On-time & complete
# 48            0                  0      False     False  On-time & complete
# 49            0                  0      False     False  On-time & complete
# 50            0                  0      False     False  On-time & complete
# 51            0                  0      False     False  On-time & complete
# 52            0                  0      False     False  On-time & complete
# 53            0                  0      False     False  On-time & complete
# 54            0                  0      False     False  On-time & complete
# 55            0                  0      False     False  On-time & complete
# 56            0                  0      False     False  On-time & complete
# 57            0                  0      False     False  On-time & complete
# 58            0                  0      False     False  On-time & complete
# 59            0                  0      False     False  On-time & complete
# 60            0                  0      False     False  On-time & complete
# 61            0                  0      False     False  On-time & complete
# 62            0                  0      False     False  On-time & complete
# 63            0                  0      False     False  On-time & complete
# 64            0                  0      False     False  On-time & complete
# 65            0                  0      False     False  On-time & complete
# 66            0                  0      False     False  On-time & complete
# 67            0                  0      False     False  On-time & complete
# 68            0                  0      False     False  On-time & complete
# 69            0                  0      False     False  On-time & complete
# 70            0                  0      False     False  On-time & complete
# 71            0                  0      False     False  On-time & complete
# 72            0                  0      False     False  On-time & complete
# 73            0                  0      False     False  On-time & complete
# 74            0                  0      False     False  On-time & complete
# 75            0                  0      False     False  On-time & complete
# 76            0                  0      False     False  On-time & complete
# 77            0                  0      False     False  On-time & complete
# 78            0                  0      False     False  On-time & complete
# 79            0                  0      False     False  On-time & complete
# 80            0                  0      False     False  On-time & complete
# 81            0                  0      False     False  On-time & complete
# 82            0                  0      False     False  On-time & complete
# 83            0                  0      False     False  On-time & complete
# 84            0                  0      False     False  On-time & complete
# 85            0                  0      False     False  On-time & complete
# 86            0                  0      False     False  On-time & complete
# 87            0                  0      False     False  On-time & complete
# 88            0                  0      False     False  On-time & complete
# 89            0                  0      False     False  On-time & complete
# 90            0                  0      False     False  On-time & complete
# 91            0                  0      False     False  On-time & complete
# 92            0                  0      False     False  On-time & complete
# 93            0                  0      False     False  On-time & complete
# 94            0                  0      False     False  On-time & complete
# 95            0                  0      False     False  On-time & complete
# 96            0                  0      False     False  On-time & complete
# 97            0                  0      False     False  On-time & complete
# 98            0                  0      False     False  On-time & complete
# 99            0                  0      False     False  On-time & complete
# 100           0                  0      False     False  On-time & complete
# 101           0                  0      False     False  On-time & complete
# 102           0                  0      False     False  On-time & complete
# 103           0                  0      False     False  On-time & complete
# 104           0                  0      False     False  On-time & complete

# %%
import matplotlib.pyplot as plt
import numpy as np

SINK = "SINK"

# 1) routes_nodes의 순서를 그대로 존중하면서 여러 경로를 하나로 병합
def merge_orders(base_order, new_order):
    """
    base_order 뒤에 new_order의 노드를 '이웃'을 기준으로 자연스럽게 삽입한다.
    - new_order[i-1]이 base에 있으면 그 뒤에 삽입
    - 아니면 new_order[i+1]이 base에 있으면 그 앞에 삽입
    - 둘 다 없으면 맨 뒤에 추가
    """
    res = list(base_order)
    for i, node in enumerate(new_order):
        if node in res:
            continue
        prev_node = new_order[i-1] if i > 0 else None
        next_node = new_order[i+1] if i+1 < len(new_order) else None
        if prev_node in res:
            res.insert(res.index(prev_node) + 1, node)
        elif next_node in res:
            res.insert(res.index(next_node), node)
        else:
            res.append(node)
    return res

def build_canonical_station_order(route_ids, routes_nodes):
    """
    route_ids: routes_nodes에서 가져올 '경부고속철도1_1', '경부선1_1' 등 경로 ID 리스트
    반환: 두(여러) 노선을 '나열된 순서대로' 병합한 단일 역 리스트
    """
    order = []
    for rid in route_ids:
        seq = routes_nodes[rid]
        order = merge_orders(order, seq)
    return order

# 2) 플롯 함수: 외부에서 만든 station_map을 사용하도록 변경
def plot_train_paths(train_list, ax, title, x_val, arc_list, h_get, 
                     routes_nodes, sched, station_map, xmax, color=None, label=None):
    ax.set_title(title)
    ax.set_xlabel("Timestep")
    ax.set_ylabel("Station")

    # 공통 y축
    order = list(station_map.keys())
    yticks = [station_map[n] for n in order]
    ax.set_yticks(yticks)
    ax.set_yticklabels(order)

    # 색상 설정
    if color is None:  # fig.1 스타일 → cmap
        cmap = plt.cm.get_cmap('tab10', max(1, len(train_list)))
        color_iter = (cmap(i % cmap.N) for i in range(len(train_list)))
    else:  # fig.2 스타일 → 단일색
        color_iter = (color for _ in range(len(train_list)))

    for tr, tr_color in zip(train_list, color_iter):
        if h_get(tr) < 0.5:
            continue

        # --- 계획 경로(점선, 회색) ---
        planned_path = routes_nodes[tr]
        p_nodes = [n for n in planned_path if n in station_map]
        if len(p_nodes) >= 2:
            p_times = [sched[tr][n] for n in p_nodes]
            p_ys    = [station_map[n] for n in p_nodes]
            ax.plot(p_times, p_ys, linestyle='--', color='gray', alpha=0.7)

        # --- 실제 경로 ---
        actual_legs = []
        tr_i = trains.index(tr)
        for k in range(len(arc_list)):
            if x_val.get((k, tr_i), 0) > 0.5:
                fr, to, eid, *_ = arc_list[k]
                u, t0 = fr.split("^")
                v, t1 = to.split("^")
                if u == SINK or v == SINK:
                    continue
                actual_legs.append((int(t0), u, v, int(t1), eid))
        actual_legs.sort(key=lambda x: x[0])
        if not actual_legs:
            continue

        # 첫 구간
        t0, u, v, t1, _ = actual_legs[0]
        if u in station_map and v in station_map:
            ax.plot([t0, t1], [station_map[u], station_map[v]], 
                    color=tr_color, linewidth=2, label=label)
            label = None  # 첫 선만 legend에 표시

        # 이후 구간 + 대기
        for i in range(1, len(actual_legs)):
            p_t0, p_u, p_v, p_t1, _ = actual_legs[i-1]
            c_t0, c_u, c_v, c_t1, _ = actual_legs[i]

            if c_t0 > p_t1 and p_v == c_u and p_v in station_map:
                ax.plot([p_t1, c_t0], [station_map[p_v], station_map[c_u]],
                        color='r', linestyle=':', linewidth=1.8)

            if c_u in station_map and c_v in station_map:
                ax.plot([c_t0, c_t1], [station_map[c_u], station_map[c_v]], 
                        color=tr_color, linewidth=2)

    ax.grid(True, linestyle='--', alpha=0.6)
    ax.set_xlim(0, xmax)
    ax.set_ylim(1, len(station_map))

# 3) 병합 기준 역 순서 만들기 (두 노선 합쳐서 하나의 y축)
# ── (A) 열차 묶기: 고속/일반 이름 접두사로 분류 ──
# 예: '경부고속철도...', '경부선...'
gbrt_trains = [tr for tr in trains if str(tr).startswith('경부고속철도1')]
gbs_trains  = [tr for tr in trains if str(tr).startswith('경부선1')]

# 대표 노선 id 선택 (없으면 가장 긴 경로로 대체)
def pick_representative(tr_list):
    return max(tr_list, key=lambda tr: len(routes_nodes[tr])) if tr_list else None

merge_route_ids = []
if '경부고속철도1_1' in routes_nodes:
    merge_route_ids.append('경부고속철도1_1')
elif gbrt_trains:
    merge_route_ids.append(pick_representative(gbrt_trains))

if '경부선1_1' in routes_nodes:
    merge_route_ids.append('경부선1_1')
elif gbs_trains:
    merge_route_ids.append(pick_representative(gbs_trains))

# 만약 둘 다 비면(데이터셋에서 못 찾으면) 안전하게 아무거나 2개 뽑기
if not merge_route_ids:
    merge_route_ids = [pick_representative(trains)]

# ── (B) h_get 정의: T_aff에만 h가 있을 때를 대비 ──
# hvar가 있으면 값, 없거나 T_ok면 1.0(운행)로 간주
try:
    _ = hvar  # 존재 검사
    def h_get(tr):
        try:
            return float(hvar[tr].X)  # T_aff
        except KeyError:
            return 1.0                # T_ok (취소 불가 모델이면 항상 1)
except NameError:
    h_get = lambda tr: 1.0

# ── (C) 병합 y축(station_map) 만들기 ──
canonical_order = build_canonical_station_order(merge_route_ids, routes_nodes)
# 혹시 병합 결과가 비면(방어)
if not canonical_order:
    # 전체 노드에서 자주 등장 순으로 임의 y축 만들기
    from collections import Counter
    cnt = Counter(n for seq in routes_nodes.values() for n in seq if n != SINK)
    canonical_order = [n for n, _ in cnt.most_common()]

station_map = {name: i+1 for i, name in enumerate(canonical_order)}


# --- fig.1 ---
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(18, 8), sharey=True)

plot_train_paths(gbrt_trains, ax1, "Gyeongbu High-Speed Rail", 
                 x_val, arc_list, h_get, routes_nodes, sched, station_map, xmax=80)
plot_train_paths(gbs_trains,  ax2, "Gyeongbu Rail",     
                 x_val, arc_list, h_get, routes_nodes, sched, station_map, xmax=80)

plt.tight_layout()
plt.show()

# --- fig.2 ---
fig2, ax = plt.subplots(figsize=(10, 8))

plot_train_paths(gbrt_trains, ax, None, 
                 x_val, arc_list, h_get, routes_nodes, sched, station_map, 
                 xmax=80, color="black", label="High-Speed")

plot_train_paths(gbs_trains, ax, None, 
                 x_val, arc_list, h_get, routes_nodes, sched, station_map, 
                 xmax=80, color="red", label="Conventional")

ax.legend()
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Minji Kang\AppData\Local\Temp\ipykernel_8088\914302618.py:54: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = plt.cm.get_cmap('tab10', max(1, len(train_list)))
# C:\Users\Minji Kang\AppData\Local\Temp\ipykernel_8088\914302618.py:54: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = plt.cm.get_cmap('tab10', max(1, len(train_list)))

# %%
# ============================================================
# timestep_flow_plot.py
# ----------------------
# (1) Gurobi 결과에서 시점별 edge-flow 계산
# (2) QGIS에서 export한 엑셀·JSON으로 좌표·수요 읽기
# (3) contextily + networkx 로 지도 시각화
#     - 엣지가 edge_fp에 존재하면 흐름이 0이어도 "무조건" 그린다
#     - demand에 없거나 흐름이 없는 것은 0으로 처리한다
#     - 컬러 스케일은 0부터 시작
# ============================================================

import json, math, itertools, contextily as ctx
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
import networkx as nx
import numpy as np
import pandas as pd
import geopandas as gpd
from pathlib import Path
from shapely import wkt
from collections import defaultdict

# Matplotlib 한글 폰트 설정
try:
    import matplotlib.font_manager as fm
    font_name = fm.FontProperties(fname=fm.findfont('Malgun Gothic')).get_name()
    plt.rc('font', family=font_name)
    plt.rcParams['axes.unicode_minus'] = False # 마이너스 기호 깨짐 방지
except:
    print("Warning: Malgun Gothic 폰트를 찾을 수 없습니다. 기본 폰트로 대체합니다.")

# ============================================================
# 0. 사용자 설정
# ============================================================
BASE      = Path(r"D:\MINJI\NETWORK RELIABILITY\QGIS\7.Korea_Full\json")
xlsx_fp   = BASE / "qgis_export.xlsx"              # QGIS export 엑셀
edge_fp   = BASE / "edges.json"                    # 네트워크 엣지
flow_type = "trains"    # "trains" (열차 수) / "pax" (승객수 합)
# t_focus    = 12        # 단일 시점 대신 아래 리스트 사용
t_steps   = [24, 48, 72, 96]  # 한 번에 그릴 시점들
cumulative = True       # True: t<=t_focus 누적 / False: t 구간 내만

# ============================================================
# 1. Gurobi 결과 로딩 (변수가 메모리에 있다고 가정)
# ============================================================
# 이 스크립트를 실행하기 전에 x_val, arc_list, trains, demand, failed_edges 변수가
# 메모리에 로드되어 있어야 합니다.
# (이 부분은 사용자 환경에 맞게 직접 실행해야 함)

# ============================================================
# 2. split_node_time 유틸
# ============================================================
def split_node_time(s):
    """
    "n123^7"  → ("n123", 7)
    "n123"    → ("n123", None)
    123       → ("n123", None)
    "SINK"    → ("SINK", None)
    """
    if isinstance(s, (int, np.integer)):
        return f"n{int(s)}", None
    s = str(s)
    if "^" in s:
        node, t = s.split("^", 1)
        return node, int(t)
    if s.isdigit():
        return f"n{int(s)}", None
    return s, None

# ============================================================
# 3. QGIS Export: 노드·엣지 좌표 로딩
#    - 이 부분은 반복문 밖에 있어야 함
# ============================================================
with open(edge_fp, encoding="utf-8") as f:
    edges_raw = json.load(f)
edges = {eid: (src, dst, int(tau)) for eid, (src, dst, tau) in edges_raw.items()}

failed_pairs = {(s, d) for eid, (s, d, _) in edges.items() if eid in failed_edges}

node_df = pd.read_excel(xlsx_fp, sheet_name="NODE", usecols=["node_id", "geometry"])
edge_df = pd.read_excel(xlsx_fp, sheet_name="EDGE",
                        usecols=["edge_id", "from_node_id", "to_node_id", "geometry"])

node_gdf = gpd.GeoDataFrame(
    node_df.assign(geometry=node_df["geometry"].apply(wkt.loads)),
    geometry="geometry", crs="EPSG:4326"
).to_crs(epsg=3857)

edge_gdf = gpd.GeoDataFrame(
    edge_df.assign(geometry=edge_df["geometry"].apply(wkt.loads)),
    geometry="geometry", crs="EPSG:4326"
).to_crs(epsg=3857)

pos = {f"n{int(r.node_id)}": (r.geometry.x, r.geometry.y)
       for r in node_gdf.itertuples(index=False)}

edges_bidir = {}
for r in edge_gdf.itertuples(index=False):
    u = f"n{int(r.from_node_id)}"
    v = f"n{int(r.to_node_id)}"
    edges_bidir[(u, v)] = r.geometry
for (u, v), geom in list(edges_bidir.items()):
    if (v, u) not in edges_bidir:
        edges_bidir[(v, u)] = geom

# ============================================================
# 4. 시각화 (반복문)
#    - 모든 플롯을 하나의 Figure에 그림
# ============================================================
fig, axs = plt.subplots(2, 2, figsize=(20, 20), constrained_layout=True)
axs = axs.flatten() # 2x2 배열을 1차원 배열로 변경하여 반복문에서 쉽게 접근

for i, t_focus in enumerate(t_steps):
    ax = axs[i]
    
    # Gurobi 결과로부터 시점별 flow 집계
    edge_flow_t = defaultdict(float)
    for (idx, ti), val in x_val.items():
        if val < 0.5:
            continue
        fr_str, to_str, eid = arc_list[idx][:3]
        if eid.startswith(("w_", "dummy")):
            continue

        u_raw, t_dep = split_node_time(fr_str)
        v_raw, t_arr = split_node_time(to_str)
        if t_dep is None or t_arr is None:
            continue

        cond = (t_dep <= t_focus) if cumulative else (t_dep <= t_focus < t_arr)
        if not cond:
            continue

        if flow_type == "trains":
            edge_flow_t[(u_raw, v_raw)] += 1.0
        else:
            tr_name = trains[ti]
            q_tot   = sum(q for _, _, q in demand[tr_name]) if demand.get(tr_name) else 0.0
            edge_flow_t[(u_raw, v_raw)] += float(q_tot)

    # edge_flow_t에 없는 엣지도 0으로 채워 넣기(누락 방지)
    for (u, v) in edges_bidir.keys():
        if (u, v) not in edge_flow_t:
            edge_flow_t[(u, v)] = 0.0

    # NetworkX 그래프 생성
    G = nx.DiGraph()
    for n, xy in pos.items():
        G.add_node(n, pos=xy)
    for (u, v), geom in edges_bidir.items():
        flow = float(edge_flow_t.get((u, v), 0.0))
        G.add_edge(u, v, weight=flow, geom=geom)

    # 색상 매핑
    flows = [d["weight"] for _, _, d in G.edges(data=True)]
    logf  = [math.log10(max(0.0, f) + 1.0) for f in flows]
    vmax  = max(logf) if logf else 1.0
    if vmax <= 0: vmax = 1.0
    norm  = mpl.colors.Normalize(vmin=0.0, vmax=vmax)
    cmap  = sns.color_palette("viridis", as_cmap=True)

    # 시각화
    ax.set_facecolor("white")
    if pos:
        xs, ys = zip(*pos.values())
        ax.set_xlim(min(xs), max(xs))
        ax.set_ylim(min(ys), max(ys))
    ctx.add_basemap(ax, crs="EPSG:3857", source=ctx.providers.CartoDB.Positron, alpha=0.7)

    # 엣지 그리기
    for (u, v, data) in G.edges(data=True):
        if (u, v) in failed_pairs:
            continue
        f = float(data["weight"])
        if f <= 0.0:
            color = "lightgray"   # 흐름이 0이면 회색
        else:
            lf = math.log10(f + 1.0)
            color = cmap(norm(lf))
        nx.draw_networkx_edges(
            G, pos, edgelist=[(u, v)], width=2.8, edge_color=[color],
            arrowstyle="-|>", arrowsize=9, connectionstyle="arc3,rad=0.07", ax=ax
        )


    # 노드
    nx.draw_networkx_nodes(G, pos, node_size=18, node_color="black", ax=ax)

    # 실패 엣지
    for (u, v, data) in G.edges(data=True):
        if (u, v) not in failed_pairs: continue
        nx.draw_networkx_edges(
            G, pos, edgelist=[(u, v)], width=3.4, edge_color=[(0.9, 0.0, 0.1, 1.0)],
            arrowstyle="-|>", arrowsize=9, connectionstyle="arc3,rad=0.07", ax=ax
        )

    # 컬러바 (흐름이 0보다 큰 경우만 반영)
    flows_nonzero = [f for f in flows if f > 0]
    if flows_nonzero:
        logf  = [math.log10(f + 1.0) for f in flows_nonzero]
        vmax  = max(logf)
        norm  = mpl.colors.Normalize(vmin=0.0, vmax=vmax)
        sm    = mpl.cm.ScalarMappable(cmap=cmap, norm=norm); sm.set_array([])
        cbar  = fig.colorbar(sm, ax=ax, fraction=0.046, pad=0.04)
        label = "Trains" if flow_type == "trains" else "Passengers"
        cbar.set_label(f"Flow ({label}, log scale)")

    ax.set_title(f"Flow distribution at t={t_focus}", fontsize=15)
    ax.axis("off")

plt.show()
