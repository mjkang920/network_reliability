# %%
import json, os, itertools, re
from collections import defaultdict
import gurobipy as gp
import pandas as pd
import numpy as np

# %% [markdown]
# ### Input data and parameters

# %%
BASE_DIR = r"D:\MINJI\NETWORK RELIABILITY\QGIS\7.Korea_Full\json"
edge_fp   = r"D:\MINJI\NETWORK RELIABILITY\QGIS\7.Korea_Full\json\5 min\edges.json"
route_fp  = os.path.join(BASE_DIR, "routes_nodes.json")
demand_fp = os.path.join(BASE_DIR, "demand_full.json")
dept_fp   = os.path.join(BASE_DIR, "dep_time.json")


T = 96
max_wait = 4

# CAPACITY = 3
CAPACITY_EDGE = 3
CAPACITY_NODE = 2

failed_edges = {"e1r", "e9"}
BIG_M = 10**6
SINK  = "SINK"
DWELL_MIN   = 1

FAIL_T   = 48
T_clear  = 96


with open(edge_fp, encoding="utf-8") as f:
    edges_raw = json.load(f)
edges = {eid: (src, dst, int(tau)) for eid, (src, dst, tau) in edges_raw.items()}

with open(route_fp, encoding="utf-8") as f:
    routes_nodes = json.load(f)

with open(dept_fp, encoding="utf-8") as f:
    dep_time = {tr: int(t) for tr, t in json.load(f).items()}

with open(demand_fp, encoding="utf-8") as f:
    dem_raw = json.load(f)
demand = {tr: [(o, d, float(q)) for o, d, q in lst] for tr, lst in dem_raw.items()}

trains = list(routes_nodes)
nodes  = {n for _, (s, d, _) in edges.items() for n in (s, d)}
nodes.add(SINK)

# %%
def route_prefix(tr_id: str) -> str: # e.g. "A1234_1" -> "A"
    m = re.match(r'^([^\d]+)\d+_\d+$', tr_id)
    return m.group(1) if m else tr_id.rsplit('_', 1)[0]


def travel_time_only(path, edges): 
    total = 0
    for u, v in zip(path[:-1], path[1:]):
        eid = next(e for e, (s, d, _) in edges.items() if s == u and d == v)
        total += edges[eid][2]
    return total


def build_sched(routes_nodes, edges, dep_time, DWELL_MIN):
    """
    sched = {
  "A1234_1": {
    "A": {"arr": 10, "dep": 10},
    "B": {"arr": 12, "dep": 13},  # A→B(2 min) 
    "C": {"arr": 16, "dep": 16}   # B→C(3 min)
  },
    """
    sched = {}
    for tr, path in routes_nodes.items():
        t = dep_time[tr]
        arr = {path[0]: {"arr": t, "dep": t}}
        for i, (u, v) in enumerate(zip(path[:-1], path[1:])):
            eid = next(e for e, (s, d, _) in edges.items() if s == u and d == v)
            travel = edges[eid][2]
            t += travel
            arr[v] = {"arr": t, "dep": t}
            if i < len(path) - 2:
                arr[v]["dep"] += DWELL_MIN
                t += DWELL_MIN
        sched[tr] = arr
    return sched

sched = build_sched(routes_nodes, edges, dep_time, DWELL_MIN)


node_pos = {tr: {n:i for i,n in enumerate(path)} for tr, path in routes_nodes.items()}
edge_tau = { (s,d): tau for _, (s,d,tau) in edges.items() }

def od_distance_on_planned(tr, o, d):
    path = routes_nodes[tr]
    pos = node_pos[tr]
    if o not in pos or d not in pos or pos[o] >= pos[d]:
        return 0.0
    dist = 0.0
    for i in range(pos[o], pos[d]):
        u, v = path[i], path[i+1]
        dist += edge_tau.get((u,v), 0.0)
    return float(dist)

d_rd = {}      # (tr,o,d) -> d
qd_rd = {}     # (tr,o,d) -> q*d
for tr in trains:
    for (o, d, q) in demand[tr]:
        dd = od_distance_on_planned(tr, o, d)
        d_rd[(tr,o,d)] = dd
        qd_rd[(tr,o,d)] = q * dd

print(d_rd, qd_rd)


from collections import defaultdict as DD
by_route = DD(list)
"""
by_route = {
  "A1234": ["A1234_1", "A1234_2"],
}
"""
for tr in trains:
    by_route[route_prefix(tr)].append(tr)


route_runtime = {}
"""
# without dwell time
route_runtime = {
  "A1234": 2 + 3,   # A→B(2) + B→C(3) = 5
}
"""
for rname, tr_list in by_route.items():
    reps = [tr for tr in tr_list if re.fullmatch(re.escape(rname) + r'\d+_1', tr)]
    if not reps:
        reps = [tr for tr in tr_list if tr.endswith('_1')]
    if not reps:
        reps = [sorted(tr_list)[0]]
    rep = reps[0]
    base_run = travel_time_only(routes_nodes[rep], edges)
    route_runtime[rname] = base_run


PADDING_BASE = 6
T_limit = {}
for tr in trains:
    L = len(routes_nodes[tr]) - 1
    dwell_need = max(0, L-1) * DWELL_MIN
    base_run = route_runtime[route_prefix(tr)]
    T_limit[tr] = min(T, dep_time[tr] + base_run + dwell_need + PADDING_BASE)


q_r = {tr: sum(q for *_, q in demand[tr]) for tr in trains}


uv2eid = {} # (u,v) -> eid
dup_keys = set()
for eid, (s, d, _) in edges.items():
    key = (s, d)
    if key in uv2eid and uv2eid[key] != eid:
        dup_keys.add(key)
    else:
        uv2eid[key] = eid
if dup_keys:
    print(f"[warn] multiple eids share the same (u,v): {sorted(list(dup_keys))[:5]} ...")


def planned_eids_of(tr):
    path = routes_nodes[tr]
    eids = []
    for u, v in zip(path[:-1], path[1:]):
        eid = uv2eid.get((u, v))
        if eid is None:
            raise KeyError(f"No edge (u={u} -> v={v}) in edges; check routes_nodes or edges.json")
        eids.append(eid)
    return eids

planned_eids = {tr: planned_eids_of(tr) for tr in trains}
blocked = {tr: int(any(e in failed_edges for e in planned_eids[tr])) for tr in trains}
T_aff = [tr for tr in trains if blocked[tr] == 1]
T_ok  = [tr for tr in trains if blocked[tr] == 0]


def get_arrival(tr, node, default=10**9):
    e = sched.get(tr, {}).get(node)
    if isinstance(e, dict) and ("arr" in e):
        return e["arr"]
    return default

allow_stop = {}
reach = {}

for tr in trains:
    path = routes_nodes[tr]
    eids = planned_eids[tr]
    L = len(path) - 1  

    last_node = path[-1]
    t_arrival_last = get_arrival(tr, last_node, default=10**9)
    reach[tr] = int(t_arrival_last <= T_limit[tr])

    first_fail = next((idx for idx, e in enumerate(eids) if e in failed_edges), None)

    for i in range(1, L + 1):  
        n = path[i]

        if i == L:
            allow = 1  
        elif reach[tr] == 0:
            allow = 1  
        else:
            if first_fail is not None and i >= (first_fail + 1):
                allow = 1
            else:
                allow = 0

        allow_stop[(tr, n)] = int(allow)
# Out:
# {('경부고속철도1_1', 'n4', 'n3'): 1.0, ('경부고속철도1_1', 'n4', 'n1'): 2.0, ('경부고속철도1_1', 'n4', 'n2'): 4.0, ('경부고속철도1_1', 'n4', 'n13'): 10.0, ('경부고속철도1_1', 'n4', 'n18'): 13.0, ('경부고속철도1_1', 'n4', 'n28'): 16.0, ('경부고속철도1_1', 'n4', 'n42'): 22.0, ('경부고속철도1_1', 'n4', 'n60'): 27.0, ('경부고속철도1_1', 'n4', 'n72'): 31.0, ('경부고속철도1_1', 'n4', 'n75'): 34.0, ('경부고속철도1_1', 'n4', 'n79'): 39.0, ('경부고속철도1_1', 'n3', 'n1'): 1.0, ('경부고속철도1_1', 'n3', 'n2'): 3.0, ('경부고속철도1_1', 'n3', 'n13'): 9.0, ('경부고속철도1_1', 'n3', 'n18'): 12.0, ('경부고속철도1_1', 'n3', 'n28'): 15.0, ('경부고속철도1_1', 'n3', 'n42'): 21.0, ('경부고속철도1_1', 'n3', 'n60'): 26.0, ('경부고속철도1_1', 'n3', 'n72'): 30.0, ('경부고속철도1_1', 'n3', 'n75'): 33.0, ('경부고속철도1_1', 'n3', 'n79'): 38.0, ('경부고속철도1_1', 'n1', 'n2'): 2.0, ('경부고속철도1_1', 'n1', 'n13'): 8.0, ('경부고속철도1_1', 'n1', 'n18'): 11.0, ('경부고속철도1_1', 'n1', 'n28'): 14.0, ('경부고속철도1_1', 'n1', 'n42'): 20.0, ('경부고속철도1_1', 'n1', 'n60'): 25.0, ('경부고속철도1_1', 'n1', 'n72'): 29.0, ('경부고속철도1_1', 'n1', 'n75'): 32.0, ('경부고속철도1_1', 'n1', 'n79'): 37.0, ('경부고속철도1_1', 'n2', 'n13'): 6.0, ('경부고속철도1_1', 'n2', 'n18'): 9.0, ('경부고속철도1_1', 'n2', 'n28'): 12.0, ('경부고속철도1_1', 'n2', 'n42'): 18.0, ('경부고속철도1_1', 'n2', 'n60'): 23.0, ('경부고속철도1_1', 'n2', 'n72'): 27.0, ('경부고속철도1_1', 'n2', 'n75'): 30.0, ('경부고속철도1_1', 'n2', 'n79'): 35.0, ('경부고속철도1_1', 'n13', 'n18'): 3.0, ('경부고속철도1_1', 'n13', 'n28'): 6.0, ('경부고속철도1_1', 'n13', 'n42'): 12.0, ('경부고속철도1_1', 'n13', 'n60'): 17.0, ('경부고속철도1_1', 'n13', 'n72'): 21.0, ('경부고속철도1_1', 'n13', 'n75'): 24.0, ('경부고속철도1_1', 'n13', 'n79'): 29.0, ('경부고속철도1_1', 'n18', 'n28'): 3.0, ('경부고속철도1_1', 'n18', 'n42'): 9.0, ('경부고속철도1_1', 'n18', 'n60'): 14.0, ('경부고속철도1_1', 'n18', 'n72'): 18.0, ('경부고속철도1_1', 'n18', 'n75'): 21.0, ('경부고속철도1_1', 'n18', 'n79'): 26.0, ('경부고속철도1_1', 'n28', 'n42'): 6.0, ('경부고속철도1_1', 'n28', 'n60'): 11.0, ('경부고속철도1_1', 'n28', 'n72'): 15.0, ('경부고속철도1_1', 'n28', 'n75'): 18.0, ('경부고속철도1_1', 'n28', 'n79'): 23.0, ('경부고속철도1_1', 'n42', 'n60'): 5.0, ('경부고속철도1_1', 'n42', 'n72'): 9.0, ('경부고속철도1_1', 'n42', 'n75'): 12.0, ('경부고속철도1_1', 'n42', 'n79'): 17.0, ('경부고속철도1_1', 'n60', 'n72'): 4.0, ('경부고속철도1_1', 'n60', 'n75'): 7.0, ('경부고속철도1_1', 'n60', 'n79'): 12.0, ('경부고속철도1_1', 'n72', 'n75'): 3.0, ('경부고속철도1_1', 'n72', 'n79'): 8.0, ('경부고속철도1_1', 'n75', 'n79'): 5.0, ('경부고속철도1_2', 'n4', 'n3'): 1.0, ('경부고속철도1_2', 'n4', 'n1'): 2.0, ('경부고속철도1_2', 'n4', 'n2'): 4.0, ('경부고속철도1_2', 'n4', 'n13'): 10.0, ('경부고속철도1_2', 'n4', 'n18'): 13.0, ('경부고속철도1_2', 'n4', 'n28'): 16.0, ('경부고속철도1_2', 'n4', 'n42'): 22.0, ('경부고속철도1_2', 'n4', 'n60'): 27.0, ('경부고속철도1_2', 'n4', 'n72'): 31.0, ('경부고속철도1_2', 'n4', 'n75'): 34.0, ('경부고속철도1_2', 'n4', 'n79'): 39.0, ('경부고속철도1_2', 'n3', 'n1'): 1.0, ('경부고속철도1_2', 'n3', 'n2'): 3.0, ('경부고속철도1_2', 'n3', 'n13'): 9.0, ('경부고속철도1_2', 'n3', 'n18'): 12.0, ('경부고속철도1_2', 'n3', 'n28'): 15.0, ('경부고속철도1_2', 'n3', 'n42'): 21.0, ('경부고속철도1_2', 'n3', 'n60'): 26.0, ('경부고속철도1_2', 'n3', 'n72'): 30.0, ('경부고속철도1_2', 'n3', 'n75'): 33.0, ('경부고속철도1_2', 'n3', 'n79'): 38.0, ('경부고속철도1_2', 'n1', 'n2'): 2.0, ('경부고속철도1_2', 'n1', 'n13'): 8.0, ('경부고속철도1_2', 'n1', 'n18'): 11.0, ('경부고속철도1_2', 'n1', 'n28'): 14.0, ('경부고속철도1_2', 'n1', 'n42'): 20.0, ('경부고속철도1_2', 'n1', 'n60'): 25.0, ('경부고속철도1_2', 'n1', 'n72'): 29.0, ('경부고속철도1_2', 'n1', 'n75'): 32.0, ('경부고속철도1_2', 'n1', 'n79'): 37.0, ('경부고속철도1_2', 'n2', 'n13'): 6.0, ('경부고속철도1_2', 'n2', 'n18'): 9.0, ('경부고속철도1_2', 'n2', 'n28'): 12.0, ('경부고속철도1_2', 'n2', 'n42'): 18.0, ('경부고속철도1_2', 'n2', 'n60'): 23.0, ('경부고속철도1_2', 'n2', 'n72'): 27.0, ('경부고속철도1_2', 'n2', 'n75'): 30.0, ('경부고속철도1_2', 'n2', 'n79'): 35.0, ('경부고속철도1_2', 'n13', 'n18'): 3.0, ('경부고속철도1_2', 'n13', 'n28'): 6.0, ('경부고속철도1_2', 'n13', 'n42'): 12.0, ('경부고속철도1_2', 'n13', 'n60'): 17.0, ('경부고속철도1_2', 'n13', 'n72'): 21.0, ('경부고속철도1_2', 'n13', 'n75'): 24.0, ('경부고속철도1_2', 'n13', 'n79'): 29.0, ('경부고속철도1_2', 'n18', 'n28'): 3.0, ('경부고속철도1_2', 'n18', 'n42'): 9.0, ('경부고속철도1_2', 'n18', 'n60'): 14.0, ('경부고속철도1_2', 'n18', 'n72'): 18.0, ('경부고속철도1_2', 'n18', 'n75'): 21.0, ('경부고속철도1_2', 'n18', 'n79'): 26.0, ('경부고속철도1_2', 'n28', 'n42'): ...

# %%
CROSS = {}
"""
CROSS[tr] = (u, v, eid, t0, t1)

# CROSS stores arcs where FAIL_T lies inside (t0, t1]:
- 45–55 arc → stored (train is on arc during FAIL_T)
- 30–50 arc → stored (train arrives exactly at FAIL_T)

e.g.
CROSS = {
  "A1234_1": ("S", "M", "e10", 30, 50),  
}
"""
for tr in trains:
    path = routes_nodes[tr]
    t = dep_time[tr]
    for u, v in zip(path[:-1], path[1:]):
        eid = uv2eid[(u, v)]
        tau = edges[eid][2]
        t0, t1 = t, t + tau
        if t0 < FAIL_T <= t1:
            CROSS[tr] = (u, v, eid, t0, t1)
            break
        t = t1
        if v != path[-1]:
            t += DWELL_MIN

# %%
def sched_arr(tr, node, default=None):
    e = sched.get(tr, {}).get(node)
    if isinstance(e, dict) and ("arr" in e):
        return e["arr"]
    return default


def initial_snapshot_at_FAIL_T():
    start_node, start_time = {}, {}
    """
    - If FAIL_T crosses an arc for train tr:
    start_node[tr] = arrival node of that arc
    start_time[tr] = arrival time t1

    - Else:
    pick the latest node with planned arr <= FAIL_T
    start_node[tr] = node
    start_time[tr] = max(FAIL_T, that arrival time)  # effectively FAIL_T

    - If nothing arrived yet (depart x):
    start_node[tr] = origin node (path[0])
    start_time[tr] = max(FAIL_T, dep_time[tr])
    """

    for tr in trains:
        if tr in CROSS:
            _, v, _, _, t1 = CROSS[tr]
            start_node[tr] = v
            start_time[tr] = t1
        else:
            path = routes_nodes[tr]
            cand = []
            for n in path:
                ta = sched_arr(tr, n)
                if ta is not None and ta <= FAIL_T:
                    cand.append((ta, n))
            if cand:
                ta, n = max(cand)
                start_node[tr] = n
                start_time[tr] = max(FAIL_T, ta)
            else:
                start_node[tr] = path[0]
                start_time[tr] = max(FAIL_T, dep_time[tr])
    return start_node, start_time

start_node, start_time = initial_snapshot_at_FAIL_T()

print("start_node:", start_node)
print("start_time:", start_time)
# Out:
# start_node: {'경부고속철도1_1': 'n79', '경부고속철도1_2': 'n79', '경부고속철도1_3': 'n75', '경부고속철도1_4': 'n72', '경부고속철도1_5': 'n72', '경부고속철도1_6': 'n60', '경부고속철도1_7': 'n60', '경부고속철도1_8': 'n42', '경부고속철도1_9': 'n42', '경부고속철도1_10': 'n28', '경부고속철도1_11': 'n18', '경부고속철도1_12': 'n18', '경부고속철도2_1': 'n3', '경부고속철도2_2': 'n1', '경부고속철도2_3': 'n2', '경부고속철도2_4': 'n2', '경부고속철도2_5': 'n13', '경부고속철도2_6': 'n13', '경부고속철도2_7': 'n18', '경부고속철도2_8': 'n28', '경부고속철도2_9': 'n28', '경부고속철도2_10': 'n42', '경부고속철도2_11': 'n42', '경부선1_1': 'n73', '경부선1_2': 'n63', '경부선1_3': 'n59', '경부선1_4': 'n41', '경부선1_5': 'n41', '경부선1_6': 'n28', '경부선2_1': 'n9', '경부선2_2': 'n14', '경부선2_3': 'n28', '경부선2_4': 'n28', '경부선2_5': 'n46', '경부선2_6': 'n60', '경북선1_1': 'n41', '경북선2_1': 'n43', '경전선1_1': 'n73', '경전선1_2': 'n73', '경전선2_1': 'n48', '경전선2_2': 'n48', '동해선1_1': 'n72', '동해선1_2': 'n72', '동해선2_1': 'n55', '동해선2_2': 'n55', '영동선1_1': 'n43', '영동선2_1': 'n51', '장항선1_1': 'n30', '장항선1_2': 'n30', '장항선1_3': 'n30', '장항선2_1': 'n14', '장항선2_2': 'n14', '장항선2_3': 'n14', '전라선1_1': 'n68', '전라선1_2': 'n68', '전라선1_3': 'n68', '전라선2_1': 'n30', '전라선2_2': 'n30', '전라선2_3': 'n30', '중앙선1_1': 'n72', '중앙선1_2': 'n67', '중앙선1_3': 'n52', '중앙선1_4': 'n43', '중앙선1_5': 'n35', '중앙선1_6': 'n29', '중앙선2_1': 'n12', '중앙선2_2': 'n29', '중앙선2_3': 'n35', '중앙선2_4': 'n43', '중앙선2_5': 'n49', '중앙선2_6': 'n52', '충북선1_1': 'n17', '충북선1_2': 'n17', '충북선1_3': 'n17', '충북선2_1': 'n29', '충북선2_2': 'n29', '충북선2_3': 'n29', '호남고속철도1_1': 'n48', '호남고속철도1_2': 'n48', '호남고속철도1_3': 'n48', '호남고속철도1_4': 'n37', '호남고속철도1_5': 'n30', '호남고속철도1_6': 'n21', '호남고속철도2_1': 'n3', '호남고속철도2_2': 'n3', '호남고속철도2_3': 'n3', '호남고속철도2_4': 'n2', '호남고속철도2_5': 'n13', '호남고속철도2_6': 'n18', '호남선1_1': 'n61', '호남선1_2': 'n61', '호남선1_3': 'n61', '호남선1_4': 'n61', '호남선1_5': 'n48', '호남선1_6': 'n37', '호남선2_1': 'n28', '호남선2_2': 'n28', '호남선2_3': 'n28', '호남선2_4': 'n25', '호남선2_5': 'n24', '호남선2_6': 'n32', 'KTX강릉선1_1': 'n22', 'KTX강릉선1_2': 'n22', 'KTX강릉선2_1': 'n51', 'KTX강릉선2_2': 'n51'}
# start_time: {'경부고속철도1_1': 49, '경부고속철도1_2': 52, '경부고속철도1_3': 49, '경부고속철도1_4': 48, '경부고속철도1_5': 51, '경부고속철도1_6': 49, '경부고속철도1_7': 52, '경부고속철도1_8': 49, '경부고속철도1_9': 52, '경부고속철도1_10': 48, '경부고속철도1_11': 48, '경부고속철도1_12': 50, '경부고속철도2_1': 48, '경부고속철도2_2': 48, '경부고속철도2_3': 48, '경부고속철도2_4': 51, '경부고속철도2_5': 48, '경부고속철도2_6': 50, '경부고속철도2_7': 49, '경부고속철도2_8': 48, '경부고속철도2_9': 51, '경부고속철도2_10': 48, '경부고속철도2_11': 50, '경부선1_1': 48, '경부선1_2': 48, '경부선1_3': 49, '경부선1_4': 48, '경부선1_5': 53, '경부선1_6': 51, '경부선2_1': 48, '경부선2_2': 50, '경부선2_3': 48, '경부선2_4': 53, '경부선2_5': 48, '경부선2_6': 48, '경북선1_1': 48, '경북선2_1': 48, '경전선1_1': 48, '경전선1_2': 49, '경전선2_1': 48, '경전선2_2': 49, '동해선1_1': 48, '동해선1_2': 48, '동해선2_1': 48, '동해선2_2': 48, '영동선1_1': 48, '영동선2_1': 48, '장항선1_1': 48, '장항선1_2': 48, '장항선1_3': 48, '장항선2_1': 48, '장항선2_2': 48, '장항선2_3': 48, '전라선1_1': 48, '전라선1_2': 48, '전라선1_3': 48, '전라선2_1': 48, '전라선2_2': 48, '전라선2_3': 48, '중앙선1_1': 49, '중앙선1_2': 50, '중앙선1_3': 50, '중앙선1_4': 48, '중앙선1_5': 49, '중앙선1_6': 49, '중앙선2_1': 50, '중앙선2_2': 48, '중앙선2_3': 48, '중앙선2_4': 48, '중앙선2_5': 50, '중앙선2_6': 52, '충북선1_1': 48, '충북선1_2': 48, '충북선1_3': 48, '충북선2_1': 48, '충북선2_2': 48, '충북선2_3': 48, '호남고속철도1_1': 48, '호남고속철도1_2': 48, '호남고속철도1_3': 48, '호남고속철도1_4': 48, '호남고속철도1_5': 49, '호남고속철도1_6': 50, '호남고속철도2_1': 48, '호남고속철도2_2': 48, '호남고속철도2_3': 48, '호남고속철도2_4': 49, '호남고속철도2_5': 48, '호남고속철도2_6': 50, '호남선1_1': 48, '호남선1_2': 48, '호남선1_3': 48, '호남선1_4': 51, '호남선1_5': 48, '호남선1_6': 48, '호남선2_1': 48, '호남선2_2': 48, '호남선2_3': 48, '호남선2_4': 48, '호남선2_5': 50, '호남선2_6': 49, 'KTX강릉선1_1': 48, 'KTX강릉선1_2': 48, 'KTX강릉선2_1': 48, 'KTX강릉선2_2': 48}

# %%
def build_arc_list_window(t_start, t_end, failed_edges, T_clear, max_wait,
                          nodes, edges, CROSS):
    arc_list = []
    for eid, (src, dst, tau) in edges.items():  # travel arcs
        for t in range(t_start, min(t_end, T + 1 - tau)):
            is_cross_whitelist = False
            for _, (_, _, e0, t0, t1) in CROSS.items():
                if e0 == eid and t == t0:
                    is_cross_whitelist = (t0 < FAIL_T <= t1)
            if (eid in failed_edges) and (t < T_clear) and (not is_cross_whitelist):
                continue
            arc_list.append((f"{src}^{t}", f"{dst}^{t+tau}", eid, tau, t, t+tau))

    for n in nodes - {SINK}: # wait arcs
        for w in range(1, max_wait+1):
            for t in range(t_start, min(t_end, T + 1 - w)):
                arc_list.append((f"{n}^{t}", f"{n}^{t+w}", f"w_{n}_{w}", w, t, t+w))

    for n in nodes - {SINK}: # dummy arcs
        for t in range(t_start, min(t_end, T+1)):
            arc_list.append((f"{n}^{t}", f"{SINK}^{t}", f"dummy_{n}", 0, t, t))


    arc_idx = {info: i for i, info in enumerate(arc_list)}
    eid_to_arcidx = defaultdict(list)
    dummy_idx_of  = defaultdict(list)
    wait_idx_of   = defaultdict(list)
    for k, (_, _, eid, *_) in enumerate(arc_list):
        s_eid = str(eid)
        if s_eid.startswith("dummy_"):
            n = s_eid.split("dummy_", 1)[1]
            dummy_idx_of[n].append(k) # dummy 아크면 해당 노드 key에 아크 인덱스 추가
        elif s_eid.startswith("w_"):
            parts = s_eid.split("_", 2)
            if len(parts) >= 3:
                n = parts[1]
                wait_idx_of[n].append(k) # wait 아크면 노드 key에 아크 인덱스 추가
        else:
            eid_to_arcidx[eid].append(k) # eid key에 아크 인덱스 추가


    # (node, time) in/out adjacency lists
    out_arcs = defaultdict(list) 
    in_arcs  = defaultdict(list)
    node_in_arcs  = defaultdict(list) 
    node_out_arcs = defaultdict(list)

    for k, (fr, to, eid, _, t0, t1) in enumerate(arc_list):
        n_fr, tt_fr = fr.split("^"); tt_fr = int(tt_fr)
        n_to, tt_to = to.split("^"); tt_to = int(tt_to)
        out_arcs[(n_fr, tt_fr)].append(k)
        in_arcs [(n_to, tt_to)].append(k)

        s_eid = str(eid)                   
        if not s_eid.startswith(("w_", "dummy")):
            node_out_arcs[n_fr].append(k)
            node_in_arcs [n_to].append(k)


    # (eid, time slot) list arcs occupying it
    cap_map = defaultdict(list)
    for k, (fr, to, eid, _, t0, t1) in enumerate(arc_list):
        if str(eid).startswith(("w_", "dummy")):
            continue
        for tt in range(max(t0, t_start), min(t1, t_end)):
            cap_map[(eid, tt)].append(k)
    for tr, (u, v, e0, t0, t1) in CROSS.items():
        if (t0 < FAIL_T <= t1):
            for tt in range(max(FAIL_T, t_start), min(t1, t_end)):
                cap_map[(e0, tt)].append(-1)  # -1: ghost occupancy


    return {
        "arc_list": arc_list,
        "arc_idx": arc_idx,
        "eid_to_arcidx": eid_to_arcidx,
        "dummy_idx_of": dummy_idx_of,
        "wait_idx_of": wait_idx_of,
        "out_arcs": out_arcs,
        "in_arcs": in_arcs,
        "cap_map": cap_map,
        "node_out_arcs": node_out_arcs,  
        "node_in_arcs": node_in_arcs,    
    }

# %%
def build_model_window(window_ctx, t_start, t_end,
                       start_node, start_time,
                       planned_eids, routes_nodes,
                       T_aff, T_ok, allow_stop, T_limit):

    arc_list      = window_ctx["arc_list"]
    eid_to_arcidx = window_ctx["eid_to_arcidx"]
    dummy_idx_of  = window_ctx["dummy_idx_of"]
    out_arcs      = window_ctx["out_arcs"]
    in_arcs       = window_ctx["in_arcs"]
    node_out_arcs = window_ctx["node_out_arcs"]
    node_in_arcs  = window_ctx["node_in_arcs"]


    m = gp.Model(); m.Params.OutputFlag = 1
    nA, nT = len(arc_list), len(trains)

    enabled_pairs = []
    for ti, tr in enumerate(trains):
        P_eids = set(planned_eids[tr])
        for k, (_, to, eid, tau, t0, t1) in enumerate(arc_list):
            s_eid = str(eid)

            # 1) 더미 종료는 allow_stop로 제한
            if s_eid.startswith("dummy_"):
                n_to = s_eid.split("dummy_", 1)[1]
                if allow_stop.get((tr, n_to), 1) == 0:
                    continue
                enabled_pairs.append((k, ti))
                continue

            # 2) 대기는 허용
            if s_eid.startswith("w_"):
                enabled_pairs.append((k, ti))
                continue

            # 3) 실제 선로 아크
            if tr in T_ok:
                if eid not in P_eids:
                    continue

            enabled_pairs.append((k, ti))


    x = m.addVars(enabled_pairs, vtype=gp.GRB.BINARY, name="x")
    t_arr = {(tr, n): m.addVar(lb=0, ub=T, vtype=gp.GRB.CONTINUOUS, name=f"tarr[{tr},{n}]")
             for tr in trains for n in nodes - {SINK}}
    delta = {(tr,o,d): m.addVar(lb=0, name=f"delta[{tr},{o},{d}]")
             for tr in trains for (o,d,_) in demand[tr]}


    gamma = {(tr,o,d): m.addVar(lb=0.0, ub=1.0, vtype=gp.GRB.CONTINUOUS,
                                name=f"gamma[{tr},{o},{d}]")
            for tr in trains for (o,d,_) in demand[tr]}
    x_pts = [0, 3, 6, 12, 24]     # delay minutes
    y_pts = [0, 0.25, 0.50, 0.75, 1] # refund ratio
    for tr in trains:
        for (o,d,_) in demand[tr]:
            m.addGenConstrPWL(delta[(tr,o,d)], gamma[(tr,o,d)], x_pts, y_pts,
                            name=f"pwl_gamma[{tr},{o},{d}]")


    h = {}
    y = {}
    s = {}
    z = {}
    u_eid = {}

    if T_aff:
        h = m.addVars(T_aff, vtype=gp.GRB.BINARY, name="h")
        y = {(tr, n): m.addVar(vtype=gp.GRB.BINARY, name=f"y[{tr},{n}]")
             for tr in T_aff for n in routes_nodes[tr][1:]}
        s = {(tr, n): m.addVar(vtype=gp.GRB.BINARY, name=f"s[{tr},{n}]")
             for tr in T_aff for n in nodes - {SINK}}
        z = {(tr,o,d): m.addVar(vtype=gp.GRB.BINARY, name=f"z[{tr},{o},{d}]")
             for tr in T_aff for (o,d,_) in demand[tr]}

        # 우회 허용: 계획에 없는 eid만 u_eid 생성 + x ≤ u_eid 
        real_eids = {eid for (_,_,eid,_,_,_) in arc_list if not str(eid).startswith(("w_","dummy"))}
        for tr in T_aff:
            P = set(planned_eids[tr])
            for eid in real_eids:
                if eid in P: continue
                u_eid[(tr, eid)] = m.addVar(vtype=gp.GRB.BINARY, name=f"u_eid[{tr},{eid}]")
                for k in eid_to_arcidx[eid]:
                    ti = trains.index(tr)
                    m.addConstr(x[k, ti] <= u_eid[(tr, eid)])


    def sum_x(tr_i, idxs):
        return gp.quicksum(x[k, tr_i] for k in idxs if (k, tr_i) in x)

    for tr_i, tr in enumerate(trains): # no same arc usage by same train
        for eid, idxs in eid_to_arcidx.items():
            m.addConstr(sum_x(tr_i, idxs) <= 1, name=f"L0[{tr},{eid}]")


    # flow conservation const.
    for tr in trains:
        tr_i = trains.index(tr)

        r_o   = routes_nodes[tr][0]
        t_dep = dep_time[tr]
        n0, t0 = start_node[tr], start_time[tr]
        src_t  = max(t0, t_start)

        out_dep_en = [k for k in out_arcs.get((r_o, t_dep), []) if (k, tr_i) in x]
        in_dep_en  = [k for k in  in_arcs.get((r_o, t_dep), []) if (k, tr_i) in x]

        can_anchor_at_origin = (t_start <= t_dep < t_end) and (len(out_dep_en)+len(in_dep_en) > 0)
        #dep_is_post_incident = (t_dep >= FAIL_T)

        if can_anchor_at_origin:
            rhs = h[tr] if tr in T_aff else 1 
            m.addConstr(gp.quicksum(x[k, tr_i] for k in out_dep_en)
                        - gp.quicksum(x[k, tr_i] for k in in_dep_en) == rhs,
                        name=f"src_origin[{tr},{r_o},{t_dep}]")

        else:
            out_snap_en = [k for k in out_arcs.get((n0, src_t), []) if (k, tr_i) in x]
            in_snap_en  = [k for k in  in_arcs.get((n0, src_t), []) if (k, tr_i) in x]
            if len(out_snap_en) + len(in_snap_en) > 0:
                m.addConstr(gp.quicksum(x[k, tr_i] for k in out_snap_en)
                            - gp.quicksum(x[k, tr_i] for k in in_snap_en) == 1,
                            name=f"src_snapshot[{tr},{n0},{src_t}]")

        for t in range(t_start, t_end):
            for n in nodes - {SINK}:
                if can_anchor_at_origin and (n == r_o) and (t == t_dep):
                    continue
                if (not can_anchor_at_origin) and (n == n0) and (t == src_t):
                    continue

                in_idxs  = in_arcs.get((n, t), [])
                out_idxs = out_arcs.get((n, t), [])
                in_en  = [k for k in in_idxs  if (k, tr_i) in x]
                out_en = [k for k in out_idxs if (k, tr_i) in x]
                if len(in_en) + len(out_en) == 0:
                    continue

                m.addConstr(gp.quicksum(x[k, tr_i] for k in in_en)
                            == gp.quicksum(x[k, tr_i] for k in out_en),
                            name=f"flow[{tr},{n},{t}]")


    # termination const.
    for tr in trains:
        ti = trains.index(tr)
        for n in routes_nodes[tr][1:]:
            if allow_stop.get((tr, n), 1) == 0:
                for k in dummy_idx_of.get(n, []):
                    if (k, ti) in x:
                        x[k, ti].UB = 0  

    for tr in T_aff:
        ti   = trains.index(tr)
        cand = routes_nodes[tr][1:]        
        term = routes_nodes[tr][-1]         

        m.addConstr(gp.quicksum(y[tr, n] for n in cand) == h[tr],
                    name=f"aff_y_sum[{tr}]")
        m.addConstr(y[tr, term] >= s[tr, term],
                    name=f"must_term_at_terminal_if_visited[{tr}]")

        for n in cand:
            idx_dum = dummy_idx_of.get(n, [])
            m.addConstr(gp.quicksum(x[k, ti] for k in idx_dum if (k, ti) in x) == y[tr, n],
                        name=f"aff_y_link[{tr},{n}]")
            if allow_stop.get((tr, n), 1) == 0:
                y[tr, n].UB = 0

    for tr in T_ok:
        ti   = trains.index(tr)
        cand = [n for n in routes_nodes[tr][1:] if allow_stop.get((tr, n), 1) == 1]
        lhs_terms = []
        for n in cand:
            lhs_terms.extend([ (k, ti) for k in dummy_idx_of.get(n, []) if (k, ti) in x ])
        m.addConstr(gp.quicksum(x[key] for key in lhs_terms) == 1, name=f"ok_term_once[{tr}]")


    # dwelling const.
    node_in_eids  = defaultdict(list)
    node_out_eids = defaultdict(list)
    for eid, (u, v, tau) in edges.items():
        node_out_eids[u].append(eid)
        node_in_eids[v].append(eid)

    for tr in trains:
        ti = trains.index(tr)
        origin = routes_nodes[tr][0]
        for i in (nodes - {origin, SINK}):
            in_eids  = node_in_eids.get(i, [])
            out_eids = node_out_eids.get(i, [])
            
            if not in_eids or not out_eids:
                continue

            for e_in in in_eids:
                idxs_in = [k for k in eid_to_arcidx.get(e_in, []) if (k, ti) in x]
                if not idxs_in:
                    continue

                alpha_in    = gp.quicksum(x[k, ti] for k in idxs_in)            
                d_time_in   = gp.quicksum(arc_list[k][5] * x[k, ti] for k in idxs_in)  

                for e_out in out_eids:
                    idxs_out = [k for k in eid_to_arcidx.get(e_out, []) if (k, ti) in x]
                    if not idxs_out:
                        continue

                    alpha_out   = gp.quicksum(x[k, ti] for k in idxs_out)      
                    e_time_out  = gp.quicksum(arc_list[k][4] * x[k, ti] for k in idxs_out)  

                    m.addConstr(
                        e_time_out - d_time_in + BIG_M * (2 - alpha_in - alpha_out) >= DWELL_MIN,
                        name=f"dwell[{tr},{i},{e_in}->{e_out}]"
                    )
        
        # dwelling const.: dwell at FAIL_T if arrived exactly at FAIL_T
        for tr in trains:
            ti   = trains.index(tr)
            n0   = start_node[tr]
            src_t = max(start_time[tr], t_start)
            origin = routes_nodes[tr][0]
            ta_plan = sched.get(tr, {}).get(n0, {}).get("arr", None)


            arrived_exact_at_fail = (
                n0 != origin and         
                ta_plan is not None and
                ta_plan == FAIL_T       
            )
            if not arrived_exact_at_fail:
                continue

            early_real_out = []
            past = max(0, src_t - ta_plan)                 # 이미 머문 시간
            need = max(0, DWELL_MIN - past)                # 남은 대기시간
            min_dep_time = src_t + need

            for k, (fr, to, eid, tau, t_begin, t_end) in enumerate(arc_list):
                if (k, ti) not in x:
                    continue
                if fr == f"{n0}^{t_begin}" and (t_begin < min_dep_time):
                    s_eid = str(eid)
                    if not s_eid.startswith(("w_", "dummy")):
                        early_real_out.append(k)

            if early_real_out:
                m.addConstr(
                    gp.quicksum(x[k, ti] for k in early_real_out) == 0,
                    name=f"dwell_at_FAIL_T_only[{tr},{n0}]"
                )
        
        # dwelling const.: dwell after crossing
        for tr, (_, v, e0, t0_cross, t1_arr) in CROSS.items():   
            ti = trains.index(tr)

            src_t = max(start_time[tr], t_start)           # 앵커 시각(보통 FAIL_T)
            past = max(0, src_t - t1_arr)                  # 이미 머문 시간
            need = max(0, DWELL_MIN - past)                # 남은 대기시간
            min_dep_time = src_t + need

            early_real_out = []
            for k, (fr, to, eid, tau, t_begin, t_end) in enumerate(arc_list):
                if (k, ti) not in x:
                    continue
                if fr == f"{v}^{t_begin}" and (t_begin < min_dep_time):
                    s_eid = str(eid)
                    if not s_eid.startswith(("w_", "dummy")):
                        early_real_out.append(k)

            if early_real_out:
                m.addConstr(gp.quicksum(x[k, ti] for k in early_real_out) == 0,
                            name=f"dwell_after_cross[{tr},{v}]")


    # visit(s) and z const.
    for tr in T_aff:
        tr_i = trains.index(tr)

        for n in nodes - {SINK}:
            idx = node_out_arcs[n] + node_in_arcs[n]
            flow = x.sum(idx, tr_i)
            m.addConstr(flow >= s[tr, n])
            m.addConstr(flow <= BIG_M * s[tr, n])

        for (o, d, q) in demand[tr]:
            m.addConstr(z[tr, o, d] <= s[tr, o])
            m.addConstr(z[tr, o, d] <= s[tr, d])
            m.addConstr(z[tr, o, d] >= s[tr, o] + s[tr, d] - 1)
            m.addConstr(z[tr, o, d] <= h[tr])


    # t_arr const. : match arrival time if arc used
    for tr_i, tr in enumerate(trains):
        for k, (fr, to, eid, *_ ) in enumerate(arc_list):
            if not (k, tr_i) in x:
                continue
            if str(eid).startswith(("w_", "dummy")):
                continue
            n_to, tt = to.split("^"); tt = int(tt)
            m.addConstr(t_arr[tr, n_to] >= tt - BIG_M * (1 - x[k, tr_i]))
            m.addConstr(t_arr[tr, n_to] <= tt + BIG_M * (1 - x[k, tr_i]))

        # should arrive or terminate in Tlim for eaxh train
        Tlim = T_limit[tr]
        if tr in T_aff:
            for n in routes_nodes[tr][1:]:
                m.addConstr(t_arr[tr, n] <= Tlim + BIG_M * (1 - y[tr, n]),
                            name=f"timecap_aff[{tr},{n}]")
        else:
            for n in [nn for nn in routes_nodes[tr][1:] if allow_stop.get((tr, nn), 1) == 1]:
                term_n = gp.quicksum(x[k, tr_i] for k in dummy_idx_of.get(n, []) if (k,tr_i) in x)
                m.addConstr(t_arr[tr, n] <= Tlim + BIG_M * (1 - term_n),
                            name=f"timecap_ok[{tr},{n}]")


    # delay const.
    def sched_arrival(tr, node, default=T):
        entry = sched.get(tr, {}).get(node)
        if isinstance(entry, dict) and ("arr" in entry):
            return entry["arr"]
        return default

    for tr in T_aff:
        for (o, d, q) in demand[tr]:
            sched_t = sched_arrival(tr, d, T)
            m.addConstr(delta[tr, o, d] >= t_arr[tr, d] - sched_t - BIG_M * (1 - z[tr, o, d]))
            m.addConstr(delta[tr, o, d] <= BIG_M * z[tr, o, d])
    for tr in T_ok:
        for (o, d, q) in demand[tr]:
            sched_t = sched_arrival(tr, d, T)
            m.addConstr(delta[tr, o, d] >= t_arr[tr, d] - sched_t)


    # objective func.
    obj = 0

    def QD(tr, o, d):
        return qd_rd.get((tr,o,d), 0.0)

    for tr in T_aff:
        total_qd = gp.quicksum(QD(tr, o, d) for (o, d, _) in demand[tr])
        obj += total_qd * (1 - h[tr])

        for (o, d, q) in demand[tr]:
            qd_val = QD(tr, o, d)
            obj += qd_val * (1 - z[(tr, o, d)])
            obj += qd_val * gamma[(tr, o, d)] * z[(tr, o, d)]

    if len(u_eid) > 0:
        obj += gp.quicksum(u_eid.values())

    for tr in T_ok:
        for (o, d, q) in demand[tr]:
            qd_val = QD(tr, o, d)
            obj += qd_val * gamma[(tr, o, d)]

    m.setObjective(obj, sense=gp.GRB.MINIMIZE)


    return m, x, t_arr, delta, h, z

# %%
def node_cap(n):
    return CAPACITY_NODE[n] if isinstance(CAPACITY_NODE, dict) else CAPACITY_NODE


MAX_WS_ITER, EPS = 40, 1e-6

t_cur = FAIL_T
snap_node = dict(start_node)
snap_time = dict(start_time)

sol_legs = {tr: [] for tr in trains}       
seen_arc_keys = set()                      
h_final = {tr: 1.0 for tr in trains}        

_last_window_ctx = None
_last_x_val = None
_last_lock_until = None


# FAIL_T 이전 구간은 스케줄대로 결과 적용
PREPEND_PRE_FAIL = True
if PREPEND_PRE_FAIL:
    for tr in trains:
        path = routes_nodes[tr]
        t = dep_time[tr]
        for u, v in zip(path[:-1], path[1:]):
            eid = uv2eid[(u, v)]
            tau = edges[eid][2]
            t0, t1 = t, t + tau

            if t1 <= FAIL_T:  
                key = (tr, t0, u, v, t1, eid)
                if key not in seen_arc_keys:
                    seen_arc_keys.add(key)
                    sol_legs[tr].append((t0, u, v, t1, eid))
            
            elif t0 < FAIL_T <= t1:
                key = (tr, t0, u, v, t1, eid)
                if key not in seen_arc_keys:
                    seen_arc_keys.add(key)
                    sol_legs[tr].append((t0, u, v, t1, eid))

            t = t1
            if v != path[-1]:
                t += DWELL_MIN


t_win_start = FAIL_T
t_win_end   = T
print(f"\n==== Window [{t_win_start}, {t_win_end}) ====")

window_ctx = build_arc_list_window(
    t_start=t_win_start, t_end=t_win_end,
    failed_edges=failed_edges, T_clear=T_clear,
    max_wait=max_wait, nodes=nodes, edges=edges,
    CROSS=CROSS
)

base, xvar, t_arr_var, delta_var, hvar, zvar = build_model_window(
    window_ctx, t_win_start, t_win_end,
    snap_node, snap_time,
    planned_eids, routes_nodes,
    T_aff, T_ok, allow_stop, T_limit)


constr_names = {}
for (eid, tt), idxs in window_ctx["cap_map"].items():
    real_idxs = [k for k in idxs if k >= 0]
    enabled_keys = [(k, ti) for k in real_idxs for ti in range(len(trains)) if (k, ti) in xvar]
    if not enabled_keys:
        continue
    expr = gp.quicksum(xvar[k, ti] for (k, ti) in enabled_keys)
    ghost = sum(1 for i in idxs if i < 0) 
    rhs = max(0, CAPACITY_EDGE - ghost)
    cname = f"cap_{eid}_{tt}"
    base.addConstr(expr <= rhs, name=f"edgecap_{eid}_{tt}")
    constr_names[(eid, tt)] = cname





# --- node capacity ---
from collections import defaultdict

node_slot_map = defaultdict(list)  

for k, (fr, to, eid, _, t0, t1) in enumerate(window_ctx["arc_list"]):
    s_eid = str(eid)
    if not s_eid.startswith("w_"):
        continue
    n_fr, _ = fr.split("^")
    for tt in range(max(t0, t_win_start), min(t1, t_win_end)):
        node_slot_map[(n_fr, tt)].append(k)

for (n, tt), idxs in node_slot_map.items():
    enabled = [(k, ti) for k in idxs for ti in range(len(trains)) if (k, ti) in xvar]
    if not enabled:
        continue
    occ = gp.quicksum(xvar[k, ti] for (k, ti) in enabled)
    base.addConstr(occ <= node_cap(n), name=f"nodecap_{n}_{tt}")





base.optimize()
if base.Status == gp.GRB.INFEASIBLE:
    base.computeIIS()
    print("---- IIS constraints ----")
    for c in base.getConstrs():
        if c.IISConstr:
            print(f"[IIS] {c.ConstrName}")
    for v in base.getVars():
        if getattr(v, "IISLB", 0) or getattr(v, "IISUB", 0):
            print(f"[IIS-Var] {v.VarName}  LB:{v.IISLB}  UB:{v.IISUB}")
    base.write(f"iis_win{t_win_start}_{t_win_end}.ilp")
    raise RuntimeError("infeasible (IIS written)")
elif base.Status != gp.GRB.OPTIMAL:
    raise RuntimeError(f"non-optimal status: {base.Status}")

x_val = {key: round(var.X) for key, var in xvar.items()}

for tr in trains:
    ti = trains.index(tr)

    if tr in T_aff:
        try:
            h_final[tr] = float(hvar[tr].X)
        except KeyError:
            pass

    for k, (fr, to, eid, tau, t0, t1) in enumerate(window_ctx["arc_list"]):
        if x_val.get((k, ti), 0) <= 0.5:
            continue
        if str(eid).startswith(("w_", "dummy")):
            continue
        u, _t0 = fr.split("^"); v, _t1 = to.split("^")
        _t0 = int(_t0); _t1 = int(_t1)
        if _t1 < 0 or _t0 > T:
            continue
        key = (tr, _t0, u, v, _t1, eid)
        if key not in seen_arc_keys:
            seen_arc_keys.add(key)
            sol_legs[tr].append((_t0, u, v, _t1, eid))

print("Complete: sol_legs length =", {tr: len(sol_legs[tr]) for tr in trains})
print("\n==== IFS done ====")
# Out:
# ==== Window [48, 96) ====
# Set parameter Username
# Set parameter LicenseID to value 2637066
# Academic license - for non-commercial use only - expires 2026-03-16
# Set parameter OutputFlag to value 1
# Gurobi Optimizer version 12.0.2 build v12.0.2rc0 (win64 - Windows 10.0 (19045.2))
#
# CPU model: AMD Ryzen 5 3600XT 6-Core Processor, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 978651 rows, 2113401 columns and 10900658 nonzeros
# Model fingerprint: 0x8073e0e6
# Model has 942 quadratic objective terms
# Model has 6312 simple general constraints
#   6312 PWL
# Variable types: 20919 continuous, 2092482 integer (2092482 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+06]
#   Objective range  [6e-02, 9e+03]
#   QObjective range [1e-01, 3e+03]
#   Bounds range     [1e+00, 1e+02]
#   RHS range        [1e+00, 2e+06]
#   PWLCon x range   [3e+00, 1e+01]
#   PWLCon y range   [3e-01, 8e-01]
# Presolve removed 621280 rows and 1759717 columns
# Presolve time: 3.16s
# Presolved: 358313 rows, 354626 columns, 2810776 nonzeros
# Presolved model has 6312 SOS constraint(s)
# Variable types: 36917 continuous, 317709 integer (316147 binary)
# Performing another presolve...
# Presolve removed 255174 rows and 8688 columns (presolve time = 5s)...
# Presolve removed 424181 rows and 9297 columns (presolve time = 10s)...
# Presolve removed 424181 rows and 9297 columns (presolve time = 15s)...
# Presolve removed 424181 rows and 84165 columns (presolve time = 21s)...
# Presolve removed 436342 rows and 85667 columns
# Presolve time: 20.77s
# Performing another presolve...
# Presolve removed 20035 rows and 1534 columns (presolve time = 5s)...
# Presolve removed 21379 rows and 16928 columns (presolve time = 11s)...
# Presolve removed 29114 rows and 30692 columns
# Presolve time: 14.46s
# Deterministic concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Root barrier log...
#
# Elapsed ordering time = 5s
# Ordering time: 6.13s
#
# Barrier statistics:
#  Dense cols : 16
#  AA' NZ     : 1.876e+06
#  Factor NZ  : 5.849e+07 (roughly 600 MB of memory)
#  Factor Ops : 2.062e+11 (roughly 2 seconds per iteration)
#  Threads    : 4
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   7.38353888e+09 -8.85253930e+10  1.00e+06 6.36e+02  2.34e+07    50s
#
# Barrier performed 0 iterations in 50.50 seconds (44.30 work units)
# Barrier solve interrupted - model solved by another algorithm
#
# Concurrent spin time: 0.10s
#
# Solved with dual simplex
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#    33785    1.1392983e+05   0.000000e+00   0.000000e+00     51s
#
# Root relaxation: objective 1.139298e+05, 33785 iterations, 8.57 seconds (5.24 work units)
# Total elapsed time = 50.75s (DegenMoves)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 113929.827    0 1471          - 113929.827      -     -   53s
#      0     0 114297.498    0 1481          - 114297.498      -     -   53s
#      0     0 114334.663    0 1502          - 114334.663      -     -   53s
#      0     0 114410.117    0 1501          - 114410.117      -     -   54s
#      0     0 114453.188    0 1490          - 114453.188      -     -   54s
#      0     0 114732.034    0 1484          - 114732.034      -     -   54s
#      0     0 114939.537    0 1485          - 114939.537      -     -   54s
#      0     0 114939.537    0 1479          - 114939.537      -     -   54s
#      0     0 114939.537    0 1475          - 114939.537      -     -   54s
#      0     0 114939.537    0 1473          - 114939.537      -     -   54s
#      0     0 114941.077    0 1480          - 114941.077      -     -   54s
#      0     0 118785.580    0 1597          - 118785.580      -     -   57s
#      0     0 118791.076    0 1592          - 118791.076      -     -   57s
#      0     0 118791.912    0 1590          - 118791.912      -     -   57s
#      0     0 118792.582    0 1595          - 118792.582      -     -   58s
#      0     0 118793.587    0 1604          - 118793.587      -     -   58s
#      0     0 118793.587    0 1588          - 118793.587      -     -   58s
#      0     0 118794.592    0 1596          - 118794.592      -     -   58s
#      0     0 118795.262    0 1591          - 118795.262      -     -   58s
#      0     0 118796.100    0 1594          - 118796.100      -     -   58s
#      0     0 118798.706    0 1592          - 118798.706      -     -   58s
#      0     0 118798.738    0 1587          - 118798.738      -     -   58s
#      0     0 118831.292    0 1590          - 118831.292      -     -   59s
#      0     0 118831.687    0 1596          - 118831.687      -     -   59s
#      0     0 118836.599    0 1594          - 118836.599      -     -   59s
#      0     0 118843.331    0 1590          - 118843.331      -     -   59s
#      0     0 118855.226    0 1591          - 118855.226      -     -   59s
#      0     0 119113.758    0 1601          - 119113.758      -     -   60s
#      0     0 119116.594    0 1599          - 119116.594      -     -   60s
#      0     0 119122.943    0 1592          - 119122.943      -     -   60s
#      0     0 121077.932    0 1635          - 121077.932      -     -   62s
#      0     0 121232.272    0 1660          - 121232.272      -     -   62s
#      0     0 121348.265    0 1694          - 121348.265      -     -   63s
#      0     0 121354.136    0 1695          - 121354.136      -     -   63s
#      0     0 123557.471    0 2027          - 123557.471      -     -   67s
#      0     0 123633.296    0 1962          - 123633.296      -     -   67s
#      0     0 123633.296    0 1963          - 123633.296      -     -   67s
#      0     0 123656.696    0 1961          - 123656.696      -     -   68s
#      0     0 124901.756    0 2009          - 124901.756      -     -   72s
#      0     0 124918.431    0 2027          - 124918.431      -     -   72s
#      0     0 124983.132    0 1915          - 124983.132      -     -   72s
#      0     0 124983.132    0 1915          - 124983.132      -     -   73s
#      0     0 125723.187    0 2119          - 125723.187      -     -   75s
#      0     0 125729.489    0 2120          - 125729.489      -     -   75s
#      0     0 125747.702    0 2003          - 125747.702      -     -   75s
#      0     0 125752.226    0 1997          - 125752.226      -     -   76s
#      0     0 125775.246    0 1951          - 125775.246      -     -   76s
#      0     0 126075.620    0 2184          - 126075.620      -     -   77s
#      0     0 126097.182    0 2172          - 126097.182      -     -   78s
#      0     0 126164.773    0 2188          - 126164.773      -     -   78s
#      0     0 127044.767    0 2206          - 127044.767      -     -   80s
#      0     0 127058.332    0 2199          - 127058.332      -     -   80s
#      0     0 127059.800    0 2197          - 127059.800      -     -   80s
#      0     0 127455.268    0 2215          - 127455.268      -     -   81s
#      0     0 127631.903    0 2211          - 127631.903      -     -   81s
#      0     0 127639.151    0 2234          - 127639.151      -     -   81s
#      0     0 128081.986    0 2186          - 128081.986      -     -   83s
#      0     0 128257.487    0 2229          - 128257.487      -     -   83s
#      0     0 128359.432    0 2230          - 128359.432      -     -   83s
#      0     0 128441.450    0 2311          - 128441.450      -     -   84s
#      0     0 128441.450    0 2310          - 128441.450      -     -   84s
#      0     0 129108.677    0 2410          - 129108.677      -     -   85s
#      0     0 129140.501    0 2411          - 129140.501      -     -   85s
#      0     0 129319.880    0 2444          - 129319.880      -     -   86s
#      0     0 129406.622    0 2533          - 129406.622      -     -   87s
#      0     0 129560.023    0 2580          - 129560.023      -     -   88s
#      0     0 129560.023    0 2579          - 129560.023      -     -   88s
#      0     0 129560.023    0 2393          - 129560.023      -     -   90s
#     30     4 144019.378    1 1938          - 129560.658      -   429  114s
#     32     6 144062.836    2 1864          - 130962.616      -   418  115s
#     42    21 144065.385    4 1861          - 131458.138      -   364  124s
#     57    41 144067.093    7 1822          - 131463.067      -   297  125s
#    144   111 145752.909   19 1624          - 131463.067      -   220  130s
#    214   170 149419.738   29 1411          - 131463.067      -   249  135s
#    270   230 151626.615   34 1063          - 131463.067      -   290  140s
#    327   283 152805.915   38  806          - 131463.067      -   330  145s
#    385   349 infeasible   48               - 131463.067      -   323  150s
#    421   376 153056.365   55  569          - 131463.067      -   304  157s
#    486   449 153429.611   63  199          - 131463.067      -   365  161s
#    622   626 153779.678   88   65          - 131463.067      -   302  174s
#    718   727 154016.613   98   63          - 131463.067      -   262  183s
#    831   812 154015.732  110   64          - 131463.067      -   262  191s
#   1024  1037 154018.420  138   42          - 131494.958      -   267  202s
#   1157  1178 154018.351  154   31          - 131494.958      -   245  210s
# * 1333  1264             172    154065.66404 131494.958  14.7%   240  213s
# * 1384   470             158    142710.28713 131494.958  7.86%   231  213s
# * 1385   470             158    142710.27713 131494.958  7.86%   231  213s
#   1481   349     cutoff  172      142710.277 131494.958  7.86%   218  217s
#   1538   374 135677.829   13 1390 142710.277 132839.479  6.92%   217  220s
#   1568   375 139842.925   16 37017 142710.277 132839.479  6.92%   222  287s
#   1570   376 142134.634   60  691 142710.277 136168.573  4.58%   221  301s
#   1573   380 138969.983   24 29769 142710.277 137679.687  3.53%   267  311s
#   1575   381 138743.084    9  633 142710.277 138743.084  2.78%   266  318s
#   1576   382 142704.832   88  527 142710.277 138940.358  2.64%   266  320s
#   1584   387 140311.137   21  795 142710.277 140311.137  1.68%   265  325s
#   1589   392 141923.444   27  448 142710.277 140946.434  1.24%   293  332s
#   1591   394 142192.619   65  645 142710.277 141503.505  0.85%   292  335s
#   1603   402 141790.914   43  853 142710.277 141790.914  0.64%   290  340s
# H 1604   381                    141456.40068 141456.401  0.00%   290  341s
#
# Cutting planes:
#   Gomory: 26
#   Cover: 96
#   Implied bound: 47
#   Projected implied bound: 25
#   Clique: 70
#   MIR: 157
#   Mixing: 3
#   StrongCG: 4
#   Flow cover: 292
#   GUB cover: 79
#   Zero half: 55
#   Network: 1
#   RLT: 167
#   Relax-and-lift: 71
#   BQP: 4
#
# Explored 1604 nodes (619080 simplex iterations) in 342.51 seconds (350.84 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 4: 141456 142710 142710 154066
#
# Optimal solution found (tolerance 1.00e-04)
# Warning: max constraint violation (3.1250e-01) exceeds tolerance
# Warning: max general constraint violation (3.1250e-01) exceeds tolerance
#          (model may be infeasible or unbounded - try turning presolve off)
# Best objective 1.414564006815e+05, best bound 1.414564006815e+05, gap 0.0000%
# Complete: sol_legs length = {'경부고속철도1_1': 11, '경부고속철도1_2': 11, '경부고속철도1_3': 11, '경부고속철도1_4': 11, '경부고속철도1_5': 11, '경부고속철도1_6': 11, '경부고속철도1_7': 11, '경부고속철도1_8': 11, '경부고속철도1_9': 11, '경부고속철도1_10': 11, '경부고속철도1_11': 11, '경부고속철도1_12': 11, '경부고속철도2_1': 12, '경부고속철도2_2': 11, '경부고속철도2_3': 8, '경부고속철도2_4': 8, '경부고속철도2_5': 13, '경부고속철도2_6': 13, '경부고속철도2_7': 13, '경부고속철도2_8': 13, '경부고속철도2_9': 13, '경부고속철도2_10': 13, '경부고속철도2_11': 13, '경부선1_1': 16, '경부선1_2': 16, '경부선1_3': 16, '경부선1_4': 16, '경부선1_5': 16, '경부선1_6': 16, '경부선2_1': 16, '경부선2_2': 16, '경부선2_3': 16, '경부선2_4': 16, '경부선2_5': 16, '경부선2_6': 16, '경북선1_1': 4, '경북선2_1': 4, '경전선1_1': 7, '경전선1_2': 7, '경전선2_1': 7, '경전선2_2': 7, '동해선1_1': 4, '동해선1_2': 4, '동해선2_1': 4, '동해선2_2': 4, '영동선1_1': 4, '영동선2_1': 4, '장항선1_1': 7, '장항선1_2': 7, '장항선1_3': 7, '장항선2_1': 7, '장항선2_2': 7, '장항선2_3': 7, '전라선1_1': 6, '전라선1_2': 6, '전라선1_3': 6, '전라선2_1': 6, '전라선2_2': 6, '전라선2_3': 6, '중앙선1_1': 16, '중앙선1_2': 16, '중앙선1_3': 16, '중앙선1_4': 16, '중앙선1_5': 16, '중앙선1_6': 16, '중앙선2_1': 16, '중앙선2_2': 16, '중앙선2_3': 16, '중앙선2_4': 16, '중앙선2_5': 16, '중앙선2_6': 16, '충북선1_1': 5, '충북선1_2': 5, '충북선1_3': 5, '충북선2_1': 5, '충북선2_2': 5, '충북선2_3': 5, '호남고속철도1_1': 8, '호남고속철도1_2': 8, '호남고속철도1_3': 8, '호남고속철도1_4': 8, '호남고속철도1_5': 8, '호남고속철도1_6': 8, '호남고속철도2_1': 8, '호남고속철도2_2': 8, '호남고속철도2_3': 8, '호남고속철도2_4': 6, '호남고속철도2_5': 10, '호남고속철도2_6': 10, '호남선1_1': 9, '호남선1_2': 9, '호남선1_3': 9, '호남선1_4': 9, '호남선1_5': 9, '호남선1_6': 9, '호남선2_1': 9, '호남선2_2': 9, '호남선2_3': 9, '호남선2_4': 9, '호남선2_5': 9, '호남선2_6': 9, 'KTX강릉선1_1': 3, 'KTX강릉선1_2': 3, 'KTX강릉선2_1': 3, 'KTX강릉선2_2': 3}
#
# ==== IFS done ====

# %%
import pandas as pd
pd.set_option('display.max_rows', None)

# h_get: T_aff는 h_final, 나머지는 1.0
def h_get(tr):
    return float(h_final.get(tr, 1.0))

def sched_arr_(tr, node):
    entry = sched.get(tr, {}).get(node)
    if isinstance(entry, dict) and ("arr" in entry):
        return entry["arr"]
    return None

# 1) Timetable (sol_legs 기반)
rows = []
for tr in trains:
    if h_get(tr) < 0.5 and len(sol_legs[tr]) == 0:
        rows.append([tr, '-', '-', '-', '-', 'Cancelled'])
        continue
    legs = sorted(sol_legs[tr], key=lambda v: v[0]) 
    for dep, frm, to, arr, eid in legs:
        rows.append([tr, frm, dep, to, arr, eid])

df = pd.DataFrame(rows, columns=["Train", "From", "Dep", "To", "Arr", "Edge"])
print("\n=== Timetable (head) ===")
display(df)

# 2) 유틸리티 (sol_legs 사용)
def planned_path_and_eids(tr):
    path = routes_nodes[tr]
    eids = []
    for u, v in zip(path[:-1], path[1:]):
        eid = next(e for e, (s, d, _) in edges.items() if s == u and d == v)
        eids.append(eid)
    return path, eids

def build_actual_legs(tr):
    legs = sorted(sol_legs[tr], key=lambda v: v[0]) 
    return legs

def path_nodes_from_legs(legs):
    if not legs: return []
    nodes_seq = [legs[0][1]]
    for _, _, to, _, _ in legs:
        nodes_seq.append(to)
    return nodes_seq

def actual_arrival_map(legs):
    amap = {}
    for _, frm, to, arr, _ in legs:
        if to not in amap or arr < amap[to]:
            amap[to] = arr
    return amap

# 3) 상태 요약 (원래 로직 거의 동일, legs만 sol_legs로)
stat_rows = []
for tr in trains:
    departed = (h_get(tr) >= 0.5) or (len(sol_legs[tr]) > 0)
    planned_path, planned_eids = planned_path_and_eids(tr)
    planned_terminal = planned_path[-1]
    planned_terminal_sched = sched_arr_(tr, planned_terminal)

    if not departed:
        stat_rows.append({
            "Train": tr, "Departed": False, "ArrivedInHorizon": False,
            "PlannedTerminal": planned_terminal,
            "ActualTerminal": None,
            "Delay(min)": None, "HorizonDelay(min)": None,
            "Truncated": False, "Rerouted": False, "Status": "Cancelled"
        })
        continue

    legs = build_actual_legs(tr)
    actual_nodes = path_nodes_from_legs(legs)
    actual_eids  = [e for *_, e in legs]
    arr_map      = actual_arrival_map(legs)
    actual_terminal = actual_nodes[-1] if actual_nodes else None
    actual_arrival  = max(arr for *_, arr, _ in legs) if legs else None

    # 계획 프리픽스(스케줄 있는 시각까지) 계산
    prefix_last_idx = 0
    for i, node in enumerate(planned_path):
        t_planned = sched_arr_(tr, node)
        if t_planned is not None and t_planned <= T:
            prefix_last_idx = i
    planned_prefix_nodes = planned_path[:prefix_last_idx+1]
    planned_prefix_eids  = planned_eids[:max(0, prefix_last_idx)]

    arrived_in_horizon = (actual_terminal == planned_terminal) and (actual_arrival is not None) and (actual_arrival <= T)
    if planned_terminal_sched is not None and planned_terminal_sched <= T:
        truncated = (not arrived_in_horizon)
    else:
        truncated = False

    common = min(len(actual_eids), len(planned_prefix_eids))
    rerouted = (actual_eids[:common] != planned_prefix_eids[:common])

    delay_min = None
    horizon_delay_min = None
    if planned_terminal_sched is not None and planned_terminal_sched <= T and arrived_in_horizon:
        delay_min = max(0, actual_arrival - planned_terminal_sched)

    if planned_prefix_nodes:
        last_plan_node = planned_prefix_nodes[-1]
        t_plan_last    = sched_arr_(tr, last_plan_node)
        t_act_last     = arr_map.get(last_plan_node, None)
        if (t_plan_last is not None) and (t_act_last is not None):
            horizon_delay_min = max(0, t_act_last - t_plan_last)

    if not departed:
        status = "Cancelled"
    elif truncated:
        status = "Truncated"
    elif rerouted:
        status = "Rerouted"
    elif (planned_terminal_sched is not None and planned_terminal_sched <= T and delay_min and delay_min > 0) \
         or (horizon_delay_min is not None and horizon_delay_min > 0):
        status = "Delayed"
    else:
        if planned_terminal_sched is not None and planned_terminal_sched > T and not arrived_in_horizon:
            status = "On-time & in-progress"
        else:
            status = "On-time & complete"

    stat_rows.append({
        "Train": tr,
        "Departed": departed,
        "ArrivedInHorizon": arrived_in_horizon,
        "PlannedTerminal": planned_terminal,
        "ActualTerminal": actual_terminal,
        "Delay(min)": delay_min,
        "HorizonDelay(min)": horizon_delay_min,
        "Truncated": truncated,
        "Rerouted": rerouted,
        "Status": status
    })

df_stat = pd.DataFrame(stat_rows, columns=[
    "Train","Departed","ArrivedInHorizon","PlannedTerminal","ActualTerminal",
    "Delay(min)","HorizonDelay(min)","Truncated","Rerouted","Status"
])
print("\n=== Train status summary — horizon-aware (T-based) ===")
display(df_stat)
# Out:
# === Timetable (head) ===
#            Train From  Dep   To  Arr  Edge
# 0      경부고속철도1_1   n4    0   n3    1    e4
# 1      경부고속철도1_1   n3    2   n1    3    e3
# 2      경부고속철도1_1   n1    4   n2    6    e1
# 3      경부고속철도1_1   n2    7  n13   13   e9r
# 4      경부고속철도1_1  n13   14  n18   17  e17r
# 5      경부고속철도1_1  n18   18  n28   21   e26
# 6      경부고속철도1_1  n28   22  n42   28  e43r
# 7      경부고속철도1_1  n42   29  n60   34   e61
# 8      경부고속철도1_1  n60   35  n72   39   e81
# 9      경부고속철도1_1  n72   40  n75   43   e89
# 10     경부고속철도1_1  n75   44  n79   49   e93
# 11     경부고속철도1_2   n4    3   n3    4    e4
# 12     경부고속철도1_2   n3    5   n1    6    e3
# 13     경부고속철도1_2   n1    7   n2    9    e1
# 14     경부고속철도1_2   n2   10  n13   16   e9r
# 15     경부고속철도1_2  n13   17  n18   20  e17r
# 16     경부고속철도1_2  n18   21  n28   24   e26
# 17     경부고속철도1_2  n28   25  n42   31  e43r
# 18     경부고속철도1_2  n42   32  n60   37   e61
# 19     경부고속철도1_2  n60   38  n72   42   e81
# 20     경부고속철도1_2  n72   43  n75   46   e89
# 21     경부고속철도1_2  n75   47  n79   52   e93
# 22     경부고속철도1_3   n4    6   n3    7    e4
# 23     경부고속철도1_3   n3    8   n1    9    e3
# 24     경부고속철도1_3   n1   10   n2   12    e1
# 25     경부고속철도1_3   n2   13  n13   19   e9r
# 26     경부고속철도1_3  n13   20  n18   23  e17r
# 27     경부고속철도1_3  n18   24  n28   27   e26
# 28     경부고속철도1_3  n28   28  n42   34  e43r
# 29     경부고속철도1_3  n42   35  n60   40   e61
# 30     경부고속철도1_3  n60   41  n72   45   e81
# 31     경부고속철도1_3  n72   46  n75   49   e89
# 32     경부고속철도1_3  n75   50  n79   55   e93
# 33     경부고속철도1_4   n4    9   n3   10    e4
# 34     경부고속철도1_4   n3   11   n1   12    e3
# 35     경부고속철도1_4   n1   13   n2   15    e1
# 36     경부고속철도1_4   n2   16  n13   22   e9r
# 37     경부고속철도1_4  n13   23  n18   26  e17r
# 38     경부고속철도1_4  n18   27  n28   30   e26
# 39     경부고속철도1_4  n28   31  n42   37  e43r
# 40     경부고속철도1_4  n42   38  n60   43   e61
# 41     경부고속철도1_4  n60   44  n72   48   e81
# 42     경부고속철도1_4  n72   49  n75   52   e89
# 43     경부고속철도1_4  n75   53  n79   58   e93
# 44     경부고속철도1_5   n4   12   n3   13    e4
# 45     경부고속철도1_5   n3   14   n1   15    e3
# 46     경부고속철도1_5   n1   16   n2   18    e1
# 47     경부고속철도1_5   n2   19  n13   25   e9r
# 48     경부고속철도1_5  n13   26  n18   29  e17r
# 49     경부고속철도1_5  n18   30  n28   33   e26
# 50     경부고속철도1_5  n28   34  n42   40  e43r
# 51     경부고속철도1_5  n42   41  n60   46   e61
# 52     경부고속철도1_5  n60   47  n72   51   e81
# 53     경부고속철도1_5  n72   52  n75   55   e89
# 54     경부고속철도1_5  n75   56  n79   61   e93
# 55     경부고속철도1_6   n4   15   n3   16    e4
# 56     경부고속철도1_6   n3   17   n1   18    e3
# 57     경부고속철도1_6   n1   19   n2   21    e1
# 58     경부고속철도1_6   n2   22  n13   28   e9r
# 59     경부고속철도1_6  n13   29  n18   32  e17r
# 60     경부고속철도1_6  n18   33  n28   36   e26
# 61     경부고속철도1_6  n28   37  n42   43  e43r
# 62     경부고속철도1_6  n42   44  n60   49   e61
# 63     경부고속철도1_6  n60   50  n72   54   e81
# 64     경부고속철도1_6  n72   55  n75   58   e89
# 65     경부고속철도1_6  n75   59  n79   64   e93
# 66     경부고속철도1_7   n4   18   n3   19    e4
# 67     경부고속철도1_7   n3   20   n1   21    e3
# 68     경부고속철도1_7   n1   22   n2   24    e1
# 69     경부고속철도1_7   n2   25  n13   31   e9r
# 70     경부고속철도1_7  n13   32  n18   35  e17r
# 71     경부고속철도1_7  n18   36  n28   39   e26
# 72     경부고속철도1_7  n28   40  n42   46  e43r
# 73     경부고속철도1_7  n42   47  n60   52   e61
# 74     경부고속철도1_7  n60   53  n72   57   e81
# 75     경부고속철도1_7  n72   58  n75   61   e89
# 76     경부고속철도1_7  n75   62  n79   67   e93
# 77     경부고속철도1_8   n4   21   n3   22    e4
# 78     경부고속철도1_8   n3   23   n1   24    e3
# 79     경부고속철도1_8   n1   25   n2   27    e1
# 80     경부고속철도1_8   n2   28  n13   34   e9r
# 81     경부고속철도1_8  n13   35  n18   38  e17r
# 82     경부고속철도1_8  n18   39  n28   42   e26
# 83     경부고속철도1_8  n28   43  n42   49  e43r
# 84     경부고속철도1_8  n42   50  n60   55   e61
# 85     경부고속철도1_8  n60   56  n72   60   e81
# 86     경부고속철도1_8  n72   61  n75   64   e89
# 87     경부고속철도1_8  n75   65  n79   70   e93
# 88     경부고속철도1_9   n4   24   n3   25    e4
# 89     경부고속철도1_9   n3   26   n1   27    e3
# 90     경부고속철도1_9   n1   28   n2   30    e1
# 91     경부고속철도1_9   n2   31  n13   37   e9r
# 92     경부고속철도1_9  n13   38  n18   41  e17r
# 93     경부고속철도1_9  n18   42  n28   45   e26
# 94     경부고속철도1_9  n28   46  n42   52  e43r
# 95     경부고속철도1_9  n42   53  n60   58   e61
# 96     경부고속철도1_9  n60   59  n72   63   e81
# 97     경부고속철도1_9  n72   64  n75   67   e89
# 98     경부고속철도1_9  n75   68  n79   73   e93
# 99    경부고속철도1_10   n4   27   n3   28    e4
# 100   경부고속철도1_10   n3   29   n1   30    e3
# 101   경부고속철도1_10   n1   31   n2   33    e1
# 102   경부고속철도1_10   n2   34  n13   40   e9r
# 103   경부고속철도1_10  n13   41  n18   44  e17r
# 104   경부고속철도1_10  n18   45  n28   48   e26
# 105   경부고속철도1_10  n28   49  n42   55  e43r
# 106   경부고속철도1_10  n42   56  n60   61   e61
# 107   경부고속철도1_10  n60   62  n72   66   e81
# 108   경부고속철도1_10  n72   67  n75   70   e89
# 109   경부고속철도1_10  n75   71  n79   76   e93
# 110   경부고속철도1_11   n4   30   n3   31    e4
# 111   경부고속철도1_11   n3   32   n1   33    e3
# 112   경부고속철도1_11   n1   34   n2   36    e1
# 113   경부고속철도1_11   n2   37  n13   43   e9r
# 114   경부고속철도1_11  n13   44  n18   47  e17r
# 115   경부고속철도1_11  n18   49  n28   52   e26
# 116   경부고속철도1_11  n28   53  n42   59  e43r
# 117   경부고속철도1_11  n42   60  n60   65   e61
# 118   경부고속철도1_11  n60   66  n72   70   e81
# 119   경부고속철도1_11  n72   71  n75   74   e89
# 120   경부고속철도1_11  n75   75  n79   80   e93
# 121   경부고속철도1_12   n4   33   n3   34    e4
# 122   경부고속철도1_12   n3   35   n1   36    e3
# 123   경부고속철도1_12   n1   37   n2   39    e1
# 124   경부고속철도1_12   n2   40  n13   46   e9r
# 125   경부고속철도1_12  n13   47  n18   50  e17r
# 126   경부고속철도1_12  n18   51  n28   54   e26
# 127   경부고속철도1_12  n28   55  n42   61  e43r
# 128   경부고속철도1_12  n42   62  n60   67   e61
# 129   경부고속철도1_12  n60   68  n72   72   e81
# 130   경부고속철도1_12  n72   73  n75   76   e89
# 131   경부고속철도1_12  n75   77  n79   82   e93
# 132    경부고속철도2_1  n79    0  n75    5  e93r
# 133    경부고속철도2_1  n75    6  n72    9  e89r
# 134    경부고속철도2_1  n72   10  n60   14  e81r
# 135    경부고속철도2_1  n60   15  n42   20  e61r
# 136    경부고속철도2_1  n42   21  n28   27   e43
# 137    경부고속철도2_1  n28   28  n18   31  e26r
# 138    경부고속철도2_1  n18   32  n13   35   e17
# 139    경부고속철도2_1  n13   36   n2   42    e9
# 140    경부고속철도2_1   n2   43   n1   45   e1r
# 141    경부고속철도2_1   n1   46   n3   47   e3r
# 142    경부고속철도2_1   n3   48   n1   49    e3
# 143    경부고속철도2_1   n1   50   n4   51   e2r
# 144    경부고속철도2_2  n79    3  n75    8  e93r
# 145    경부고속철도2_2  n75    9  n72   12  e89r
# 146    경부고속철도2_2  n72   13  n60   17  e81r
# 147    경부고속철도2_2  n60   18  n42   23  e61r
# 148    경부고속철도2_2  n42   24  n28   30   e43
# 149    경부고속철도2_2  n28   31  n18   34  e26r
# 150    경부고속철도2_2  n18   35  n13   38   e17
# 151    경부고속철도2_2  n13   39   n2   45    e9
# 152    경부고속철도2_2   n2   46   n1   48   e1r
# 153    경부고속철도2_2   n1   49   n3   50   e3r
# 154    경부고속철도2_2   n3   51   n4   52   e4r
# 155    경부고속철도2_3  n79    6  n75   11  e93r
# 156    경부고속철도2_3  n75   12  n72   15  e89r
# 157    경부고속철도2_3  n72   16  n60   20  e81r
# 158    경부고속철도2_3  n60   21  n42   26  e61r
# 159    경부고속철도2_3  n42   27  n28   33   e43
# 160    경부고속철도2_3  n28   34  n18   37  e26r
# 161    경부고속철도2_3  n18   38  n13   41   e17
# 162    경부고속철도2_3  n13   42   n2   48    e9
# 163    경부고속철도2_4  n79    9  n75   14  e93r
# 164    경부고속철도2_4  n75   15  n72   18  e89r
# 165    경부고속철도2_4  n72   19  n60   23  e81r
# 166    경부고속철도2_4  n60   24  n42   29  e61r
# 167    경부고속철도2_4  n42   30  n28   36   e43
# 168    경부고속철도2_4  n28   37  n18   40  e26r
# 169    경부고속철도2_4  n18   41  n13   44   e17
# 170    경부고속철도2_4  n13   45   n2   51    e9
# 171    경부고속철도2_5  n79   12  n75   17  e93r
# 172    경부고속철도2_5  n75   18  n72   21  e89r
# 173    경부고속철도2_5  n72   22  n60   26  e81r
# 174    경부고속철도2_5  n60   27  n42   32  e61r
# 175    경부고속철도2_5  n42   33  n28   39   e43
# 176    경부고속철도2_5  n28   40  n18   43  e26r
# 177    경부고속철도2_5  n18   44  n13   47   e17
# 178    경부고속철도2_5  n13   48  n14   50  e14r
# 179    경부고속철도2_5  n14   51   n9   53  e12r
# 180    경부고속철도2_5   n9   54   n7   57   e10
# 181    경부고속철도2_5   n7   58   n1   61    e6
# 182    경부고속철도2_5   n1   62   n3   63   e3r
# 183    경부고속철도2_5   n3   64   n4   65   e4r
# 184    경부고속철도2_6  n79   15  n75   20  e93r
# 185    경부고속철도2_6  n75   21  n72   24  e89r
# 186    경부고속철도2_6  n72   25  n60   29  e81r
# 187    경부고속철도2_6  n60   30  n42   35  e61r
# 188    경부고속철도2_6  n42   36  n28   42   e43
# 189    경부고속철도2_6  n28   43  n18   46  e26r
# 190    경부고속철도2_6  n18   47  n13   50   e17
# 191    경부고속철도2_6  n13   51  n14   53  e14r
# 192    경부고속철도2_6  n14   54   n9   56  e12r
# 193    경부고속철도2_6   n9   57   n7   60   e10
# 194    경부고속철도2_6   n7   61   n1   64    e6
# 195    경부고속철도2_6   n1   66   n3   67   e3r
# 196    경부고속철도2_6   n3   68   n4   69   e4r
# 197    경부고속철도2_7  n79   18  n75   23  e93r
# 198    경부고속철도2_7  n75   24  n72   27  e89r
# 199    경부고속철도2_7  n72   28  n60   32  e81r
# 200    경부고속철도2_7  n60   33  n42   38  e61r
# 201    경부고속철도2_7  n42   39  n28   45   e43
# 202    경부고속철도2_7  n28   46  n18   49  e26r
# 203    경부고속철도2_7  n18   50  n13   53   e17
# 204    경부고속철도2_7  n13   54  n14   56  e14r
# 205    경부고속철도2_7  n14   57   n9   59  e12r
# 206    경부고속철도2_7   n9   60   n7   63   e10
# 207    경부고속철도2_7   n7   64   n1   67    e6
# 208    경부고속철도2_7   n1   68   n3   69   e3r
# 209    경부고속철도2_7   n3   70   n4   71   e4r
# 210    경부고속철도2_8  n79   21  n75   26  e93r
# 211    경부고속철도2_8  n75   27  n72   30  e89r
# 212    경부고속철도2_8  n72   31  n60   35  e81r
# 213    경부고속철도2_8  n60   36  n42   41  e61r
# 214    경부고속철도2_8  n42   42  n28   48   e43
# 215    경부고속철도2_8  n28   49  n18   52  e26r
# 216    경부고속철도2_8  n18   53  n13   56   e17
# 217    경부고속철도2_8  n13   57  n14   59  e14r
# 218    경부고속철도2_8  n14   60   n9   62  e12r
# 219    경부고속철도2_8   n9   63   n7   66   e10
# 220    경부고속철도2_8   n7   67   n1   70    e6
# 221    경부고속철도2_8   n1   71   n3   72   e3r
# 222    경부고속철도2_8   n3   73   n4   74   e4r
# 223    경부고속철도2_9  n79   24  n75   29  e93r
# 224    경부고속철도2_9  n75   30  n72   33  e89r
# 225    경부고속철도2_9  n72   34  n60   38  e81r
# 226    경부고속철도2_9  n60   39  n42   44  e61r
# 227    경부고속철도2_9  n42   45  n28   51   e43
# 228    경부고속철도2_9  n28   52  n18   55  e26r
# 229    경부고속철도2_9  n18   56  n13   59   e17
# 230    경부고속철도2_9  n13   60  n14   62  e14r
# 231    경부고속철도2_9  n14   63   n9   65  e12r
# 232    경부고속철도2_9   n9   66   n7   69   e10
# 233    경부고속철도2_9   n7   70   n1   73    e6
# 234    경부고속철도2_9   n1   74   n3   75   e3r
# 235    경부고속철도2_9   n3   76   n4   77   e4r
# 236   경부고속철도2_10  n79   27  n75   32  e93r
# 237   경부고속철도2_10  n75   33  n72   36  e89r
# 238   경부고속철도2_10  n72   37  n60   41  e81r
# 239   경부고속철도2_10  n60   42  n42   47  e61r
# 240   경부고속철도2_10  n42   48  n28   54   e43
# 241   경부고속철도2_10  n28   55  n18   58  e26r
# 242   경부고속철도2_10  n18   59  n13   62   e17
# 243   경부고속철도2_10  n13   63  n14   65  e14r
# 244   경부고속철도2_10  n14   66   n9   68  e12r
# 245   경부고속철도2_10   n9   69   n7   72   e10
# 246   경부고속철도2_10   n7   73   n1   76    e6
# 247   경부고속철도2_10   n1   77   n3   78   e3r
# 248   경부고속철도2_10   n3   79   n4   80   e4r
# 249   경부고속철도2_11  n79   30  n75   35  e93r
# 250   경부고속철도2_11  n75   36  n72   39  e89r
# 251   경부고속철도2_11  n72   40  n60   44  e81r
# 252   경부고속철도2_11  n60   45  n42   50  e61r
# 253   경부고속철도2_11  n42   51  n28   57   e43
# 254   경부고속철도2_11  n28   58  n18   61  e26r
# 255   경부고속철도2_11  n18   62  n13   65   e17
# 256   경부고속철도2_11  n13   66  n14   68  e14r
# 257   경부고속철도2_11  n14   69   n9   71  e12r
# 258   경부고속철도2_11   n9   72   n7   75   e10
# 259   경부고속철도2_11   n7   76   n1   79    e6
# 260   경부고속철도2_11   n1   80   n3   81   e3r
# 261   경부고속철도2_11   n3   82   n4   83   e4r
# 262       경부선1_1   n4    0   n1    1    e2
# 263       경부선1_1   n1    2   n7    5   e6r
# 264       경부선1_1   n7    6   n9    9  e10r
# 265       경부선1_1   n9   10  n14   12   e12
# 266       경부선1_1  n14   13  n17   16  e16r
# 267       경부선1_1  n17   17  n28   21   e25
# 268       경부선1_1  n28   22  n41   29  e42r
# 269       경부선1_1  n41   30  n46   32  e55r
# 270       경부선1_1  n46   33  n59   37   e66
# 271       경부선1_1  n59   38  n60   39  e72r
# 272       경부선1_1  n60   40  n63   41   e75
# 273       경부선1_1  n63   42  n70   46   e82
# 274       경부선1_1  n70   47  n73   48   e86
# 275       경부선1_1  n73   49  n76   51   e90
# 276       경부선1_1  n76   52  n77   54   e92
# 277       경부선1_1  n77   55  n79   57   e94
# 278       경부선1_2   n4    6   n1    7    e2
# 279       경부선1_2   n1    8   n7   11   e6r
# 280       경부선1_2   n7   12   n9   15  e10r
# 281       경부선1_2   n9   16  n14   18   e12
# 282       경부선1_2  n14   19  n17   22  e16r
# 283       경부선1_2  n17   23  n28   27   e25
# 284       경부선1_2  n28   28  n41   35  e42r
# 285       경부선1_2  n41   36  n46   38  e55r
# 286       경부선1_2  n46   39  n59   43   e66
# 287       경부선1_2  n59   44  n60   45  e72r
# 288       경부선1_2  n60   46  n63   47   e75
# 289       경부선1_2  n63   48  n70   52   e82
# 290       경부선1_2  n70   53  n73   54   e86
# 291       경부선1_2  n73   55  n76   57   e90
# 292       경부선1_2  n76   58  n77   60   e92
# 293       경부선1_2  n77   61  n79   63   e94
# 294       경부선1_3   n4   12   n1   13    e2
# 295       경부선1_3   n1   14   n7   17   e6r
# 296       경부선1_3   n7   18   n9   21  e10r
# 297       경부선1_3   n9   22  n14   24   e12
# 298       경부선1_3  n14   25  n17   28  e16r
# 299       경부선1_3  n17   29  n28   33   e25
# 300       경부선1_3  n28   34  n41   41  e42r
# 301       경부선1_3  n41   42  n46   44  e55r
# 302       경부선1_3  n46   45  n59   49   e66
# 303       경부선1_3  n59   50  n60   51  e72r
# 304       경부선1_3  n60   52  n63   53   e75
# 305       경부선1_3  n63   54  n70   58   e82
# 306       경부선1_3  n70   59  n73   60   e86
# 307       경부선1_3  n73   61  n76   63   e90
# 308       경부선1_3  n76   64  n77   66   e92
# 309       경부선1_3  n77   67  n79   69   e94
# 310       경부선1_4   n4   18   n1   19    e2
# 311       경부선1_4   n1   20   n7   23   e6r
# 312       경부선1_4   n7   24   n9   27  e10r
# 313       경부선1_4   n9   28  n14   30   e12
# 314       경부선1_4  n14   31  n17   34  e16r
# 315       경부선1_4  n17   35  n28   39   e25
# 316       경부선1_4  n28   40  n41   47  e42r
# 317       경부선1_4  n41   48  n46   50  e55r
# 318       경부선1_4  n46   51  n59   55   e66
# 319       경부선1_4  n59   56  n60   57  e72r
# 320       경부선1_4  n60   58  n63   59   e75
# 321       경부선1_4  n63   60  n70   64   e82
# 322       경부선1_4  n70   65  n73   66   e86
# 323       경부선1_4  n73   67  n76   69   e90
# 324       경부선1_4  n76   70  n77   72   e92
# 325       경부선1_4  n77   73  n79   75   e94
# 326       경부선1_5   n4   24   n1   25    e2
# 327       경부선1_5   n1   26   n7   29   e6r
# 328       경부선1_5   n7   30   n9   33  e10r
# 329       경부선1_5   n9   34  n14   36   e12
# 330       경부선1_5  n14   37  n17   40  e16r
# 331       경부선1_5  n17   41  n28   45   e25
# 332       경부선1_5  n28   46  n41   53  e42r
# 333       경부선1_5  n41   54  n46   56  e55r
# 334       경부선1_5  n46   57  n59   61   e66
# 335       경부선1_5  n59   62  n60   63  e72r
# 336       경부선1_5  n60   64  n63   65   e75
# 337       경부선1_5  n63   66  n70   70   e82
# 338       경부선1_5  n70   71  n73   72   e86
# 339       경부선1_5  n73   73  n76   75   e90
# 340       경부선1_5  n76   76  n77   78   e92
# 341       경부선1_5  n77   79  n79   81   e94
# 342       경부선1_6   n4   30   n1   31    e2
# 343       경부선1_6   n1   32   n7   35   e6r
# 344       경부선1_6   n7   36   n9   39  e10r
# 345       경부선1_6   n9   40  n14   42   e12
# 346       경부선1_6  n14   43  n17   46  e16r
# 347       경부선1_6  n17   47  n28   51   e25
# 348       경부선1_6  n28   52  n41   59  e42r
# 349       경부선1_6  n41   60  n46   62  e55r
# 350       경부선1_6  n46   63  n59   67   e66
# 351       경부선1_6  n59   68  n60   69  e72r
# 352       경부선1_6  n60   70  n63   71   e75
# 353       경부선1_6  n63   72  n70   76   e82
# 354       경부선1_6  n70   77  n73   78   e86
# 355       경부선1_6  n73   79  n76   81   e90
# 356       경부선1_6  n76   82  n77   84   e92
# 357       경부선1_6  n77   85  n79   87   e94
# 358       경부선2_1  n79    0  n77    2  e94r
# 359       경부선2_1  n77    3  n76    5  e92r
# 360       경부선2_1  n76    6  n73    8  e90r
# 361       경부선2_1  n73    9  n70   10  e86r
# 362       경부선2_1  n70   11  n63   15  e82r
# 363       경부선2_1  n63   16  n60   17  e75r
# 364       경부선2_1  n60   18  n59   19   e72
# 365       경부선2_1  n59   20  n46   24  e66r
# 366       경부선2_1  n46   25  n41   27   e55
# 367       경부선2_1  n41   28  n28   35   e42
# 368       경부선2_1  n28   36  n17   40  e25r
# 369       경부선2_1  n17   41  n14   44   e16
# 370       경부선2_1  n14   45   n9   47  e12r
# 371       경부선2_1   n9   48   n7   51   e10
# 372       경부선2_1   n7   52   n1   55    e6
# 373       경부선2_1   n1   56   n4   57   e2r
# 374       경부선2_2  n79    6  n77    8  e94r
# 375       경부선2_2  n77    9  n76   11  e92r
# 376       경부선2_2  n76   12  n73   14  e90r
# 377       경부선2_2  n73   15  n70   16  e86r
# 378       경부선2_2  n70   17  n63   21  e82r
# 379       경부선2_2  n63   22  n60   23  e75r
# 380       경부선2_2  n60   24  n59   25   e72
# 381       경부선2_2  n59   26  n46   30  e66r
# 382       경부선2_2  n46   31  n41   33   e55
# 383       경부선2_2  n41   34  n28   41   e42
# 384       경부선2_2  n28   42  n17   46  e25r
# 385       경부선2_2  n17   47  n14   50   e16
# 386       경부선2_2  n14   51   n9   53  e12r
# 387       경부선2_2   n9   54   n7   57   e10
# 388       경부선2_2   n7   58   n1   61    e6
# 389       경부선2_2   n1   62   n4   63   e2r
# 390       경부선2_3  n79   12  n77   14  e94r
# 391       경부선2_3  n77   15  n76   17  e92r
# 392       경부선2_3  n76   18  n73   20  e90r
# 393       경부선2_3  n73   21  n70   22  e86r
# 394       경부선2_3  n70   23  n63   27  e82r
# 395       경부선2_3  n63   28  n60   29  e75r
# 396       경부선2_3  n60   30  n59   31   e72
# 397       경부선2_3  n59   32  n46   36  e66r
# 398       경부선2_3  n46   37  n41   39   e55
# 399       경부선2_3  n41   40  n28   47   e42
# 400       경부선2_3  n28   48  n17   52  e25r
# 401       경부선2_3  n17   53  n14   56   e16
# 402       경부선2_3  n14   57   n9   59  e12r
# 403       경부선2_3   n9   60   n7   63   e10
# 404       경부선2_3   n7   64   n1   67    e6
# 405       경부선2_3   n1   68   n4   69   e2r
# 406       경부선2_4  n79   18  n77   20  e94r
# 407       경부선2_4  n77   21  n76   23  e92r
# 408       경부선2_4  n76   24  n73   26  e90r
# 409       경부선2_4  n73   27  n70   28  e86r
# 410       경부선2_4  n70   29  n63   33  e82r
# 411       경부선2_4  n63   34  n60   35  e75r
# 412       경부선2_4  n60   36  n59   37   e72
# 413       경부선2_4  n59   38  n46   42  e66r
# 414       경부선2_4  n46   43  n41   45   e55
# 415       경부선2_4  n41   46  n28   53   e42
# 416       경부선2_4  n28   54  n17   58  e25r
# 417       경부선2_4  n17   59  n14   62   e16
# 418       경부선2_4  n14   63   n9   65  e12r
# 419       경부선2_4   n9   66   n7   69   e10
# 420       경부선2_4   n7   70   n1   73    e6
# 421       경부선2_4   n1   74   n4   75   e2r
# 422       경부선2_5  n79   24  n77   26  e94r
# 423       경부선2_5  n77   27  n76   29  e92r
# 424       경부선2_5  n76   30  n73   32  e90r
# 425       경부선2_5  n73   33  n70   34  e86r
# 426       경부선2_5  n70   35  n63   39  e82r
# 427       경부선2_5  n63   40  n60   41  e75r
# 428       경부선2_5  n60   42  n59   43   e72
# 429       경부선2_5  n59   44  n46   48  e66r
# 430       경부선2_5  n46   49  n41   51   e55
# 431       경부선2_5  n41   52  n28   59   e42
# 432       경부선2_5  n28   60  n17   64  e25r
# 433       경부선2_5  n17   65  n14   68   e16
# 434       경부선2_5  n14   69   n9   71  e12r
# 435       경부선2_5   n9   72   n7   75   e10
# 436       경부선2_5   n7   76   n1   79    e6
# 437       경부선2_5   n1   80   n4   81   e2r
# 438       경부선2_6  n79   30  n77   32  e94r
# 439       경부선2_6  n77   33  n76   35  e92r
# 440       경부선2_6  n76   36  n73   38  e90r
# 441       경부선2_6  n73   39  n70   40  e86r
# 442       경부선2_6  n70   41  n63   45  e82r
# 443       경부선2_6  n63   46  n60   47  e75r
# 444       경부선2_6  n60   48  n59   49   e72
# 445       경부선2_6  n59   50  n46   54  e66r
# 446       경부선2_6  n46   55  n41   57   e55
# 447       경부선2_6  n41   58  n28   65   e42
# 448       경부선2_6  n28   66  n17   70  e25r
# 449       경부선2_6  n17   71  n14   74   e16
# 450       경부선2_6  n14   75   n9   77  e12r
# 451       경부선2_6   n9   78   n7   81   e10
# 452       경부선2_6   n7   82   n1   85    e6
# 453       경부선2_6   n1   86   n4   87   e2r
# 454       경북선1_1  n43    0  n40    3   e53
# 455       경북선1_1  n40    4  n36    6   e47
# 456       경북선1_1  n36    7  n38    9   e45
# 457       경북선1_1  n38   10  n41   13   e49
# 458       경북선2_1  n41    0  n38    3  e49r
# 459       경북선2_1  n38    4  n36    6  e45r
# 460       경북선2_1  n36    7  n40    9  e47r
# 461       경북선2_1  n40   10  n43   13  e53r
# 462       경전선1_1  n48    0  n57    3   e65
# 463       경전선1_1  n57    4  n64    7   e74
# 464       경전선1_1  n64    8  n65   11  e79r
# 465       경전선1_1  n65   12  n62   14  e76r
# 466       경전선1_1  n62   15  n66   21  e78r
# 467       경전선1_1  n66   22  n71   26  e83r
# 468       경전선1_1  n71   27  n73   31  e87r
# 469       경전선1_2  n48   18  n57   21   e65
# 470       경전선1_2  n57   22  n64   25   e74
# 471       경전선1_2  n64   26  n65   29  e79r
# 472       경전선1_2  n65   30  n62   32  e76r
# 473       경전선1_2  n62   33  n66   39  e78r
# 474       경전선1_2  n66   40  n71   44  e83r
# 475       경전선1_2  n71   45  n73   49  e87r
# 476       경전선2_1  n73    0  n71    4   e87
# 477       경전선2_1  n71    5  n66    9   e83
# 478       경전선2_1  n66   10  n62   16   e78
# 479       경전선2_1  n62   17  n65   19   e76
# 480       경전선2_1  n65   20  n64   23   e79
# 481       경전선2_1  n64   24  n57   27  e74r
# 482       경전선2_1  n57   28  n48   31  e65r
# 483       경전선2_2  n73   18  n71   22   e87
# 484       경전선2_2  n71   23  n66   27   e83
# 485       경전선2_2  n66   28  n62   34   e78
# 486       경전선2_2  n62   35  n65   37   e76
# 487       경전선2_2  n65   38  n64   41   e79
# 488       경전선2_2  n64   42  n57   45  e74r
# 489       경전선2_2  n57   46  n48   49  e65r
# 490       동해선1_1  n55    0  n58    2   e69
# 491       동해선1_1  n58    3  n69    9   e77
# 492       동해선1_1  n69   10  n74   14   e85
# 493       동해선1_1  n74   15  n72   18   e88
# 494       동해선1_2  n55   18  n58   20   e69
# 495       동해선1_2  n58   21  n69   27   e77
# 496       동해선1_2  n69   28  n74   32   e85
# 497       동해선1_2  n74   33  n72   36   e88
# 498       동해선2_1  n72    0  n74    3  e88r
# 499       동해선2_1  n74    4  n69    8  e85r
# 500       동해선2_1  n69    9  n58   15  e77r
# 501       동해선2_1  n58   16  n55   18  e69r
# 502       동해선2_2  n72   18  n74   21  e88r
# 503       동해선2_2  n74   22  n69   26  e85r
# 504       동해선2_2  n69   27  n58   33  e77r
# 505       동해선2_2  n58   34  n55   36  e69r
# 506       영동선1_1  n51    0  n55    3   e67
# 507       영동선1_1  n55    4  n54    9   e68
# 508       영동선1_1  n54   10  n50   15   e64
# 509       영동선1_1  n50   16  n43   20   e58
# 510       영동선2_1  n43    0  n50    4  e58r
# 511       영동선2_1  n50    5  n54   10  e64r
# 512       영동선2_1  n54   11  n55   16  e68r
# 513       영동선2_1  n55   17  n51   20  e67r
# 514       장항선1_1  n14    0  n13    2   e14
# 515       장항선1_1  n13    3  n11    5  e96r
# 516       장항선1_1  n11    6  n10    8   e13
# 517       장항선1_1  n10    9  n15   12   e15
# 518       장항선1_1  n15   13  n16   15   e18
# 519       장항선1_1  n16   16  n27   19   e24
# 520       장항선1_1  n27   20  n30   23  e35r
# 521       장항선1_2  n14    9  n13   11   e14
# 522       장항선1_2  n13   12  n11   14  e96r
# 523       장항선1_2  n11   15  n10   17   e13
# 524       장항선1_2  n10   18  n15   21   e15
# 525       장항선1_2  n15   22  n16   24   e18
# 526       장항선1_2  n16   25  n27   28   e24
# 527       장항선1_2  n27   29  n30   32  e35r
# 528       장항선1_3  n14   18  n13   20   e14
# 529       장항선1_3  n13   21  n11   23  e96r
# 530       장항선1_3  n11   24  n10   26   e13
# 531       장항선1_3  n10   27  n15   30   e15
# 532       장항선1_3  n15   31  n16   33   e18
# 533       장항선1_3  n16   34  n27   37   e24
# 534       장항선1_3  n27   38  n30   41  e35r
# 535       장항선2_1  n30    0  n27    3   e35
# 536       장항선2_1  n27    4  n16    7  e24r
# 537       장항선2_1  n16    8  n15   10  e18r
# 538       장항선2_1  n15   11  n10   14  e15r
# 539       장항선2_1  n10   15  n11   17  e13r
# 540       장항선2_1  n11   18  n13   20   e96
# 541       장항선2_1  n13   21  n14   23  e14r
# 542       장항선2_2  n30    9  n27   12   e35
# 543       장항선2_2  n27   13  n16   16  e24r
# 544       장항선2_2  n16   17  n15   19  e18r
# 545       장항선2_2  n15   20  n10   23  e15r
# 546       장항선2_2  n10   24  n11   26  e13r
# 547       장항선2_2  n11   27  n13   29   e96
# 548       장항선2_2  n13   30  n14   32  e14r
# 549       장항선2_3  n30   18  n27   21   e35
# 550       장항선2_3  n27   22  n16   25  e24r
# 551       장항선2_3  n16   26  n15   28  e18r
# 552       장항선2_3  n15   29  n10   32  e15r
# 553       장항선2_3  n10   33  n11   35  e13r
# 554       장항선2_3  n11   36  n13   38   e96
# 555       장항선2_3  n13   39  n14   41  e14r
# 556       전라선1_1  n30    0  n33    3  e39r
# 557       전라선1_1  n33    4  n45    9   e48
# 558       전라선1_1  n45   10  n47   12   e59
# 559       전라선1_1  n47   13  n56   15   e63
# 560       전라선1_1  n56   16  n62   19   e71
# 561       전라선1_1  n62   20  n68   23   e80
# 562       전라선1_2  n30   12  n33   15  e39r
# 563       전라선1_2  n33   16  n45   21   e48
# 564       전라선1_2  n45   22  n47   24   e59
# 565       전라선1_2  n47   25  n56   27   e63
# 566       전라선1_2  n56   28  n62   31   e71
# 567       전라선1_2  n62   32  n68   35   e80
# 568       전라선1_3  n30   24  n33   27  e39r
# 569       전라선1_3  n33   28  n45   33   e48
# 570       전라선1_3  n45   34  n47   36   e59
# 571       전라선1_3  n47   37  n56   39   e63
# 572       전라선1_3  n56   40  n62   43   e71
# 573       전라선1_3  n62   44  n68   47   e80
# 574       전라선2_1  n68    0  n62    3  e80r
# 575       전라선2_1  n62    4  n56    7  e71r
# 576       전라선2_1  n56    8  n47   10  e63r
# 577       전라선2_1  n47   11  n45   13  e59r
# 578       전라선2_1  n45   14  n33   19  e48r
# 579       전라선2_1  n33   20  n30   23   e39
# 580       전라선2_2  n68   12  n62   15  e80r
# 581       전라선2_2  n62   16  n56   19  e71r
# 582       전라선2_2  n56   20  n47   22  e63r
# 583       전라선2_2  n47   23  n45   25  e59r
# 584       전라선2_2  n45   26  n33   31  e48r
# 585       전라선2_2  n33   32  n30   35   e39
# 586       전라선2_3  n68   24  n62   27  e80r
# 587       전라선2_3  n62   28  n56   31  e71r
# 588       전라선2_3  n56   32  n47   34  e63r
# 589       전라선2_3  n47   35  n45   37  e59r
# 590       전라선2_3  n45   38  n33   43  e48r
# 591       전라선2_3  n33   44  n30   47   e39
# 592       중앙선1_1   n3    0   n5    1   e5r
# 593       중앙선1_1   n5    2   n6    3   e7r
# 594       중앙선1_1   n6    4   n8    6   e8r
# 595       중앙선1_1   n8    7  n12   10  e11r
# 596       중앙선1_1  n12   11  n22   15  e19r
# 597       중앙선1_1  n22   16  n29   19  e32r
# 598       중앙선1_1  n29   20  n31   21  e37r
# 599       중앙선1_1  n31   22  n35   25  e40r
# 600       중앙선1_1  n35   26  n39   28  e46r
# 601       중앙선1_1  n39   29  n43   30   e52
# 602       중앙선1_1  n43   31  n49   34   e56
# 603       중앙선1_1  n49   35  n52   38   e60
# 604       중앙선1_1  n52   39  n67   44   e73
# 605       중앙선1_1  n67   45  n72   49   e84
# 606       중앙선1_1  n72   50  n78   54   e91
# 607       중앙선1_1  n78   55  n79   61   e95
# 608       중앙선1_2   n3    6   n5    7   e5r
# 609       중앙선1_2   n5    8   n6    9   e7r
# 610       중앙선1_2   n6   10   n8   12   e8r
# 611       중앙선1_2   n8   13  n12   16  e11r
# 612       중앙선1_2  n12   17  n22   21  e19r
# 613       중앙선1_2  n22   22  n29   25  e32r
# 614       중앙선1_2  n29   26  n31   27  e37r
# 615       중앙선1_2  n31   28  n35   31  e40r
# 616       중앙선1_2  n35   32  n39   34  e46r
# 617       중앙선1_2  n39   35  n43   36   e52
# 618       중앙선1_2  n43   37  n49   40   e56
# 619       중앙선1_2  n49   41  n52   44   e60
# 620       중앙선1_2  n52   45  n67   50   e73
# 621       중앙선1_2  n67   51  n72   55   e84
# 622       중앙선1_2  n72   56  n78   60   e91
# 623       중앙선1_2  n78   61  n79   67   e95
# 624       중앙선1_3   n3   12   n5   13   e5r
# 625       중앙선1_3   n5   14   n6   15   e7r
# 626       중앙선1_3   n6   16   n8   18   e8r
# 627       중앙선1_3   n8   19  n12   22  e11r
# 628       중앙선1_3  n12   23  n22   27  e19r
# 629       중앙선1_3  n22   28  n29   31  e32r
# 630       중앙선1_3  n29   32  n31   33  e37r
# 631       중앙선1_3  n31   34  n35   37  e40r
# 632       중앙선1_3  n35   38  n39   40  e46r
# 633       중앙선1_3  n39   41  n43   42   e52
# 634       중앙선1_3  n43   43  n49   46   e56
# 635       중앙선1_3  n49   47  n52   50   e60
# 636       중앙선1_3  n52   51  n67   56   e73
# 637       중앙선1_3  n67   57  n72   61   e84
# 638       중앙선1_3  n72   62  n78   66   e91
# 639       중앙선1_3  n78   67  n79   73   e95
# 640       중앙선1_4   n3   18   n5   19   e5r
# 641       중앙선1_4   n5   20   n6   21   e7r
# 642       중앙선1_4   n6   22   n8   24   e8r
# 643       중앙선1_4   n8   25  n12   28  e11r
# 644       중앙선1_4  n12   29  n22   33  e19r
# 645       중앙선1_4  n22   34  n29   37  e32r
# 646       중앙선1_4  n29   38  n31   39  e37r
# 647       중앙선1_4  n31   40  n35   43  e40r
# 648       중앙선1_4  n35   44  n39   46  e46r
# 649       중앙선1_4  n39   47  n43   48   e52
# 650       중앙선1_4  n43   49  n49   52   e56
# 651       중앙선1_4  n49   53  n52   56   e60
# 652       중앙선1_4  n52   57  n67   62   e73
# 653       중앙선1_4  n67   63  n72   67   e84
# 654       중앙선1_4  n72   68  n78   72   e91
# 655       중앙선1_4  n78   73  n79   79   e95
# 656       중앙선1_5   n3   24   n5   25   e5r
# 657       중앙선1_5   n5   26   n6   27   e7r
# 658       중앙선1_5   n6   28   n8   30   e8r
# 659       중앙선1_5   n8   31  n12   34  e11r
# 660       중앙선1_5  n12   35  n22   39  e19r
# 661       중앙선1_5  n22   40  n29   43  e32r
# 662       중앙선1_5  n29   44  n31   45  e37r
# 663       중앙선1_5  n31   46  n35   49  e40r
# 664       중앙선1_5  n35   50  n39   52  e46r
# 665       중앙선1_5  n39   53  n43   54   e52
# 666       중앙선1_5  n43   55  n49   58   e56
# 667       중앙선1_5  n49   59  n52   62   e60
# 668       중앙선1_5  n52   63  n67   68   e73
# 669       중앙선1_5  n67   69  n72   73   e84
# 670       중앙선1_5  n72   74  n78   78   e91
# 671       중앙선1_5  n78   79  n79   85   e95
# 672       중앙선1_6   n3   30   n5   31   e5r
# 673       중앙선1_6   n5   32   n6   33   e7r
# 674       중앙선1_6   n6   34   n8   36   e8r
# 675       중앙선1_6   n8   37  n12   40  e11r
# 676       중앙선1_6  n12   41  n22   45  e19r
# 677       중앙선1_6  n22   46  n29   49  e32r
# 678       중앙선1_6  n29   50  n31   51  e37r
# 679       중앙선1_6  n31   52  n35   55  e40r
# 680       중앙선1_6  n35   56  n39   58  e46r
# 681       중앙선1_6  n39   59  n43   60   e52
# 682       중앙선1_6  n43   61  n49   64   e56
# 683       중앙선1_6  n49   65  n52   68   e60
# 684       중앙선1_6  n52   69  n67   74   e73
# 685       중앙선1_6  n67   75  n72   79   e84
# 686       중앙선1_6  n72   80  n78   84   e91
# 687       중앙선1_6  n78   85  n79   91   e95
# 688       중앙선2_1  n79    0  n78    6  e95r
# 689       중앙선2_1  n78    7  n72   11  e91r
# 690       중앙선2_1  n72   12  n67   16  e84r
# 691       중앙선2_1  n67   17  n52   22  e73r
# 692       중앙선2_1  n52   23  n49   26  e60r
# 693       중앙선2_1  n49   27  n43   30  e56r
# 694       중앙선2_1  n43   31  n39   32  e52r
# 695       중앙선2_1  n39   33  n35   35   e46
# 696       중앙선2_1  n35   36  n31   39   e40
# 697       중앙선2_1  n31   40  n29   41   e37
# 698       중앙선2_1  n29   42  n22   45   e32
# 699       중앙선2_1  n22   46  n12   50   e19
# 700       중앙선2_1  n12   51   n8   54   e11
# 701       중앙선2_1   n8   55   n6   57    e8
# 702       중앙선2_1   n6   58   n5   59    e7
# 703       중앙선2_1   n5   60   n3   61    e5
# 704       중앙선2_2  n79    6  n78   12  e95r
# 705       중앙선2_2  n78   13  n72   17  e91r
# 706       중앙선2_2  n72   18  n67   22  e84r
# 707       중앙선2_2  n67   23  n52   28  e73r
# 708       중앙선2_2  n52   29  n49   32  e60r
# 709       중앙선2_2  n49   33  n43   36  e56r
# 710       중앙선2_2  n43   37  n39   38  e52r
# 711       중앙선2_2  n39   39  n35   41   e46
# 712       중앙선2_2  n35   42  n31   45   e40
# 713       중앙선2_2  n31   46  n29   47   e37
# 714       중앙선2_2  n29   48  n22   51   e32
# 715       중앙선2_2  n22   52  n12   56   e19
# 716       중앙선2_2  n12   57   n8   60   e11
# 717       중앙선2_2   n8   61   n6   63    e8
# 718       중앙선2_2   n6   64   n5   65    e7
# 719       중앙선2_2   n5   66   n3   67    e5
# 720       중앙선2_3  n79   12  n78   18  e95r
# 721       중앙선2_3  n78   19  n72   23  e91r
# 722       중앙선2_3  n72   24  n67   28  e84r
# 723       중앙선2_3  n67   29  n52   34  e73r
# 724       중앙선2_3  n52   35  n49   38  e60r
# 725       중앙선2_3  n49   39  n43   42  e56r
# 726       중앙선2_3  n43   43  n39   44  e52r
# 727       중앙선2_3  n39   45  n35   47   e46
# 728       중앙선2_3  n35   48  n31   51   e40
# 729       중앙선2_3  n31   52  n29   53   e37
# 730       중앙선2_3  n29   54  n22   57   e32
# 731       중앙선2_3  n22   58  n12   62   e19
# 732       중앙선2_3  n12   63   n8   66   e11
# 733       중앙선2_3   n8   67   n6   69    e8
# 734       중앙선2_3   n6   70   n5   71    e7
# 735       중앙선2_3   n5   72   n3   73    e5
# 736       중앙선2_4  n79   18  n78   24  e95r
# 737       중앙선2_4  n78   25  n72   29  e91r
# 738       중앙선2_4  n72   30  n67   34  e84r
# 739       중앙선2_4  n67   35  n52   40  e73r
# 740       중앙선2_4  n52   41  n49   44  e60r
# 741       중앙선2_4  n49   45  n43   48  e56r
# 742       중앙선2_4  n43   49  n39   50  e52r
# 743       중앙선2_4  n39   51  n35   53   e46
# 744       중앙선2_4  n35   54  n31   57   e40
# 745       중앙선2_4  n31   58  n29   59   e37
# 746       중앙선2_4  n29   60  n22   63   e32
# 747       중앙선2_4  n22   64  n12   68   e19
# 748       중앙선2_4  n12   69   n8   72   e11
# 749       중앙선2_4   n8   73   n6   75    e8
# 750       중앙선2_4   n6   76   n5   77    e7
# 751       중앙선2_4   n5   78   n3   79    e5
# 752       중앙선2_5  n79   24  n78   30  e95r
# 753       중앙선2_5  n78   31  n72   35  e91r
# 754       중앙선2_5  n72   36  n67   40  e84r
# 755       중앙선2_5  n67   41  n52   46  e73r
# 756       중앙선2_5  n52   47  n49   50  e60r
# 757       중앙선2_5  n49   51  n43   54  e56r
# 758       중앙선2_5  n43   55  n39   56  e52r
# 759       중앙선2_5  n39   57  n35   59   e46
# 760       중앙선2_5  n35   60  n31   63   e40
# 761       중앙선2_5  n31   64  n29   65   e37
# 762       중앙선2_5  n29   66  n22   69   e32
# 763       중앙선2_5  n22   70  n12   74   e19
# 764       중앙선2_5  n12   75   n8   78   e11
# 765       중앙선2_5   n8   79   n6   81    e8
# 766       중앙선2_5   n6   82   n5   83    e7
# 767       중앙선2_5   n5   84   n3   85    e5
# 768       중앙선2_6  n79   30  n78   36  e95r
# 769       중앙선2_6  n78   37  n72   41  e91r
# 770       중앙선2_6  n72   42  n67   46  e84r
# 771       중앙선2_6  n67   47  n52   52  e73r
# 772       중앙선2_6  n52   53  n49   56  e60r
# 773       중앙선2_6  n49   57  n43   60  e56r
# 774       중앙선2_6  n43   61  n39   62  e52r
# 775       중앙선2_6  n39   63  n35   65   e46
# 776       중앙선2_6  n35   66  n31   69   e40
# 777       중앙선2_6  n31   70  n29   71   e37
# 778       중앙선2_6  n29   72  n22   75   e32
# 779       중앙선2_6  n22   76  n12   80   e19
# 780       중앙선2_6  n12   81   n8   84   e11
# 781       중앙선2_6   n8   85   n6   87    e8
# 782       중앙선2_6   n6   88   n5   89    e7
# 783       중앙선2_6   n5   90   n3   91    e5
# 784       충북선1_1  n29    0  n26    3   e34
# 785       충북선1_1  n26    4  n20    7   e27
# 786       충북선1_1  n20    8  n19   12   e23
# 787       충북선1_1  n19   13  n18   14   e21
# 788       충북선1_1  n18   15  n17   17   e20
# 789       충북선1_2  n29   12  n26   15   e34
# 790       충북선1_2  n26   16  n20   19   e27
# 791       충북선1_2  n20   20  n19   24   e23
# 792       충북선1_2  n19   25  n18   26   e21
# 793       충북선1_2  n18   27  n17   29   e20
# 794       충북선1_3  n29   24  n26   27   e34
# 795       충북선1_3  n26   28  n20   31   e27
# 796       충북선1_3  n20   32  n19   36   e23
# 797       충북선1_3  n19   37  n18   38   e21
# 798       충북선1_3  n18   39  n17   41   e20
# 799       충북선2_1  n17    0  n18    2  e20r
# 800       충북선2_1  n18    3  n19    4  e21r
# 801       충북선2_1  n19    5  n20    9  e23r
# 802       충북선2_1  n20   10  n26   13  e27r
# 803       충북선2_1  n26   14  n29   17  e34r
# 804       충북선2_2  n17   12  n18   14  e20r
# 805       충북선2_2  n18   15  n19   16  e21r
# 806       충북선2_2  n19   17  n20   21  e23r
# 807       충북선2_2  n20   22  n26   25  e27r
# 808       충북선2_2  n26   26  n29   29  e34r
# 809       충북선2_3  n17   24  n18   26  e20r
# 810       충북선2_3  n18   27  n19   28  e21r
# 811       충북선2_3  n19   29  n20   33  e23r
# 812       충북선2_3  n20   34  n26   37  e27r
# 813       충북선2_3  n26   38  n29   41  e34r
# 814    호남고속철도1_1   n3    0   n1    1    e3
# 815    호남고속철도1_1   n1    2   n2    4    e1
# 816    호남고속철도1_1   n2    5  n13   11   e9r
# 817    호남고속철도1_1  n13   12  n18   15  e17r
# 818    호남고속철도1_1  n18   16  n21   20   e22
# 819    호남고속철도1_1  n21   21  n30   25   e30
# 820    호남고속철도1_1  n30   26  n37   30   e41
# 821    호남고속철도1_1  n37   31  n48   36   e54
# 822    호남고속철도1_2   n3    6   n1    7    e3
# 823    호남고속철도1_2   n1    8   n2   10    e1
# 824    호남고속철도1_2   n2   11  n13   17   e9r
# 825    호남고속철도1_2  n13   18  n18   21  e17r
# 826    호남고속철도1_2  n18   22  n21   26   e22
# 827    호남고속철도1_2  n21   27  n30   31   e30
# 828    호남고속철도1_2  n30   32  n37   36   e41
# 829    호남고속철도1_2  n37   37  n48   42   e54
# 830    호남고속철도1_3   n3   12   n1   13    e3
# 831    호남고속철도1_3   n1   14   n2   16    e1
# 832    호남고속철도1_3   n2   17  n13   23   e9r
# 833    호남고속철도1_3  n13   24  n18   27  e17r
# 834    호남고속철도1_3  n18   28  n21   32   e22
# 835    호남고속철도1_3  n21   33  n30   37   e30
# 836    호남고속철도1_3  n30   38  n37   42   e41
# 837    호남고속철도1_3  n37   43  n48   48   e54
# 838    호남고속철도1_4   n3   18   n1   19    e3
# 839    호남고속철도1_4   n1   20   n2   22    e1
# 840    호남고속철도1_4   n2   23  n13   29   e9r
# 841    호남고속철도1_4  n13   30  n18   33  e17r
# 842    호남고속철도1_4  n18   34  n21   38   e22
# 843    호남고속철도1_4  n21   39  n30   43   e30
# 844    호남고속철도1_4  n30   44  n37   48   e41
# 845    호남고속철도1_4  n37   49  n48   54   e54
# 846    호남고속철도1_5   n3   24   n1   25    e3
# 847    호남고속철도1_5   n1   26   n2   28    e1
# 848    호남고속철도1_5   n2   29  n13   35   e9r
# 849    호남고속철도1_5  n13   36  n18   39  e17r
# 850    호남고속철도1_5  n18   40  n21   44   e22
# 851    호남고속철도1_5  n21   45  n30   49   e30
# 852    호남고속철도1_5  n30   50  n37   54   e41
# 853    호남고속철도1_5  n37   55  n48   60   e54
# 854    호남고속철도1_6   n3   30   n1   31    e3
# 855    호남고속철도1_6   n1   32   n2   34    e1
# 856    호남고속철도1_6   n2   35  n13   41   e9r
# 857    호남고속철도1_6  n13   42  n18   45  e17r
# 858    호남고속철도1_6  n18   46  n21   50   e22
# 859    호남고속철도1_6  n21   51  n30   55   e30
# 860    호남고속철도1_6  n30   56  n37   60   e41
# 861    호남고속철도1_6  n37   61  n48   66   e54
# 862    호남고속철도2_1  n48    0  n37    5  e54r
# 863    호남고속철도2_1  n37    6  n30   10  e41r
# 864    호남고속철도2_1  n30   11  n21   15  e30r
# 865    호남고속철도2_1  n21   16  n18   20  e22r
# 866    호남고속철도2_1  n18   21  n13   24   e17
# 867    호남고속철도2_1  n13   25   n2   31    e9
# 868    호남고속철도2_1   n2   32   n1   34   e1r
# 869    호남고속철도2_1   n1   35   n3   36   e3r
# 870    호남고속철도2_2  n48    6  n37   11  e54r
# 871    호남고속철도2_2  n37   12  n30   16  e41r
# 872    호남고속철도2_2  n30   17  n21   21  e30r
# 873    호남고속철도2_2  n21   22  n18   26  e22r
# 874    호남고속철도2_2  n18   27  n13   30   e17
# 875    호남고속철도2_2  n13   31   n2   37    e9
# 876    호남고속철도2_2   n2   38   n1   40   e1r
# 877    호남고속철도2_2   n1   41   n3   42   e3r
# 878    호남고속철도2_3  n48   12  n37   17  e54r
# 879    호남고속철도2_3  n37   18  n30   22  e41r
# 880    호남고속철도2_3  n30   23  n21   27  e30r
# 881    호남고속철도2_3  n21   28  n18   32  e22r
# 882    호남고속철도2_3  n18   33  n13   36   e17
# 883    호남고속철도2_3  n13   37   n2   43    e9
# 884    호남고속철도2_3   n2   44   n1   46   e1r
# 885    호남고속철도2_3   n1   47   n3   48   e3r
# 886    호남고속철도2_4  n48   18  n37   23  e54r
# 887    호남고속철도2_4  n37   24  n30   28  e41r
# 888    호남고속철도2_4  n30   29  n21   33  e30r
# 889    호남고속철도2_4  n21   34  n18   38  e22r
# 890    호남고속철도2_4  n18   39  n13   42   e17
# 891    호남고속철도2_4  n13   43   n2   49    e9
# 892    호남고속철도2_5  n48   24  n37   29  e54r
# 893    호남고속철도2_5  n37   30  n30   34  e41r
# 894    호남고속철도2_5  n30   35  n21   39  e30r
# 895    호남고속철도2_5  n21   40  n18   44  e22r
# 896    호남고속철도2_5  n18   45  n13   48   e17
# 897    호남고속철도2_5  n13   49  n14   51  e14r
# 898    호남고속철도2_5  n14   52   n9   54  e12r
# 899    호남고속철도2_5   n9   55   n7   58   e10
# 900    호남고속철도2_5   n7   59   n1   62    e6
# 901    호남고속철도2_5   n1   63   n2   65    e1
# 902    호남고속철도2_6  n48   30  n37   35  e54r
# 903    호남고속철도2_6  n37   36  n30   40  e41r
# 904    호남고속철도2_6  n30   41  n21   45  e30r
# 905    호남고속철도2_6  n21   46  n18   50  e22r
# 906    호남고속철도2_6  n18   51  n13   54   e17
# 907    호남고속철도2_6  n13   55  n14   57  e14r
# 908    호남고속철도2_6  n14   58   n9   60  e12r
# 909    호남고속철도2_6   n9   61   n7   64   e10
# 910    호남고속철도2_6   n7   65   n1   68    e6
# 911    호남고속철도2_6   n1   69   n2   71    e1
# 912       호남선1_1  n28    0  n25    2   e31
# 913       호남선1_1  n25    3  n24    6   e29
# 914       호남선1_1  n24    7  n30   10   e33
# 915       호남선1_1  n30   11  n32   13   e38
# 916       호남선1_1  n32   14  n37   17   e44
# 917       호남선1_1  n37   18  n44   21   e50
# 918       호남선1_1  n44   22  n48   24   e57
# 919       호남선1_1  n48   25  n53   27   e62
# 920       호남선1_1  n53   28  n61   33   e70
# 921       호남선1_2  n28    6  n25    8   e31
# 922       호남선1_2  n25    9  n24   12   e29
# 923       호남선1_2  n24   13  n30   16   e33
# 924       호남선1_2  n30   17  n32   19   e38
# 925       호남선1_2  n32   20  n37   23   e44
# 926       호남선1_2  n37   24  n44   27   e50
# 927       호남선1_2  n44   28  n48   30   e57
# 928       호남선1_2  n48   31  n53   33   e62
# 929       호남선1_2  n53   34  n61   39   e70
# 930       호남선1_3  n28   12  n25   14   e31
# 931       호남선1_3  n25   15  n24   18   e29
# 932       호남선1_3  n24   19  n30   22   e33
# 933       호남선1_3  n30   23  n32   25   e38
# 934       호남선1_3  n32   26  n37   29   e44
# 935       호남선1_3  n37   30  n44   33   e50
# 936       호남선1_3  n44   34  n48   36   e57
# 937       호남선1_3  n48   37  n53   39   e62
# 938       호남선1_3  n53   40  n61   45   e70
# 939       호남선1_4  n28   18  n25   20   e31
# 940       호남선1_4  n25   21  n24   24   e29
# 941       호남선1_4  n24   25  n30   28   e33
# 942       호남선1_4  n30   29  n32   31   e38
# 943       호남선1_4  n32   32  n37   35   e44
# 944       호남선1_4  n37   36  n44   39   e50
# 945       호남선1_4  n44   40  n48   42   e57
# 946       호남선1_4  n48   43  n53   45   e62
# 947       호남선1_4  n53   46  n61   51   e70
# 948       호남선1_5  n28   24  n25   26   e31
# 949       호남선1_5  n25   27  n24   30   e29
# 950       호남선1_5  n24   31  n30   34   e33
# 951       호남선1_5  n30   35  n32   37   e38
# 952       호남선1_5  n32   38  n37   41   e44
# 953       호남선1_5  n37   42  n44   45   e50
# 954       호남선1_5  n44   46  n48   48   e57
# 955       호남선1_5  n48   49  n53   51   e62
# 956       호남선1_5  n53   52  n61   57   e70
# 957       호남선1_6  n28   30  n25   32   e31
# 958       호남선1_6  n25   33  n24   36   e29
# 959       호남선1_6  n24   37  n30   40   e33
# 960       호남선1_6  n30   41  n32   43   e38
# 961       호남선1_6  n32   44  n37   47   e44
# 962       호남선1_6  n37   48  n44   51   e50
# 963       호남선1_6  n44   52  n48   54   e57
# 964       호남선1_6  n48   55  n53   57   e62
# 965       호남선1_6  n53   58  n61   63   e70
# 966       호남선2_1  n61    0  n53    5  e70r
# 967       호남선2_1  n53    6  n48    8  e62r
# 968       호남선2_1  n48    9  n44   11  e57r
# 969       호남선2_1  n44   12  n37   15  e50r
# 970       호남선2_1  n37   16  n32   19  e44r
# 971       호남선2_1  n32   20  n30   22  e38r
# 972       호남선2_1  n30   23  n24   26  e33r
# 973       호남선2_1  n24   27  n25   30  e29r
# 974       호남선2_1  n25   31  n28   33  e31r
# 975       호남선2_2  n61    6  n53   11  e70r
# 976       호남선2_2  n53   12  n48   14  e62r
# 977       호남선2_2  n48   15  n44   17  e57r
# 978       호남선2_2  n44   18  n37   21  e50r
# 979       호남선2_2  n37   22  n32   25  e44r
# 980       호남선2_2  n32   26  n30   28  e38r
# 981       호남선2_2  n30   29  n24   32  e33r
# 982       호남선2_2  n24   33  n25   36  e29r
# 983       호남선2_2  n25   37  n28   39  e31r
# 984       호남선2_3  n61   12  n53   17  e70r
# 985       호남선2_3  n53   18  n48   20  e62r
# 986       호남선2_3  n48   21  n44   23  e57r
# 987       호남선2_3  n44   24  n37   27  e50r
# 988       호남선2_3  n37   28  n32   31  e44r
# 989       호남선2_3  n32   32  n30   34  e38r
# 990       호남선2_3  n30   35  n24   38  e33r
# 991       호남선2_3  n24   39  n25   42  e29r
# 992       호남선2_3  n25   43  n28   45  e31r
# 993       호남선2_4  n61   18  n53   23  e70r
# 994       호남선2_4  n53   24  n48   26  e62r
# 995       호남선2_4  n48   27  n44   29  e57r
# 996       호남선2_4  n44   30  n37   33  e50r
# 997       호남선2_4  n37   34  n32   37  e44r
# 998       호남선2_4  n32   38  n30   40  e38r
# 999       호남선2_4  n30   41  n24   44  e33r
# 1000      호남선2_4  n24   45  n25   48  e29r
# 1001      호남선2_4  n25   49  n28   51  e31r
# 1002      호남선2_5  n61   24  n53   29  e70r
# 1003      호남선2_5  n53   30  n48   32  e62r
# 1004      호남선2_5  n48   33  n44   35  e57r
# 1005      호남선2_5  n44   36  n37   39  e50r
# 1006      호남선2_5  n37   40  n32   43  e44r
# 1007      호남선2_5  n32   44  n30   46  e38r
# 1008      호남선2_5  n30   47  n24   50  e33r
# 1009      호남선2_5  n24   51  n25   54  e29r
# 1010      호남선2_5  n25   55  n28   57  e31r
# 1011      호남선2_6  n61   30  n53   35  e70r
# 1012      호남선2_6  n53   36  n48   38  e62r
# 1013      호남선2_6  n48   39  n44   41  e57r
# 1014      호남선2_6  n44   42  n37   45  e50r
# 1015      호남선2_6  n37   46  n32   49  e44r
# 1016      호남선2_6  n32   50  n30   52  e38r
# 1017      호남선2_6  n30   53  n24   56  e33r
# 1018      호남선2_6  n24   57  n25   60  e29r
# 1019      호남선2_6  n25   61  n28   63  e31r
# 1020   KTX강릉선1_1  n51    0  n34    4   e51
# 1021   KTX강릉선1_1  n34    5  n23    7   e36
# 1022   KTX강릉선1_1  n23    8  n22   10   e28
# 1023   KTX강릉선1_2  n51   18  n34   22   e51
# 1024   KTX강릉선1_2  n34   23  n23   25   e36
# 1025   KTX강릉선1_2  n23   26  n22   28   e28
# 1026   KTX강릉선2_1  n22    0  n23    2  e28r
# 1027   KTX강릉선2_1  n23    3  n34    5  e36r
# 1028   KTX강릉선2_1  n34    6  n51   10  e51r
# 1029   KTX강릉선2_2  n22   18  n23   20  e28r
# 1030   KTX강릉선2_2  n23   21  n34   23  e36r
# 1031   KTX강릉선2_2  n34   24  n51   28  e51r
# === Train status summary — horizon-aware (T-based) ===
#           Train  Departed  ArrivedInHorizon PlannedTerminal ActualTerminal  \
# 0     경부고속철도1_1      True              True             n79            n79
# 1     경부고속철도1_2      True              True             n79            n79
# 2     경부고속철도1_3      True              True             n79            n79
# 3     경부고속철도1_4      True              True             n79            n79
# 4     경부고속철도1_5      True              True             n79            n79
# 5     경부고속철도1_6      True              True             n79            n79
# 6     경부고속철도1_7      True              True             n79            n79
# 7     경부고속철도1_8      True              True             n79            n79
# 8     경부고속철도1_9      True              True             n79            n79
# 9    경부고속철도1_10      True              True             n79            n79
# 10   경부고속철도1_11      True              True             n79            n79
# 11   경부고속철도1_12      True              True             n79            n79
# 12    경부고속철도2_1      True              True              n4             n4
# 13    경부고속철도2_2      True              True              n4             n4
# 14    경부고속철도2_3      True             False              n4             n2
# 15    경부고속철도2_4      True             False              n4             n2
# 16    경부고속철도2_5      True              True              n4             n4
# 17    경부고속철도2_6      True              True              n4             n4
# 18    경부고속철도2_7      True              True              n4             n4
# 19    경부고속철도2_8      True              True              n4             n4
# 20    경부고속철도2_9      True              True              n4             n4
# 21   경부고속철도2_10      True              True              n4             n4
# 22   경부고속철도2_11      True              True              n4             n4
# 23       경부선1_1      True              True             n79            n79
# 24       경부선1_2      True              True             n79            n79
# 25       경부선1_3      True              True             n79            n79
# 26       경부선1_4      True              True             n79            n79
# 27       경부선1_5      True              True             n79            n79
# 28       경부선1_6      True              True             n79            n79
# 29       경부선2_1      True              True              n4             n4
# 30       경부선2_2      True              True              n4             n4
# 31       경부선2_3      True              True              n4             n4
# 32       경부선2_4      True              True              n4             n4
# 33       경부선2_5      True              True              n4             n4
# 34       경부선2_6      True              True              n4             n4
# 35       경북선1_1      True              True             n41            n41
# 36       경북선2_1      True              True             n43            n43
# 37       경전선1_1      True              True             n73            n73
# 38       경전선1_2      True              True             n73            n73
# 39       경전선2_1      True              True             n48            n48
# 40       경전선2_2      True              True             n48            n48
# 41       동해선1_1      True              True             n72            n72
# 42       동해선1_2      True              True             n72            n72
# 43       동해선2_1      True              True             n55            n55
# 44       동해선2_2      True              True             n55            n55
# 45       영동선1_1      True              True             n43            n43
# 46       영동선2_1      True              True             n51            n51
# 47       장항선1_1      True              True             n30            n30
# 48       장항선1_2      True              True             n30            n30
# 49       장항선1_3      True              True             n30            n30
# 50       장항선2_1      True              True             n14            n14
# 51       장항선2_2      True              True             n14            n14
# 52       장항선2_3      True              True             n14            n14
# 53       전라선1_1      True              True             n68            n68
# 54       전라선1_2      True              True             n68            n68
# 55       전라선1_3      True              True             n68            n68
# 56       전라선2_1      True              True             n30            n30
# 57       전라선2_2      True              True             n30            n30
# 58       전라선2_3      True              True             n30            n30
# 59       중앙선1_1      True              True             n79            n79
# 60       중앙선1_2      True              True             n79            n79
# 61       중앙선1_3      True              True             n79            n79
# 62       중앙선1_4      True              True             n79            n79
# 63       중앙선1_5      True              True             n79            n79
# 64       중앙선1_6      True              True             n79            n79
# 65       중앙선2_1      True              True              n3             n3
# 66       중앙선2_2      True              True              n3             n3
# 67       중앙선2_3      True              True              n3             n3
# 68       중앙선2_4      True              True              n3             n3
# 69       중앙선2_5      True              True              n3             n3
# 70       중앙선2_6      True              True              n3             n3
# 71       충북선1_1      True              True             n17            n17
# 72       충북선1_2      True              True             n17            n17
# 73       충북선1_3      True              True             n17            n17
# 74       충북선2_1      True              True             n29            n29
# 75       충북선2_2      True              True             n29            n29
# 76       충북선2_3      True              True             n29            n29
# 77    호남고속철도1_1      True              True             n48            n48
# 78    호남고속철도1_2      True              True             n48            n48
# 79    호남고속철도1_3      True              True             n48            n48
# 80    호남고속철도1_4      True              True             n48            n48
# 81    호남고속철도1_5      True              True             n48            n48
# 82    호남고속철도1_6      True              True             n48            n48
# 83    호남고속철도2_1      True              True              n3             n3
# 84    호남고속철도2_2      True              True              n3             n3
# 85    호남고속철도2_3      True              True              n3             n3
# 86    호남고속철도2_4      True             False              n3             n2
# 87    호남고속철도2_5      True             False              n3             n2
# 88    호남고속철도2_6      True             False              n3             n2
# 89       호남선1_1      True              True             n61            n61
# 90       호남선1_2      True              True             n61            n61
# 91       호남선1_3      True              True             n61            n61
# 92       호남선1_4      True              True             n61            n61
# 93       호남선1_5      True              True             n61            n61
# 94       호남선1_6      True              True             n61            n61
# 95       호남선2_1      True              True             n28            n28
# 96       호남선2_2      True              True             n28            n28
# 97       호남선2_3      True              True             n28            n28
# 98       호남선2_4      True              True             n28            n28
# 99       호남선2_5      True              True             n28            n28
# 100      호남선2_6      True              True             n28            n28
# 101   KTX강릉선1_1      True              True             n22            n22
# 102   KTX강릉선1_2      True              True             n22            n22
# 103   KTX강릉선2_1      True              True             n51            n51
# 104   KTX강릉선2_2      True              True             n51            n51
#
#      Delay(min)  HorizonDelay(min)  Truncated  Rerouted              Status
# 0           0.0                0.0      False     False  On-time & complete
# 1           0.0                0.0      False     False  On-time & complete
# 2           0.0                0.0      False     False  On-time & complete
# 3           0.0                0.0      False     False  On-time & complete
# 4           0.0                0.0      False     False  On-time & complete
# 5           0.0                0.0      False     False  On-time & complete
# 6           0.0                0.0      False     False  On-time & complete
# 7           0.0                0.0      False     False  On-time & complete
# 8           0.0                0.0      False     False  On-time & complete
# 9           0.0                0.0      False     False  On-time & complete
# 10          1.0                1.0      False     False             Delayed
# 11          0.0                0.0      False     False  On-time & complete
# 12          2.0                2.0      False      True            Rerouted
# 13          0.0                0.0      False     False  On-time & complete
# 14          NaN                NaN       True     False           Truncated
# 15          NaN                NaN       True     False           Truncated
# 16          4.0                4.0      False      True            Rerouted
# 17          5.0                5.0      False      True            Rerouted
# 18          4.0                4.0      False      True            Rerouted
# 19          4.0                4.0      False      True            Rerouted
# 20          4.0                4.0      False      True            Rerouted
# 21          4.0                4.0      False      True            Rerouted
# 22          4.0                4.0      False      True            Rerouted
# 23          0.0                0.0      False     False  On-time & complete
# 24          0.0                0.0      False     False  On-time & complete
# 25          0.0                0.0      False     False  On-time & complete
# 26          0.0                0.0      False     False  On-time & complete
# 27          0.0                0.0      False     False  On-time & complete
# 28          0.0                0.0      False     False  On-time & complete
# 29          0.0                0.0      False     False  On-time & complete
# 30          0.0                0.0      False     False  On-time & complete
# 31          0.0                0.0      False     False  On-time & complete
# 32          0.0                0.0      False     False  On-time & complete
# 33          0.0                0.0      False     False  On-time & complete
# 34          0.0                0.0      False     False  On-time & complete
# 35          0.0                0.0      False     False  On-time & complete
# 36          0.0                0.0      False     False  On-time & complete
# 37          0.0                0.0      False     False  On-time & complete
# 38          0.0                0.0      False     False  On-time & complete
# 39          0.0                0.0      False     False  On-time & complete
# 40          0.0                0.0      False     False  On-time & complete
# 41          0.0                0.0      False     False  On-time & complete
# 42          0.0                0.0      False     False  On-time & complete
# 43          0.0                0.0      False     False  On-time & complete
# 44          0.0                0.0      False     False  On-time & complete
# 45          0.0                0.0      False     False  On-time & complete
# 46          0.0                0.0      False     False  On-time & complete
# 47          0.0                0.0      False     False  On-time & complete
# 48          0.0                0.0      False     False  On-time & complete
# 49          0.0                0.0      False     False  On-time & complete
# 50          0.0                0.0      False     False  On-time & complete
# 51          0.0                0.0      False     False  On-time & complete
# 52          0.0                0.0      False     False  On-time & complete
# 53          0.0                0.0      False     False  On-time & complete
# 54          0.0                0.0      False     False  On-time & complete
# 55          0.0                0.0      False     False  On-time & complete
# 56          0.0                0.0      False     False  On-time & complete
# 57          0.0                0.0      False     False  On-time & complete
# 58          0.0                0.0      False     False  On-time & complete
# 59          0.0                0.0      False     False  On-time & complete
# 60          0.0                0.0      False     False  On-time & complete
# 61          0.0                0.0      False     False  On-time & complete
# 62          0.0                0.0      False     False  On-time & complete
# 63          0.0                0.0      False     False  On-time & complete
# 64          0.0                0.0      False     False  On-time & complete
# 65          0.0                0.0      False     False  On-time & complete
# 66          0.0                0.0      False     False  On-time & complete
# 67          0.0                0.0      False     False  On-time & complete
# 68          0.0                0.0      False     False  On-time & complete
# 69          0.0                0.0      False     False  On-time & complete
# 70          0.0                0.0      False     False  On-time & complete
# 71          0.0                0.0      False     False  On-time & complete
# 72          0.0                0.0      False     False  On-time & complete
# 73          0.0                0.0      False     False  On-time & complete
# 74          0.0                0.0      False     False  On-time & complete
# 75          0.0                0.0      False     False  On-time & complete
# 76          0.0                0.0      False     False  On-time & complete
# 77          0.0                0.0      False     False  On-time & complete
# 78          0.0                0.0      False     False  On-time & complete
# 79          0.0                0.0      False     False  On-time & complete
# 80          0.0                0.0      False     False  On-time & complete
# 81          0.0                0.0      False     False  On-time & complete
# 82          0.0                0.0      False     False  On-time & complete
# 83          0.0                0.0      False     False  On-time & complete
# 84          0.0                0.0      False     False  On-time & complete
# 85          0.0                0.0      False     False  On-time & complete
# 86          NaN                NaN       True     False           Truncated
# 87          NaN                NaN       True      True           Truncated
# 88          NaN                NaN       True      True           Truncated
# 89          0.0                0.0      False     False  On-time & complete
# 90          0.0                0.0      False     False  On-time & complete
# 91          0.0                0.0      False     False  On-time & complete
# 92          0.0                0.0      False     False  On-time & complete
# 93          0.0                0.0      False     False  On-time & complete
# 94          0.0                0.0      False     False  On-time & complete
# 95          0.0                0.0      False     False  On-time & complete
# 96          0.0                0.0      False     False  On-time & complete
# 97          0.0                0.0      False     False  On-time & complete
# 98          0.0                0.0      False     False  On-time & complete
# 99          0.0                0.0      False     False  On-time & complete
# 100         0.0                0.0      False     False  On-time & complete
# 101         0.0                0.0      False     False  On-time & complete
# 102         0.0                0.0      False     False  On-time & complete
# 103         0.0                0.0      False     False  On-time & complete
# 104         0.0                0.0      False     False  On-time & complete

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import numpy as np
from collections import Counter

def merge_orders(base_order, new_order):
    res = list(base_order)
    for i, node in enumerate(new_order):
        if node in res:
            continue
        prev_node = new_order[i-1] if i > 0 else None
        next_node = new_order[i+1] if i+1 < len(new_order) else None
        if prev_node in res:
            res.insert(res.index(prev_node) + 1, node)
        elif next_node in res:
            res.insert(res.index(next_node), node)
        else:
            res.append(node)
    return res

def build_canonical_station_order(route_ids, routes_nodes):
    order = []
    for rid in route_ids:
        if rid is None:
            continue
        seq = routes_nodes.get(rid, None)
        if not seq:
            continue
        order = merge_orders(order, seq)
    return order

SINK = "SINK"

def sched_arr(tr, node, default=None):
    e = sched.get(tr, {}).get(node)
    if isinstance(e, dict) and ("arr" in e):
        return e["arr"]
    return default

def sched_dep(tr, node, default=None):
    e = sched.get(tr, {}).get(node)
    if isinstance(e, dict) and ("dep" in e):
        return e["dep"]
    return default

def plot_train_paths(train_list, ax, title, h_get, 
                     routes_nodes, sched, station_map, xmax,
                     color=None, label=None,
                     failed_edges=None, edges=None,
                     incident_x0=None, incident_x1=None,
                     show_incident_line=True, show_incident_legend=True):
    if title is not None:
        ax.set_title(title)
    ax.set_xlabel("Timestep")
    ax.set_ylabel("Station")

    order = list(station_map.keys())
    yticks = [station_map[n] for n in order]
    ax.set_yticks(yticks)
    ax.set_yticklabels(order)

    if failed_edges and edges and incident_x0 is not None and incident_x1 is not None:
        drawn_pairs = set()
        for eid in failed_edges:
            if eid not in edges:
                continue
            u, v, _ = edges[eid]
            if (u not in station_map) or (v not in station_map):
                continue
            y0 = station_map[u]; y1 = station_map[v]
            yb, yt = (y0, y1) if y0 <= y1 else (y1, y0)
            key = (min(y0, y1), max(y0, y1))
            if key in drawn_pairs:
                continue
            drawn_pairs.add(key)

            rect = mpatches.Rectangle((incident_x0, yb),   
                                      incident_x1 - incident_x0,  
                                      yt - yb,                  
                                      facecolor=(0.6,0.6,0.6,0.15),  
                                      hatch='////',
                                      edgecolor='lightgray',
                                      linewidth=0,
                                      zorder=0.5)
            ax.add_patch(rect)

        if show_incident_line:
            ax.axvline(incident_x0, color='k', linestyle='--', alpha=0.3, zorder=0.6)

        if show_incident_legend and drawn_pairs:
            patch = mpatches.Patch(facecolor=(0.6,0.6,0.6,0.15), hatch='////',
                                   edgecolor='lightgray', label='Incident block')
            handles, labels = ax.get_legend_handles_labels()
            if 'Incident block' not in labels:
                handles.append(patch)
                labels.append('Incident block')
                ax.legend(handles=handles, labels=labels)

    if color is None:
        cmap = plt.cm.get_cmap('tab10', max(1, len(train_list)))
        color_iter = (cmap(i % cmap.N) for i in range(len(train_list)))
    else:
        color_iter = (color for _ in range(len(train_list)))

    for tr, tr_color in zip(train_list, color_iter):
        if h_get(tr) < 0.5 and len(sol_legs[tr]) == 0:
            continue

        # planned path (dashed line)
        planned_path = routes_nodes[tr]
        p_nodes = [n for n in planned_path if n in station_map]
        plan_pts = []
        for n in p_nodes:
            t_arr = sched_arr(tr, n, None)
            t_dep = sched_dep(tr, n, None)
            y     = station_map[n]
            if t_arr is not None:
                plan_pts.append((t_arr, y))
            if (t_dep is not None) and (t_arr is not None) and (t_dep < t_arr):
                t_dep = t_arr
            if (t_dep is not None) and (t_dep != t_arr):
                plan_pts.append((t_dep, y))
        plan_pts = sorted(plan_pts, key=lambda xy: xy[0])
        if len(plan_pts) >= 2:
            p_times, p_ys = zip(*plan_pts)
            ax.plot(list(p_times), list(p_ys), linestyle='--', color='gray', alpha=0.7)

        # actual path (solid line)
        actual_legs = sorted(sol_legs[tr], key=lambda x: x[0])
        if not actual_legs:
            continue
        t0, u, v, t1, _ = actual_legs[0]
        if u in station_map and v in station_map:
            ax.plot([t0, t1], [station_map[u], station_map[v]], 
                    color=tr_color, linewidth=2, label=label)
            label = None
        for i in range(1, len(actual_legs)):
            p_t0, p_u, p_v, p_t1, _ = actual_legs[i-1]
            c_t0, c_u, c_v, c_t1, _ = actual_legs[i]
            # 대기(정차) — 열차 색으로 실선 연결
            if c_t0 > p_t1 and p_v == c_u and p_v in station_map:
                ax.plot([p_t1, c_t0], [station_map[p_v], station_map[c_u]],
                        color=tr_color, linewidth=2)  # linestyle 생략 = 실선
            if c_u in station_map and c_v in station_map:
                ax.plot([c_t0, c_t1], [station_map[c_u], station_map[c_v]], 
                        color=tr_color, linewidth=2)

    ax.grid(True, linestyle='--', alpha=0.6)
    ax.set_xlim(0, xmax)
    ax.set_ylim(1, len(station_map))


gbrt_trains = [tr for tr in trains if str(tr).startswith('경부고속철도1')]
gbs_trains  = [tr for tr in trains if str(tr).startswith('경부선1')]
gbrt2_trains = [tr for tr in trains if str(tr).startswith('경부고속철도2')]
gbs2_trains  = [tr for tr in trains if str(tr).startswith('경부선2')]
gbh_trains  = [tr for tr in trains if str(tr).startswith('호남선1')]
gbh2_trains  = [tr for tr in trains if str(tr).startswith('호남선2')]
gbhrt_trains  = [tr for tr in trains if str(tr).startswith('호남고속철도1')]
gbhrt2_trains  = [tr for tr in trains if str(tr).startswith('호남고속철도2')]

def pick_representative(tr_list):
    return max(tr_list, key=lambda tr: len(routes_nodes[tr])) if tr_list else None

merge_route_ids = []
if '경부고속철도1_1' in routes_nodes:
    merge_route_ids.append('경부고속철도1_1')
elif gbrt_trains:
    merge_route_ids.append(pick_representative(gbrt_trains))

if '경부선1_1' in routes_nodes:
    merge_route_ids.append('경부선1_1')
elif gbs_trains:
    merge_route_ids.append(pick_representative(gbs_trains))

if '경부고속철도2_1' in routes_nodes:
    merge_route_ids.append('경부고속철도2_1')
elif gbrt_trains:
    merge_route_ids.append(pick_representative(gbrt_trains))

if '경부선2_1' in routes_nodes:
    merge_route_ids.append('경부선2_1')
elif gbs_trains:
    merge_route_ids.append(pick_representative(gbs_trains))

if '호남고속철도1_1' in routes_nodes:
    merge_route_ids.append('호남고속철도1_1')
elif gbh_trains:
    merge_route_ids.append(pick_representative(gbh_trains))

if '호남고속철도2_1' in routes_nodes:
    merge_route_ids.append('호남고속철도2_1')
elif gbh_trains:
    merge_route_ids.append(pick_representative(gbh_trains))

if '호남선1_1' in routes_nodes:
    merge_route_ids.append('호남선1_1')
elif gbh_trains:
    merge_route_ids.append(pick_representative(gbh_trains))

if '호남선2_1' in routes_nodes:
    merge_route_ids.append('호남선2_1')
elif gbh_trains:
    merge_route_ids.append(pick_representative(gbh_trains))


if not merge_route_ids:
    merge_route_ids = [pick_representative(trains)]

canonical_order = build_canonical_station_order(merge_route_ids, routes_nodes)
if not canonical_order:
    from collections import Counter
    cnt = Counter(n for seq in routes_nodes.values() for n in seq if n != SINK)
    canonical_order = [n for n, _ in cnt.most_common()]
station_map = {name: i+1 for i, name in enumerate(canonical_order)}

def h_get(tr):
    return float(h_final.get(tr, 1.0))

# --- fig.1 ---
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(18, 8), sharey=True)

# High-Speed subplot
#plot_train_paths(
#    gbrt_trains, ax1, "Gyeongbu High-Speed Rail",
#    h_get, routes_nodes, sched, station_map, xmax=96,
#    failed_edges=failed_edges, edges=edges,
#    incident_x0=FAIL_T, incident_x1=T_clear
#)
#plot_train_paths(
#    gbrt2_trains, ax1, None,   # 제목은 한 번만
#    h_get, routes_nodes, sched, station_map, xmax=96,
#    failed_edges=failed_edges, edges=edges,
#    incident_x0=FAIL_T, incident_x1=T_clear
#)

# Conventional subplot
plot_train_paths(
    gbs_trains, ax1, "Gyeongbu Rail",
    h_get, routes_nodes, sched, station_map, xmax=96,
    failed_edges=failed_edges, edges=edges,
    incident_x0=FAIL_T, incident_x1=T_clear
)
plot_train_paths(
    gbs2_trains, ax1, None,
    h_get, routes_nodes, sched, station_map, xmax=96,
    failed_edges=failed_edges, edges=edges,
    incident_x0=FAIL_T, incident_x1=T_clear
)

plot_train_paths(
    gbh_trains, ax2, "Honam Rail",
    h_get, routes_nodes, sched, station_map, xmax=96,
    failed_edges=failed_edges, edges=edges,
    incident_x0=FAIL_T, incident_x1=T_clear
)

#plot_train_paths(
#    gbh2_trains, ax2, None,
#    h_get, routes_nodes, sched, station_map, xmax=96,
#    failed_edges=failed_edges, edges=edges,
#    incident_x0=FAIL_T, incident_x1=T_clear
#)

fig.tight_layout()

# --- fig.2 (합쳐 그리기) ---
fig2, ax = plt.subplots(figsize=(10, 8))

# High-Speed (검정) — 라벨은 한 번만
plot_train_paths(
    gbs_trains, ax, None,
    h_get, routes_nodes, sched, station_map, xmax=96,
    color="red", label="Gyeongbu Rail",
    failed_edges=failed_edges, edges=edges,
    incident_x0=FAIL_T, incident_x1=T_clear
)
plot_train_paths(
    gbs2_trains, ax, None,
    h_get, routes_nodes, sched, station_map, xmax=96,
    color="red", label=None,
    failed_edges=failed_edges, edges=edges,
    incident_x0=FAIL_T, incident_x1=T_clear
)

# Conventional (빨강) — 라벨은 한 번만
plot_train_paths(
    gbrt_trains, ax, None,
    h_get, routes_nodes, sched, station_map, xmax=96,
    color="black", label="Gyeongbu High-Speed Rail",
    failed_edges=failed_edges, edges=edges,
    incident_x0=FAIL_T, incident_x1=T_clear
)
plot_train_paths(
    gbrt2_trains, ax, None,
    h_get, routes_nodes, sched, station_map, xmax=96,
    color="black", label=None,
    failed_edges=failed_edges, edges=edges,
    incident_x0=FAIL_T, incident_x1=T_clear
)

# Conventional (파랑) — 라벨은 한 번만
plot_train_paths(
    gbh_trains, ax, None,
    h_get, routes_nodes, sched, station_map, xmax=96,
    color="blue", label="Honam Rail",
    failed_edges=failed_edges, edges=edges,
    incident_x0=FAIL_T, incident_x1=T_clear
)
plot_train_paths(
    gbh2_trains, ax, None,
    h_get, routes_nodes, sched, station_map, xmax=96,
    color="blue", label=None,
    failed_edges=failed_edges, edges=edges,
    incident_x0=FAIL_T, incident_x1=T_clear
)

# Conventional (파랑) — 라벨은 한 번만
plot_train_paths(
    gbhrt_trains, ax, None,
    h_get, routes_nodes, sched, station_map, xmax=96,
    color="green", label="Honam High-Speed Rail",
    failed_edges=failed_edges, edges=edges,
    incident_x0=FAIL_T, incident_x1=T_clear
)
plot_train_paths(
    gbhrt2_trains, ax, None,
    h_get, routes_nodes, sched, station_map, xmax=96,
    color="green", label=None,
    failed_edges=failed_edges, edges=edges,
    incident_x0=FAIL_T, incident_x1=T_clear
)


ax.legend()
fig2.tight_layout()
plt.show()
# Out:
# C:\Users\Minji Kang\AppData\Local\Temp\ipykernel_39788\2635328924.py:100: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = plt.cm.get_cmap('tab10', max(1, len(train_list)))
# C:\Users\Minji Kang\AppData\Local\Temp\ipykernel_39788\2635328924.py:100: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = plt.cm.get_cmap('tab10', max(1, len(train_list)))
# C:\Users\Minji Kang\AppData\Local\Temp\ipykernel_39788\2635328924.py:100: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = plt.cm.get_cmap('tab10', max(1, len(train_list)))

# %%
import os
import matplotlib.pyplot as plt

# 1) 저장 경로 설정 및 폴더 생성
out_dir = r"D:\MINJI\NETWORK RELIABILITY\KRRI"
os.makedirs(out_dir, exist_ok=True)
out_fp = os.path.join(out_dir, "SOS2.pdf")

# 2) 기존 코드
x = [0, 15, 30, 60, 120]
y = [0, 0.25, 0.5, 0.75, 1]

plt.figure(figsize=(8, 5))
plt.plot(x, y, color='brown', marker='o', label='passenger-facing compensation', linewidth=3)
plt.xlabel(r'Delay time $\Delta$', fontsize=18)
plt.ylabel(r'Refund ratio $\Gamma$', fontsize=18)
plt.legend(fontsize=18)
plt.grid(True, linestyle='--', alpha=0.6)
plt.ylim(0, 1.1)
plt.xlim(0, 130)
plt.tight_layout()

# 3) PDF 저장
plt.savefig(out_fp, format="pdf", bbox_inches="tight")
plt.close()
print(f"Saved to: {out_fp}")
# Out:
# Saved to: D:\MINJI\NETWORK RELIABILITY\KRRI\SOS2.pdf
